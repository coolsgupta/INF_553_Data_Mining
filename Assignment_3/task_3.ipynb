# %%
import findspark
import json
import itertools
import sys
import time
import random

findspark.init()
from pyspark import SparkConf, SparkContext

# %%
import math

# %%
def build_min_hash_func(a, b, p, m):
    def min_hash_func(x):
        return (((a * x + b) % p) % m)

    return min_hash_func

# %%
def get_min_hash_functions(num_func, buckets):
    list_a = random.sample(range(50331653, 92233720), num_func)
    list_b = random.sample(range(25165843, 92233720), num_func)
    p = 12582917
    min_hash_func_list = [build_min_hash_func(a, b, p, buckets) for a, b in zip(list_a, list_b)]

    return min_hash_func_list

# %%
def check_jaccard_similarity(candidate, business_user_tokens):
    business_set_1 = set(business_user_tokens.get(candidate[0], []))
    business_set_2 = set(business_user_tokens.get(candidate[1], []))
    pair_jac_sim = 0
    if business_set_1 and business_set_2:
        pair_jac_sim = len(business_set_1.intersection(business_set_2)) / len(business_set_1.union(business_set_2))
    return tuple([candidate, pair_jac_sim])

# %%
def write_results(results, file_path):
    with open(file_path, 'w') as file:
        for line in results:
            file.write(json.dumps(line) + '\n')
    file.close()

# %%
def computeSimilarity(dict1, dict2):
    """
    compute Pearson Correlation Similarity
    :param dict1:
    :param dict2:
    :return: a float number
    """
    co_rated_user = list(set(dict1.keys()) & (set(dict2.keys())))
    val1_list, val2_list = list(), list()
    [(val1_list.append(dict1[user_id]),
      val2_list.append(dict2[user_id])) for user_id in co_rated_user]

    avg1 = sum(val1_list) / len(val1_list)
    avg2 = sum(val2_list) / len(val2_list)

    numerator = sum(map(lambda pair: (pair[0] - avg1) * (pair[1] - avg2), zip(val1_list, val2_list)))

    if numerator == 0:
        return 0
    denominator = math.sqrt(sum(map(lambda val: (val - avg1) ** 2, val1_list))) * \
                  math.sqrt(sum(map(lambda val: (val - avg2) ** 2, val2_list)))
    if denominator == 0:
        return 0

    return numerator / denominator

# %% [markdown]
# # Main

# %%
conf = SparkConf()
conf.set("spark.driver.memory", "4g")
conf.set("spark.executor.memory", "4g")
conf.setMaster('local[8]')
conf.setAppName('Assignment_3')
sc = SparkContext.getOrCreate(conf)

# %%
reviews_json = sc.textFile("asnlib/publicdata/train_review.json").map(json.loads)

# %%
reviews_json.first()

# %%
user_business_rating_sets = reviews_json.map(lambda x: (x.get('user_id'), x.get('business_id'), x.get('stars'))).distinct()

# %%
# create user tokens
user_tokens_dict = user_business_rating_sets\
    .map(lambda x: x[0])\
    .distinct()\
    .sortBy(lambda x: x)\
    .zipWithIndex()\
    .collectAsMap()

inverse_user_tokens_dict = {bid: token for token, bid in user_tokens_dict.items()}

# %%
# create business tokens
business_tokens = user_business_rating_sets\
    .map(lambda x: x[1])\
    .distinct()\
    .sortBy(lambda x: x)\
    .zipWithIndex()\
    
business_tokens_dict = business_tokens.collectAsMap()

inverse_business_tokens_dict = {bid: token for token, bid in business_tokens_dict.items()}

# %%
min_hash_func_list = get_min_hash_functions(30, len(user_tokens_dict) * 2)

# %%
# get user business tokenized maps
user_business_rating_tokenized_sets = user_business_rating_sets\
    .map(lambda x: (user_tokens_dict.get(x[0]), business_tokens_dict.get(x[1]), x[2]))

# %%
business_user_tokenized_pairs = user_business_rating_tokenized_sets.map(lambda x: (x[1], x[0]))

# %%
# create business user list
business_user_tokenized_map = business_user_tokenized_pairs.groupByKey().mapValues(lambda x: list(set(x))).filter(lambda x: len(x[1])>=3)

# %%
business_user_tokenized_map.count()

# %%
user_business_tokenized_dict = business_user_tokenized_map.flatMap(lambda x: [(user, x[0]) for user in x[1]]).groupByKey().mapValues(lambda x: list(set(x))).collectAsMap()

# %%
business_hashed_values = business_tokens.map(lambda x: (x[1], [min_hash(x[1]) for min_hash in min_hash_func_list]))

# %%
signature_matrix_rdd = business_user_tokenized_map\
    .leftOuterJoin(business_hashed_values)\
    .map(lambda x: x[1])\
    .flatMap(lambda user_set: [(x, user_set[1]) for x in user_set[0]])\
    .reduceByKey(lambda a, b: [min(x, y) for x, y in zip(a, b)])

# %%
signature_matrix_rdd.first()

# %%
candidate_pairs = signature_matrix_rdd \
    .flatMap(lambda x: [(tuple([i, tuple(x[1][i:i + 1])]), x[0]) for i in range(0, 30)]) \
    .groupByKey()\
    .map(lambda x: list(x[1]))\
    .filter(lambda val: len(val) > 1) \
    .flatMap(lambda uid_list: [pair for pair in itertools.combinations(uid_list, 2)])

# %%
candidate_pairs.count()

# %%
jaccard_similar_users = candidate_pairs\
        .distinct()\
        .map(lambda x: check_jaccard_similarity(x, user_business_tokenized_dict))\
        .filter(lambda x: x[1] >= 0.01)\
#         .map(lambda x: {"b1": inverse_business_tokens_dict[x[0][0]], "b2": inverse_business_tokens_dict[x[0][1]], "sim": x[1]})\
#         .collect()

# %%
jaccard_similar_users.first()

# %%
jaccard_similar_users.count()

# %%
user_business_rating_map = user_business_rating_tokenized_sets.map(lambda x: (x[0], (x[1], x[2]))).groupByKey().mapValues(lambda x: {business_rating_pair[0]: business_rating_pair[1] for business_rating_pair in list(x)}).collectAsMap()

# %%
user_business_rating_map

# %%
pearson_similar_pairs = jaccard_similar_users.map(lambda id_pair: (id_pair[0], computeSimilarity(user_business_rating_map[id_pair[0][0]], user_business_rating_map[id_pair[0][1]]))).filter(lambda kv: kv[1] > 0)

# %%
pearson_similar_pairs.count()

# %%
pearson_similar_pairs.take(100)

# %%
pearson_similar_results_untokenized = pearson_similar_pairs.map(lambda kv: {"u1": inverse_user_tokens_dict[kv[0][0]], "u2": inverse_user_tokens_dict[kv[0][1]], "sim": kv[1]})

# %%
pearson_similar_results_untokenized.first()

# %% [markdown]
# # Predict

# %%
import findspark
import json
import itertools
import sys
import time
import random
import math

findspark.init()
from pyspark import SparkConf, SparkContext

# %%
def write_results(results, file_path):
    with open(file_path, 'w') as file:
        for line in results:
            file.write(json.dumps(line) + '\n')
    file.close()

# %%
start_time = time.time()
conf = SparkConf()
conf.set("spark.driver.memory", "4g")
conf.set("spark.executor.memory", "4g")
conf.setMaster('local[8]')
conf.setAppName('Assignment_3')
sc = SparkContext.getOrCreate(conf)
sc.setLogLevel("ERROR")

cf_model = 'item_based'

# load data
train_reviews_json = sc.textFile('asnlib/publicdata/train_review.json').map(json.loads)
# test_reviews_json = sc.textFile('asnlib/publicdata/test_review_ratings.json').map(json.loads)

# create user business rating sets
train_user_business_rating_sets = train_reviews_json \
    .map(lambda x: (x.get('user_id'), x.get('business_id'), x.get('stars'))).distinct()

# create user tokens
user_tokens = train_user_business_rating_sets \
    .map(lambda x: x[0]) \
    .distinct() \
    .sortBy(lambda x: x) \
    .zipWithIndex()

user_tokens_dict = user_tokens.collectAsMap()

inverse_user_tokens_dict = {bid: token for token, bid in user_tokens_dict.items()}

# create business tokens
candidate_business_tokens = train_user_business_rating_sets \
    .map(lambda x: x[1]) \
    .distinct() \
    .sortBy(lambda x: x) \
    .zipWithIndex()

business_tokens_dict = candidate_business_tokens.collectAsMap()

inverse_business_tokens_dict = {bid: token for token, bid in business_tokens_dict.items()}

# tokenize trains sets
train_user_business_rating_sets_tokenized = train_user_business_rating_sets\
    .map(lambda x: (user_tokens_dict[x[0]], business_tokens_dict[x[1]], x[2]))

# load test set
# test_user_business_pairs_tokenized = test_reviews_json\
#     .map(lambda x: (user_tokens_dict.get(x['user_id', None], business_tokens_dict.get['business_id', None])))\
#     .filter(lambda x: x[0] is not None and x[1] is not None)

# %%
test_reviews_json = sc.textFile('asnlib/publicdata/test_review_ratings.json').map(json.loads)

# %%
test_reviews_json.first()['user_id']

# %%
test_user_business_pairs_tokenized = test_reviews_json\
    .map(lambda x: (user_tokens_dict.get(x['user_id'], None), business_tokens_dict.get(x['business_id'], None)))\
    .filter(lambda x: x[0] is not None and x[1] is not None)

# %%
test_user_business_pairs_tokenized.first()

# %%
# load model from memory
model = sc.textFile('task3item.model')\
    .map(json.loads)

# %%
# get model keys
keys = list(model.first().keys())

# %%
# collect final model as similarity pairs
model = model\
    .map(lambda x: ((x[keys[0]], x[keys[1]]), x[keys[2]]))\
    .collectAsMap()

# %%
business_user_rating_sets = train_user_business_rating_sets_tokenized\
        .map(lambda x: (x[1], (x[0], x[2])))\
        .groupByKey()\
        .map(lambda x: (x[0], [(user_rating[0], user_rating[1]) for user_rating in list(x[1])]))

user_average_ratings = sc.textFile('asnlib/publicdata/user_avg.json')\
        .map(json.loads)\
        .collect()[0]

test_business_user_pairs_tokenized = test_user_business_pairs_tokenized\
        .map(lambda x: (x[1], x[0]))

# %%
user_average_ratings['dcpE4CUvtqLf63tRJgNqKQ']

# %%
# users and list of rated businesses with respective ratings
user_business_rating_sets = train_user_business_rating_sets_tokenized\
    .map(lambda x: (x[0], (x[1], x[2])))\
    .groupByKey()\
    .map(lambda x: (x[0], [(business_rating[0], business_rating[1]) for business_rating in list(x[1])]))

# dictionary of average ratings for each business from the given file
business_average_ratings = sc.textFile('asnlib/publicdata/business_avg.json')\
    .map(json.loads)\
    .collect()[0]

# %%
user_business_rating_sets.first()

# %%
test_business_user_pairs_tokenized.first()

# %%
test_data_join_train_data = test_user_business_pairs_tokenized.leftOuterJoin(user_business_rating_sets)

# %%
test_data_join_train_data.first()

# %%
def item_based_model_predict(bid_user_ratings, n, item_model, business_average_ratings_dict, inverse_tokens_dict):
    candidate_id = bid_user_ratings[0]
    rating_similarity_pairs = sorted(
        [
            tuple([business_rating_pair[1], item_model.get(tuple(sorted([candidate_id, business_rating_pair[0]])), 0)])
            for business_rating_pair in list(bid_user_ratings[1])
        ],
        key=lambda x: x[1]
    )
    
    n_similar_businesses = rating_similarity_pairs[:n]
    
    try:
        return tuple(
            (
                candidate_id, 
                sum(map(lambda item: item[0] * item[1], n_similar_businesses)) / sum(map(lambda item: abs(item[1]), n_similar_businesses))
            )
        )
    
    except:
        return tuple((candidate_id, business_average_ratings_dict.get(inverse_tokens_dict.get(candidate_id), 3)))

# %%
results = test_data_join_train_data.mapValues(lambda x: item_based_model_predict(x, 3, model, business_average_ratings, inverse_business_tokens_dict))

# %%
results.collect()

# %%
def user_based_model_predict(uid_business_ratings, user_model, user_average_ratings_dict, inverse_tokens_dict):
    candidate_id = uid_business_ratings[0]
    rating_similarity_sets = sorted(
        [
            tuple([
                user_rating_pair[1],
                user_average_ratings_dict.get(inverse_tokens_dict.get(user_rating_pair[0], ''), 3),
                user_model.get(tuple(sorted([candidate_id, user_rating_pair[0]])), 0)
            ])
            for user_rating_pair in list(uid_business_ratings[1])
        ],
        key=lambda x: x[1]
    )

    try:
        return tuple(
            (
                candidate_id,
                user_average_ratings_dict.get(candidate_id, 3) +
                sum(map(lambda x: (x[0] - x[1]) * x[2], rating_similarity_sets)) /
                sum(map(lambda item: abs(item[2]), rating_similarity_sets))
            )
        )

    except:
        return tuple((candidate_id, user_average_ratings_dict.get(inverse_tokens_dict.get(candidate_id), 3)))

# %% [markdown]
# # pycharm code

# %%
import findspark
import json
import sys
import time

findspark.init()
from pyspark import SparkConf, SparkContext


def write_results(results, file_path):
    with open(file_path, 'w') as file:
        for line in results:
            file.write(json.dumps(line) + '\n')
    file.close()

# %%
def item_based_model_predict(bid_user_ratings, n, item_model, business_average_ratings_dict, inverse_tokens_dict):
    candidate_id = bid_user_ratings[0]
    rating_similarity_pairs = sorted(
        [
            tuple([
                business_rating_pair[1],
                item_model.get(tuple(sorted([candidate_id, business_rating_pair[0]])), 0)
            ])
            for business_rating_pair in list(bid_user_ratings[1])
        ],
        key=lambda x: x[1]
    )

    n_similar_businesses = rating_similarity_pairs[:n]

    try:
        return tuple(
            [
                candidate_id,
                sum(map(lambda x: x[0] * x[1], n_similar_businesses)) / sum(
                    map(lambda x: abs(x[1]), n_similar_businesses))
            ]
        )

    except:
        return tuple([candidate_id, business_average_ratings_dict.get(inverse_tokens_dict.get(candidate_id), 3)])

# %%
def user_based_model_predict(uid_business_ratings, user_model, user_average_ratings_dict, inverse_tokens_dict):
    candidate_id = uid_business_ratings[0]
    rating_similarity_sets = [
        tuple([
            user_rating_pair[1],
            user_average_ratings_dict.get(inverse_tokens_dict.get(user_rating_pair[0], ''), 3),
            user_model.get(tuple(sorted([candidate_id, user_rating_pair[0]])), 0)
        ])
        for user_rating_pair in list(uid_business_ratings[1])
    ]


    try:
        return tuple(
            [
                candidate_id,
                user_average_ratings_dict.get(candidate_id, 3) +
                sum(map(lambda x: (x[0] - x[1]) * x[2], rating_similarity_sets)) /
                sum(map(lambda item: abs(item[2]), rating_similarity_sets))
            ]
        )

    except:
        return tuple([candidate_id, user_average_ratings_dict.get(inverse_tokens_dict.get(candidate_id), 3)])

# %%
# argv = sys.argv

start_time = time.time()
conf = SparkConf()
conf.set("spark.driver.memory", "4g")
conf.set("spark.executor.memory", "4g")
conf.setMaster('local[8]')
conf.setAppName('Assignment_3')
sc = SparkContext.getOrCreate(conf)
sc.setLogLevel("ERROR")

# load data
train_reviews_json = sc.textFile('asnlib/publicdata/train_review.json').map(json.loads)
test_reviews_json = sc.textFile('asnlib/publicdata/test_review_ratings.json').map(json.loads)



# create user business rating sets
train_user_business_rating_sets = train_reviews_json \
    .map(lambda x: (x.get('user_id'), x.get('business_id'), x.get('stars'))).distinct()

# create user tokens
user_tokens = train_user_business_rating_sets \
    .map(lambda x: x[0]) \
    .distinct() \
    .sortBy(lambda x: x) \
    .zipWithIndex()

user_tokens_dict = user_tokens.collectAsMap()

inverse_user_tokens_dict = {bid: token for token, bid in user_tokens_dict.items()}

# create business tokens
candidate_business_tokens = train_user_business_rating_sets \
    .map(lambda x: x[1]) \
    .distinct() \
    .sortBy(lambda x: x) \
    .zipWithIndex()

business_tokens_dict = candidate_business_tokens.collectAsMap()

inverse_business_tokens_dict = {bid: token for token, bid in business_tokens_dict.items()}

# tokenize trains sets
train_user_business_rating_sets_tokenized = train_user_business_rating_sets \
    .map(lambda x: (user_tokens_dict[x[0]], business_tokens_dict[x[1]], x[2]))

# load test set
test_user_business_pairs_tokenized = test_reviews_json \
    .map(lambda x: (user_tokens_dict.get(x['user_id'], None), business_tokens_dict.get(x['business_id'], None))) \
    .filter(lambda x: x[0] is not None and x[1] is not None)

# load model from memory
model = sc.textFile('task3item.model') \
    .map(json.loads)

# get model keys
keys = list(model.first().keys())

# collect final model as similarity pairs
model = model \
    .map(lambda x: ((x[keys[0]], x[keys[1]]), x[keys[2]])) \
    .collectAsMap()

# %%
test_user_business_pairs_tokenized.first()
# Out:
# (20625, 1716)

# %% [markdown]
# # item based

# %%
model.items()

# %%
# users and list of rated businesses with respective ratings
user_business_rating_sets = train_user_business_rating_sets_tokenized \
    .map(lambda x: (x[0], (x[1], x[2]))) \
    .groupByKey() \
    .map(lambda x: (x[0], [(business_rating[0], business_rating[1]) for business_rating in list(x[1])]))

# %%
user_business_rating_sets_dict = user_business_rating_sets.collectAsMap()

# %%
len(user_business_rating_sets_dict[23792])
# Out:
# 29

# %%
# dictionary of average ratings for each business from the given file
business_average_ratings = sc.textFile('asnlib/publicdata/business_avg.json')\
    .map(json.loads)\
    .map(lambda x: dict(x))\
    .flatMap(lambda x: x.items()) \
    .collectAsMap()
over_all_avg = sum(business_average_ratings.values())/len(business_average_ratings)
# business_average_ratings = business_average_ratings[0]

# %%
over_all_avg
# Out:
# 3.809428219215185

# %%
len(business_average_ratings)
# Out:
# 10254

# %%
test_user_business_pairs_tokenized.count()
# Out:
# 58473

# %%
results = test_user_business_pairs_tokenized\
    .leftOuterJoin(user_business_rating_sets) \

# %%
results.first()
# Out:
# (19008,
#  (146,
#   [(6858, 4.0),
#    (8754, 4.0),
#    (6797, 5.0),
#    (9631, 3.0),
#    (6334, 5.0),
#    (1655, 3.0),
#    (5348, 4.0),
#    (9900, 4.0),
#    (1926, 4.0),
#    (2029, 4.0),
#    (3440, 5.0),
#    (1984, 4.0),
#    (1207, 4.0),
#    (6673, 4.0),
#    (8983, 3.0),
#    (8963, 3.0),
#    (182, 3.0),
#    (6698, 3.0),
#    (4843, 4.0),
#    (1878, 4.0),
#    (3092, 5.0),
#    (9854, 5.0),
#    (9446, 4.0),
#    (758, 4.0),
#    (7085, 5.0),
#    (8297, 4.0),
#    (1040, 4.0),
#    (899, 4.0),
#    (7984, 4.0),
#    (3401, 4.0),
#    (6976, 5.0),
#    (4711, 4.0)]))

# %%
results = results.mapValues(
    lambda x: item_based_model_predict(x, 3, model, business_average_ratings, inverse_business_tokens_dict)) \

# %%
results.first()
# Out:
# (19008, (146, 3.2966101694915255))

# %%
results.map(lambda x:
         {
             "user_id": inverse_user_tokens_dict[x[0]],
             "business_id": inverse_business_tokens_dict[x[1][0]],
             "stars": x[1][1]
         }
         ) \
    .collect()
# Out:
# [{'user_id': 'iCqpb2C3TZrB5gdMASf8LQ',
#   'business_id': '-wuqvqzPR0pHkxCT3SMtIA',
#   'stars': 3.2966101694915255},
#  {'user_id': 'iCqpb2C3TZrB5gdMASf8LQ',
#   'business_id': '2HIhAc5SWb9GUOru_Vc5zQ',
#   'stars': 3.4},
#  {'user_id': 'iCqpb2C3TZrB5gdMASf8LQ',
#   'business_id': 'ECOkEVUodMLUxvI0PMI4gQ',
#   'stars': 3.296577946768061},
#  {'user_id': 'OD6wbZ1jQOW30wYCDD6X3Q',
#   'business_id': 'rcaPajgKOJC2vo_l3xa42A',
#   'stars': 4.030769230769231},
#  {'user_id': 'OD6wbZ1jQOW30wYCDD6X3Q',
#   'business_id': 'YuiM5VKscO8rS1EX7f19_g',
#   'stars': 3.7457627118644066},
#  {'user_id': 'OD6wbZ1jQOW30wYCDD6X3Q',
#   'business_id': 'O3OH5IEFMPtz7mPKakPZ3Q',
#   'stars': 4.27536231884058},
#  {'user_id': 'OD6wbZ1jQOW30wYCDD6X3Q',
#   'business_id': 'ZwNfUuh88cvjqiNtIxxHHg',
#   'stars': 3.814814814814815},
#  {'user_id': 'vkTlI0k3HqS1axQS1z8whg',
#   'business_id': 'm_CqRpEZ2XDH3fp-KFAycQ',
#   'stars': 3.65625},
#  {'user_id': 'vkTlI0k3HqS1axQS1z8whg',
#   'business_id': 'hroo5nOO8b9QhHX0GLg7oA',
#   'stars': 3.5649122807017544},
#  {'user_id': 'vkTlI0k3HqS1axQS1z8whg',
#   'business_id': 'aSAE_2ON-DNliRY7K-PiWQ',
#   'stars': 3.2777777777777777},
#  {'user_id': 's3kRi7b8t2sdtYcsMbqlJA',
#   'business_id': 'BLIJ-p5wYuAhw6Pp6mh6mw',
#   'stars': 3.5088028169014085},
#  {'user_id': 's3kRi7b8t2sdtYcsMbqlJA',
#   'business_id': 'AyEtowSGi9vx0-xFfrgjWw',
#   'stars': 3.7062146892655368},
#  {'user_id': 'EiT_pSuIb08oRn4CfwfMJg',
#   'business_id': 'vx4YAA02Qz6khRD1fZ1MFA',
#   'stars': 3.5379939209726445},
#  {'user_id': 'EiT_pSuIb08oRn4CfwfMJg',
#   'business_id': '4JNXUYY8wbaaDmk3BPzlWw',
#   'stars': 4.060895084372707},
#  {'user_id': 'EiT_pSuIb08oRn4CfwfMJg',
#   'business_id': '1iZJlc1b6FfRsWa3FHm4lw',
#   'stars': 3.9705882352941178},
#  {'user_id': 'EiT_pSuIb08oRn4CfwfMJg',
#   'business_id': 'oXoVJ0xKv82cBo9U6oEjlQ',
#   'stars': 3.043956043956044},
#  {'user_id': '1PfEtkSwdXiyeIqExpeKOA',
#   'business_id': 'EhIMjTklf4QPvRvMIhoQiA',
#   'stars': 3.642857142857143},
#  {'user_id': 'i6YHXZfcdtDzZSeEF9Wo3w',
#   'business_id': 'a8ACgZ_bPPT6iRQ6R7Ridg',
#   'stars': 3.541176470588235},
#  {'user_id': 'i6YHXZfcdtDzZSeEF9Wo3w',
#   'business_id': 'J3FUxMAHfCl-WFo86u5DqA',
#   'stars': 3.8264462809917354},
#  {'user_id': 'i6YHXZfcdtDzZSeEF9Wo3w',
#   'business_id': 'K0j_Znzin0jShXVnpvW86A',
#   'stars': 3.767634854771784},
#  {'user_id': 'i6YHXZfcdtDzZSeEF9Wo3w',
#   'business_id': 'BH9z7IJ4zydAqgwsbqoVZQ',
#   'stars': 4.328320802005012},
#  {'user_id': 'i6YHXZfcdtDzZSeEF9Wo3w',
#   'business_id': 'GI-CAiZ_Gg3h21PwrANB4Q',
#   'stars': 4.322463768115942},
#  {'user_id': 'i6YHXZfcdtDzZSeEF9Wo3w',
#   'business_id': 'FHVJlxEwgirjG6B3NMMoOA',
#   'stars': 4.25},
#  {'user_id': 'Spgm6HFWgc4YXJlbhg11Pg',
#   'business_id': 'GMrwDXRlAZU2zj5nH6l4vQ',
#   'stars': 3.7012987012987013},
#  {'user_id': 'Spgm6HFWgc4YXJlbhg11Pg',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.0},
#  {'user_id': 'Spgm6HFWgc4YXJlbhg11Pg',
#   'business_id': 'Qihead6oTtWCwde3TBqlGg',
#   'stars': 3.853982300884956},
#  {'user_id': 'Spgm6HFWgc4YXJlbhg11Pg',
#   'business_id': 'QJatAcxYgK1Zp9BRZMAx7g',
#   'stars': 3.867298578199052},
#  {'user_id': 'Spgm6HFWgc4YXJlbhg11Pg',
#   'business_id': 'xVEtGucSRLk5pxxN0t4i6g',
#   'stars': 4.08080808080808},
#  {'user_id': 'Spgm6HFWgc4YXJlbhg11Pg',
#   'business_id': 'XXW_OFaYQkkGOGniujZFHg',
#   'stars': 3.945130315500686},
#  {'user_id': 'Spgm6HFWgc4YXJlbhg11Pg',
#   'business_id': 'f-4N8MXGy_ifyGtfZrh6SQ',
#   'stars': 3.5},
#  {'user_id': 'Spgm6HFWgc4YXJlbhg11Pg',
#   'business_id': 'G9Cz2lUnLxv1cj6fnv73XA',
#   'stars': 2.7142857142857144},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'FNe5PPA9pyj8FjcDefCBpg',
#   'stars': 4.11969111969112},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'q3YnYPjLuBGRDi_59yTC5g',
#   'stars': 3.985645933014354},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'wZvSsHFU0NdyQ03625kh6g',
#   'stars': 3.607843137254902},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'fAo-3jt3oD69nwnr5M6FLQ',
#   'stars': 3.8529411764705883},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'qVbZ_VrZEGJKJg9ZpkGzjw',
#   'stars': 4.258064516129032},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'XBEx2FI2GKmsjs7eWNr7Lw',
#   'stars': 4.31},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'JpgVl3d20CMRNjf1DVnzGA',
#   'stars': 3.0898876404494384},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'mU3vlAVzTxgmZUu6F4XixA',
#   'stars': 4.087136929460581},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'TfabYPasZ1oOMN6JLa-yvw',
#   'stars': 3.8516129032258064},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'TrGBHqHVzJM5tk2C1D1ctQ',
#   'stars': 4.439024390243903},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': 'hroo5nOO8b9QhHX0GLg7oA',
#   'stars': 3.5649122807017544},
#  {'user_id': 'PQAR1z013WjtH6bMl5295A',
#   'business_id': '_RiwESa2w64ls6y_5tE4CA',
#   'stars': 4.0},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'SzI7eYjq0hMEqQlWh3UYpQ',
#   'stars': 3.4285714285714284},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'v_yCY6NCwxCPIsNZR80UfQ',
#   'stars': 4.162264150943396},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 't_gXmB7l8l1JOTnxqwHl-Q',
#   'stars': 4.096774193548387},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': '2vL6xxAxRhJS7LabjjDyhw',
#   'stars': 4.708860759493671},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'xk-fOf_M39kDTgzfVgu0Tw',
#   'stars': 3.761904761904762},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'CQk3WJtULz_xOkUM6o7wpQ',
#   'stars': 3.9065040650406506},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'iNKMTWEZ-uuXzCbPsAv-kQ',
#   'stars': 3.8981481481481484},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'W1Yr6c2XDx_RBjb6WsV-aQ',
#   'stars': 3.9859154929577465},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'BslEhCyzaQPfpHtDogb4hQ',
#   'stars': 3.810344827586207},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'k7Sy557_ZaQSGHFlZgeJzw',
#   'stars': 4.078703703703703},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'hZAxcfDnLOkFY6G5ofI2RQ',
#   'stars': 4.464285714285714},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'g83WbX_recywc4DEIZ-xug',
#   'stars': 4.371900826446281},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'xTOX8D1Tavoi9vPWL-nWdQ',
#   'stars': 3.395209580838323},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'YcGHCoSkl2PLKsHQCiu0HA',
#   'stars': 4.571428571428571},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'ybHlmdUHLPKfv85bRK4Wtw',
#   'stars': 4.582010582010582},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'vyQD-pu9jFKRXWI9tt16_Q',
#   'stars': 3.6944444444444446},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'lvuuyYZ-CzFrg1BLdV2OPw',
#   'stars': 3.661870503597122},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'iJ4uoZkPNJ39Vfh0HirI3w',
#   'stars': 3.6728971962616823},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'jDfX74uyLQpHufvSa7zwMw',
#   'stars': 4.45},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': '3tSCyhkRIa7-drYrG5_6uA',
#   'stars': 3.7872340425531914},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'IZivKqtHyz4-ts8KsnvMrA',
#   'stars': 4.210106382978723},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': '9PIC380tmNYpIC3z5cvcNA',
#   'stars': 4.168},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'Ur6qSirXUZQgRMumvXJvrA',
#   'stars': 4.491228070175438},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': '1VCCa_oLqO94Wh8hTyMD-A',
#   'stars': 4.363636363636363},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'NXNa5OYmN1CNmXwHhDxpRA',
#   'stars': 4.138528138528138},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'gGdcKpfiQDl3vlByqJxlPA',
#   'stars': 4.315789473684211},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': '5aLB4PlOkvkln54wUT78ZA',
#   'stars': 4.75},
#  {'user_id': 'i_DR3vdE73nVm2GlMbGpGA',
#   'business_id': 'Fmij544FE1iOruoxI41kew',
#   'stars': 5.0},
#  {'user_id': 'dM1HHK4szA5Qs6NSAaEk1Q',
#   'business_id': 'dxeu5YQIzw0jOp1cSVkimg',
#   'stars': 4.278787878787878},
#  {'user_id': 'dM1HHK4szA5Qs6NSAaEk1Q',
#   'business_id': 'HaWU8ICNtjIkCN_ZNrx1hw',
#   'stars': 4.033057851239669},
#  {'user_id': 'dM1HHK4szA5Qs6NSAaEk1Q',
#   'business_id': 'LR0qF0FEVsCOhYWUOiH26A',
#   'stars': 3.2163355408388523},
#  {'user_id': 'dM1HHK4szA5Qs6NSAaEk1Q',
#   'business_id': 'r4KXghbUeo7mugAzinG9bA',
#   'stars': 3.9661016949152543},
#  {'user_id': 'dM1HHK4szA5Qs6NSAaEk1Q',
#   'business_id': 'YemQ_iZIftV5zpdAXqkkdw',
#   'stars': 3.507936507936508},
#  {'user_id': 'dM1HHK4szA5Qs6NSAaEk1Q',
#   'business_id': 'O7uA5Rlo4vIVoh7KthEEXg',
#   'stars': 4.571428571428571},
#  {'user_id': 'pkq41Qh9yGOI_4pwdVmmDg',
#   'business_id': 'zdE82PiD6wquvjYLyhOJNA',
#   'stars': 4.210900473933649},
#  {'user_id': 'pkq41Qh9yGOI_4pwdVmmDg',
#   'business_id': '4ugJ4F8jDJ9-2dEiZ47wLg',
#   'stars': 3.806451612903226},
#  {'user_id': 'pkq41Qh9yGOI_4pwdVmmDg',
#   'business_id': 'vUYz-JgVTAtUGUbQuF7czw',
#   'stars': 3.5833333333333335},
#  {'user_id': 'pkq41Qh9yGOI_4pwdVmmDg',
#   'business_id': 'RZGxU6bCoqgbi7xVB_UckQ',
#   'stars': 3.8333333333333335},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'F4VS-6xnpDoNBRGPoLrtjA',
#   'stars': 4.304347826086956},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'zsQk990PubOHjr1YcLkQFw',
#   'stars': 3.933333333333333},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '2lPLbTenaBH3SGHgpwM54A',
#   'stars': 3.4583333333333335},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'iRwT2pBa87Y54q8nqfNAzw',
#   'stars': 3.923076923076923},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'rS0ReiIhmugq3UcK_7aGAQ',
#   'stars': 3.6},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'WyZAeMGsjUE7OToI4Jdqfw',
#   'stars': 3.566666666666667},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'RqpL5Y50F9exjyHfpTzp3w',
#   'stars': 2.9622641509433962},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'Nt7f1POFo_BMxQ6jTSeNCw',
#   'stars': 3.789473684210526},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'sEIYwtCebPe9QZJfEQ5Pdg',
#   'stars': 3.111111111111111},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '33Tr0eRki1Yamzleu4GMdw',
#   'stars': 4.236641221374046},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '1u_FbiGTSTCc1XvvoT2txw',
#   'stars': 3.5833333333333335},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '_nL5u09k7J7XAww1_UJ-tw',
#   'stars': 2.984848484848485},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'PaF9DsA8aQSSKXSJxdd8lA',
#   'stars': 3.5},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'VsIx1NnhM5PA8prJjIZNYg',
#   'stars': 3.6315789473684212},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'lOQPeguczAueJnLmDUTfGg',
#   'stars': 4.057142857142857},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'rquarcYSOS9PIstXZAP_kA',
#   'stars': 3.3333333333333335},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'liGn7sPOvUuy3kcwbhRkbA',
#   'stars': 2.8378378378378377},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'Yiw2jUJzUdFmglHZgj4RaQ',
#   'stars': 3.7547169811320753},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'uW6UHfONAmm8QttPkbMewQ',
#   'stars': 4.345098039215686},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'YnmtUJGqQIQL9tz1MRyfqA',
#   'stars': 3.746153846153846},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'dYDuaXVyIXMXlmeMYf2ktw',
#   'stars': 4.150259067357513},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'HaPwC4nxs6RPfe1pAQkQ4A',
#   'stars': 3.983050847457627},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'd_L-rfS1vT3JMzgCUGtiow',
#   'stars': 3.903225806451613},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'zYKblyjRDoiOum6NYuvZ6g',
#   'stars': 3.6},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'TUrQG_XfJA_kCOSN0oUbTQ',
#   'stars': 3.287878787878788},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'FvVSy2r7_zDEhZWqLgjXNQ',
#   'stars': 3.9685230024213074},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'aYTiyhUbc6uL7jSAXGKhrA',
#   'stars': 4.247524752475248},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '_Kd0kQ8RF70hJ1ykLqCRyQ',
#   'stars': 3.4748201438848922},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'iA8Ve2sZKN5Vz3mYKrtCaQ',
#   'stars': 4.101941747572815},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'CauQnqZ5eowyrr7oWF_p3Q',
#   'stars': 4.337792642140468},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'YC8Llp3jlgKh8b-czHedHg',
#   'stars': 3.9473684210526314},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'YIYE7Zk61McLaekLFluzTg',
#   'stars': 4.576271186440678},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'r6igU1Fqs5szOOhyXPbayw',
#   'stars': 4.338842975206612},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'mAX7l3SQNs8Fa4kBpOT7hg',
#   'stars': 2.75},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'gJ-svVBsgkmE4Iy_hrGHMQ',
#   'stars': 3.7142857142857144},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'K-iqIqMTTvESaAz2KgwulA',
#   'stars': 4.4963503649635035},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'inXu0sfSxf7PF4GvWTfbEg',
#   'stars': 4.911111111111111},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'W8apgXmOxESpoL_EeogC5w',
#   'stars': 4.038961038961039},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '7HIa2lYy5jgcZuADlRjKSg',
#   'stars': 2.75},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'sUXs9ATmb423TcxgtMalzQ',
#   'stars': 4.059322033898305},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'Yq92uUpugGyJLvDtcDRunw',
#   'stars': 4.383177570093458},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'XXW_OFaYQkkGOGniujZFHg',
#   'stars': 3.945130315500686},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '54WM5coZonA0izd2y04p_A',
#   'stars': 3.6666666666666665},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '9WAnQD1nj1j3zLZ7ONtvfQ',
#   'stars': 3.466666666666667},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'Uut2Y-n5eMO6qIn7tvEYKA',
#   'stars': 3.6865671641791047},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '8SwMaPL6AJIs1ZPSZ3NJ4w',
#   'stars': 4.20625},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'NyOaA9zJ_59E8ch5HgHofw',
#   'stars': 3.6},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'GwcfhhBoAUT-kJQpDjsHxQ',
#   'stars': 3.787878787878788},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'NlNZgDWJhOYz9zoKE2ydMQ',
#   'stars': 3.654320987654321},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '5iHctUjkQTGwEvOaBkwMRQ',
#   'stars': 4.333333333333333},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '1SqLPgnZEVeVYDM-AuoFhg',
#   'stars': 3.779591836734694},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'eaNenRk_liZBERFFLCXqqQ',
#   'stars': 4.458204334365325},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'PR23v1X54OtNHOmWyE5TFQ',
#   'stars': 3.7333333333333334},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'iPM85PQMs7QoAxw-Og9ChQ',
#   'stars': 3.6588235294117646},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'j7HO1YeMQGYo3KibMXZ5vg',
#   'stars': 3.731707317073171},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '-C8sSrFqaCxp51pyo-fQLQ',
#   'stars': 4.320754716981132},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '_paJE9yQfSvo25BKBQrKZA',
#   'stars': 3.1818181818181817},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '06MlxbtB4ZYeg_ri02RIAQ',
#   'stars': 3.0},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'Er8DpPwf_lHHv64ncWhD8g',
#   'stars': 3.765},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'dVbZ0xbkwl8BWiqaDS0t-w',
#   'stars': 3.8823529411764706},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'NLWOiFwHn2PlWrjC6UhJSg',
#   'stars': 3.4814814814814814},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'XwQ6lQro2FKvtD0YAUeOAA',
#   'stars': 3.8732394366197185},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'ct43PIwz_XflYImvopdvIQ',
#   'stars': 3.9411764705882355},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'mShOJ9qFk79KnZq7E8k9hQ',
#   'stars': 3.415929203539823},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '6kkxRV8H9SQLybj0xnEbMw',
#   'stars': 3.6796536796536796},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'zUbqJk1KtbMnStiMfrMegA',
#   'stars': 3.125},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'aD0EslPREWGDlSpD0RMlEg',
#   'stars': 4.146341463414634},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'eSLwC2iFJOU4UWXyuPiTpg',
#   'stars': 3.1458333333333335},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'axfGq2ooUSB9MpL1RQTmeQ',
#   'stars': 2.9},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'Z6t15TXGlVh3-2ClZunCgg',
#   'stars': 3.909090909090909},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '-CQokjildrY7UZezXCdEBw',
#   'stars': 4.777777777777778},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': 'cZBCVzd4lg_jx8IiFz-Iag',
#   'stars': 3.0},
#  {'user_id': 'UYcmGbelzRa0Q6JqzLoguw',
#   'business_id': '41WfL6MGTAXYgRQfNT3dyA',
#   'stars': 3.0},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': '6bgjcFOy4WHMyw62_1V9Pw',
#   'stars': 3.670103092783505},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': '-ipc5f0XiXwH3hbNnro54Q',
#   'stars': 3.869565217391304},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': '_8yxceldCT7oe0wJC-yDPA',
#   'stars': 3.619047619047619},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'mnU3iGsL55MCWXiWV3AcAQ',
#   'stars': 4.322033898305085},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'S3-Zmeg2FALMsx9GhHJ5HQ',
#   'stars': 4.310077519379845},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'Kn8nZztS41bKfSOHedqX3g',
#   'stars': 4.359649122807017},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'ZAuAwz1ijuydn5yL3q3rzA',
#   'stars': 4.370666666666667},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': '0xvdC8F0HmFpAFkJk6nXLg',
#   'stars': 4.3630573248407645},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'RnAb4KkRDmWUBWhhZhugZQ',
#   'stars': 3.772727272727273},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': '01VPJkcU0m8WzlA7dCEpVQ',
#   'stars': 4.137254901960785},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'Jur1iiejUFw_YCkfDfy1gQ',
#   'stars': 3.566860465116279},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'q3YnYPjLuBGRDi_59yTC5g',
#   'stars': 3.985645933014354},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': '9M6eqYZlyBMo8K9QztXcIA',
#   'stars': 3.739130434782609},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'FQB3VXrWYM_m_XrzwRozAg',
#   'stars': 3.617777777777778},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'KYasaF1nov1bn7phfSgWeg',
#   'stars': 3.8333333333333335},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'I6u-OhmI_IUltexEOSCKzg',
#   'stars': 3.4257425742574257},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'RESDUcs7fIiihp38-d6_6g',
#   'stars': 3.9086614173228345},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'IBKNR0-FL_Y5KzXqA1yS4A',
#   'stars': 4.271844660194175},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'ux6ZekIlKJbJUKWRe7RjUQ',
#   'stars': 4.368421052631579},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'cxnbk6t6L3jnfT5n2Hbl3Q',
#   'stars': 3.48},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'gWlasTc2Af0VV24mCR1tWg',
#   'stars': 2.9583333333333335},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'rT9OKEmoTr2uHzj3m2HTkQ',
#   'stars': 3.2666666666666666},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'c-NXKTJ0jrrusTPxJAUwvA',
#   'stars': 2.8518518518518516},
#  {'user_id': 'Nbr4DYLPxURjxelLVTSt8A',
#   'business_id': 'B2UUBK1Wtaf46yl71AGtww',
#   'stars': 5.0},
#  {'user_id': 'sGI1svtG_retrGgnythe1g',
#   'business_id': 'zlFyjtCp4AQ1cPx59qeFQQ',
#   'stars': 3.556390977443609},
#  {'user_id': 'sGI1svtG_retrGgnythe1g',
#   'business_id': 'xObQl57iTZrg8-hfMkMF6g',
#   'stars': 4.333333333333333},
#  {'user_id': 'sGI1svtG_retrGgnythe1g',
#   'business_id': 'vtj3lt38T9Icu_RXHAQ__w',
#   'stars': 4.096774193548387},
#  {'user_id': 'sGI1svtG_retrGgnythe1g',
#   'business_id': 'ZU3ZU_wGF2S4CKavMEtI_w',
#   'stars': 3.5294117647058822},
#  {'user_id': 'sGI1svtG_retrGgnythe1g',
#   'business_id': 'JhqsE8IGN-UXwNli474w7g',
#   'stars': 2.6},
#  {'user_id': 'sGI1svtG_retrGgnythe1g',
#   'business_id': '3iQ4H1WRqg1EvSZSRLeb-A',
#   'stars': 4.266666666666667},
#  {'user_id': 'SJuSiO27FTKi5qKrNDa8Lg',
#   'business_id': 'dKdApYVFDSNYsNOso6NYlA',
#   'stars': 3.089700996677741},
#  {'user_id': 'SJuSiO27FTKi5qKrNDa8Lg',
#   'business_id': 'AnXovUgUHJap3QaDRnjL1w',
#   'stars': 3.746987951807229},
#  {'user_id': 'SJuSiO27FTKi5qKrNDa8Lg',
#   'business_id': 'yBxzqKXHhvNVaFnEOd4f7Q',
#   'stars': 4.0},
#  {'user_id': 'SJuSiO27FTKi5qKrNDa8Lg',
#   'business_id': 'bxCKBd1qsafnKXlWrCK20g',
#   'stars': 3.2564102564102564},
#  {'user_id': 'SJuSiO27FTKi5qKrNDa8Lg',
#   'business_id': 'y-ZZe1dz8AMjiAwNVo3h_A',
#   'stars': 3.5972222222222223},
#  {'user_id': 'SJuSiO27FTKi5qKrNDa8Lg',
#   'business_id': 'uSxWwjS7wbK2XeVwlgSqdw',
#   'stars': 4.44},
#  {'user_id': 'LaFfXvrcgWQXH1YqswREgA',
#   'business_id': 'iPM8BXV6vEVEci8ttsOObQ',
#   'stars': 3.4066666666666667},
#  {'user_id': 'LaFfXvrcgWQXH1YqswREgA',
#   'business_id': '16tWXenJ1wTqugXJU7yiZg',
#   'stars': 3.7736842105263158},
#  {'user_id': 'LaFfXvrcgWQXH1YqswREgA',
#   'business_id': 'f1ZKauu7dCB6iplmKqplAQ',
#   'stars': 3.5876288659793816},
#  {'user_id': 'LaFfXvrcgWQXH1YqswREgA',
#   'business_id': 'MyTsAeShB9pcWP84GSTAdw',
#   'stars': 4.048192771084337},
#  {'user_id': 'LaFfXvrcgWQXH1YqswREgA',
#   'business_id': 'OJdufUU3hVabgviIBHksYw',
#   'stars': 3.463855421686747},
#  {'user_id': 'LaFfXvrcgWQXH1YqswREgA',
#   'business_id': 'lUSAupdaVSoEaUO63RdPZA',
#   'stars': 3.4444444444444446},
#  {'user_id': 'VdkAX9khigCjpMGuMNWYMQ',
#   'business_id': '6TQ0gCdAqaBbuDyCGa0joA',
#   'stars': 3.8524590163934427},
#  {'user_id': 'VdkAX9khigCjpMGuMNWYMQ',
#   'business_id': 'bzI2YREsxDomhVvvaZmcSw',
#   'stars': 4.008928571428571},
#  {'user_id': 'VdkAX9khigCjpMGuMNWYMQ',
#   'business_id': 'y8d90Pt16Nip-B5UXWBP-w',
#   'stars': 3.835},
#  {'user_id': 'VdkAX9khigCjpMGuMNWYMQ',
#   'business_id': 'UT6L3b7Zll_nvRidijiDSA',
#   'stars': 3.8238993710691824},
#  {'user_id': 'VdkAX9khigCjpMGuMNWYMQ',
#   'business_id': '0ldxjei8v4q95fApIei3Lg',
#   'stars': 3.82972972972973},
#  {'user_id': 'VdkAX9khigCjpMGuMNWYMQ',
#   'business_id': 'B7XwqO9Lbzq-VtOiRobfCg',
#   'stars': 3.5421686746987953},
#  {'user_id': 'VdkAX9khigCjpMGuMNWYMQ',
#   'business_id': 'SeNOJ2zYHziptxLuiRINLg',
#   'stars': 4.075},
#  {'user_id': 'VdkAX9khigCjpMGuMNWYMQ',
#   'business_id': 'SycXTaA4MeJZuDK4Y1owDQ',
#   'stars': 3.4193548387096775},
#  {'user_id': 'VdkAX9khigCjpMGuMNWYMQ',
#   'business_id': 'IMLrj2klosTFvPRLv56cng',
#   'stars': 3.841897233201581},
#  {'user_id': 'V5Th21KjUiYLJQyV-vGtpg',
#   'business_id': 'K7lWdNUhCbcnEvI0NhGewg',
#   'stars': 3.7328881469115194},
#  {'user_id': 'V5Th21KjUiYLJQyV-vGtpg',
#   'business_id': '3cHL1r5w2oLYH-veijtweA',
#   'stars': 3.641025641025641},
#  {'user_id': 'V5Th21KjUiYLJQyV-vGtpg',
#   'business_id': 'VyjyHoBg3KC5BSFRlD0ZPQ',
#   'stars': 3.7721518987341773},
#  {'user_id': 'V5Th21KjUiYLJQyV-vGtpg',
#   'business_id': 'YZGSNhgTS6YeyUYoivD-Ww',
#   'stars': 3.725},
#  {'user_id': 'gm0V0GmBBlUlTqoZHsjWqw',
#   'business_id': 'IT_4EEIbv6Ox1jBRMyE7pg',
#   'stars': 4.329268292682927},
#  {'user_id': 'gm0V0GmBBlUlTqoZHsjWqw',
#   'business_id': 'yfxDa8RFOvJPQh0rNtakHA',
#   'stars': 3.5912117177097205},
#  {'user_id': 'gm0V0GmBBlUlTqoZHsjWqw',
#   'business_id': 'J4CATH00YZrq8Bne2S4_cw',
#   'stars': 4.206751054852321},
#  {'user_id': 'gm0V0GmBBlUlTqoZHsjWqw',
#   'business_id': 'Er8DpPwf_lHHv64ncWhD8g',
#   'stars': 3.765},
#  {'user_id': 'CuYWG1kNYydAZuQ_Ay6bFQ',
#   'business_id': 'sqRX-XLlhx4rs2c1TpBf8A',
#   'stars': 4.368831168831169},
#  {'user_id': 'gvuvcjAVl1ElyXTgU80VRg',
#   'business_id': 'ugLqbAvBdRDc-gS4hpslXw',
#   'stars': 3.868131868131868},
#  {'user_id': 'gvuvcjAVl1ElyXTgU80VRg',
#   'business_id': 'Vs7gc9EE3k9wARuUcN9piA',
#   'stars': 4.253164556962025},
#  {'user_id': 'gvuvcjAVl1ElyXTgU80VRg',
#   'business_id': 'wWuGa3OOQJro_XGe-GKBXA',
#   'stars': 4.659574468085107},
#  {'user_id': 'gvuvcjAVl1ElyXTgU80VRg',
#   'business_id': 'YJ8ljUhLsz6CtT_2ORNFmg',
#   'stars': 3.509433962264151},
#  {'user_id': 'gvuvcjAVl1ElyXTgU80VRg',
#   'business_id': '-K82LBrI3H0FVuhTbNDpRA',
#   'stars': 3.4482758620689653},
#  {'user_id': 'TwFP5Ibxx3AYsX6ZCW_Vow',
#   'business_id': '_eDVVS8wwXcdllaW6nfLyg',
#   'stars': 3.982456140350877},
#  {'user_id': 'TwFP5Ibxx3AYsX6ZCW_Vow',
#   'business_id': 'iFCz-xI7CV98fcaB4Chh3g',
#   'stars': 4.407692307692308},
#  {'user_id': 'TwFP5Ibxx3AYsX6ZCW_Vow',
#   'business_id': 'R_z9LFtqbBB9pANO530w9w',
#   'stars': 4.238095238095238},
#  {'user_id': 'TwFP5Ibxx3AYsX6ZCW_Vow',
#   'business_id': 'zpoZ6WyQUYff18-z4ZU1mA',
#   'stars': 4.513513513513513},
#  {'user_id': 'TwFP5Ibxx3AYsX6ZCW_Vow',
#   'business_id': 'YQxBwqAkXBPinESqiHlnmw',
#   'stars': 3.869565217391304},
#  {'user_id': 'TwFP5Ibxx3AYsX6ZCW_Vow',
#   'business_id': 'RtDEwPI69XidCCklUtSLQA',
#   'stars': 3.7777777777777777},
#  {'user_id': '-YV1yESQXqR3vpIgBjKDsw',
#   'business_id': 'ysv6yhVYOoH9Pf7PlMyD0g',
#   'stars': 3.311111111111111},
#  {'user_id': '-YV1yESQXqR3vpIgBjKDsw',
#   'business_id': '56Ll9rqG2WxXj4X2pmlkHQ',
#   'stars': 3.7},
#  {'user_id': '-YV1yESQXqR3vpIgBjKDsw',
#   'business_id': 'OVTZNSkSfbl3gVB9XQIJfw',
#   'stars': 3.3333333333333335},
#  {'user_id': '-YV1yESQXqR3vpIgBjKDsw',
#   'business_id': 'uUEKndnFbHD8mVkGiirtpA',
#   'stars': 4.059459459459459},
#  {'user_id': '-YV1yESQXqR3vpIgBjKDsw',
#   'business_id': '2PS9kBbuJcmBhcNp-D62uA',
#   'stars': 4.558139534883721},
#  {'user_id': 'PE8s8ACYABRNANI-T_WmzA',
#   'business_id': 'zpoZ6WyQUYff18-z4ZU1mA',
#   'stars': 4.513513513513513},
#  {'user_id': 'PE8s8ACYABRNANI-T_WmzA',
#   'business_id': 'I6EDDi4-Eq_XlFghcDCUhw',
#   'stars': 4.334851936218679},
#  {'user_id': 'PE8s8ACYABRNANI-T_WmzA',
#   'business_id': 'PWGIAIXAoh91nayfIOQMTQ',
#   'stars': 3.75},
#  {'user_id': 'PE8s8ACYABRNANI-T_WmzA',
#   'business_id': 'QCCVxVRt1amqv0AaEWSKkg',
#   'stars': 4.414634146341464},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': '5zDP3Y2hdh6GJL9DVbQ2KA',
#   'stars': 3.8525345622119818},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': 'y8d90Pt16Nip-B5UXWBP-w',
#   'stars': 3.835},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': 'EhuKnhTKJTm_EZ_QGe7PvQ',
#   'stars': 3.65},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': '--FBCX-N37CMYDfs790Bnw',
#   'stars': 3.8636363636363638},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': '9cw870n3gsGikVoOT5YOYg',
#   'stars': 4.337078651685394},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': 'E0OKctOhZpUQgwUUBc_RwA',
#   'stars': 4.075},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': 'Kbbm6Vd5UdbP10dwjBghRw',
#   'stars': 4.258620689655173},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': 'vjhB95c5nOXflNoyq_jKzw',
#   'stars': 3.3347457627118646},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': 'ByXko9JQ6Jne7v8t4IaQjg',
#   'stars': 1.7894736842105263},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': 'oH6QAuoTLFaX97oqqpLTMg',
#   'stars': 4.017094017094017},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': '7YpipG1N4nsvQZ_WGiV9PA',
#   'stars': 3.92},
#  {'user_id': 'vef-mhDgJP7FzFCdTTds-w',
#   'business_id': 'GI-CAiZ_Gg3h21PwrANB4Q',
#   'stars': 4.322463768115942},
#  {'user_id': 'l1jYrj9DvTe4t92kGEH3BQ',
#   'business_id': 'YXohNvMTCmGhFMSQsDZq1g',
#   'stars': 3.8677966101694916},
#  {'user_id': 'l1jYrj9DvTe4t92kGEH3BQ',
#   'business_id': '6Vyp-9i1jzwK_bvisuPJpQ',
#   'stars': 3.348360655737705},
#  {'user_id': 'l1jYrj9DvTe4t92kGEH3BQ',
#   'business_id': 'Y-3UVcgmi9H9t808pUBawQ',
#   'stars': 4.5},
#  {'user_id': 'l1jYrj9DvTe4t92kGEH3BQ',
#   'business_id': 'quD839G-_0HIwAIE0knV6g',
#   'stars': 2.111111111111111},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'eR7Iw_X54m3YLWkXp9y35Q',
#   'stars': 4.376190476190477},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'qtZ50TWkfNS2UtLLuD1m8Q',
#   'stars': 4.1645569620253164},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'jfmyj519pg2flxGEQ2xdPg',
#   'stars': 3.8117647058823527},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'A5Rkh7UymKm0_Rxm9K2PJw',
#   'stars': 3.915936952714536},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'K7lWdNUhCbcnEvI0NhGewg',
#   'stars': 3.7328881469115194},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'JPfi__QJAaRzmfh5aOyFEw',
#   'stars': 4.292490118577075},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'VMXl3Dm1Nwvgwo1PVYTXbg',
#   'stars': 3.8898678414096914},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'sxNMGQwUuaDsviR4BtuX0g',
#   'stars': 3.96943231441048},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': '7wHLFohwCw8l6WS-feLjeg',
#   'stars': 4.327014218009479},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'FsbzGuFBMVV99T2otrfsmA',
#   'stars': 4.166666666666667},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'fhoFsFK6TqJOEo30LtXeDA',
#   'stars': 3.515625},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'QJatAcxYgK1Zp9BRZMAx7g',
#   'stars': 3.867298578199052},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': '54LYVM1gCGQ2UVFK9QhgTw',
#   'stars': 4.023809523809524},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'oUX2bYbqjqST-urKbOHG6w',
#   'stars': 4.255813953488372},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'yYMTMtguT90BfMJVxasFuw',
#   'stars': 3.787878787878788},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'AbHdwEfXJWqGHqabTb5S5A',
#   'stars': 4.928571428571429},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'HaWU8ICNtjIkCN_ZNrx1hw',
#   'stars': 4.033057851239669},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'F5uXN5v-GHBSewbCoipGyg',
#   'stars': 3.7},
#  {'user_id': 'w9WmBotuUdQlmuLa3XUkFQ',
#   'business_id': 'zelX9HDxrnS-_LcvVy82cA',
#   'stars': 5.0},
#  {'user_id': 'Ro6tWGZ2Z7UrWlsTw_ve8A',
#   'business_id': 'osu1j_Lg8R9brpuMMn3a3A',
#   'stars': 4.180451127819549},
#  {'user_id': '2-RlTk9dJNpj85MR2B46Cg',
#   'business_id': 'OVTZNSkSfbl3gVB9XQIJfw',
#   'stars': 3.3333333333333335},
#  {'user_id': '2-RlTk9dJNpj85MR2B46Cg',
#   'business_id': '7zec5DCEukcx8GRFn9LbLQ',
#   'stars': 3.935483870967742},
#  {'user_id': 'N5URmpyygDBSC_8UShI_6Q',
#   'business_id': 'RqpL5Y50F9exjyHfpTzp3w',
#   'stars': 2.9622641509433962},
#  {'user_id': 'N5URmpyygDBSC_8UShI_6Q',
#   'business_id': 'tsf1JNdeeQf_654YUSrzRw',
#   'stars': 4.2259887005649714},
#  {'user_id': 'N5URmpyygDBSC_8UShI_6Q',
#   'business_id': 'S-egzF2c7bRpCUNbZqV8dg',
#   'stars': 4.069672131147541},
#  {'user_id': 'N5URmpyygDBSC_8UShI_6Q',
#   'business_id': 'oj5k-I0YSbuc5tDInt2isQ',
#   'stars': 4.5607476635514015},
#  {'user_id': 'N5URmpyygDBSC_8UShI_6Q',
#   'business_id': 'x71EvWJDVKZfM-OiYDWZ6A',
#   'stars': 3.9047619047619047},
#  {'user_id': 'N5URmpyygDBSC_8UShI_6Q',
#   'business_id': '0QzCeORfF8EY34UODWRV9A',
#   'stars': 3.5},
#  {'user_id': 'N5URmpyygDBSC_8UShI_6Q',
#   'business_id': 'NFMD_-wFrbfdhTcdHPDCZQ',
#   'stars': 4.230769230769231},
#  {'user_id': 'N5URmpyygDBSC_8UShI_6Q',
#   'business_id': 'nOidqR9yk6clKeXbuT_gZg',
#   'stars': 3.6216216216216215},
#  {'user_id': 'Wwza9sx8iS-VbIHEWt-RIg',
#   'business_id': 'oljOuU-B7XUNQFPBjed2yQ',
#   'stars': 3.611111111111111},
#  {'user_id': 'Wwza9sx8iS-VbIHEWt-RIg',
#   'business_id': 'ugf6qjoG5h6VXR5-vpq0Qw',
#   'stars': 3.776978417266187},
#  {'user_id': 'Wwza9sx8iS-VbIHEWt-RIg',
#   'business_id': 'ZGXd87vme_dDVYqr-HpRQQ',
#   'stars': 3.5416666666666665},
#  {'user_id': 'Wwza9sx8iS-VbIHEWt-RIg',
#   'business_id': '80wYgfv6sDNQlbJ7NbovGg',
#   'stars': 2.727272727272727},
#  {'user_id': 'Wwza9sx8iS-VbIHEWt-RIg',
#   'business_id': 'QiuTcA0bKQMCyOFBFJZ58w',
#   'stars': 3.696969696969697},
#  {'user_id': 'lzgEUPNFGboDm1U7aO8gTQ',
#   'business_id': 'NfM1YE-FJCToO1LB36T6lQ',
#   'stars': 3.4591836734693877},
#  {'user_id': 'lzgEUPNFGboDm1U7aO8gTQ',
#   'business_id': 'SXzJL5egnVXurANcg-G28A',
#   'stars': 2.4074074074074074},
#  {'user_id': 'QLTRaK92CWXDrZwbI46KOg',
#   'business_id': 'XXW_OFaYQkkGOGniujZFHg',
#   'stars': 3.945130315500686},
#  {'user_id': 'euqDhXqWZQ5CO2c0eMyPHg',
#   'business_id': 'jBhOVAEdnzCJvgSnvA4UDw',
#   'stars': 4.040697674418604},
#  {'user_id': 'euqDhXqWZQ5CO2c0eMyPHg',
#   'business_id': 'f_DnhukOHbKbR8vFHDUDaA',
#   'stars': 3.451219512195122},
#  {'user_id': 'euqDhXqWZQ5CO2c0eMyPHg',
#   'business_id': 'FYEJOYOrF1FTl5Gkg6Rl3g',
#   'stars': 3.8},
#  {'user_id': 'euqDhXqWZQ5CO2c0eMyPHg',
#   'business_id': 'Xck2KzJcZDJGMtwxMwD71w',
#   'stars': 3.3488372093023258},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': '77h11eWv6HKJAgojLx8G4w',
#   'stars': 3.8996138996139},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'yp2nRId4v-bDtrYl5A3F-g',
#   'stars': 4.209677419354839},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'e7N0AW-sKkJmRIpEovxBAg',
#   'stars': 3.7567567567567566},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'WmLTIN4qzZ8SjpPxsPH27Q',
#   'stars': 4.175182481751825},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'P8uECqGqXWTwEndkh-6bQw',
#   'stars': 3.9022988505747125},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'ozMd45nXHTCl3mdOwouwlw',
#   'stars': 4.2772277227722775},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'fAo-3jt3oD69nwnr5M6FLQ',
#   'stars': 3.8529411764705883},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'wX1ORSDKPkA5ftE7F6UONw',
#   'stars': 4.228187919463087},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'SU6DscrONGa2tOB2th7RJA',
#   'stars': 3.7333333333333334},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': '5LNZ67Yw9RD6nf4_UhXOjw',
#   'stars': 4.1746411483253585},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'ml9WFLPNAIryG6zQnd9qBA',
#   'stars': 3.9285714285714284},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'MaCvfp-VwZraxICluRwF1w',
#   'stars': 3.066666666666667},
#  {'user_id': '_pMzR6yoPbU98t-NH8TZ3w',
#   'business_id': 'UuEHNF6rzvRWf3WpnkdvhQ',
#   'stars': 2.0},
#  {'user_id': 'VlUnhotMqY6msql_GMyvhg',
#   'business_id': 'No3BsB8fFF03WmRPs1d7tw',
#   'stars': 4.519230769230769},
#  {'user_id': 'VlUnhotMqY6msql_GMyvhg',
#   'business_id': 'UceIYWaKErRX_CSviEgVuw',
#   'stars': 3.311111111111111},
#  {'user_id': 'VlUnhotMqY6msql_GMyvhg',
#   'business_id': 'OARQDsxyoGnnX2FfSl9HjA',
#   'stars': 4.239316239316239},
#  {'user_id': 'VlUnhotMqY6msql_GMyvhg',
#   'business_id': '9Rs7n2LbINBN8kLbScjhmA',
#   'stars': 3.7555555555555555},
#  {'user_id': 'qb-8RrNbVj-3WkXYuxpi3w',
#   'business_id': 'q18xbq3Cbyp_BJyfMQxFxg',
#   'stars': 3.720754716981132},
#  {'user_id': 'qb-8RrNbVj-3WkXYuxpi3w',
#   'business_id': 'OiqDNSdnchr8zQhiMSInLQ',
#   'stars': 4.0394736842105265},
#  {'user_id': 'qb-8RrNbVj-3WkXYuxpi3w',
#   'business_id': 'OaksCsORs2tUGxSJWhydJg',
#   'stars': 3.9078947368421053},
#  {'user_id': 'qb-8RrNbVj-3WkXYuxpi3w',
#   'business_id': '7SJoMX5ti-VoEsEW6mJLRA',
#   'stars': 4.408805031446541},
#  {'user_id': 'xFJ5Ja8y40CdMa1sfC4-gg',
#   'business_id': '--9e1ONYQuAa-CB_Rrw7Tw',
#   'stars': 4.0851851851851855},
#  {'user_id': 'xFJ5Ja8y40CdMa1sfC4-gg',
#   'business_id': '7fxebHYUwIF6CakxSr70iQ',
#   'stars': 3.8217391304347825},
#  {'user_id': 'xFJ5Ja8y40CdMa1sfC4-gg',
#   'business_id': 'Cni2l-VKG_pdospJ6xliXQ',
#   'stars': 3.8288431061806656},
#  {'user_id': 'xFJ5Ja8y40CdMa1sfC4-gg',
#   'business_id': 'Y-S2LhHefBdnX8VP5Bh_JA',
#   'stars': 3.215909090909091},
#  {'user_id': 'xFJ5Ja8y40CdMa1sfC4-gg',
#   'business_id': 'p4db4wsINzJmV3ZbCZZoVA',
#   'stars': 4.1},
#  {'user_id': 'wM1cuy_w6qsdWLeqQFWqVA',
#   'business_id': '56Ll9rqG2WxXj4X2pmlkHQ',
#   'stars': 3.7},
#  {'user_id': 'wM1cuy_w6qsdWLeqQFWqVA',
#   'business_id': 'zBD6zc8YU-TA0_KJmN1tpA',
#   'stars': 3.4545454545454546},
#  {'user_id': 'wM1cuy_w6qsdWLeqQFWqVA',
#   'business_id': 'WyZAeMGsjUE7OToI4Jdqfw',
#   'stars': 3.566666666666667},
#  {'user_id': 'wM1cuy_w6qsdWLeqQFWqVA',
#   'business_id': 'NLEe-RzDSU-5BN6xp_WWCw',
#   'stars': 3.7766497461928936},
#  {'user_id': 'wM1cuy_w6qsdWLeqQFWqVA',
#   'business_id': '0pIhgokp0NeM9h8oQQULOg',
#   'stars': 4.29126213592233},
#  {'user_id': 'wM1cuy_w6qsdWLeqQFWqVA',
#   'business_id': 'slx9qstc2U2Tc4s7dzbbBg',
#   'stars': 3.689655172413793},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': '0KjY3gmtqQjc4sK-uG-6fQ',
#   'stars': 4.062937062937063},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': 'Y9kXVlU4xPfSZvkZH6C_2Q',
#   'stars': 3.933333333333333},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': 'ty5KQYqYRxwXDG_e4pz-4w',
#   'stars': 4.519774011299435},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': 'KskYqH1Bi7Z_61pH6Om8pg',
#   'stars': 4.138134592680047},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': 'wuQDMDlqM17jQNo0lYQZ7g',
#   'stars': 3.779935275080906},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': 'xk-fOf_M39kDTgzfVgu0Tw',
#   'stars': 3.761904761904762},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': 't33qVzQ6AdSiq4lnI0KOyg',
#   'stars': 4.426229508196721},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.139344262295082},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': '7vHvQCjPq5pWj7Rio1A--w',
#   'stars': 3.9105263157894736},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': '3IwCop28R1_L5jMv6AkL8Q',
#   'stars': 3.872093023255814},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': '7JWWeXqil03Ua_wV9KN8ZQ',
#   'stars': 3.6296296296296298},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': 'BN9ZBXKBvtPdG3sujNSWSw',
#   'stars': 3.888888888888889},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': 'xowy4YxBXXGOYuajsxjwkA',
#   'stars': 4.75},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': '61eY5QRISGo8SZOmgU2p5A',
#   'stars': 3.923076923076923},
#  {'user_id': '3J6CA09CCIAN4MlHwCcsXw',
#   'business_id': '2s2ww6WaulfOEI16s1uyDg',
#   'stars': 4.119205298013245},
#  {'user_id': 'Oz8Bp1NY-Szz4lvSbVsV4Q',
#   'business_id': 'LJQCv30PCIpC3FnvHF5mXQ',
#   'stars': 3.707692307692308},
#  {'user_id': 'Oz8Bp1NY-Szz4lvSbVsV4Q',
#   'business_id': 'e13SEvJud_vgeDR_doL4sQ',
#   'stars': 3.5436241610738257},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': '0AQnRQw34IQW9-1gJkYnMA',
#   'stars': 3.0935960591133007},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': 'VKmGedwOk-16D7OawNg_ng',
#   'stars': 3.062015503875969},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': 'czyhvf93Txsfxdxqcm16mA',
#   'stars': 3.8666666666666667},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': '9M6eqYZlyBMo8K9QztXcIA',
#   'stars': 3.739130434782609},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': 'FfG8twx5K18y268Gp4dSKA',
#   'stars': 2.9557522123893807},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': 'KmuLLSyZJdNoarwcIERHcw',
#   'stars': 4.136842105263158},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': 'dOGLTIMqqQZn8xxBRsU6CQ',
#   'stars': 3.6147540983606556},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': 'vYOtdnBm-45KQiiHj8jqaw',
#   'stars': 4.125827814569536},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': 'K7lWdNUhCbcnEvI0NhGewg',
#   'stars': 3.7328881469115194},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': 'ruWTngdiC68O9la27hvvHw',
#   'stars': 3.9673202614379086},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': 'S1N5-ZXwR4fUIPs6dLnBYQ',
#   'stars': 3.356589147286822},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': '9wxxjUKdaiWeK0fGxSYhzQ',
#   'stars': 3.1649484536082473},
#  {'user_id': '8NPnK5h5Te91Ot6nbX9a5g',
#   'business_id': '3_SA-8Y7geULcNHATYumEQ',
#   'stars': 4.2105263157894735},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'sb5Y5ECN7kEODrBk67dbrQ',
#   'stars': 4.6521739130434785},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'ItDjdi6mMczhgrt4DylWew',
#   'stars': 4.318181818181818},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'tMdgY7Ou4k3bYZZulJCiuQ',
#   'stars': 4.521978021978022},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'AyOKFrLeuFCp9CzGDB_qYw',
#   'stars': 3.7058823529411766},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'DY1_vls0_VQnTZ7CJ3AeFQ',
#   'stars': 3.032608695652174},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': '7RR1rbyEKKo2G-RACqAfoA',
#   'stars': 4.666666666666667},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'O7UMzd3i-Zk8dMeyY9ZwoA',
#   'stars': 4.64},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'gTw6PENNGl68ZPUpYWP50A',
#   'stars': 4.067415730337078},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'Qc0l8rZ3nvrcERitgxu8XA',
#   'stars': 4.166666666666667},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'oVTvVdJiaRAwBLy6HUxE8A',
#   'stars': 4.379310344827586},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'pyqnGlIfP9Zw8LLxBjyAiA',
#   'stars': 4.153284671532846},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'WuhUKJAoby57lLjVLpQVPw',
#   'stars': 3.619047619047619},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': '-qYuPncpK8elgD-6Qx3v7A',
#   'stars': 4.205882352941177},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'OFw59czUoeeosFMKfRawmg',
#   'stars': 3.3805970149253732},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'Wcuo6YmYj3xhCso5sMQcOw',
#   'stars': 4.371134020618556},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'jScBTQtdAt-8RshaiBEHgw',
#   'stars': 4.206666666666667},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': '6Ct57qgmXwOnzfSZoUGh0Q',
#   'stars': 3.3685714285714288},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'uBdYMY6a6A7FyxzTSwOiDg',
#   'stars': 4.16403785488959},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'Gen0ei06dGq13OJ8DRXUjg',
#   'stars': 3.8300653594771243},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'gqdqnFg2lYeSyS20q2ZK_Q',
#   'stars': 4.453658536585366},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': '3uC7Lbc3RgUDTWQlBu4PqQ',
#   'stars': 3.9411764705882355},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'KQoeETpQ1nBEQ6fVOtFgWQ',
#   'stars': 3.890909090909091},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'FMo1PJTUV5OpyiZlnTM1Rg',
#   'stars': 4.025316455696203},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'MVjkFLHNJmbQ-ZTd3QY3nQ',
#   'stars': 4.357142857142857},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'pk3C3zEvBWl8Pfby1HjvUw',
#   'stars': 3.4},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'UPIYuRaZvknINOd1w8kqRQ',
#   'stars': 4.064900662251656},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'A-uZAD4zP3rRxb44WUGV5w',
#   'stars': 4.624078624078624},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': '68jn0s0snbO5dhasLaVvDw',
#   'stars': 4.348837209302325},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'X91rjC4EkH_3ZGY3ciIs8Q',
#   'stars': 4.151785714285714},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'HnsGCps7TY3vnC7u4xVEew',
#   'stars': 3.65},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': '0LD904DOPU3T_asJGOTZyg',
#   'stars': 4.464285714285714},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'D6WXf0lB4pfuXZH3P7c5Ow',
#   'stars': 4.277777777777778},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'FaHADZARwnY4yvlvpnsfGA',
#   'stars': 3.601709401709402},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'NblDoJBEwhkJyvAuxzh4rg',
#   'stars': 4.010416666666667},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'sqRX-XLlhx4rs2c1TpBf8A',
#   'stars': 4.368831168831169},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'wWDQDPuuwQ5kFeT2a72b6Q',
#   'stars': 2.9382716049382718},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'kABF0hYfAEnl166mn1zR1A',
#   'stars': 3.811158798283262},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'QRbIBAnX-5LnKZsKrrObUg',
#   'stars': 3.4814814814814814},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'cOKf37Wb1oKc9X1Q5GHxsQ',
#   'stars': 4.612903225806452},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'wAKV6rA1QppMTS3-FXRTSA',
#   'stars': 4.455357142857143},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'aS1qJzTGyluRT2tJ09Jbaw',
#   'stars': 4.265486725663717},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'ygaOvp0PLBYaYeN9cZAlGg',
#   'stars': 4.254295532646048},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'GZifPY-KTnZQ9iYfGwT2wg',
#   'stars': 4.102564102564102},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'zpoZ6WyQUYff18-z4ZU1mA',
#   'stars': 4.513513513513513},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'IZivKqtHyz4-ts8KsnvMrA',
#   'stars': 4.210106382978723},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'MX2OYa2sS5ys_6AiK-gs3A',
#   'stars': 3.727272727272727},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'LNGBEEelQx4zbfWnlc66cw',
#   'stars': 4.033950617283951},
#  {'user_id': '_VMGbmIeK71rQGwOBWt_Kg',
#   'business_id': 'D6K3VT6S8FwFm4u5uN8T8g',
#   'stars': 4.128787878787879},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'Ec9CBmL3285XkeHaNp-bSQ',
#   'stars': 4.058558558558558},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'U0UnBjz9DugW2qRZputKBg',
#   'stars': 3.988095238095238},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'Dh6JsWOKQqIjuw4ZPnWkOg',
#   'stars': 3.966666666666667},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'rIeXMt92PLNjZbemWKRXcA',
#   'stars': 4.011764705882353},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'Izuc4hE7h053dLOHAW99OQ',
#   'stars': 4.324324324324325},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'MwCai0x6GILtK4KkwufZig',
#   'stars': 3.89247311827957},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'ZjdcfPbkBVtMnXm8jLSV_A',
#   'stars': 3.611111111111111},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'W8xPHUqL088jdcmNZyH-eA',
#   'stars': 3.8},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'OHFH6ALQqq35NiEbD1eXuw',
#   'stars': 3.4846938775510203},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'D1BrHyiZON7u_ef-qt4_Uw',
#   'stars': 3.8181818181818183},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': '_R76PYZqTRvw840SP6s5GA',
#   'stars': 3.8461538461538463},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'XnJeadLrlj9AZB8qSdIR2Q',
#   'stars': 4.52},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'R1PQEK6qvrZVC9qcWfKvDA',
#   'stars': 4.142857142857143},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'HykZIiaHS35N2c5_QHoClA',
#   'stars': 4.434782608695652},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'JyxHvtj-syke7m9rbza7mA',
#   'stars': 3.8442211055276383},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'ZW5ReCY3B9_TekUYWhr7HA',
#   'stars': 4.0},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'AtD6B83S4Mbmq0t7iDnUVA',
#   'stars': 4.340277777777778},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': '4tMzl8EslTx-rOCo9WjaUA',
#   'stars': 3.8181818181818183},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'bcJmbFHVAkLFqhJbUTdbyQ',
#   'stars': 4.141891891891892},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'MohTx0z3LnzAnr0bIsstHQ',
#   'stars': 4.03030303030303},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'RfyVHSYSTX_oWbv1nzONxg',
#   'stars': 4.285714285714286},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'NsnE3qKwwhSSLYRvKtFVrA',
#   'stars': 4.857142857142857},
#  {'user_id': 'gtwM4ijo65AN4DvXdgCu_w',
#   'business_id': 'tZqG8XeaVSY157QpqREuXw',
#   'stars': 4.555555555555555},
#  {'user_id': 'PUdifmlsaUMIfPlhQnZbHg',
#   'business_id': 'RNi6tW22UMgHwWLAb0mYdA',
#   'stars': 4.173228346456693},
#  {'user_id': 'PUdifmlsaUMIfPlhQnZbHg',
#   'business_id': 'qfj5Ih8-6RPF2ccvNGvCcg',
#   'stars': 3.622950819672131},
#  {'user_id': 'PUdifmlsaUMIfPlhQnZbHg',
#   'business_id': 'gBy6UXTpoSHhW6qd15XU0g',
#   'stars': 3.966666666666667},
#  {'user_id': 'ZjTzwlXBbg6-I4vtXTLHHQ',
#   'business_id': 'o7AiTlyWUrBSzdz6oMHj5w',
#   'stars': 2.8911917098445596},
#  {'user_id': '6VGY4RRd-najo6dQhL3mdw',
#   'business_id': 'OYHpqY6-3C-wXR-uPbHhwA',
#   'stars': 3.4754098360655736},
# ...
#   'stars': 3.947674418604651},
#  {'user_id': 'hem7ZHa4Mz_m4x0qIMCynA',
#   'business_id': 'fknU3sWplCBn26b6HwJ1kQ',
#   'stars': 3.76},
#  {'user_id': 'hem7ZHa4Mz_m4x0qIMCynA',
#   'business_id': 'KkmPDIWzvwbBpyqOHT6pcQ',
#   'stars': 3.7093023255813953},
#  {'user_id': 'hem7ZHa4Mz_m4x0qIMCynA',
#   'business_id': 'NvKNe9DnQavC9GstglcBJQ',
#   'stars': 3.82015503875969},
#  {'user_id': 'hem7ZHa4Mz_m4x0qIMCynA',
#   'business_id': 'J4CATH00YZrq8Bne2S4_cw',
#   'stars': 4.206751054852321},
#  {'user_id': 's_rK7Dda29Gy6clJ1TFNmQ',
#   'business_id': 'XZbuPXdyA0ZtTu3AzqtQhg',
#   'stars': 3.9560632688927946},
#  {'user_id': 's_rK7Dda29Gy6clJ1TFNmQ',
#   'business_id': 'ugLqbAvBdRDc-gS4hpslXw',
#   'stars': 3.868131868131868},
#  {'user_id': 's_rK7Dda29Gy6clJ1TFNmQ',
#   'business_id': 'I4Nr-MVc26qWr08-S3Q1ow',
#   'stars': 3.9176470588235293},
#  {'user_id': 's_rK7Dda29Gy6clJ1TFNmQ',
#   'business_id': 'N98tlF53bqiWZ72INWaFyg',
#   'stars': 3.8333333333333335},
#  {'user_id': '9nYGi-5vHUIUbr8t6cPX2w',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.198380566801619},
#  {'user_id': '9nYGi-5vHUIUbr8t6cPX2w',
#   'business_id': 'eoHdUeQDNgQ6WYEnP2aiRw',
#   'stars': 3.1775147928994083},
#  {'user_id': 'ovfFjvK_etNHZfX0CdwjhQ',
#   'business_id': '4qG3Gh8QyugC1XvoTlmgcQ',
#   'stars': 4.03765690376569},
#  {'user_id': 'ovfFjvK_etNHZfX0CdwjhQ',
#   'business_id': 'pHJu8tj3sI8eC5aIHLFEfQ',
#   'stars': 4.016260162601626},
#  {'user_id': 'ovfFjvK_etNHZfX0CdwjhQ',
#   'business_id': 'h5a8aJ_Pd71JzUGFA-IaAg',
#   'stars': 3.723684210526316},
#  {'user_id': 'ovfFjvK_etNHZfX0CdwjhQ',
#   'business_id': 'e7N0AW-sKkJmRIpEovxBAg',
#   'stars': 3.7567567567567566},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'ym5FOqL6tGbgynzwKMHZuw',
#   'stars': 3.335294117647059},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'Gt4z3AylNTsEPDkzkaC7HA',
#   'stars': 3.477815699658703},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'hYX0z2C6Th5XmcrKOP31fQ',
#   'stars': 3.817073170731707},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'g8OnV26ywJlZpezdBnOWUQ',
#   'stars': 3.694275274056029},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'VzUo-RURV3VnfNItAYM8yg',
#   'stars': 3.8703703703703702},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'tA5mqEP68qjbTFK9c14D7A',
#   'stars': 4.0},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'WCFz9KVJTtIXSVvD5NMYoQ',
#   'stars': 3.902173913043478},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'jxbEwtV8Et1lm8ubk4AGuw',
#   'stars': 4.282828282828283},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'uh7DUWtPoZkuEE05fghJ_w',
#   'stars': 4.09433962264151},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': '9yFqdZa0osahV6qjFJ_Saw',
#   'stars': 4.166666666666667},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'nUpz0YiBsOK7ff9k3vUJ3A',
#   'stars': 3.9493087557603688},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'I1gRYCt2exnOMsTr-lEJVA',
#   'stars': 4.2330827067669174},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': '7HIa2lYy5jgcZuADlRjKSg',
#   'stars': 2.75},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'JPfi__QJAaRzmfh5aOyFEw',
#   'stars': 4.292490118577075},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'W4sNI_ZMvgzN9vwUNu4ViA',
#   'stars': 4.081081081081081},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'l8LYK3kqDBrqgVyvd2MoHQ',
#   'stars': 4.232142857142857},
#  {'user_id': 'fVILhIglx6RNOXQba5t4kQ',
#   'business_id': 'F5uXN5v-GHBSewbCoipGyg',
#   'stars': 3.7},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': '6GzwaQeb3brmyBucng_WPg',
#   'stars': 4.041237113402062},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': 'eEnNw3_hBvxcFHyr23kAuA',
#   'stars': 3.522598870056497},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': 'XXW_OFaYQkkGOGniujZFHg',
#   'stars': 3.945130315500686},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': '3GEEy7RP6e4bT4LAiWFMFQ',
#   'stars': 4.089630931458699},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': 'lsLelczQjIZLHVt2-e44lA',
#   'stars': 3.125},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': 'DXlDzOcpdUE_F21tok0fgw',
#   'stars': 4.082405345211582},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': 'CMN3KmB5SEfONN00s2nEeQ',
#   'stars': 2.0977443609022557},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': '8mIrX_LrOnAqWsB5JrOojQ',
#   'stars': 4.51830985915493},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': 'DxgSVufr_6y_Rc63CC17Zg',
#   'stars': 4.127586206896551},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': 'K7fip0nDFFdCC7OCnNOotQ',
#   'stars': 3.6666666666666665},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': 'VMXl3Dm1Nwvgwo1PVYTXbg',
#   'stars': 3.8898678414096914},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': '4X0KWUPcD2EkHN83aa4cXg',
#   'stars': 2.942528735632184},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': '2aoKv8DjAeVBjTT9O9sx5g',
#   'stars': 4.078125},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': 'xTOX8D1Tavoi9vPWL-nWdQ',
#   'stars': 3.395209580838323},
#  {'user_id': '_vy7K2Q9X8p7Jl1OkY_JOQ',
#   'business_id': 'L9hxsakFxY315yPqCZL-zQ',
#   'stars': 3.1052631578947367},
#  {'user_id': '1Hhz6FGgvi9qd1q6PR0AEA',
#   'business_id': '5iSlHNIy3RLbCP5AayB31g',
#   'stars': 3.6153846153846154},
#  {'user_id': '1Hhz6FGgvi9qd1q6PR0AEA',
#   'business_id': 'UPIYuRaZvknINOd1w8kqRQ',
#   'stars': 4.064900662251656},
#  {'user_id': '1Hhz6FGgvi9qd1q6PR0AEA',
#   'business_id': 'z0rSmZQz9eEXjg_C3_E5-g',
#   'stars': 3.9568345323741005},
#  {'user_id': '1Hhz6FGgvi9qd1q6PR0AEA',
#   'business_id': 'qKn9nynsVYIST8rf6tEFRQ',
#   'stars': 3.806451612903226},
#  {'user_id': '1Hhz6FGgvi9qd1q6PR0AEA',
#   'business_id': 'Wg9272hxpu9IBTXMTB6EeQ',
#   'stars': 3.0375},
#  {'user_id': '1Hhz6FGgvi9qd1q6PR0AEA',
#   'business_id': 'SVGApDPNdpFlEjwRQThCxA',
#   'stars': 4.520661157024794},
#  {'user_id': '1Hhz6FGgvi9qd1q6PR0AEA',
#   'business_id': 'VWtT4DKxQ4YVRWT88Z5SMA',
#   'stars': 3.8732394366197185},
#  {'user_id': '1Hhz6FGgvi9qd1q6PR0AEA',
#   'business_id': 'rYWbCTwJV14BvcOhHlcD5A',
#   'stars': 3.0},
#  {'user_id': '8eQ7LmOK6KeSRXq_o8KaAw',
#   'business_id': 'XZbuPXdyA0ZtTu3AzqtQhg',
#   'stars': 3.9560632688927946},
#  {'user_id': '8eQ7LmOK6KeSRXq_o8KaAw',
#   'business_id': 'ECOkEVUodMLUxvI0PMI4gQ',
#   'stars': 3.296577946768061},
#  {'user_id': 'r2R9t9_0Je8wP-wh4-xM3w',
#   'business_id': 'WRQ-9LluyivReFiQZFUujw',
#   'stars': 4.212624584717608},
#  {'user_id': 'r2R9t9_0Je8wP-wh4-xM3w',
#   'business_id': '0XEqyl_lVaJNHRKxNcjJZg',
#   'stars': 4.072916666666667},
#  {'user_id': 'r2R9t9_0Je8wP-wh4-xM3w',
#   'business_id': 'a0v7Si0DK4cIko7AQY4YXg',
#   'stars': 3.992619926199262},
#  {'user_id': 'r2R9t9_0Je8wP-wh4-xM3w',
#   'business_id': 'sDT7CvVLsPG1JizVddhxzg',
#   'stars': 3.79375},
#  {'user_id': 'r2R9t9_0Je8wP-wh4-xM3w',
#   'business_id': 'QNHmtZSfFEyIvuKe73DzMA',
#   'stars': 4.689655172413793},
#  {'user_id': 'r2R9t9_0Je8wP-wh4-xM3w',
#   'business_id': 'KcCEAft-n9JiKPgad7y2lg',
#   'stars': 5.0},
#  {'user_id': 'TitajCNNiQAnH_3VTp7gtQ',
#   'business_id': '7tNY4BYLA4laqWNV4IWGQg',
#   'stars': 4.256830601092896},
#  {'user_id': 'TitajCNNiQAnH_3VTp7gtQ',
#   'business_id': 'qqs7LP4TXAoOrSlaKRfz3A',
#   'stars': 4.2465753424657535},
#  {'user_id': 'TitajCNNiQAnH_3VTp7gtQ',
#   'business_id': 'AJvGLW8_B5zCE8huCkPNGw',
#   'stars': 4.538461538461538},
#  {'user_id': 'F9r9fv9Zf0mt3D8QaX3_nQ',
#   'business_id': 'Cr4ipI-tr-R8Q0NilkWNkA',
#   'stars': 3.8465346534653464},
#  {'user_id': 'F9r9fv9Zf0mt3D8QaX3_nQ',
#   'business_id': 'zlpLjbwrKuNs8zROgB_qUQ',
#   'stars': 3.2335329341317367},
#  {'user_id': 'F9r9fv9Zf0mt3D8QaX3_nQ',
#   'business_id': 'vIr0LbBNDTB0HV0DZrnk6A',
#   'stars': 3.4864864864864864},
#  {'user_id': 'F9r9fv9Zf0mt3D8QaX3_nQ',
#   'business_id': 'EkuSy_kM8dpGrlb2pTxCBw',
#   'stars': 3.3658536585365852},
#  {'user_id': 'F9r9fv9Zf0mt3D8QaX3_nQ',
#   'business_id': 'W7UxnVfXdUFm5OlJz0KBhw',
#   'stars': 3.75},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': 'VmVTDmlLZdwoRVTJO4niaQ',
#   'stars': 3.7},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': 'UNI1agsPX2k3eJSJVB91nw',
#   'stars': 4.079002079002079},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': 'HUWLnKD5LSZY134amUO2Rg',
#   'stars': 4.033333333333333},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': '41b2SLmjLcxTGLVRxASiDA',
#   'stars': 3.7777777777777777},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': 'GTR39A2jwNIS_NV8q2r_JA',
#   'stars': 3.83739837398374},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': 'vstifTjwsVFXc1aprX9_iQ',
#   'stars': 4.085714285714285},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': 'TCWMgOiV0PxQkWE1SyBIWQ',
#   'stars': 4.011111111111111},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': 'IJUCRd5v-XLkcGrKjb8IfA',
#   'stars': 3.794392523364486},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': 'eJCDUkFa7wl-BHYKZzaTMQ',
#   'stars': 3.575},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': 'UAEoomKQwpiFhaJSzrboQA',
#   'stars': 4.027027027027027},
#  {'user_id': 'xU4silHWZGOWz92hPIdFpQ',
#   'business_id': 'c5TOGBUCCUUNBPM7h_KbmQ',
#   'stars': 3.711864406779661},
#  {'user_id': 'lXG7Mbhi6_nXaTZojpneUg',
#   'business_id': '_w5hBpkjHs5_Hv3pLeHtIw',
#   'stars': 3.814917127071823},
#  {'user_id': 'lXG7Mbhi6_nXaTZojpneUg',
#   'business_id': '364hhL5st0LV16UcBHRJ3A',
#   'stars': 4.301652892561983},
#  {'user_id': 'lXG7Mbhi6_nXaTZojpneUg',
#   'business_id': 'UPIYuRaZvknINOd1w8kqRQ',
#   'stars': 4.064900662251656},
#  {'user_id': 'lXG7Mbhi6_nXaTZojpneUg',
#   'business_id': 'kICgNgVRkIh4doz0atyMMA',
#   'stars': 4.059523809523809},
#  {'user_id': 'DKm7CyodCUrOO_v3IScDvA',
#   'business_id': 'g8OnV26ywJlZpezdBnOWUQ',
#   'stars': 3.694275274056029},
#  {'user_id': '_8g1fuUaePfZ8CcrAceuqg',
#   'business_id': 'ujHiaprwCQ5ewziu0Vi9rw',
#   'stars': 3.6257982120051087},
#  {'user_id': '_8g1fuUaePfZ8CcrAceuqg',
#   'business_id': 'ZQ4iaZ-9952plCoDEryMjA',
#   'stars': 3.3333333333333335},
#  {'user_id': 'XfHOhgHWjLwh80qvA94Dsg',
#   'business_id': '7SJoMX5ti-VoEsEW6mJLRA',
#   'stars': 4.408805031446541},
#  {'user_id': 'AQRqMBHwZd_hDBxnTshmKA',
#   'business_id': 'eLFfWcdb7VkqNyTONksHiQ',
#   'stars': 3.7715617715617715},
#  {'user_id': 'AQRqMBHwZd_hDBxnTshmKA',
#   'business_id': 'jBhOVAEdnzCJvgSnvA4UDw',
#   'stars': 4.040697674418604},
#  {'user_id': 'AQRqMBHwZd_hDBxnTshmKA',
#   'business_id': '07AZL5XenCQ_-op_onKLdw',
#   'stars': 4.172413793103448},
#  {'user_id': 'AQRqMBHwZd_hDBxnTshmKA',
#   'business_id': 'wpkmz67yw3oyXc0ykIslNw',
#   'stars': 4.3125},
#  {'user_id': 'khXwaOAkgSaM1T3O_TCpKA',
#   'business_id': '4k3RlMAMd46DZ_JyZU0lMg',
#   'stars': 4.179203539823009},
#  {'user_id': 'khXwaOAkgSaM1T3O_TCpKA',
#   'business_id': 'f6CTsNX30XmC8siHWYV2bA',
#   'stars': 3.5179856115107913},
#  {'user_id': 'khXwaOAkgSaM1T3O_TCpKA',
#   'business_id': 'EdY6q0CO2mlATpoTFkvHAw',
#   'stars': 3.777027027027027},
#  {'user_id': 'khXwaOAkgSaM1T3O_TCpKA',
#   'business_id': 'MwCai0x6GILtK4KkwufZig',
#   'stars': 3.89247311827957},
#  {'user_id': 'khXwaOAkgSaM1T3O_TCpKA',
#   'business_id': 'jMrpr92nMEhe4cC4FF00VQ',
#   'stars': 4.21875},
#  {'user_id': 'khXwaOAkgSaM1T3O_TCpKA',
#   'business_id': 'w6l6uq95_-36unVjTaFIXw',
#   'stars': 5.0},
#  {'user_id': 'G8Eyf9zTP6lI7dx5wL64zw',
#   'business_id': 'eoyvbnRYQe-z85e8Rc6vAg',
#   'stars': 3.900900900900901},
#  {'user_id': 'G8Eyf9zTP6lI7dx5wL64zw',
#   'business_id': 'aKcqKNcbwNydCBnvAA4TeQ',
#   'stars': 3.6384615384615384},
#  {'user_id': 'aqWXHhcR_CdmKmxggFOlEA',
#   'business_id': '5LNZ67Yw9RD6nf4_UhXOjw',
#   'stars': 4.1746411483253585},
#  {'user_id': 'dbPErDhuH1dfO1k8me3XBQ',
#   'business_id': 'zRqi6L1u-YmmVAHjeUbGMQ',
#   'stars': 4.234866828087167},
#  {'user_id': 'dbPErDhuH1dfO1k8me3XBQ',
#   'business_id': 'sOYsxYYFl03PhHmz_rBDZQ',
#   'stars': 3.9491525423728815},
#  {'user_id': 'dbPErDhuH1dfO1k8me3XBQ',
#   'business_id': '73oP6zoYZKNlO8642EMD_Q',
#   'stars': 3.765957446808511},
#  {'user_id': 'F4dfncYAZdlJw-YTEHEi6A',
#   'business_id': 'ZkGDCVKSdf8m76cnnalL-A',
#   'stars': 3.2263374485596708},
#  {'user_id': 'Tz7sOM6PYX2BgRM5hP0dQw',
#   'business_id': 'DbEszO3wk1xVmN3pCPob2g',
#   'stars': 4.041800643086817},
#  {'user_id': 'Tz7sOM6PYX2BgRM5hP0dQw',
#   'business_id': 'hHe1mFDxxrtejXHfiysJJg',
#   'stars': 4.049180327868853},
#  {'user_id': 'Tz7sOM6PYX2BgRM5hP0dQw',
#   'business_id': 'cd0exBNvw7LcezbQqt9wlQ',
#   'stars': 4.2727272727272725},
#  {'user_id': 'Tz7sOM6PYX2BgRM5hP0dQw',
#   'business_id': 'UDs3bbFKFA5TfeFXJuPXxA',
#   'stars': 2.92},
#  {'user_id': 'Tz7sOM6PYX2BgRM5hP0dQw',
#   'business_id': 'RC24XhaFXlntFlYrYmn_Zg',
#   'stars': 3.2142857142857144},
#  {'user_id': 'g1_M-7uw6KSGx747Uz16AA',
#   'business_id': 'B89xU39A243rNNoQpcCKYA',
#   'stars': 4.3875},
#  {'user_id': 'g1_M-7uw6KSGx747Uz16AA',
#   'business_id': 'jxbEwtV8Et1lm8ubk4AGuw',
#   'stars': 4.282828282828283},
#  {'user_id': 'GazHAcJxomM2sHm0hf86jw',
#   'business_id': 'Jt28TYWanzKrJYYr0Tf1MQ',
#   'stars': 3.295918367346939},
#  {'user_id': 'GazHAcJxomM2sHm0hf86jw',
#   'business_id': 'g83WbX_recywc4DEIZ-xug',
#   'stars': 4.371900826446281},
#  {'user_id': 'GazHAcJxomM2sHm0hf86jw',
#   'business_id': 'eJKnymd0BywNPrJw1IuXVw',
#   'stars': 3.7205882352941178},
#  {'user_id': 'GazHAcJxomM2sHm0hf86jw',
#   'business_id': 'FaHADZARwnY4yvlvpnsfGA',
#   'stars': 3.601709401709402},
#  {'user_id': 'GazHAcJxomM2sHm0hf86jw',
#   'business_id': 'wX1ORSDKPkA5ftE7F6UONw',
#   'stars': 4.228187919463087},
#  {'user_id': 'GazHAcJxomM2sHm0hf86jw',
#   'business_id': '3GEEy7RP6e4bT4LAiWFMFQ',
#   'stars': 4.089630931458699},
#  {'user_id': 'GazHAcJxomM2sHm0hf86jw',
#   'business_id': 'AjWFFZN8KwyqJzzi0DyEsw',
#   'stars': 3.475},
#  {'user_id': 'GazHAcJxomM2sHm0hf86jw',
#   'business_id': 'QJR4qBUHegWEozSQrGmBPw',
#   'stars': 3.863905325443787},
#  {'user_id': 'GazHAcJxomM2sHm0hf86jw',
#   'business_id': 'fwuvm9wWcvFwpQXzcneaDQ',
#   'stars': 4.666666666666667},
#  {'user_id': 'GF-UBIwA0gEcUbAkve6s3A',
#   'business_id': 'kpZjgADHSklBk3JqcO4b4Q',
#   'stars': 3.9411764705882355},
#  {'user_id': 'GF-UBIwA0gEcUbAkve6s3A',
#   'business_id': 'BBJ6Y9Kb2-luoBFBfc8o9w',
#   'stars': 3.41025641025641},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': '-FtngCwHCD2tRlH8jpj_Ag',
#   'stars': 3.2568306010928962},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': 'lKOvx_aAXiXQGooZ-4bq9Q',
#   'stars': 3.8115942028985508},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': 'Hqs4YNST_ZHbshwyi4bnsQ',
#   'stars': 4.321782178217822},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': '2vL6xxAxRhJS7LabjjDyhw',
#   'stars': 4.708860759493671},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': 'ruWTngdiC68O9la27hvvHw',
#   'stars': 3.9673202614379086},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': 'RESDUcs7fIiihp38-d6_6g',
#   'stars': 3.9086614173228345},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': '9p-cpmHaga-EXyc6ZzYCcQ',
#   'stars': 4.448818897637795},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': 'yj8lfLr9fn9g_0nqHluLRQ',
#   'stars': 3.8513513513513513},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': 'igHYkXZMLAc9UdV5VnR_AA',
#   'stars': 4.351851851851852},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': 'YILyHegzhy1vlc_LNVfObw',
#   'stars': 3.99375},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': '5LNZ67Yw9RD6nf4_UhXOjw',
#   'stars': 4.1746411483253585},
#  {'user_id': 'XnuuGtEl7E8syck0QhjO3w',
#   'business_id': 'uBdYMY6a6A7FyxzTSwOiDg',
#   'stars': 4.16403785488959},
#  {'user_id': 'wxDM6hqyW5OPp5cXzn6F0w',
#   'business_id': 'z0rSmZQz9eEXjg_C3_E5-g',
#   'stars': 3.9568345323741005},
#  {'user_id': 'wxDM6hqyW5OPp5cXzn6F0w',
#   'business_id': 'GMrwDXRlAZU2zj5nH6l4vQ',
#   'stars': 3.7012987012987013},
#  {'user_id': 'NXaIkd4sEMDiXlfHOJkO8Q',
#   'business_id': 'N6BDiFk2CyJTMPGUlcOfAg',
#   'stars': 3.7413793103448274},
#  {'user_id': 'NXaIkd4sEMDiXlfHOJkO8Q',
#   'business_id': '2rvBPUBtQU0WfcOAHLQWRQ',
#   'stars': 3.88},
#  {'user_id': 'NXaIkd4sEMDiXlfHOJkO8Q',
#   'business_id': 'DYAorbxOyubUB_wtQRCdug',
#   'stars': 3.7906137184115525},
#  {'user_id': 'NXaIkd4sEMDiXlfHOJkO8Q',
#   'business_id': 'p4JsD_Ya0NRXNdnhbVBs0A',
#   'stars': 3.5675675675675675},
#  {'user_id': 'ALi-f4sN83HdCDDfwSxf6w',
#   'business_id': 'I01C9Xg_SVyMrQSGIGeQ-g',
#   'stars': 3.9},
#  ...]

# %% [markdown]
# # user based

# %%
# load model from memory
model = sc.textFile('task3user.model') \
    .map(json.loads)

# get model keys
keys = list(model.first().keys())

# collect final model as similarity pairs
model = model \
    .map(lambda x: (tuple(sorted([user_tokens_dict[x[keys[0]]], user_tokens_dict[x[keys[1]]]])), x[keys[2]])) \
    .collectAsMap()

# %%
model[(646, 22764)]
# Out:
# 0.5000000000000001

# %%
# business and list of user and respective user ratings
business_user_rating_sets = train_user_business_rating_sets_tokenized \
    .map(lambda x: (x[1], (x[0], x[2]))) \
    .groupByKey() \
    .map(lambda x: (x[0], [(user_rating[0], user_rating[1]) for user_rating in list(set(x[1]))]))

# %%
business_user_rating_sets.first()
# Out:
# (9422,
#  [(21588, 5.0),
#   (22117, 4.0),
#   (4688, 5.0),
#   (8656, 4.0),
#   (6350, 4.0),
#   (18872, 5.0),
#   (16698, 2.0),
#   (18156, 5.0),
#   (23537, 2.0),
#   (7244, 5.0),
#   (25246, 5.0),
#   (1720, 1.0),
#   (15508, 4.0),
#   (3338, 2.0)])

# %%
# dictionary of average ratings for each user from the given file
user_average_ratings = sc.textFile('asnlib/publicdata/user_avg.json') \
    .map(json.loads)\
    .map(lambda x: dict(x))\
    .flatMap(lambda x: x.items()) \
    .collectAsMap()
# user_average_ratings = user_average_ratings[0]

# %%
user_average_ratings
# Out:
# {'OLR4DvqFxCKLOEHqfAxpqQ': 3.5952380952380953,
#  '0XMLbsJt-fvcQsOHt3_B_Q': 4.555555555555555,
#  'bQCHF5rn5lMI9c5kEwCaNA': 3.6818181818181817,
#  '-gQm-IoK2_BMEMx9OgtQnw': 3.8484848484848486,
#  'S6x7z26X_HdmdxwkmujlEg': 3.9583333333333335,
#  'b1wjZL3EBm4h2vbeXjfcTA': 4.2105263157894735,
#  'PKEzKWv_FktMm2mGPjwd0Q': 3.6078224101479917,
#  'txu_KwZOGYG6O3yYHjztbg': 3.2413793103448274,
#  'n_a826hPtfMFnucaVwnqIg': 3.6444444444444444,
#  'evS0cCehNU_EiDiD3286Jw': 3.7209302325581395,
#  '8drMKNHWavs2g6uf0pLtvg': 3.588888888888889,
#  'CNaaizAUc2c4WIb1M3BBPw': 3.8587570621468927,
#  'tEy1MNP7tHJlZgP7xqF4yA': 3.2142857142857144,
#  'JQIZhoQB-Tg9hdBEj90m4g': 3.9740259740259742,
#  'fiGqQ7pIGKyZ9G0RqWLMpg': 3.9763779527559056,
#  'bvPS4vrfiO7ZZ4KAo8KBTw': 3.838235294117647,
#  'FAjCZoxiGw9HJKueB8YWTg': 4.133333333333334,
#  '7vFWz2YcWWC5UnPYNm7KNA': 4.470588235294118,
#  'XYk552OWzrYviwebRCgEJA': 3.466666666666667,
#  'Dw36lKvjYEfa6BDgeMs61Q': 3.909090909090909,
#  'D1OMbUi-jYVnvJ8gZ2LXHQ': 4.884615384615385,
#  'Spgm6HFWgc4YXJlbhg11Pg': 3.5517241379310347,
#  'VTbkwu0nGwtD6xiIdtD00Q': 3.8857142857142857,
#  'C4Q8HL0pDMUTj5ioWeEsjQ': 3.8823529411764706,
#  'RCgfxH5PclsgSKRWDGJ86A': 3.913793103448276,
#  '14UnRoEiLipkKZyQTmTfWw': 3.769230769230769,
#  'HixtBO7z5OW5bo_6qo6D_g': 3.7222222222222223,
#  'xBCz3eCraehERyQdQ2ESsg': 4.611111111111111,
#  'mlaf-HDu-XsyqZbrH6ci8A': 4.0,
#  'S9Du2m57nou0kusygVZNyA': 4.052631578947368,
#  'pzMvoRhpuwwC3jHZtZSCeg': 3.8,
#  'eOVpEtSR8inu0TCmwmeNgw': 3.769230769230769,
#  '06o1DmiBoiyxI2q3v2QRbg': 4.418918918918919,
#  'EeNxafbMAJg7m4mIe1h95A': 3.6666666666666665,
#  '0nOIH8qIMnmZdLCTemnRsw': 4.145833333333333,
#  'ELfzWgdf64VBLi5z1ECItw': 3.4017094017094016,
#  'FOoN3DJzDUnl4EAQaTJIGg': 3.6796875,
#  'cnab2lH02dtnFeh-eQP-sg': 4.5,
#  'rR_ELUZj2gJusWingVi4WQ': 4.642857142857143,
#  'brt4G_5syXSGBLoiZE6lsQ': 2.909090909090909,
#  'bVTu2_lx2j8G8SJZDMDO8g': 3.769230769230769,
#  'bEZjkjMe1HDWjec-R5O8bw': 3.85,
#  '-AGXyI_K8StzQ7CGehQ2tQ': 4.017241379310345,
#  'rYPjqZO89ABei1fsZBSUbA': 4.031914893617022,
#  'c-zLdUAfhgMvw57ATblheg': 4.6521739130434785,
#  'gthdAFBTwFeOrPZQKnlvUg': 3.5714285714285716,
#  '7YWkpjUb-YWbfpN7d7sRqg': 4.8,
#  'y3FcL4bLy0eLlkb0SDPnBQ': 3.8856502242152464,
#  'Q1MSqlemsO43eKL_gjiAFA': 4.882352941176471,
#  'zgFpxIm2_I86lhtHOdmjsQ': 3.6226415094339623,
#  'HmrLyqR8skk7ReB2vwJ4HQ': 4.2272727272727275,
#  'sDlRFzGHzfpFHaxvJ1JtTg': 3.4246575342465753,
#  'HXOfPXPMvdXNpQ_l0RRjKw': 4.428571428571429,
#  'keBv05MsMFBd0Hu98vXThQ': 4.818965517241379,
#  'peuxbSQwXed-81cSqL7Ykw': 4.0,
#  'mX84lBw8jwS2uQqdgKu_aA': 4.147058823529412,
#  'w-_md1Qslb7r6098SHydlg': 3.9523809523809526,
#  'EW2So0HMefCyxC8S3Lt2pw': 4.111111111111111,
#  'lQCY0csLfjdDn6cdVq43UA': 4.042735042735043,
#  '-7dBCLn5LWYB_6qsdPLadQ': 3.2,
#  '9yaA8hGIxFubvf1XbL9h9A': 4.225806451612903,
#  '0vcevXgdQ5qOZyBI9uyHNQ': 4.466666666666667,
#  '1he_r7kQnK5MXOYqXD-Gkg': 4.606060606060606,
#  'oknzpMgHOnbijayveG-PKQ': 3.574468085106383,
#  'WpLDTv1dx5419PDHI1VpeQ': 3.857142857142857,
#  'WzgAFIonfQZpArNuqrHYkQ': 3.35,
#  '1uO7nwlNX3PRmdN7mxZ-PA': 3.508771929824561,
#  '8cFJbEX-c7O8YwaWECk2eQ': 4.571428571428571,
#  'QzXS25_FwIUrYTyDMZkUQA': 3.878787878787879,
#  'fsToOBLT0QvreGObauMCjA': 4.038461538461538,
#  'bWavcIJp3L3aTCH82y6bRA': 3.8125,
#  'o5R_ih-TpP1l8rsL4j7PHQ': 3.5,
#  'JbKLNv9jW9BK0IiHcmZQZQ': 3.6785714285714284,
#  'efBcJ56cdUZqHCS1fv0Hvw': 3.4,
#  '7RGTzYE960tWRWoPJBVa3w': 4.909090909090909,
#  'WKPG2IvcLFB9SA7MERCzUQ': 3.217391304347826,
#  'wkrFqNxwTEEkG3mJV88Izw': 3.675,
#  '1M7qbeQoL8O5r_cUVEuKEw': 3.943396226415094,
#  'Mfmx6DSGOrJjr4jeWmqCuw': 4.32258064516129,
#  '_WwIIa9GpoGZQHS5v853KA': 4.071428571428571,
#  'BqAu7D5qHMQsrlRW8bRl-w': 4.181818181818182,
#  'FgyvflZtqRF03j5bIrlnlA': 2.825174825174825,
#  'gczcslKnGPvJ5xcGUThWVw': 4.666666666666667,
#  'qRU7nYMJIV05lpKQq4jVjw': 2.473684210526316,
#  'NAd6QWoKzSMVcDRKUM4iBw': 4.333333333333333,
#  'M4tyqwsqBRXKAasRrFAD7w': 3.5043478260869567,
#  'd976WkRYJVqJyP3vH2Kayg': 3.727272727272727,
#  'JHFuMHQBLuQ3TtkWwx1bmQ': 3.672727272727273,
#  'QoBW_ZoUpHYISTiIzFIJeQ': 4.0,
#  'rTIVsxvTEm5b94C2th5xQQ': 2.902439024390244,
#  '2WzeDz2CObN9Xfh67UoftA': 3.7777777777777777,
#  '7QXtasoVTQJuEjbmbLsDGA': 3.8805970149253732,
#  'Wi0VgIrbb8vqU6weyVw6tg': 4.086956521739131,
#  '8DEyKVyplnOcSKx39vatbg': 3.8356940509915014,
#  'DsVnd4PH2nkbxo8UeGW3Mw': 4.222222222222222,
#  'pETFbaIvYoOWl1-sSUex6w': 4.3,
#  'rKkpHJkJ27xOwnhy_bMkvA': 3.5852842809364547,
#  'foI26DVq1aI0E-DYWzXeSQ': 2.966666666666667,
#  'pb4r35GQnVCsfM8My6IHJw': 4.0,
#  'Os_u1VHoESbCIHmHclF0CQ': 4.75,
#  'zqeOwIpO1a2IUXkU8s1oyg': 3.6923076923076925,
#  'o2Or6xqxeWaE46tdzK0UGg': 3.34375,
#  'zzMJLd3cWBM6HT8eMbOGbA': 2.727272727272727,
#  'ZRnsUs9q6DbeJbOLjCY4ZA': 4.318181818181818,
#  'RqFZ2BrldMOs6faJBq7jQA': 3.9,
#  'Z8pXinJSRSfjciAaP4M-ag': 4.0625,
#  'v5dxjxKLuINf5E6_kYckXg': 3.875,
#  'mLJ3zQwiEzAIBaXb-7iXBw': 3.46,
#  'NSAVRghckESCnwCKV2hITQ': 3.875,
#  '09Jn_afJxwZ20eukds1nxA': 3.2666666666666666,
#  'UpdXvltvfyTwlJnhOm-B0g': 3.5454545454545454,
#  'Xe3pWGZURKCVYo8AxS4ggA': 4.75,
#  'loOoIBFpGbkx8WaIpQndiA': 3.773913043478261,
#  '-C7dUrRVniKxQxH3a0mzgQ': 3.066666666666667,
#  'PQ6-FZpUn2oFLyBGvdiG3w': 3.5454545454545454,
#  '42xgrLr84qgmPsSQ1N_ICA': 3.857142857142857,
#  'CLqLwpRLY0KcalvgmWJ6Zg': 4.769230769230769,
#  'liDy_VOjCGwHeN1t5HT6bg': 3.5789473684210527,
#  'SLOQ-fNEbDLVya3O345Fog': 4.777777777777778,
#  'xRpAEg0M0azAPuKVg7WtgA': 3.393939393939394,
#  'Kr8GVDf5UupHTozB0em_fg': 3.8518518518518516,
#  'gmM7maEZA7FrV9XbGsThrQ': 3.96,
#  'OfKSNsVA70DXvQCEl30DKw': 3.0714285714285716,
#  'qygZCCfKpi0CNU3tq20ddg': 4.0,
#  '4E1WzSMDp46y__maH8SKMw': 3.238095238095238,
#  'D-ZyQ4iT1XRFkcOAWXnxCQ': 4.037974683544304,
#  'kWj6AdUtkvbzhdsqRifwLQ': 3.794701986754967,
#  'WaAOt_eG0_-yLpG3fI--3g': 3.565714285714286,
#  'zh7sSdnM3CefK8RBRWahZQ': 4.128205128205129,
#  'OtZfrVp36gfcY6fNd8lKGQ': 3.4516129032258065,
#  'W4Qg9-8PAojxB4oDpBMRTA': 3.6,
#  'u6LJK8nExHjYpFVcne0mpA': 4.111111111111111,
#  'bWTIMv6FKnkOEfxw7yR5jw': 3.380952380952381,
#  'VFiSo5T76-0Xp4oULkv-lQ': 3.9285714285714284,
#  'TSsEprcX7Df32FVbyQKNLg': 3.951219512195122,
#  'bMUllZks5Vo6ut6NdLRpWw': 4.875,
#  '1KTOdG4HltlP5GwGD3jJ-w': 2.892857142857143,
#  'uO4cnsITi_1N0zQmw1KYCw': 3.75,
#  '45VBwDLRS82qFon7pXlGDg': 4.666666666666667,
#  'ibvH1Y7Rh_tstiWgH0OFTA': 3.8620689655172415,
#  'tUShFCNl4Mb2-kJ5J__w0Q': 3.260869565217391,
#  '9teqovwDI0r7m1M-f5eq5w': 4.365853658536586,
#  '_ir8NHMtV7KPTwmBmlkmQw': 3.684931506849315,
#  'aPkFbCC9lCZsJoLaNeTY7A': 3.5,
#  '-C-l8EHSLXtZZVfUAUhsPA': 3.78,
#  '_fH4s3ls08eSl_PfX38KIA': 4.5,
#  '0gXtDaDscQPs8tp-gckMiA': 3.5454545454545454,
#  'oMFeTt2Ry4m2ZIcgKKqx0A': 4.673076923076923,
#  'CPoD0N3yUnxD6w9zUP9Rvg': 4.7272727272727275,
#  'HEvyblFw4I-UsMqgPGYY_Q': 3.2286821705426356,
#  'ZU6F9koaNP8yw81NUJb5Qg': 4.285714285714286,
#  'zR6gkXk4UVeyHEjJg-vGiQ': 3.7142857142857144,
#  'o-NyPP5v3xbGOPPUGmm4Xg': 2.6923076923076925,
#  'jpaBV6e6Sf3_CgvShteDSQ': 4.137931034482759,
#  'KCD6daAp293FoOUoTjT_YA': 3.50561797752809,
#  'VQHGS5qNZvuN2Y78zDA2KQ': 3.760869565217391,
#  'pZ6P_1V-bTSoYG1fg1TXzw': 3.981707317073171,
#  'hZfzVrhsCQ9JDAb2jYoJNQ': 3.5561959654178676,
#  'sL9dYZyNLpzLD3cfTWwyOQ': 4.046728971962617,
#  'QQAC9qyS9eQrdz1vDunkYw': 4.2727272727272725,
#  '9f6JDBTV4SBO8EZAnBq42Q': 3.0,
#  'WdD8hWn-NjSyDYoHqin_tQ': 4.253968253968254,
#  'TSMFB4bXjaEBdhQqIp8yGg': 3.5555555555555554,
#  'lg5f5JPxo6AjHz-EvW1hVQ': 4.333333333333333,
#  '7snUVhqLSTTuyBqtercSNg': 4.173913043478261,
#  'DTyZsQS0KbG8AZm4XmTORw': 4.285714285714286,
#  'QJI9OSEn6ujRCtrX06vs1w': 3.6267806267806266,
#  'DeVGAiOf2mHVUDfxvuhVlQ': 4.2181069958847734,
#  'MHCLwCG6bB7P6CmGhIyngw': 3.28,
#  'R7_bFyf6OFcySWj55WeuUA': 3.0,
#  'slazr8QlWY1Fuwrb3DJQ5Q': 3.142857142857143,
#  'XUH5KDiFbLRUk4G4re-jew': 3.4516129032258065,
#  'CZs1Eq7t1fqpXV1yox-CVg': 4.065693430656935,
#  'PhrU49E7XuWyAV_FEZrXWg': 3.6666666666666665,
#  'LR9E4bHOHnYnjLnUGYOV8A': 3.9,
#  'eZHCEjr5iJ1iiTm_snGZHQ': 4.148148148148148,
#  'Lvu9L4HuOCw00UIB4boqtw': 4.166666666666667,
#  'hilL60vuuh06sMxs6Ckkog': 3.5033557046979866,
#  'LTCxnnAQGaGZPHZx4KbvGA': 4.351648351648351,
#  'JumU1enAh-hYo0dYW43gUg': 3.8947368421052633,
#  '0HdTa-MiPaoeEfM8RK63kA': 3.5384615384615383,
#  'aZ2DKwGjjTfrGn4AOSI34w': 3.230769230769231,
#  '14D8NcXo_rgdkaO8WAgemA': 3.8181818181818183,
#  'j7Ew20Kh33lFEaUXW1rGNw': 3.7938144329896906,
#  'kIWV4qQQHz0jE5S7pmXR7g': 4.368421052631579,
#  'btk3ZCxMwLxVU5iQNJ8JNA': 3.6153846153846154,
#  'bCmSOZdTdYPHR7ONeNo3Bw': 4.2,
#  'eMOpOLfR1Zz5tfHUlzMp_w': 4.318181818181818,
#  'IoAWPFOjYUY-16q1mp-i1A': 4.090909090909091,
#  'TFfFBvt2GM7uj3LmLie_7w': 4.253968253968254,
#  'BTGQRGhvMNff9GD0Im59Qg': 4.016949152542373,
#  'SZVBKjtG-x0Rmb0TmkHCLw': 4.0588235294117645,
#  'XqsuWJIwdy0OXYvUX1I2-Q': 3.6363636363636362,
#  'w3O5oJH4svPOp3Brz350yA': 3.4615384615384617,
#  'EoWvfs7oWq3GZVDr7pghTA': 3.6666666666666665,
#  'dc-VNryDSdP2rUQltUNLhw': 4.7272727272727275,
#  'Jbd1x8jj3EgOkQMZ3RImKw': 3.75,
#  'sI8d5Usaa_2OzUj6cpvPUQ': 4.111111111111111,
#  'K2EV5TzIQRGn20WLpKLmcg': 3.2222222222222223,
#  'ZlgmfdzsNpa8zD6NmSrcVA': 3.375,
#  'yQiFb3kzronkldMDomOAWg': 3.7291666666666665,
#  'VZRxANvyTm2ixS6jYDGgEw': 3.58974358974359,
#  'G3L-DWwDiVUcXcKNo4LYNA': 4.083333333333333,
#  'sD6pnjnciK--3OSdM12FOA': 4.166666666666667,
#  'dW97nCS-BZQ3QUhsTtVuiw': 4.35,
#  'M2rcaIx3yYtMnOl1pyWzYA': 3.875,
#  'ANLSKvFmCgRMjxtELq70FQ': 3.970149253731343,
#  'AT_C6bbCRJFVvavYu7Ul1w': 4.625,
#  '009dH98iUAxqX6pGLP8fcw': 4.25,
#  'qmVXmbchh1V-PYSpvWU_rw': 3.90625,
#  'renPzRDqMZpMaHiCD_e1_A': 3.8199052132701423,
#  'A5A34ixb-yy6nwL42iZsnw': 3.794736842105263,
#  '0QnT-jtnkvHpm55RNZkRdw': 4.142857142857143,
#  'n86B7IkbU20AkxlFX_5aew': 3.709621993127148,
#  'doqjzWCz8eXnDh4gDh3o8A': 3.7058823529411766,
#  '5AChTpe8dWTVudOWKkKo0w': 3.857142857142857,
#  'wDc4RxHpfwB49EpNZu1jfg': 3.3333333333333335,
#  'xzmo4fTFundFCZVUxzxRKQ': 4.3,
#  '3rsZCoTmr8EM7DwtGm_RsQ': 3.150943396226415,
#  '7Oe6ikklTjVBbEFw9emLcA': 4.189910979228487,
#  '_5VyC9QOdtManMMLUeSusQ': 4.3076923076923075,
#  '6J5CwW4lqGMWJ-8ogwTWWw': 3.8125,
#  'TY7QgNKJEhvo1zCULlT9Rg': 3.75,
#  'C_DFGgxjfciqbOvlMLGTHQ': 4.418181818181818,
#  'JM0GL6Dx4EuZ1mprLk5Gyg': 3.739130434782609,
#  'rypcWiSNGM0suWsiSLh9xA': 4.175438596491228,
#  'frWrWdOAdHF3vgeZN4n1kA': 4.2,
#  'yJhYNXnLvDcg8Aap3I663Q': 4.153846153846154,
#  '3xmsld7B7blgGr4MGh0oiQ': 4.28,
#  'los0tmpSW5seBsBE1orrdg': 3.3076923076923075,
#  'ugNQV0isqQSAuuGzoK87sQ': 3.7870967741935484,
#  's5dm_bAbXdS7k8AceZjuAA': 3.909090909090909,
#  '67zOuDms6nAJDFXdOaJpyA': 3.6808510638297873,
#  '4I2W5ZQpm90z0oqva7qsbw': 3.9444444444444446,
#  'CmPjoba7N2ZSa3goSsSN6Q': 3.9473684210526314,
#  'bc8mJG5B-QWCOJPF4qn-0w': 4.636363636363637,
#  'lFcmHJTpCXLY_RtMQHS1BQ': 3.625,
#  'P_g8FIa-PYnCmm8qHTn3kw': 3.5675675675675675,
#  'DAIF6BwUEBCPqPvhNby9IQ': 3.3333333333333335,
#  '-kLhkJkl93Cgquwep6G4WA': 3.3333333333333335,
#  '8qsmYLq50FrvChuNrJbLEw': 4.3,
#  'VJHKjBELocrf5Eh-QxScLw': 3.4375,
#  '2Q96iowmMaWfibiWrsJiIw': 3.5555555555555554,
#  'Nhk0jTP2gkU12G4LHJVR3A': 4.2272727272727275,
#  'CXTEm80fN8V2k4FuD5ub1g': 3.814814814814815,
#  'ft8zU9vAMp4FkcxB43ysTA': 4.918918918918919,
#  '1-2Oed3A3J2lzLnRp12FWw': 3.36,
#  'A7cHIYhG0WQHv6ZtOVNLgA': 3.769230769230769,
#  'KavG2RBt77vRLqG1_6RBvQ': 3.0,
#  '4b6cHH3_mjTaMVt-VYVvow': 3.6153846153846154,
#  'FKyQWTe-yrm1tRTRveurkA': 3.5384615384615383,
#  'I6TRzTZs0azxssDpobWT4Q': 3.6842105263157894,
#  '-GbpqwAIvI01lGN51E_bfg': 2.888888888888889,
#  'D43OWyfzIQjL8feJpYh2SQ': 4.081218274111675,
#  '1ov32gHwnkj0jnBmrApvQw': 4.285714285714286,
#  'QDK3GMzAozVhTphX1RbWkg': 4.416666666666667,
#  'J2o_DNR1JFTTz86xICw7_g': 5.0,
#  '0JgjdJUgsMxh8U9-RWSomw': 4.0,
#  'rKWjWrJBqrx91SqhmsBM-w': 2.6666666666666665,
#  'L15JCA18Ib_vMUVJILxiSw': 3.4901960784313726,
#  '-kLwexA3byS8IV_3Yw-b6Q': 4.181818181818182,
#  'kmE8w5Y785eZmodsx0V6Ag': 3.810344827586207,
#  '-lh59ko3dxChBSZ9U7LfUw': 3.789473684210526,
#  'cQrnxjgVBhjAcOJttw48aw': 3.810810810810811,
#  'QuZbJquRtbY9O9JrB9NpxQ': 3.2962962962962963,
#  '3yFqq4CjHY39tiBHobMhfQ': 4.777777777777778,
#  '-qj9ouN0bzMXz1vfEslG-A': 3.6382978723404253,
#  'FMqXkkfaOAUQaNo8a5w20w': 3.111111111111111,
#  'rvVoA0LRk78csKFPxMHUNQ': 4.0625,
#  'px8P3jO0Jgr_Amwdvo-vuw': 4.857142857142857,
#  'D3N7SvN-jULaFLbDM1nGrw': 3.3333333333333335,
#  'l_fCnDWlT6UFLxwqguI_2g': 3.3793103448275863,
#  'kzTDJ4Vgzz_Hjix1YPi4Vw': 3.909090909090909,
#  '-4Oa4-j9-X-h21Lr4wr1EA': 4.2,
#  'CAU5cGUf5FpckKPL7WC4gw': 4.653061224489796,
#  'JCBBmqUxWeEX8Y0tmYgD8g': 4.234375,
#  'VLZJeBCDmNuZ5ZvraLuAOg': 3.44,
#  'hulIBBzPsCaQDcoh_JgSBA': 2.7083333333333335,
#  'KYGqNb0JSKkQSJfaWiyJCg': 3.5384615384615383,
#  'ynK_4lHrkqdXSHdrtQdq6g': 4.0,
#  'u53sKuzUuiV1xH1QzKmb6w': 4.578947368421052,
#  'GU1Pd9QxsaWf_ExSyYdv_w': 2.875,
#  '3r9BVzKJ7jA4SCDgjhBzZQ': 3.4893617021276597,
#  'KFWOn7x19RmrO6kzTJYmrQ': 3.9375,
#  'sT24I2klqh6_KUwcfRGNUA': 4.148148148148148,
#  '9kcmuaqb8Xy1Ovf9BFtpVg': 4.0,
#  'kFFhw53ZEPoDo6okPU4eRg': 3.024390243902439,
#  'hKJqd_8jzqZ1y17ZQsK_GQ': 4.0,
#  '0SNNcdn2ftrENGsQrqRd_A': 4.090909090909091,
#  'qrhXNejkv_CP3_IZoXB1CA': 4.3,
#  'RRsbPGYyKJ3zqMMkzcHZaQ': 3.6666666666666665,
#  '6arPqqPM-4O_OpT_Gf8agA': 3.6666666666666665,
#  '7hlF-dR-m-e8nFZMWao8cQ': 3.953846153846154,
#  'lf_hJmK9H7t4L2JXNdkF2A': 3.727272727272727,
#  'Tdv7HZa4Hyjm-X0MtNmeag': 3.837078651685393,
#  '9SS37PzKIixIZDbfSS5Lkw': 3.7,
#  'E0uldQnhiqB27Z4a7O7WTQ': 3.625,
#  'svbWpiDlAVFQa6dwfMtgQg': 3.56,
#  'T4rXSHtNUOA47GXS63S6mg': 3.85,
#  'OdhUSNW6TIeYw9rIM1CDUA': 3.5384615384615383,
#  'B7ygjO6fbs5IhW2ykL_MQQ': 2.5643564356435644,
#  'r1M84A56bViGJKKuxr1_PA': 4.0,
#  's2o_JsABvrZVm_T03qrBUw': 4.086065573770492,
#  'lK-nDdaTfvhuhUowIyOpmw': 3.869565217391304,
#  'y0axDGrceM7ve0chunw2Iw': 3.6666666666666665,
#  'zbRjeEkON8EXFk_VrcTAiA': 3.3157894736842106,
#  'g_AhgIEyx7J3NVsOPoalhA': 4.2727272727272725,
#  'sMPNFm9hBVT-dhOdUcod5Q': 3.357142857142857,
#  'HPoMcxrxwmV1PuIOYZcCVg': 4.25,
#  'GdAT9SHZ_IOJYrzG2AuIgA': 4.0,
#  '11gxVnIOvxL5PI4Ur9qa2g': 2.090909090909091,
#  'dHxvSPU6PZqX1LQRXajGDQ': 3.8666666666666667,
#  'uwiwGGCfKNCQx0MMbddKbA': 4.5,
#  'FzBt6pSciU5RYPKPssoNig': 4.083333333333333,
#  'bJQmnnp9n1t05NBy-ssedw': 4.666666666666667,
#  'JN8gzcEtoWTyIKHPBr2msA': 3.6153846153846154,
#  '5qBTq4XLs-3ch4AxRXXNmg': 4.5,
#  'xpWTenRR72Bv0RINUov92g': 2.3636363636363638,
#  'gWxuXLY25gGGZl85Q2rgRw': 3.2758620689655173,
#  'Vth2iRVJE6rnovR2OcdNog': 3.56,
#  'WbFk1imKyG8zg8jRFpXMAw': 3.6296296296296298,
#  'lEEYctFjdxJ8eOq_F7OK0Q': 3.761904761904762,
#  'JvjWVp1PuZRUphl8HMrJig': 2.9,
#  'DDUgbKGYYSXxhsp0-yr9FA': 2.857142857142857,
#  'EL_nDe2Rpkny5K5ZZBKjoA': 3.3846153846153846,
#  'D4-lez3FljZScDQGSJu3ww': 4.375,
#  'T_RiQ-TOeZf8N2kiCNCiSg': 3.603448275862069,
#  'Gj6HpCLCU56Z8HPNeZlSww': 3.5,
#  'YLlOU89RwpRfvk4H5tOQAA': 4.685185185185185,
#  'v3YOx9T4jRSw8XP9Rd9H4g': 3.76,
#  'AGpnVxWBOSsLw4VuC81q7A': 3.875,
#  'HmajgVWuJFudI4vdyzfLqg': 3.5833333333333335,
#  'CcG46EeYwQzTrU1MYCrUTg': 4.636363636363637,
#  'hNaGB47YOGe6FOthh3SxKg': 3.607142857142857,
#  'pG4SBHyD9P-OedH2i4IVJg': 4.090909090909091,
#  'yQuEw5dp9G3Uac5XaSogQg': 3.5238095238095237,
#  'XCNi6raOHuxmI66Cg2Er2Q': 4.0638297872340425,
#  'Pxi1YSerIqfDaTRW0A7z_Q': 4.142857142857143,
#  'i3bLA4sEdFk8j3Pq6tx8wQ': 3.67,
#  'I2qJvA0tbGdZJ3XrwzwfzA': 3.3454545454545452,
#  'OAjdl9eHjW1-415FTbPbHg': 3.6666666666666665,
#  'SBFwL9OhG5VPWXuzMxm7bQ': 3.7,
#  'Bet1qVniQY7FX8UFuUCVMw': 4.5,
#  'OzPoqJ0TDqNCOVm1vGPQuw': 4.0,
#  'ADNLYx9DMGoGPhZvnviTag': 4.172413793103448,
#  'WwhMBjrtxbwLCdZCZPx8rA': 4.444444444444445,
#  'pTwxE38QWUxvu5I_D0y6fg': 3.888888888888889,
#  'Cn3pKcYrMX3rOp01eG3WJw': 3.8636363636363638,
#  'zD7nzkNvZHEA64yaE8uc2A': 4.4,
#  'E_Ts8j758tpiAZknHR7k4g': 3.611111111111111,
#  'vlgvVIDyY0fYLZOS2KAO7g': 3.3636363636363638,
#  'SdyD3VeFsrzeR6WoOhhq4Q': 3.6153846153846154,
#  'WFcDOsTSZwOHE77H_bL1fA': 2.3076923076923075,
#  'sAr8w-qz1RYlQB7_hHbwFQ': 3.0,
#  'CDvhiRiczAq0M5pktyiyog': 3.432,
#  'MZ70U0pR16IiZEfxVmkyyA': 3.9743589743589745,
#  'Ao2X4BBYO8ibQE8_5Me6_g': 3.4,
#  'B7mqXzrSFKM_Wff2tbBagw': 4.0,
#  'fKYjGV2OSkSFD1_vdFhh0Q': 2.888888888888889,
#  'H0tfWQsGjEBuhXD4WUtpHw': 3.757575757575758,
#  'EyuGDX5_MY6LuMYSYWjsxw': 3.2222222222222223,
#  'hBRBoalwEnKB30Frky4xXg': 3.6666666666666665,
#  '8c-uDy8mRJADntHbUtwjbw': 4.266666666666667,
#  '7lBuMxcAaPyIVbH2ce689g': 3.5652173913043477,
#  'XUEwSGOGARxW-3gPiGJKUg': 3.7837837837837838,
#  'M4YEi9-KcBV5qJmG1_LGdA': 3.76,
#  'kbJeRTki8F984KdOlibxzA': 4.028169014084507,
#  'u8rZU2h95PU2cASiyAIGYg': 4.388888888888889,
#  'IcJxvIDNFqwi6_4qHxVy6w': 4.4,
#  'hPv5xh4cETVINMduWfLFVQ': 3.3333333333333335,
#  'V5rSusyViI7WZ8C6t20FfQ': 3.7857142857142856,
#  'PHW4Ixb3yO6dFECILUnZnQ': 3.75,
#  '0RlLudgPci8uGdSqaG_4UA': 5.0,
#  'CjvFxl6_7AK3lw5O49MN8g': 3.8620689655172415,
#  'dCipnCeaDSuIvKW20_jpxA': 4.428571428571429,
#  'B9lDn4yYQrazBbAeb4Zn5w': 3.0526315789473686,
#  'X7zysG3Cja6G2blwDyE76Q': 3.9651162790697674,
#  'IdnbvI-jYalwwSdLldiw0w': 3.4166666666666665,
#  '1kkQtcFWAk1jQGixPVJ4xA': 4.071428571428571,
#  'FT-G28ekjjb3draGTHCmDw': 2.8,
#  'B8uaZH1Jl7X466NJLhRJOw': 4.111111111111111,
#  'yx5lxcChJViDUQHErPpzxQ': 4.333333333333333,
#  'AJd0U8QrJSeK9Y-ljNJdhA': 4.083333333333333,
#  '8pR9rJepoXrjIR1_2YhYiw': 4.625,
#  'wumGR88hKlOin5c8Ubsfrw': 4.555555555555555,
#  'PoMSgPEu9vqR2Dx4WpbXrg': 4.0,
#  'UtUy4oOu92zOahLQAO34eQ': 3.9473684210526314,
#  '4KvLj56lJBh-VuADarRfQQ': 4.125,
#  '_8y-kAoK4BQ_MmzawRpQFw': 3.6236559139784945,
#  '5tFUXNnFh7g1V2waWvQfbA': 3.486842105263158,
#  'c-YbKFuw-vhEOBLad_NMBA': 2.8,
#  'Ly-ZEgIHT6imBIGMDwNX8w': 3.871794871794872,
#  'YsL6vAU_COmCnP0iZk0PGA': 3.206896551724138,
#  'JhV-D6a2tL6xpzGdBruepg': 4.352941176470588,
#  'jo8vV5iUZLHp617cTKZ7mA': 3.8362573099415203,
#  'fvk1MuhEuvOX_WR51Ghv6A': 4.0,
#  'cImvLb3Wvd5EZ8SRjKAPsw': 3.6216216216216215,
#  'Dd6ElS2Cng3Qag_h4IQC-Q': 4.111111111111111,
#  'Sdz4oDRGXRLwdgFUBJutMw': 2.8,
#  'aKHRHlG-MQVImPAEak8qiQ': 3.0588235294117645,
#  'Ryxj0u0AW3mRsRypdYli2A': 4.2905982905982905,
#  '8P8dgzKDQg7OSlEiAUUqlQ': 3.717391304347826,
#  'nfp4QXnZM4c_HhdYlyuu0w': 3.176470588235294,
#  'u7f8qsRYHCwWGUomm659SA': 3.533333333333333,
#  'SHEziY_V4G60mVyLNvjLSQ': 3.588235294117647,
#  'yjB4myNUyWyPpkIHY4kdcw': 3.8333333333333335,
#  '1dwa6Wkp0chKBcrRuO05lA': 3.6382978723404253,
#  'NCF8_lVpX0sHy9p9Cvft4g': 3.8974358974358974,
#  'INHFOcLzPBFAEO9QHbQ6Pw': 3.870967741935484,
#  '2JDWKHpR0g4QA4MHmFDprg': 3.1333333333333333,
#  '4vj_0BQeXjCyNB7ESS5mGg': 3.5277777777777777,
#  'Zn8tgekH0oCfyk4SUtygoA': 3.8,
#  'bgJLZAEaB04x9UQIm3sATQ': 4.396825396825397,
#  '8t0hmAWTCobt8jIbRAWsyQ': 4.545454545454546,
#  'WANhIVSoD5oIIu2LfKx5Ig': 4.090909090909091,
#  'm-R9m15HgUJkEMIJeaR2dw': 4.357142857142857,
#  'nSXHEz55nM2oDI_j3X5k4g': 4.166666666666667,
#  'FPEDwrWxK-CPjlgJM8r3fQ': 3.5625,
#  'VbiNVc4pAWtxvGG9y-IfQg': 3.972972972972973,
#  'SM6qMCO1BLfuRbJkFLaAAA': 3.5833333333333335,
#  'OyRL2O3rigUFfpWGK9uNFw': 3.3055555555555554,
#  'viwKpVVaOhWur77Sh4L4cw': 3.347826086956522,
#  'Gz9RkREF4_NoapuD4hRmGg': 4.553571428571429,
#  '89jyGlrPsoHF074gqtIbXQ': 3.9444444444444446,
#  'g-Bt1AfbfpwT2gwIjRDnHQ': 4.066666666666666,
#  'LnX7-WmpML5bY6Fzlz468g': 4.035714285714286,
#  'y1yiXi5EFrCLlmblEDWAFA': 3.9,
#  'XLNaiWF21OsAf0fMV6kuSg': 3.6962025316455698,
#  'DppLDUOJjiIRuxjpZETrsg': 3.0,
#  'cnyCyr5az4YzlQ1oCSYNvQ': 3.5698924731182795,
#  '-Ng6kNjzZee-hT-RZYg_Eg': 3.193548387096774,
#  'lQGJcwX105k17081f6pulg': 3.7235772357723578,
#  'dxCce2EdLOAy78Y3fAXCgw': 3.75,
#  'AkxF-Hc7e8iAQkcTcJHGiA': 3.72,
#  'x00GbHWf3R20AJJfiHC5zQ': 3.625,
#  'DJ-ZFC5RLfEO9z2H7PFffA': 3.7142857142857144,
#  '1ZhcB8kduDlsC3j70GYAOg': 3.857142857142857,
#  'vh8v72MaEqUCsNwWsslibg': 4.03030303030303,
#  '38u6Umpnj9s4QobruUH0nA': 4.2,
#  '49QmxIrpcKTfOtHH3wL8sQ': 3.4444444444444446,
#  'HXKZYi1d24WdafgmKhVUow': 3.923076923076923,
#  'zH6racrZ7rUqqv_Qy6dZDQ': 3.6903225806451614,
#  'Z4-fGDigomv6Yr6TZ93s1w': 3.7096774193548385,
#  '004tPynrrWu5c4x4t0aOcg': 4.636363636363637,
#  'O-qCegMPqzFL6BqWJBga0g': 3.76,
#  '6NYDXzkyYW3O2zYjzPRMsg': 3.6780821917808217,
#  'OoyQYSeYNyRVOmdO3tsxYA': 3.5277777777777777,
#  'dAVGTSsykWzKZHTp3yU_xA': 3.5,
#  'VlyHGaMz3gbbQz5hytCeGA': 3.7142857142857144,
#  '_j1KnsWLVz3AU1mmm0G0JQ': 3.4035087719298245,
#  'erJ1HQwavgZx4996SMIxrA': 3.6758241758241756,
#  'pWlelwBYGwvzISHzauw6-A': 4.042553191489362,
#  'MqcfaSdLXh7H1Aey_HPUsw': 4.098591549295775,
#  'Ozmf732ox-TNhfKrjWBXpg': 3.9166666666666665,
#  'vX4zE6Plk7lOlSme_U2lKw': 2.9454545454545453,
#  'cH5r3LgzNgrN5mkXfy8NNA': 4.545454545454546,
#  'nmdkHL2JKFx55T3nq5VziA': 3.7551020408163267,
#  'YEg9YxQQ0dL5ajzkwokyyQ': 4.363636363636363,
#  'oqTZC9WriodTCby6jl0LfQ': 3.5495495495495497,
#  'SqjP1cV8JwDdN0K9QULzog': 3.3863636363636362,
#  'ncZt8sBl46djtHNMD2r0hw': 2.0,
#  'Nid4TY_aKEUpvH42ymLFZA': 3.6818181818181817,
#  'ztJWCATVXFxkF2aDsq60Hw': 4.625,
#  'nPPG6fcNHOEqoFGVpZyUyg': 4.578947368421052,
#  'UQa9RqoJZWAawzqN-2pT2Q': 3.2666666666666666,
#  '7j06R8z6M8jTI8anwfjemA': 4.333333333333333,
#  '1Jj7LukYTA7oisUSC1o_fg': 4.4,
#  'Ahe7lp0DdVfhhCHb8yaXOA': 2.7777777777777777,
#  'MsorGGoa9_1rCP93v8qGPQ': 3.6,
#  'rExD8M5ivyNGWUMRjDnPMw': 3.65625,
#  'yvAYprNnakItO2O4zjDHtw': 3.9310344827586206,
#  'wzMXdjM-_DlDBkpg3xKnGQ': 3.9761904761904763,
#  'gxnderBVp-gmFh5jP_AxKw': 4.428571428571429,
#  '-IEX8bYlf16ezWSjlCZnnw': 4.2727272727272725,
#  'DoRCeCcJbrsM2BiAKj3trA': 3.4505494505494507,
#  '-n2_-g_OOYh5HWVeGi-gjw': 4.388888888888889,
#  '9gdm5DHwLdTWar7BZ7KG5Q': 2.9047619047619047,
#  'KbwOwQZTOfrtaeJdmucALQ': 3.8292682926829267,
#  'o2Wgvsv-nY-hRZpTVap48w': 3.8,
#  '_apmon0mHFn1ouYGXqELQg': 3.652173913043478,
#  'w6IbR_xC6tvlIEJcUqtKuQ': 4.0,
#  'c7_xsZYNs-_G6IceEW2WoA': 3.5217391304347827,
#  'U6Yb2BFi-5tDyqD_9aeSlA': 2.8275862068965516,
#  'wnO99pBbGqwqOoTQM25iCw': 3.5114155251141552,
#  'Pf7FI0OukC_CEcCz0ZxoUw': 3.7058823529411766,
#  'n19aioZtPanZVN71IgRRyA': 4.0625,
#  'aq7PsU-EerT2gSPsBc_FCw': 4.202020202020202,
#  '6NlUuoTeWNgNqwpGqk3LrQ': 4.3125,
#  '9UFh3Ppozo26HXpNtYCUAQ': 4.75,
#  'UqgmkQuYXFrJ--vOgN_IRA': 4.631578947368421,
#  'nrUQRMx6K-KJnoC15rMO2g': 3.9859154929577465,
#  'ihTu74HkXnKGuY5v_Z8b0g': 4.025316455696203,
#  'AwotTxzd_M5ZevluUUVkwQ': 3.9313725490196076,
#  'aHlInGQfBBsNADjXl2AUTQ': 4.088235294117647,
#  'oliH71SozUmTwL9i7I1jPA': 4.095238095238095,
#  'PzWBUzHIaIvqn4tS4nBNFw': 3.4444444444444446,
#  'c9S6nVI4Hw7jcXy-S34YVw': 3.838709677419355,
#  '5wT0vDycEzgq95yVCZ60Aw': 3.6492537313432836,
#  'On1XShu9XSaoVsoKYqKXPw': 4.875,
#  'rhBT5AQi8LPTc3Mk2Qpxpw': 3.975,
#  'eArDc4Z-1oM1NirhGRlk0A': 4.25,
#  '1Z-uHCBZiH1Xshqgqyx3_Q': 4.454545454545454,
#  'ESBXYiZQJcXNNAvRki-IiQ': 4.4,
#  'sb4c-3hnt6qnPNdczp84rQ': 4.909090909090909,
#  'cG7-mlCp_cV8gfRC_9LW-Q': 3.685185185185185,
#  'n9NEd4wwuMs72gffl21AOg': 4.153846153846154,
#  'csEL3VrnnX-T2rWX16v3nA': 3.1463414634146343,
#  'w-kN5hI24NLoKFPrrLX-Xw': 4.178571428571429,
#  '1O638BDK_fWuxgTVJwff-A': 3.76734693877551,
#  'yctYv9E1rK6AYTx1FHU3gw': 2.75,
#  '1IDGT7RHqYF76jm7CRuXdQ': 3.1666666666666665,
#  'P19z16iz5I9Hh4T99pY8Sg': 4.148648648648648,
#  'nHPjI8IDJprdAlNk3G1mNQ': 4.357142857142857,
#  'zLG3U9f8s3s_FPwI3So_8A': 4.6,
#  'WTE4gtyCs1eJDSCj2Afo_A': 4.206896551724138,
#  'C97l1A1fmsBQO9CIwcAY8Q': 3.5185185185185186,
#  'sGO8cyCMw8RZ_z-Gnmo3MA': 3.7,
#  'GtYRpcD0TyFJcglJdh1SZw': 4.5,
#  'N3oNEwh0qgPqPP3Em6wJXw': 3.782214156079855,
#  'nwnyfjz-sCALUnAXIMnsUQ': 3.875,
#  'M3JvONWLsX7mG3NoaVumrg': 3.923076923076923,
#  'CF4cpK1gkAf756lhgis1eQ': 3.6,
#  'xkxH8a8-jMietVcuFKlUrA': 4.333333333333333,
#  '_ZMD-Abvm-DHCmsOF-f8FA': 4.170212765957447,
#  '6y3XgANQ4YGtR8Tv0pgl8Q': 4.0,
#  '7P6t9qnhKLOa8SqGb85B7w': 3.7884615384615383,
#  'erdvrYG2b-YkTfZljgrXIg': 4.2444444444444445,
#  'k27gfV9y4TkCYtHW1MBCZw': 4.275862068965517,
#  'KtIh1kjkVESCqd2CCsQnhA': 2.890909090909091,
#  'QdPY0W7WIgBZrzRuL1lZMA': 3.0,
#  'C1pbgjAruOJSPt2FU5hbXA': 3.125,
#  'm1UhUjNS7Uo1Uz_CaZ1wJA': 3.9411764705882355,
#  'ludhQ7t2y0VjipY_knXxBg': 3.909090909090909,
#  '-8EnCioUmDygAbsYZmTeRQ': 3.9027777777777777,
#  'ejBGQeL177ECBqgMXe7sdg': 3.5737704918032787,
#  'sxxL6TjvDolUE7GeWBRZrg': 4.1,
#  'UsyfgPYRH5iiIaMRFpf5LQ': 4.3125,
#  'dnUa4GdkaPG95D9gyPfBRQ': 3.0,
#  'qa04NQ2wr6G2YVQ_GOEv1g': 3.4166666666666665,
#  'U-nR7ND8CDN2x8ia73CH2Q': 3.606060606060606,
#  'D9mgcl6MFE3vRKTVadFFdQ': 3.6153846153846154,
#  'Tk6GBteWESMezm8EDPwo8g': 3.5135135135135136,
#  'lK6vU1_UCK1owB6VEIOZPQ': 3.7755102040816326,
#  'qb-8RrNbVj-3WkXYuxpi3w': 4.0,
#  'gITLv-5CQIpXBRCbXxsnPg': 2.1333333333333333,
#  'WXA_4WVO1tpD0So3pZOQQQ': 3.5,
#  'hiYAibEH9q02UJ2waLOW5A': 1.8888888888888888,
#  'Zvc6nSaAN1WusH_sf8PjBw': 3.75,
#  '0LzxzSM6oqOilJ_Tx8AXzg': 4.2,
#  'MjxvMgTOC0is2p5NDY4kAw': 4.421052631578948,
#  'mfh0N8JSVtLudPZ_tC_Ofg': 3.65,
#  'xsRaqE75ZUlId5coIT9pKA': 5.0,
#  'AkIZlaQe7GUXttx_epYcfg': 3.675675675675676,
#  'k1KsRRNTOb5h8SAzxCXPlA': 5.0,
#  'dwmciE9bB4Naug5SvM8KZA': 4.219178082191781,
#  'fwcfgdbBpv8qUD-46NIviw': 2.68,
#  'p8IDOaEADVMeV65GzHbqKQ': 4.2063492063492065,
#  'DK57YibC5ShBmqQl97CKog': 3.7027027027027026,
#  '7Q6nBHl6NJ9gbJ900FkkAg': 3.8271604938271606,
#  'U-05lj3UvME4JQ6mQ1rREA': 3.8181818181818183,
#  'O-nFhs8UBvWaCkgkOTynDw': 4.2727272727272725,
#  'yyDp7MZ2st7p0fOQuFYpcA': 3.860294117647059,
#  '1ZxQe_ZeUG24aEL1r6gTcA': 3.227272727272727,
#  'V7cGEFexpXTY-jKWhqkHcw': 3.851063829787234,
#  '1-SOnEuoLwq0mk_naLx66g': 4.466666666666667,
#  '57nPVrSrvaUTmurnAYvqeA': 3.84,
#  '8QKrhvVqhEkD8xo4E4s0GQ': 3.611428571428571,
#  'ZAfQEyVZ9yerd7lgRKlGkQ': 3.586206896551724,
#  'UJPy-RaihCkZM0cduqKpBg': 4.0,
#  'kzRq4H_nSf4b3F_sdymWSw': 3.3508771929824563,
#  'bLbSNkLggFnqwNNzzq-Ijw': 3.341501976284585,
#  'YYbPsFrMEdD8C1m4EhXOpQ': 3.1666666666666665,
#  'vpSruwUEfZw_TyaTDHEFDA': 3.5384615384615383,
#  'Xsyw11gZiltqWL5RvWGKJg': 3.9285714285714284,
#  'cATjrFm75NRPyUWtQ2YEYw': 3.8285714285714287,
#  'BYRid79EKYIfTNn5yvAITA': 4.888888888888889,
#  'GFv75j9zT8D7WqTQQbs87A': 3.6666666666666665,
#  'Y3PQ5P_R7jcgiIS_1dIv-w': 4.056603773584905,
#  'JYcCYNWs8Ul6ewG5kCYW4Q': 3.2845849802371543,
#  'rJoaf3Cy66EUFmFg0b_wpw': 3.0,
#  'oDyEexUT09e3XhxIp0-Wxg': 3.75,
#  'VN_n0Ddxny0J6Z0ehMsvUw': 4.142857142857143,
#  'iHGsi2zgjGEm2zEQg8w0og': 3.15,
#  'EZJgrPBq8sGFjAvyJEJzTQ': 4.5,
#  'm-_Ed9mCK_jNN1T5sC51aQ': 3.2,
#  'uC3Q_kk-pSVDv_446401Fw': 3.8181818181818183,
#  'zMEdR4h7FHNExwQLKvPP8g': 3.5714285714285716,
#  'Sosl51bdhJYt8Yh9B614pw': 3.736842105263158,
#  '_erSx4V12Xc_G_Owz59BDA': 4.2,
#  'xFTwjBMXHJwp8MSTUD-rlQ': 3.7241379310344827,
#  'M2whdwvMtNxLllxOvt7cOw': 4.208333333333333,
#  'PgKzSH8jxM-DPzcxv2KtJg': 3.0,
#  '8B188riM26vd9B2uGqV3cg': 3.4615384615384617,
#  'LLsyjn2GZ715AwIPlWZ4Pg': 4.3478260869565215,
#  'Gin-GoejFVkq5qYUCY2WYg': 4.6,
#  '0DGh3LaLFDDES3OtOqGq1w': 3.3333333333333335,
#  'dkwVTiFDVIwTJplmw7wwdw': 4.722222222222222,
#  'sAOdKC09kMqFfnVCrJRWvQ': 3.5595238095238093,
#  'BdRMVROS1MXOHxr-bdZv0g': 4.5,
#  '5i5en8JouIFF9wzAhLPH2w': 4.0,
#  'xWD_4PR5V0H2HvmqlfS-pw': 4.25,
#  'V_dT-3YVhfcwlTM_ztG0fQ': 3.5,
#  'XSTrK_qYAMKcdgQj_-BZvA': 4.2,
#  'QGOtNZfasBwWCuawKjypYA': 3.909090909090909,
#  'WPNYp3IyJpOSJ4bhFbYAcw': 3.761904761904762,
#  'KFZISl5mOUJ6bu3qCUrO-g': 3.5064935064935066,
#  'x2KHPyEmsg0VL3B40-xfDQ': 3.4464285714285716,
#  'Ye3o_zp2H1k7N8QRusWV4g': 4.173913043478261,
#  'D-KX6N7hepq1jFj5ka0SHQ': 2.6,
#  'P4FVZHeocn3rXdZ3yYoUng': 3.3333333333333335,
#  '0CKo5RHHoN6AI7vSMnKV_g': 3.7,
#  'Anuuo7l9KgAsSvnOHXcE1g': 3.3508771929824563,
#  'P49ulSRSHLNnIP-efK-qhw': 4.27027027027027,
#  'BNJBHkHVQvZjOV4wn-JYgQ': 4.266666666666667,
#  'G1J-MuWmwt3PMfkSga1k-A': 4.648648648648648,
#  'TwjiWvK0ZP15lzGC049oIQ': 3.9545454545454546,
#  'QFvxjeMpAKhYqVeLXCX_uw': 3.5806451612903225,
#  'njUgJcn8ZN0BdZdNEswRwA': 4.237804878048781,
#  'pplVMJ2UA2tdb8Vbu7xnag': 3.125,
#  'g-HFMffU6L2nH4bwv04FIw': 4.745283018867925,
#  'QmuVgaQkkQwdzQtUI0cHmw': 4.5,
#  'f3x6dINZolXO3OVbjKhiAw': 3.392857142857143,
#  'OG8HE8xgs7C2p7XG150MCw': 3.0434782608695654,
#  'zLVD_wXUpBJfviNQiKrQyA': 4.866666666666666,
#  'IWWlO6cWFKbXGBA6WhYvDA': 4.444444444444445,
#  'GmXOSEbXy8JXmvo9hM5WWQ': 3.8529411764705883,
#  'mEdv24bUQY8liQBbkPe11g': 3.1818181818181817,
#  'kHEQu2K4TIiXdw7Onj9TIw': 4.023255813953488,
#  'bDbNA6qnScQa453kK7UeiQ': 3.2222222222222223,
#  'sdnjNnQNpGB9OsX9fyJ0FQ': 3.5,
#  'p8eHROuRDiStavK6iEkS8g': 3.6551724137931036,
#  'HGybiCvPc1YCp9tuBG6BNw': 4.0,
#  'E6Aoz-3s4avfweIjziHjbA': 3.111111111111111,
#  '4mdgpnuxbtNJ7lzljvwl-w': 2.7142857142857144,
#  's75d8PSqVbCJtclvBdne3Q': 4.12,
#  'ORJnGXXkS9tQBTNyPQJF9A': 4.439024390243903,
#  'D3fOi-5w4intrUTWXzIQew': 3.901734104046243,
#  'I2uiqGOwg6uBNX3SXRGiFg': 3.7,
#  'EXLQpXJDGmcN-7_douwqZw': 3.8636363636363638,
#  'FTPe7VVwGDM8j9csFhShWA': 3.9242424242424243,
#  'zZu_XJiWi6lzls6O82HZqA': 4.409090909090909,
#  '4TJF62R5ytolOmiMWKtjGA': 3.3529411764705883,
#  '_ucMEPl0IRvHpruqTXndiQ': 4.238095238095238,
#  'FG7pjfHdjG26A4lhKlLHpQ': 3.72,
#  'NnRw7bdSHviQe5swWCv9iA': 4.678571428571429,
#  'f_5VRh79aew1cVWUmC1PJA': 4.86734693877551,
#  'wc4XAA5pC3b1UgooSypHwA': 3.417391304347826,
#  'MT4AnzfbdlYM36KgHVIx3Q': 3.076923076923077,
#  '3IBIIaiOrzVP-LTOLPBqRw': 4.238095238095238,
#  '_4vUerBTzh1M4e02lbyBqw': 3.2857142857142856,
#  'tuiR8GCh5eX-Z8twljeueg': 3.4363636363636365,
#  'yypLU1-65sD8cN9G4Kwvdw': 4.171428571428572,
#  'Yg08tRMxm0eaL-rXyNIAHw': 3.816,
#  'DhZnSoyq3mVUsADMJw6JDw': 3.9411764705882355,
#  'ltAkqxbf-OMexfAaelQ2hQ': 3.75,
#  '__tjTZTk6krolZ-hZ1ZJpw': 3.6875,
#  'Onuu7uWNgkKtg0hCg-VnJQ': 4.3,
#  'p0hlNNwzFxKxt7feNvbN7Q': 3.6,
#  'zuopKcPI1VBVFG8ynCHIMA': 3.696969696969697,
#  'YRYGfJ4EQS6vlh2pDk1kkA': 2.75,
#  '03iMNggjXP2tOkfih15ccA': 4.166666666666667,
#  '3iIi_jjgQQgVclgD2w6yEw': 4.142857142857143,
#  'iqsUoSxTpzAxt8AX8OgSZA': 3.7142857142857144,
#  'fF2bbPBF6GV9kQ_oY5fZcw': 4.5,
#  'F3egUvup1QxG_vJqBH-ZAA': 3.7857142857142856,
#  'T5KBc5QbwZ-Oj9ApE4vZJA': 3.9935064935064934,
#  'PWgcYLgF2iO86dEVQFxH9g': 4.1923076923076925,
#  'ifdF3F9cJ3RGVrFluC34aQ': 4.181818181818182,
#  'FvHtYHUqf-BjwIcM9Wa3VQ': 4.2727272727272725,
#  'TpY45NJHexIdwdBbatYmpQ': 4.0,
#  'ae7zi8F0B6l_JCITh1mXDg': 3.2580645161290325,
#  'lLfcbYGTeVxQN5Ig0ompJg': 3.488888888888889,
#  'Y89I-YYL8cnKYLlVyrKHuw': 4.166666666666667,
#  'YIMeEHUYm69m-Mqf-NjPHw': 3.831578947368421,
#  'witROkozjVqJMsi_2X0Byw': 3.6666666666666665,
#  'xPXHraGdyp5JDt5LHjm5wQ': 3.7777777777777777,
#  'C2C0GPKvzWWnP57Os9eQ0w': 3.677350427350427,
#  'ysgGEHp5EmcTB_RXnuKtbg': 3.75,
#  'Rq9GgEisa8MpORaBbJBcKQ': 3.0714285714285716,
#  'ZnIaEvJwrxlBUjimIpx2Qw': 4.3076923076923075,
#  'PhUqhfyk3jdaS0Xb619RJQ': 3.925925925925926,
#  'sjzv-c1k_HGGT9vZbfimWw': 3.914285714285714,
#  'fN8W36jOBHJLK66xne1kvg': 4.3,
#  'xoZvMJPDW6Q9pDAXI0e_Ww': 3.5517241379310347,
#  'lCfvxcfqtWvFr7RF_UedQA': 2.9047619047619047,
#  'fNBbsjfpGXinu7ud0DyyIw': 3.230769230769231,
#  'iBcGfYnZIIZie_LxUJxSIA': 4.0,
#  'QsJKgW79PxkH6Dx9bsHr3w': 4.705882352941177,
#  '3gm_H_pt20MSNXxPObkhIw': 3.0,
#  '53pDWm-S6vjCo_9aFyptcw': 3.5714285714285716,
#  'xPqMjZrlX8BKRAyREd5WuA': 3.9615384615384617,
#  'pj4NKEZZbh4dTWbl3b983g': 3.1818181818181817,
#  'lwZprlhvaw7NgU4J90Fm9A': 3.6363636363636362,
#  'AoAJc0mp6OJWcjj4-cj7Kw': 3.25,
#  'KmBPYlD00BupKSwWxOWA6w': 3.9572649572649574,
#  'ZaTExw4m0O25mKrcsW5A6Q': 4.454545454545454,
#  '8aXyfFUFrypoE6PkUQBtmg': 4.310344827586207,
#  'MZINn-irLWvJKe7jd0_ctg': 3.6451612903225805,
#  'Sadfir42vt64m_AWV18WLA': 3.7777777777777777,
#  '7xwLiQx0-lCOXBUDAcazZA': 4.333333333333333,
#  'QFWVSSPbMOk-PN0bdG3lMg': 3.8947368421052633,
#  '4Ch_27GkNV5p7I7ewlX3DQ': 3.5205479452054793,
#  'f1fSYK3QRnUZ0QnFXAAbKg': 4.393939393939394,
#  'BoeoaSuMSGMmMq_JA9UH-w': 4.410256410256411,
#  'SwbADifd3CLsWSHyOJ_BiQ': 3.6923076923076925,
#  'umpKz5SA6UPEs0_bsuFKfA': 4.076923076923077,
#  '-ANmlu80D7ApI0iRaIiPag': 3.888888888888889,
#  'n2HyyuQ18NnsB2slsxt37Q': 3.6956521739130435,
#  'O8BcJ8S4JwHHZWnx3Asd1A': 3.723404255319149,
#  'tlchIlg-3pH2MwCDn_IAFA': 4.315789473684211,
#  'loHq4MfAzNeWidlVBK3k9g': 3.864864864864865,
#  'PPBAZSIvh27e_mkj0DZfXw': 4.304347826086956,
#  'S5VulfXE4EMxWsoEdETCsw': 3.5,
#  'q6mqVoPaqViEFjAInSKtuQ': 3.6666666666666665,
#  'xRdl9ircjzxA7_j4qLFmGQ': 5.0,
#  '4N-HU_T32hLENLntsNKNBg': 3.825242718446602,
#  'p_QErki4bI6Ni598P0QX9A': 3.5945945945945947,
#  '8rYnOC6IU_A_f-o73aDt9g': 3.74,
#  'wVkekb8v7bFRMKAYYHrLOg': 4.157894736842105,
#  'OGjXGh5Nb2Ly53MObm6PcA': 4.157894736842105,
#  '8fsZcLADFrPTbGrFqMACpg': 4.076433121019108,
#  'yvWZJA-h-UEC_Xf51eE0OQ': 2.6470588235294117,
#  'Vkf4e4SLFm3gApONFnWk7Q': 3.3333333333333335,
#  'a0cwFxm4rOlNVJxSaCRw5g': 3.5384615384615383,
#  'kaJCbdYCy657hmpY6Eb82w': 3.413793103448276,
#  'eZZyuJDouIg4p-GYB3PV_A': 3.8981132075471696,
#  'TPnUIDk4QajkCshM-rsjSQ': 3.9444444444444446,
#  'IX8mam81dgMmRS9TZWRLyQ': 3.962962962962963,
#  'xhhE0txKwQtRzgQVVdKkvg': 3.6666666666666665,
#  'NyhqLRZ-ITUCM9Nys2KewA': 4.071428571428571,
#  'EsOu51dW3UTDJTApBxwz2g': 3.810344827586207,
#  '-Cm0UFJ2ks2_XgvVtTqMVA': 2.8181818181818183,
#  '4sLhuOs4K9mov0bBj7HaYg': 3.3846153846153846,
#  'RBIXQRg9BcPttJ5p-fc31A': 1.875,
#  'm0mhvB8iIvWOpHqG8wDngg': 4.090909090909091,
#  '929r8bJ3dzW_d3jpwUxYVw': 3.761904761904762,
#  'pCRJpp0OwZ0T5tHzL081qw': 4.2,
#  '_ykg4Fp8j_tU83q2tYC2FQ': 4.398773006134969,
#  'PomQayG1WhMxeSl1zohAUA': 3.650717703349282,
#  'bLExVDNKxXMjjZcx3YG36Q': 4.342105263157895,
#  '0SDV8Z5nBEqSD8hHmnj5_Q': 3.7333333333333334,
#  'iAevEfcmtCr2cpd6IRqnTA': 3.8048780487804876,
#  '8nOAfr6VEl4r77W15RU4AQ': 4.066666666666666,
#  'wuT2zH7Atq-98BirpB-8Aw': 3.5106382978723403,
#  '2z-2ryQElSf_hwIbHEnZ8g': 4.166666666666667,
#  'MnKem6zgtJy0gQnssJXrkQ': 2.7,
#  'xL3lEz-T2zfQOCneobegzQ': 4.37037037037037,
#  'zviIkWQleYMGPeFyyGaVCw': 3.111111111111111,
#  'HQF6pQ9mC52J3BEEDSevOw': 3.847826086956522,
#  '3dbkO9K5vcvJXuKrVu4BMA': 3.557894736842105,
#  'DEf7B5g_RscGRrWWiYqJnA': 4.636363636363637,
#  'yZqLx81DcmUKLDkU0lrEqA': 4.25,
#  'aiSMCaIQzyLgJu7xXHfuoA': 4.0,
#  'XUM2ddIWYN02TuMx_0pDxw': 4.133333333333334,
#  'g-cGhCYwQ0azyPqNBbT1nA': 4.0,
#  'l7Wl2UisRwnmXtTCJ9eTdQ': 4.583333333333333,
#  'wxQCLMnuVYbdtmQCc2ryZg': 3.7804878048780486,
#  'mdCAsnSP3uCH2859UYW66A': 3.764705882352941,
#  'kaqlSjOjI8YW7PcLdanK-w': 3.5180722891566263,
#  '_slO6TbtN2-8K_Qio4sOxQ': 4.5,
#  'y4aEhXdfKAX8klEvOszSCA': 3.25,
#  'KuaxDMa_GsdWC0EF4eLz6Q': 3.5,
#  'fesmBxZyYQSElqWD11F4bQ': 4.076923076923077,
#  '-Vrb0dmE3AxJuJ0dyVY4NA': 3.5,
#  '9qjLfaAqMxgfqdtTlPwRUQ': 3.875,
#  'JnGjZVSlfCkKHErvO5ts4g': 3.533333333333333,
#  '1i-jH7VC8-aL4FYlljJAwA': 2.6363636363636362,
#  'FTSIBLNPHSOcVXSK8Iz0kA': 4.125,
#  'OmSz8hJI5tbG7Ww0Q9IkNQ': 2.873015873015873,
#  'U-TKAJXAJAXTHZTBlKjSsQ': 4.181818181818182,
#  'oKhpMYvIntENZ5UzuoZWUg': 4.125,
#  'W1Cey68uEuG4PKaXuJ4WsA': 3.5833333333333335,
#  'I9TSSFY4BAuKRFHbra0u8w': 4.229508196721311,
#  'C1ccV5ednpSJSL5NKibCOw': 3.418181818181818,
#  'YV-6sw3s29CPDilatMaT2Q': 4.136363636363637,
#  'rSZhh3j6hs9zcsMj7aZQKg': 3.6923076923076925,
#  'SyFNjWGac8FSRsvc8KkAJA': 3.611111111111111,
#  'Tf9eq2qBukCUDHNgsIR5NA': 3.75,
#  'NKlkCLSuIXepGFhMXyATPw': 4.15,
#  'xL4EOIKW6ZRM06T1lMjb_w': 3.6666666666666665,
#  'RQmkfHm2y_aokz88-woQEQ': 4.5,
#  'pW6UR8gtcmO_Zf6pmaprnw': 3.411764705882353,
#  'Qb8sDTzr54wRtT9hm1ZBCg': 3.5555555555555554,
#  '1LESyVBmCGVvkODSRMT_WQ': 4.6,
#  '9xQ4yXdZEtYHvm5KwrjqOQ': 4.714285714285714,
#  'c2MQ_LPuvtiiKFR_-OY9pg': 3.9518072289156625,
#  'NDWXMczMOcR20febmuM88w': 3.9375,
#  'qbq4zC9SrZuaQ4-J-wtRuw': 3.4095238095238094,
#  'j1tqWHCnEG9kTbTeipojDQ': 3.227272727272727,
#  'KLUvRyRDUftXgFvUx50Kyg': 4.229166666666667,
#  'Nw-RuNh3HKIiQ5xb8sXSQQ': 4.269230769230769,
#  'x-W0OQiUdNLsoMhg6GfXSg': 3.9565217391304346,
#  '8tc-ayfCYdAV70fbzu_iJg': 3.2222222222222223,
#  '8nqcdY9b-zolA3DgfeHSxw': 4.125,
#  '9BuTUHt6Zlm-UCjaGD6aJQ': 2.7473684210526317,
#  'iS4m_LE7f2oEzYl09HiIuw': 4.809523809523809,
#  '-tkF9tLShT5t4xsFf6xCEw': 2.6,
#  'G7petnMalWRzvI4shPxNIA': 4.260869565217392,
#  'GH6XqTz5Jx39SobsTYQJXQ': 4.173913043478261,
#  '48vRThjhuhiSQINQ2KV8Sw': 3.903703703703704,
#  'u_wqt9RshdZsoj8ikLqoEQ': 3.6222222222222222,
#  'O3KxAeolnjeF3e2hMxwwNw': 4.0,
#  'dgcVExoR_Gpo_tmzY5HpGQ': 3.6956521739130435,
#  'y3BRV9BnG7OZTJ7mRcMP_A': 4.0,
#  'hM3eIi3WXzQLCrl8ykcyjg': 3.4285714285714284,
#  'CG7vDoa2iGGrYQonSVn4Bw': 4.298701298701299,
#  'Sn6DV1-Xk7du4dGqnXuEdg': 3.25,
#  'dcpE4CUvtqLf63tRJgNqKQ': 4.142857142857143,
#  '5pWIJ2ZNWMnYHzybLzpHJw': 3.5454545454545454,
#  '3eAzUp-Oo5N6ifDNFpj-_g': 4.3,
#  'qXV12m_U8rewItBwCJ8HmQ': 4.933333333333334,
#  'FQZ0KtTWLBHMT2RWX7hArw': 4.083333333333333,
#  'ERcsc0YO5CCUbkC8EV2INg': 3.8433734939759034,
#  'l5Xg9LtfU_ddD9mp_EN23w': 3.5384615384615383,
#  'TP84hS-tDZGv0vEDSowrxQ': 4.066666666666666,
#  'KUk_d1uZSblqwA8TPHtgmQ': 3.9516129032258065,
#  'N0SJIKDLyo4005hgXeOT6g': 3.625,
#  'oNMSGUU0g8zFfpfSh--xyQ': 3.3448275862068964,
#  'Dz9kA_XAUCLBmNYNIcPXuw': 3.5714285714285716,
#  'crL0l0Jq2s9E3AudnsUzvw': 4.75,
#  'wR1TWVHX8NwLKpHMKu2PyQ': 4.65625,
#  'U3pMtWI3DCfAnZgXkISwZg': 4.0,
#  'RnGUBhZekRILJfbUAB8_TA': 4.538461538461538,
#  'MX4SInWQcb6QDZiZJLfubA': 4.714285714285714,
#  'xIjw368KoWqmAZ7JUrwf3A': 3.3333333333333335,
#  'rzatTfGhdFwgyfAP9yhPLg': 4.162790697674419,
#  'zBi_JWB5uUdVuz3JLoAxGQ': 3.515748031496063,
#  'MOcQx-Mh70Ry3aMV8jccew': 3.6875,
#  'UL5K2rnSYIPD1LcqPgbmDQ': 3.725806451612903,
#  'hX0-0jfbXUNUTzyGtg090g': 4.216216216216216,
#  'w9WmBotuUdQlmuLa3XUkFQ': 4.2,
#  '1i6KoGjzSkKo4iDZ5LhkEw': 4.318181818181818,
#  'Lvw-RNCkDdbwTDNPNLq-VA': 3.6666666666666665,
#  'YJYFsF4z-C2qODH5HnGXiw': 3.3636363636363638,
#  'd7PExbmCMloi87tLvKeudA': 3.272727272727273,
#  'sCelgwFoaNLMC_A7Y8usCw': 4.3931623931623935,
#  'H5Asta4LpiKmRhSjWaogIg': 3.4285714285714284,
#  '-bY7G6deWMZRrOxhFUrNhA': 4.882352941176471,
#  'BGZcv3B3mlofVJYG_TTsMw': 3.857142857142857,
#  '0pipGS0dkdxjP-YcyU6Opw': 3.8181818181818183,
#  'C0m8JV9YjQ6i1cCUojLLLg': 3.9444444444444446,
#  '1wLCq_1Gy6ingAE4uBSV2g': 4.230769230769231,
#  '9zsiE28lpoXevnn-cHJq7g': 4.0,
#  '3Cod7voqhkzYhWL8_3AH4Q': 4.133333333333334,
#  'nUcQM8aXckWq0WraI2_3kA': 3.3636363636363638,
#  'MZ3xgnosTaxKooMhxB3SUA': 4.5,
#  '5vFZ15MXySh_ggS7REdA2w': 4.524590163934426,
#  'BjNJgAQcEYoKP7EVrn3Pjw': 4.857142857142857,
#  'FAsoP7gzkDmFdP-eYuysmw': 3.3191489361702127,
#  'FIk4lQQu1eTe2EpzQ4xhBA': 4.0886075949367084,
#  'tBB6kLk5ZS03PlizPxLpoA': 3.6,
#  'LFHNbRdOJL2LDZUzyHz7Vw': 3.0625,
#  'aBMgdtHYfs3MnMz6tS32GA': 3.1875,
#  'wkHQoxEthiAyQE_B9tkAmw': 3.393939393939394,
#  'dpvR4LYXr0CYHtHf8BeCKg': 4.125,
#  'vLAYtY8GWMBkDLrLW7wu7Q': 2.7333333333333334,
#  'htXolAbmJlOjVZqXcnmQnQ': 3.727272727272727,
#  '8rQfsqXYv8UDvVItGczDBg': 4.444444444444445,
#  'hAZEee0Q7APAcerRQ4Ze3g': 3.9444444444444446,
#  'eWyhZ-114SqkZkG0RyJG9A': 4.076923076923077,
#  'ZKIqjJH1M-F_oj9z4YD-3g': 3.1176470588235294,
#  'JXHrhT72U6sZJQSkFfNzjw': 3.670103092783505,
#  'pDvDLpD7CiMlIebsDPCRSQ': 3.682926829268293,
#  'b0ZGXpc6drGGnV8SyTne4w': 4.823529411764706,
#  'gqpnDoFx42U5NdtejYfKOg': 3.054054054054054,
#  'HK-TlD0yVA_tpTXZxfzu2w': 3.020979020979021,
#  'VvC0o-ipycCZkIgDAGvCKg': 3.3636363636363638,
#  'E4Y4CmoeE1NQgpgKtoatnA': 4.523809523809524,
#  'trAgaopRYs3-yNpSdnAvTg': 3.1,
#  '-NbeVN5tnwdyYAvdNkKMjw': 3.78125,
#  'Kez5MabViniF-HUZ166HFw': 4.541666666666667,
#  'hQ4E5Do650x1OypMDZer4Q': 3.6470588235294117,
#  'ePmJ-eiGA961__UjYrCaRQ': 3.272727272727273,
#  'p6tAhR1A6Ok5oCmXWGLAjQ': 4.0,
#  'YWFbTcVnun8i03XnEU7kVg': 4.1,
#  'xgVj5MjSlyDyPZN55APadQ': 4.388888888888889,
#  '0D5WAgaOM1M00t3KIEf_Fw': 3.5098039215686274,
#  '0EJNWlsatHyfSr2jJ3BJ6g': 4.035714285714286,
#  '4UAqdgiCe1jwI1IQl96MIA': 4.2,
#  'xAWA2aheTP6YwcFWgmeLaQ': 4.4,
#  '49xkBUeRM0Ii_PiaQMGL_g': 4.3,
#  '5CSAtdgFiJYCuu3C9kWTWw': 4.333333333333333,
#  'kq61kSviGeXBsqOv3-xiAA': 4.28,
#  'o2b3y3m4-sT4jUllCn2-oA': 3.5,
#  'c9-jEIfBnLa4iNHxVmXAHA': 3.7777777777777777,
#  '5G7hz3klRng9I_KCIf-UGg': 3.75,
#  'DTo6vHKzyx8RmMrVbTgowg': 3.5833333333333335,
#  'mlXLPBayYqjbUMmtFrlw4g': 3.810810810810811,
#  'SfVmZ58U_0A9I2k5jiqCJg': 3.5714285714285716,
#  'JiqUeiXgugNrmvJEOx7NyA': 3.76,
#  'NPhf2jDAJnIsMVOyn_VjkQ': 3.923076923076923,
#  '_Ac7EfJcJoIFRJf6a9Tcag': 3.857142857142857,
#  'ywgGlGLRmvCIu6iCtJnODQ': 4.090909090909091,
#  'h949ZwQiQAXD5GR3G5wMCQ': 3.3,
#  'lrr1RKm8mIwB3LJ3Z2b-Eg': 3.6,
#  'vXSw50X6SurDHp8MpOSvjw': 4.0,
#  'UvY0E6Wuhv_0Bita52RPOw': 3.6930693069306932,
#  'SAdmlwTOxA9p-1GLamEssw': 4.033333333333333,
#  'wvB9Rzn3BHzUUMUzLL4u2w': 3.92,
#  'F7LhnDvi2t6B56iaPeNZHw': 4.2727272727272725,
#  'sB5wBopRWDge2h2U6FfcuA': 4.333333333333333,
#  'RdTdVgd9u58BA52d0eHqcQ': 4.073170731707317,
#  'U4INQZOPSUaj8hMjLlZ3KA': 3.65625,
#  'JA4Rw3qdKuGDCFbexnbN5w': 3.325,
#  'EC9GL1I1NnCLWILy-os3Fw': 4.0,
#  'qd5x2GyU2BMuWYqMqL1BZA': 4.5,
#  'QZDS5x8YE7KWsOBhXmw0Fg': 3.4098360655737703,
#  'D5Cmz4luMLa0WD4LjYgpKQ': 4.054054054054054,
#  'T_nB1cdXiX2qiNEu5mJAYA': 4.2,
#  'swK-Lhk-gcbuuB1swIyeCQ': 3.4545454545454546,
#  'jWgueH87pyZADiZV42sSaw': 3.611111111111111,
#  'wt57fkTOcSCYNb2fNAOlyg': 3.6470588235294117,
#  '_2Sa7pq5z2XOUhS9DOCGHw': 4.257142857142857,
#  'jFstakj1H7l3zuVESp0Ygw': 3.9642857142857144,
#  'zUftxbDN37tL_ghulwdwFA': 4.125,
#  'Ud6j2HN40qEhycq2PuwcBA': 3.590909090909091,
#  'Bmn3g0gKsOcG7c0WWRE_xQ': 3.849056603773585,
#  'UGBJ86rBN6RkFaOUd_iN_A': 4.75,
#  'zAaSoPQXHNx0bcSZG27JHA': 3.2083333333333335,
#  'MfPimAFtij9KSvJLSisGlg': 3.8333333333333335,
#  'ryqJ5re09J5u94jDVImCew': 4.3023255813953485,
#  'Ggx8iUdJ7lsQSqXRuclXtg': 4.253333333333333,
#  'qfc45SoRX4d8cRQ-4kvXkA': 3.5,
#  'scu1qTGz6xsVKgW_-0Gmjw': 3.8333333333333335,
#  'vWP8-aQX0rYJszqkWVL7Ew': 3.630901287553648,
#  'oAdS1AI3gQHGFLVXb5qsjA': 4.666666666666667,
#  '5mcQhUGDfo71Dlh8sDZP9w': 3.75,
#  'vFPmKFBFNb-J-fjzdBGmEg': 4.2727272727272725,
#  'gWXHcnt5uCSG4afTLOSJEg': 4.538461538461538,
#  'R_uxlSD2MMkNwA8ers0DhQ': 3.75,
#  'NUtVG7jNPLJR2cxMXMH2-A': 3.69811320754717,
#  '90sTc0TQ7F1Uj5NGiIE30Q': 3.7,
#  'd38f6MEqblbq7v6zmhVibQ': 3.4615384615384617,
#  'yNH3Z0MvqpjXq1NbFsDLFg': 3.953488372093023,
#  'EPa3uxyyGfRMpPX47lKwvQ': 3.772727272727273,
#  'WU9eoIz9KCcSB4bAxhOHXQ': 4.644444444444445,
#  'L-L1X9Q7ptjFLExAIxf3yw': 2.9,
#  '0uIGx_NZmzLVrToCD9bTjw': 4.0,
#  'NIfsLZ9qaxenKGN7iTUWxg': 4.137931034482759,
#  'fkf5UTsQTakNIAiwZfDW5g': 4.285714285714286,
#  'Q7IoE5m2heQKThuVq3SYFA': 3.573394495412844,
#  'rG1-LWGOfb47ZHMBbffKDA': 3.6363636363636362,
#  '-WCWlsVGhxaLQMfpKuuKhw': 4.3538461538461535,
#  '5KzHxAaHgG0UCUQiaXH5oQ': 3.8378378378378377,
#  'I27oeyiA_r2zEKetds7QCA': 4.216216216216216,
#  'Z0yHptbS93271s_h6LJOMw': 3.4347826086956523,
#  '82GOQIPlSzLvRphl9MzRhw': 4.405797101449275,
#  'vYfFmRk0IP5T2n87EtQUxw': 4.111111111111111,
#  'ZYZNcugF3xUEGyLOVGiZ0Q': 3.6666666666666665,
#  'sC1ZpecksB6-hmIB6if1yg': 4.142857142857143,
#  'a3KIzDHFWabZ58tVuvWQog': 3.7142857142857144,
#  '24zEYgcKDXuW9HB_GJM0lw': 3.6923076923076925,
#  'ZcFB7xOpJufgX9hHPFh9mQ': 4.487179487179487,
#  'rTpsaH0Hz7XW92_tES1B2Q': 4.470588235294118,
#  'CrEBVkzIQs7tS-wWfaCjNQ': 3.8974358974358974,
#  'sgTRJRhaGL__BsJcWaE3qQ': 4.027777777777778,
#  'ro8lGoWMsa49B3tWLaWwSA': 4.65,
#  '3nDUQBjKyVor5wV0reJChg': 3.915463917525773,
#  'XbrgwqwKyCUAVeQMSE7Lvg': 3.875,
#  '2Fvbxp9SSBj0jGl0Wpsyug': 3.923076923076923,
#  '_yEXH2SP25G12gVjni5IJg': 3.652173913043478,
#  'J0ZPW95M2F8PH9w9XdBpDg': 4.173913043478261,
#  'ikEbNrDG-0Qtmo9FFb2qwg': 3.6744186046511627,
#  'Eypq5gLLjCapBVVnMw_MyA': 3.619047619047619,
#  'UYcmGbelzRa0Q6JqzLoguw': 3.5557251908396945,
#  '55JSQKPBoZP9GHf6squqIA': 3.5833333333333335,
#  '4xgbVGM9yklvk8zrOf7tiA': 4.166666666666667,
#  'ZiMiC7Jkm4lOOL1-fcQpMQ': 4.333333333333333,
#  '06xIElWq6CAvmtk1xHJWNA': 3.772727272727273,
#  'iW9kc8xqCulyXGRPrllvNA': 3.4285714285714284,
#  'l0-VQ8nA_oijpKlRB7dkow': 4.393939393939394,
#  'SoiacX2r2mvHqIh3GgRMUw': 3.8645833333333335,
#  'WlWgl1aWl-8wGZYUncV-2A': 4.0,
#  'yhJ1SVBSjC_R2viEh5AbUA': 3.3617021276595747,
#  'O11n5wP5sq_NtxEGF6dwMA': 3.8833333333333333,
#  'IfX18Uxx_zjipapPOG7CwQ': 3.2916666666666665,
#  'PTX3ps_kEII6VnHPXz2qAg': 4.266666666666667,
#  'RQlnSCjuqMnhR3Qk6j4KoA': 3.6893939393939394,
#  'RM7Spl6bORgnOwLO8SiaJg': 4.56,
#  'xWk0I0S9KWMB06wKUEDYxg': 3.8735632183908044,
#  'bc0sPPBlutfpvGgaw9SYgA': 5.0,
#  'w5bnlvDwF-vhsA6ENqxQAA': 3.6530612244897958,
#  'sjYH9lpV6O7kjq515V0XQQ': 3.3043478260869565,
#  'PYxHpeTz2ZxZNJEBIAJgvg': 3.782608695652174,
#  'BMxUzUaBnXCQ0r382-ygsg': 4.857142857142857,
#  'SnfOcGYcpgeWWPnjNgz1Sg': 3.6,
#  'B2F7f8NdlBUESv8cskE-jw': 3.4651162790697674,
#  'IUSDyfv9t2V0G3vrLd9ZVQ': 2.75,
#  'rn2DB_YX0BvToYe50RNr_Q': 3.418181818181818,
#  'QGtuYyH2w_R1r-X5BGmgzw': 4.0227272727272725,
#  'lvGlIBv4xkHiQBnNOuRYZQ': 3.5625,
#  'lf00pYEXIGjpfGtoOr5yOA': 3.7083333333333335,
#  'SvkOt67Q4pOw2oviK_13og': 4.461538461538462,
#  'yFqO3NGu5xHOo20Xs4JUjg': 4.176470588235294,
#  'wXZS42D0L8hoCiSh2Krc_A': 3.643884892086331,
#  'TmRKppBexBYGHtHaWE1w4w': 2.878787878787879,
#  '4JbHIqlHawoGQPpGigAkVQ': 4.75,
#  'hK4vjoYGOXX7lSYYWrTZyw': 4.363636363636363,
#  'tw0A3slIPPQoGTNF8yRJcg': 4.414634146341464,
#  'iyaQG1fqocn2snHrYU-FYg': 4.2,
#  ...}

# %%
# re-order the test set
test_user_business_pairs_tokenized = test_user_business_pairs_tokenized \
    .map(lambda x: (x[1], x[0]))

# %%
test_user_business_pairs_tokenized.first()
# Out:
# (1716, 20625)

# %%
# making predictions
results = test_user_business_pairs_tokenized\
    .leftOuterJoin(business_user_rating_sets)

# %%
results.first()
# Out:
# (9328,
#  (3668,
#   [(8199, 3.0),
#    (22347, 4.0),
#    (23888, 4.0),
#    (3597, 4.0),
#    (19064, 5.0),
#    (7186, 4.0),
#    (22003, 3.0),
#    (14790, 5.0),
#    (22982, 5.0),
#    (8375, 4.0),
#    (18949, 5.0),
#    (6022, 3.0),
#    (5416, 5.0),
#    (16661, 4.0),
#    (17769, 5.0),
#    (19165, 4.0),
#    (4916, 4.0),
#    (2274, 4.0),
#    (16515, 5.0),
#    (3894, 3.0),
#    (3474, 3.0),
#    (19503, 3.0),
#    (16749, 4.0),
#    (9311, 5.0),
#    (2931, 4.0),
#    (4512, 5.0),
#    (3561, 4.0),
#    (576, 4.0),
#    (925, 5.0),
#    (6648, 5.0),
#    (22357, 4.0),
#    (16570, 5.0),
#    (18618, 5.0),
#    (371, 3.0),
#    (19620, 3.0),
#    (4075, 4.0),
#    (26096, 4.0),
#    (25852, 3.0),
#    (19930, 5.0),
#    (3943, 5.0),
#    (22521, 3.0),
#    (22575, 5.0),
#    (12299, 4.0),
#    (21157, 5.0),
#    (10681, 4.0),
#    (441, 4.0),
#    (7871, 5.0),
#    (2048, 5.0),
#    (19577, 2.0),
#    (20061, 4.0),
#    (7171, 5.0),
#    (23851, 4.0),
#    (1704, 2.0),
#    (25848, 4.0),
#    (23148, 5.0),
#    (12725, 4.0),
#    (3027, 3.0),
#    (23643, 5.0),
#    (18228, 5.0),
#    (21373, 4.0),
#    (18031, 5.0),
#    (20253, 5.0),
#    (3659, 4.0),
#    (22521, 4.0),
#    (4089, 4.0),
#    (11161, 5.0),
#    (25870, 4.0),
#    (19156, 1.0),
#    (1600, 5.0),
#    (3465, 4.0),
#    (11817, 5.0),
#    (5969, 4.0),
#    (16209, 4.0),
#    (2627, 5.0),
#    (7526, 4.0),
#    (7849, 4.0),
#    (15043, 4.0),
#    (7517, 5.0),
#    (24776, 4.0),
#    (24124, 5.0),
#    (11813, 5.0),
#    (23055, 3.0),
#    (4274, 5.0),
#    (4671, 5.0),
#    (2226, 5.0),
#    (6165, 4.0),
#    (8213, 4.0),
#    (17353, 4.0),
#    (24608, 4.0),
#    (4660, 4.0),
#    (9186, 4.0),
#    (19974, 5.0),
#    (18949, 3.0),
#    (4092, 4.0),
#    (2675, 4.0),
#    (3975, 4.0),
#    (14646, 4.0),
#    (3468, 4.0),
#    (19258, 4.0),
#    (21628, 5.0),
#    (18422, 2.0),
#    (20272, 5.0),
#    (1864, 2.0),
#    (889, 4.0),
#    (14007, 5.0),
#    (5918, 4.0),
#    (6941, 4.0),
#    (12185, 4.0),
#    (23792, 4.0),
#    (14854, 3.0),
#    (20245, 5.0),
#    (2426, 4.0),
#    (5833, 5.0),
#    (5268, 4.0),
#    (9601, 4.0),
#    (17112, 4.0),
#    (23256, 4.0),
#    (21398, 4.0),
#    (7199, 3.0),
#    (9295, 5.0),
#    (13512, 5.0),
#    (9416, 5.0),
#    (12305, 4.0),
#    (12330, 4.0),
#    (10443, 5.0),
#    (3647, 4.0),
#    (5523, 5.0),
#    (16295, 5.0),
#    (19131, 4.0),
#    (1365, 5.0),
#    (367, 5.0),
#    (16791, 4.0),
#    (1220, 5.0),
#    (16122, 3.0),
#    (24600, 4.0),
#    (6614, 4.0),
#    (4393, 5.0),
#    (2345, 5.0),
#    (26058, 5.0),
#    (5643, 5.0),
#    (25060, 5.0),
#    (2532, 5.0),
#    (16686, 4.0),
#    (2889, 2.0),
#    (11922, 5.0),
#    (17633, 4.0),
#    (3384, 4.0),
#    (5877, 4.0),
#    (18252, 4.0),
#    (21141, 5.0),
#    (13467, 5.0),
#    (20996, 5.0),
#    (15949, 4.0),
#    (20698, 2.0),
#    (8981, 4.0),
#    (23241, 4.0),
#    (10978, 4.0),
#    (8910, 5.0),
#    (11687, 1.0),
#    (9997, 5.0),
#    (4641, 4.0),
#    (3719, 4.0),
#    (2261, 5.0),
#    (1620, 4.0),
#    (14886, 5.0),
#    (12195, 5.0),
#    (14727, 3.0),
#    (10949, 4.0),
#    (22967, 5.0),
#    (4816, 4.0),
#    (24979, 4.0),
#    (563, 5.0),
#    (19527, 5.0),
#    (24142, 2.0),
#    (24610, 4.0),
#    (19921, 4.0),
#    (23104, 1.0),
#    (6871, 5.0),
#    (25660, 4.0),
#    (21970, 3.0),
#    (11572, 3.0),
#    (12548, 4.0),
#    (15548, 5.0),
#    (25124, 4.0),
#    (17362, 4.0),
#    (16871, 4.0),
#    (10902, 4.0),
#    (19610, 4.0),
#    (12975, 4.0),
#    (1539, 5.0),
#    (8113, 5.0),
#    (13078, 5.0),
#    (12666, 2.0),
#    (24884, 5.0),
#    (382, 4.0),
#    (14718, 4.0),
#    (20591, 5.0),
#    (1965, 5.0),
#    (274, 4.0),
#    (22235, 4.0),
#    (3581, 3.0),
#    (6233, 3.0),
#    (1007, 3.0),
#    (24249, 5.0),
#    (9779, 4.0),
#    (7064, 5.0),
#    (12630, 5.0),
#    (18193, 2.0),
#    (5622, 4.0),
#    (21687, 3.0),
#    (5391, 4.0),
#    (15037, 4.0),
#    (10053, 2.0),
#    (6338, 4.0),
#    (3292, 4.0),
#    (11980, 5.0),
#    (21665, 5.0),
#    (21013, 4.0),
#    (24839, 5.0),
#    (25651, 3.0),
#    (10266, 4.0),
#    (13929, 5.0),
#    (22534, 5.0),
#    (22504, 4.0),
#    (13660, 5.0),
#    (18632, 1.0),
#    (24730, 5.0),
#    (16268, 4.0),
#    (3029, 5.0),
#    (13787, 5.0),
#    (25423, 4.0),
#    (14319, 5.0),
#    (24005, 4.0),
#    (16924, 4.0),
#    (17785, 4.0),
#    (2808, 5.0),
#    (23341, 5.0),
#    (14864, 2.0),
#    (22307, 4.0),
#    (2850, 4.0),
#    (8601, 4.0),
#    (17682, 5.0),
#    (3507, 4.0),
#    (3531, 3.0),
#    (23766, 5.0),
#    (4961, 4.0),
#    (12565, 5.0),
#    (9062, 5.0),
#    (25446, 5.0),
#    (21866, 5.0),
#    (22263, 5.0),
#    (1291, 4.0),
#    (2745, 4.0),
#    (341, 2.0),
#    (3312, 1.0),
#    (12728, 1.0),
#    (22366, 4.0),
#    (18196, 5.0),
#    (16422, 4.0),
#    (4217, 5.0),
#    (12449, 4.0),
#    (17053, 1.0),
#    (3098, 5.0),
#    (8809, 4.0),
#    (15536, 5.0),
#    (10219, 5.0),
#    (7876, 5.0),
#    (1438, 3.0),
#    (525, 4.0),
#    (25619, 4.0),
#    (117, 5.0),
#    (20980, 4.0),
#    (15233, 2.0),
#    (2059, 5.0),
#    (19540, 2.0),
#    (16005, 4.0),
#    (10992, 5.0),
#    (17977, 4.0),
#    (24740, 4.0),
#    (3349, 4.0),
#    (8986, 4.0),
#    (6878, 4.0),
#    (18141, 4.0),
#    (20881, 4.0),
#    (9125, 4.0),
#    (1808, 5.0),
#    (17477, 5.0),
#    (16319, 4.0),
#    (3524, 4.0),
#    (21799, 5.0),
#    (2785, 2.0),
#    (16607, 4.0),
#    (11390, 5.0),
#    (4960, 4.0),
#    (6174, 4.0),
#    (25972, 4.0),
#    (15043, 5.0),
#    (14391, 4.0),
#    (17744, 5.0),
#    (14945, 4.0),
#    (24915, 5.0),
#    (23002, 5.0),
#    (5634, 2.0),
#    (3572, 5.0),
#    (7215, 5.0),
#    (7978, 3.0),
#    (9693, 5.0),
#    (3478, 3.0),
#    (18949, 4.0),
#    (1059, 3.0),
#    (13188, 5.0),
#    (23329, 5.0),
#    (25885, 2.0),
#    (13758, 5.0),
#    (10338, 4.0),
#    (3718, 5.0),
#    (15484, 4.0),
#    (23850, 4.0),
#    (6270, 3.0),
#    (11129, 5.0),
#    (24813, 4.0),
#    (8873, 3.0),
#    (7446, 5.0),
#    (13932, 5.0),
#    (21569, 5.0),
#    (7694, 3.0),
#    (2274, 5.0),
#    (25966, 5.0),
#    (14543, 3.0),
#    (13581, 4.0),
#    (22904, 5.0),
#    (18861, 5.0),
#    (10535, 4.0),
#    (3155, 2.0),
#    (21365, 5.0),
#    (11262, 5.0),
#    (15739, 5.0),
#    (25818, 4.0),
#    (17666, 5.0),
#    (20232, 5.0),
#    (21923, 4.0),
#    (25425, 4.0),
#    (1603, 5.0),
#    (3516, 4.0),
#    (87, 5.0),
#    (15210, 4.0),
#    (23086, 4.0),
#    (10823, 4.0),
#    (9601, 5.0),
#    (22518, 4.0),
#    (4602, 4.0),
#    (12181, 5.0),
#    (3618, 5.0),
#    (4667, 2.0),
#    (11242, 5.0),
#    (20188, 4.0),
#    (13063, 5.0),
#    (19995, 4.0),
#    (10778, 4.0),
#    (10287, 4.0),
#    (488, 4.0),
#    (5980, 5.0),
#    (21157, 4.0),
#    (10928, 4.0),
#    (15163, 4.0),
#    (10846, 5.0),
#    (3764, 5.0),
#    (21602, 5.0),
#    (8687, 5.0),
#    (11206, 4.0),
#    (21532, 4.0),
#    (17225, 3.0),
#    (9517, 5.0),
#    (14488, 4.0),
#    (3670, 4.0),
#    (14761, 5.0),
#    (23176, 5.0),
#    (648, 5.0),
#    (11715, 5.0),
#    (19907, 5.0),
#    (2929, 5.0),
#    (22757, 4.0),
#    (21066, 5.0),
#    (9867, 5.0),
#    (9273, 5.0),
#    (13666, 3.0),
#    (7808, 4.0),
#    (19739, 5.0),
#    (4157, 4.0),
#    (4641, 5.0),
#    (1671, 5.0),
#    (11911, 5.0),
#    (20224, 5.0),
#    (15550, 5.0),
#    (16361, 5.0),
#    (20457, 5.0),
#    (23370, 3.0),
#    (23912, 4.0),
#    (5101, 4.0),
#    (20231, 4.0),
#    (16503, 3.0),
#    (25781, 4.0),
#    (11099, 5.0),
#    (17022, 4.0),
#    (13777, 5.0),
#    (2885, 4.0),
#    (16286, 3.0),
#    (19987, 4.0),
#    (14866, 4.0),
#    (22838, 5.0),
#    (22308, 3.0),
#    (15483, 5.0),
#    (8591, 5.0),
#    (11784, 5.0),
#    (22470, 5.0),
#    (11959, 4.0),
#    (25431, 5.0),
#    (26084, 5.0),
#    (19585, 5.0),
#    (25063, 5.0),
#    (16610, 3.0),
#    (7593, 4.0),
#    (116, 5.0),
#    (11849, 5.0),
#    (19906, 4.0),
#    (23274, 5.0),
#    (4771, 3.0),
#    (16010, 4.0),
#    (26030, 5.0),
#    (12571, 4.0),
#    (9597, 5.0),
#    (17655, 4.0),
#    (5677, 2.0),
#    (20037, 5.0),
#    (371, 4.0),
#    (5395, 5.0),
#    (140, 4.0),
#    (16980, 4.0),
#    (24855, 4.0),
#    (12330, 5.0),
#    (13751, 5.0),
#    (19819, 5.0),
#    (5840, 4.0),
#    (22002, 5.0),
#    (3967, 5.0),
#    (1365, 4.0),
#    (21378, 5.0),
#    (18467, 4.0),
#    (16358, 4.0),
#    (25201, 5.0),
#    (24575, 4.0),
#    (18583, 2.0),
#    (18729, 4.0),
#    (12476, 5.0),
#    (22122, 5.0),
#    (15978, 5.0),
#    (5643, 4.0),
#    (1486, 4.0),
#    (1572, 4.0),
#    (10170, 3.0),
#    (8146, 4.0),
#    (21101, 5.0),
#    (21619, 5.0),
#    (5143, 5.0),
#    (15171, 3.0),
#    (12878, 5.0),
#    (21881, 5.0),
#    (17283, 1.0),
#    (17144, 4.0),
#    (24684, 5.0),
#    (13889, 5.0),
#    (12731, 4.0),
#    (16433, 4.0),
#    (20038, 4.0),
#    (14917, 4.0),
#    (7775, 4.0),
#    (11022, 4.0),
#    (8467, 4.0),
#    (5260, 5.0),
#    (19596, 5.0),
#    (1572, 3.0),
#    (17290, 3.0),
#    (16648, 5.0),
#    (4647, 3.0),
#    (10442, 5.0),
#    (21177, 5.0),
#    (8324, 4.0),
#    (7510, 5.0),
#    (23808, 4.0),
#    (23412, 5.0),
#    (15038, 4.0),
#    (12322, 5.0),
#    (25477, 4.0),
#    (16345, 5.0),
#    (5168, 3.0),
#    (21924, 4.0),
#    (13696, 5.0),
#    (24334, 2.0),
#    (5096, 4.0),
#    (7985, 5.0),
#    (22012, 4.0),
#    (25332, 3.0),
#    (13512, 1.0),
#    (978, 5.0),
#    (3544, 5.0),
#    (2523, 5.0),
#    (6619, 5.0),
#    (18686, 4.0),
#    (13827, 4.0),
#    (15011, 5.0),
#    (11743, 4.0),
#    (2430, 5.0),
#    (2811, 5.0),
#    (25339, 5.0),
#    (10882, 5.0),
#    (16028, 5.0),
#    (24999, 3.0),
#    (2125, 5.0),
#    (5893, 4.0),
#    (12737, 3.0),
#    (21596, 4.0),
#    (9913, 4.0),
#    (18724, 4.0),
#    (292, 4.0),
#    (15725, 5.0),
#    (20772, 4.0),
#    (7399, 4.0),
#    (22934, 4.0),
#    (21909, 4.0),
#    (14927, 5.0),
#    (13646, 5.0),
#    (10660, 5.0),
#    (2392, 5.0),
#    (16781, 5.0),
#    (22038, 5.0),
#    (1528, 4.0),
#    (26134, 5.0),
#    (22849, 5.0),
#    (12982, 4.0),
#    (10266, 5.0),
#    (7947, 3.0),
#    (19803, 5.0),
#    (6863, 4.0),
#    (1411, 4.0)]))

# %%
results = results.mapValues(lambda x: user_based_model_predict(x, model, user_average_ratings, inverse_user_tokens_dict))

# %%
results.first()
# Out:
# (7920, (5038, 3.5992063492063493))

# %%
results = results.map(lambda x:
         {
             "user_id": inverse_user_tokens_dict[x[1][0]],
             "business_id": inverse_business_tokens_dict[x[0]],
             "stars": x[1][1]
         }
         ) \
    .collect()

# %%
results
# Out:
# [{'user_id': '98rLDXbloLXekGjieuQSlA',
#   'business_id': 'E96XW5-Me9nnBIkpg0nNBA',
#   'stars': 4.388888888888889},
#  {'user_id': '9iIhOj--TcuxmJ6CGHnBOw',
#   'business_id': '5fpXjlC71y_mKORnPdX5zA',
#   'stars': 3.4615384615384617},
#  {'user_id': '1q6K81JT5eing3VlloekvA',
#   'business_id': '5fpXjlC71y_mKORnPdX5zA',
#   'stars': 3.7083333333333335},
#  {'user_id': 'zviIkWQleYMGPeFyyGaVCw',
#   'business_id': '5fpXjlC71y_mKORnPdX5zA',
#   'stars': 3.111111111111111},
#  {'user_id': 'OjTzg-3qGUKtd9c2q9tnhQ',
#   'business_id': '5fpXjlC71y_mKORnPdX5zA',
#   'stars': 4.0},
#  {'user_id': 'BEE2u5krVuRG7kaAfx4cMw',
#   'business_id': 'InYPeA1WM9uGR_mA5Wia1g',
#   'stars': 3.3636363636363638},
#  {'user_id': 'is5vAvanYvmF-28i9no2LQ',
#   'business_id': 'NTQXBbCa5Ugj5lNr6E4J5w',
#   'stars': 3.391304347826087},
#  {'user_id': '6mMk9hO_RAbdGMEGeg3oWQ',
#   'business_id': 'NTQXBbCa5Ugj5lNr6E4J5w',
#   'stars': 3.5135135135135136},
#  {'user_id': 'w57Yn8npGhdDHmHFGKk2jA',
#   'business_id': 'NTQXBbCa5Ugj5lNr6E4J5w',
#   'stars': 4.294117647058823},
#  {'user_id': 'EpYamb9fMrQyv-wYUdPtIA',
#   'business_id': 'NTQXBbCa5Ugj5lNr6E4J5w',
#   'stars': 4.166666666666667},
#  {'user_id': '3Hn5PexeY0tir0uFWk4jJg',
#   'business_id': 'NTQXBbCa5Ugj5lNr6E4J5w',
#   'stars': 4.25},
#  {'user_id': 'n0r_0HkCFaC175vXtIVcaQ',
#   'business_id': 'NTQXBbCa5Ugj5lNr6E4J5w',
#   'stars': 4.551020408163265},
#  {'user_id': 'b1wjZL3EBm4h2vbeXjfcTA',
#   'business_id': 'NTQXBbCa5Ugj5lNr6E4J5w',
#   'stars': 4.2105263157894735},
#  {'user_id': '4Iwu57GSychxpqa4w4HAMQ',
#   'business_id': 'iPxDmZVbssspPtUEBnUyQw',
#   'stars': 4.0},
#  {'user_id': 'f--ona4DuvVKoKoumX4Tyg',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 3.769230769230769},
#  {'user_id': 'oDul78mjMnUw98BBuyPs3g',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 4.0},
#  {'user_id': 'l_fCnDWlT6UFLxwqguI_2g',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 3.3793103448275863},
#  {'user_id': 'j3ZRIArCfioGC5aeeRdaog',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 2.9285714285714284},
#  {'user_id': 'w-92U0za7XEY5b12t2qCJw',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 2.6363636363636362},
#  {'user_id': '7gcDkii2VD22uM0TI1Ap7A',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 4.461538461538462},
#  {'user_id': 'k8I8La2Wj-cEPgKsz3sO7g',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 4.185185185185185},
#  {'user_id': '60OhUP904CWpFUOWKdI1gg',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 3.625},
#  {'user_id': 'w2TcpGt0-70BZ666fZWnMA',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 4.153846153846154},
#  {'user_id': '3-0YHZtq01Peq6I7zzSN3A',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 4.2727272727272725},
#  {'user_id': 'Ehhqt8tceJuSF7I73J5ArQ',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 4.714285714285714},
#  {'user_id': 'Gm1xtIExtjjmyvddBZSIww',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 3.6666666666666665},
#  {'user_id': 'bo_i7rffQkbvaCFcb-2weQ',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 4.111111111111111},
#  {'user_id': 'OvHYa3jg6ZJceNH1XU772w',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 3.7857142857142856},
#  {'user_id': '-XPUcrd6F2wHVUITFAlOYA',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 4.25},
#  {'user_id': 'IOoUETTTS5hzN78Hyjjv5g',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 3.111111111111111},
#  {'user_id': 'FzA6wYMmV6O5C1VmngZfTw',
#   'business_id': 'm-xsH8VkcYtTTvp2Fa6Ajw',
#   'stars': 3.875},
#  {'user_id': 'FcWu03iLuGYGHbFXO556pA',
#   'business_id': 'wz_v1iSb2LmY1LOOIDFIhQ',
#   'stars': 4.141176470588236},
#  {'user_id': 'EVluxufybVB5bbzoOoMoxA',
#   'business_id': 'wz_v1iSb2LmY1LOOIDFIhQ',
#   'stars': 4.571428571428571},
#  {'user_id': '9Ld3tMbfaRaz0xLDU5BVCw',
#   'business_id': 'wz_v1iSb2LmY1LOOIDFIhQ',
#   'stars': 4.178571428571429},
#  {'user_id': 'N044aCKJv3G5WuvwT5AJcA',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.511111111111111},
#  {'user_id': 'LNLMsRqQ3Rx9VzJ7LbaRkQ',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.1666666666666665},
#  {'user_id': 'N3oNEwh0qgPqPP3Em6wJXw',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.782214156079855},
#  {'user_id': 'v6oGFvXjuJ5DMT3pUqMXnw',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.7954545454545454},
#  {'user_id': 'omYjiX9WyiBhyjX-0EEKUQ',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.6},
#  {'user_id': 'YrCZjdJ6jU2tQQCB6P0Dsw',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.7906976744186047},
#  {'user_id': '76CP9Yw-34M_rNnOcwXzkw',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.2},
#  {'user_id': '3A80C5JYpR83o-DqmemK1Q',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.166666666666667},
#  {'user_id': 'k9dPWLh91nj46fEsMrPxYA',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.9285714285714284},
#  {'user_id': 'SssXdhbeYJOCF6sfSFwC-Q',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.6301369863013697},
#  {'user_id': 'WwoM6hQbgPnzcX3taqK-xQ',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.9473684210526314},
#  {'user_id': 'JfnY0VcP63s5RF1sfOHjBQ',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.783132530120482},
#  {'user_id': 'ufn1IPTJP7mRlmQP3a5dIQ',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.660377358490566},
#  {'user_id': 'zgV0ZroIF956gw4cul8MHA',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.8764478764478763},
#  {'user_id': 'YMgZqBUAddmFErxLtCfK_w',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.541850220264317},
#  {'user_id': 'HdIjMHe6FtvTtJZt7vBKIw',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.857142857142857},
#  {'user_id': 'DoRCeCcJbrsM2BiAKj3trA',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.4505494505494507},
#  {'user_id': '_9dmaq_V3JAJYI5Mpyr30w',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.142857142857143},
#  {'user_id': '0KeT9NKimYkHN0wlrij-dg',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.522222222222222},
#  {'user_id': 'eh9uc8xHYR9-rki7fWggQQ',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.0},
#  {'user_id': 'b1M1M84HFN8_obj_5RBWeA',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.625},
#  {'user_id': 'Zb10UXC7hYFl0Hli-KOY4A',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.75},
#  {'user_id': 'I-0RAUZvL_E_HlaoyuBW7w',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 3.2857142857142856},
#  {'user_id': 'imUgKz_a1y8gWkDw8btwgA',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 2.875},
#  {'user_id': '0PDuIlK-VLy3oZNngNeaWQ',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.4},
#  {'user_id': 'IU2bzisRQmx2hT1JUaxdLw',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.5},
#  {'user_id': 'HwFOmwRTlCTnr-nXi0YV1Q',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.0625},
#  {'user_id': 'L2-hLqX1stB9xD2aJCJMYg',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 2.1176470588235294},
#  {'user_id': 'l9FhTx_Q8VtWmGc2IdN3Vg',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.785714285714286},
#  {'user_id': 'hIRRLWoY7m6gP_ws7jO1Rg',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.142857142857143},
#  {'user_id': 'uL0-qCTIi21KWQPZZCzmzQ',
#   'business_id': '5_ymZOB8eIfi6nzzL5-SbQ',
#   'stars': 4.833333333333333},
#  {'user_id': 'rdz9QHEPoecQ7DJk49ZI-g',
#   'business_id': '6MpOzb5ImLdDXHsn4HwI-Q',
#   'stars': 3.9166666666666665},
#  {'user_id': 'ldqh2aWLTW6D2RHDCj_2TA',
#   'business_id': '6MpOzb5ImLdDXHsn4HwI-Q',
#   'stars': 3.72},
#  {'user_id': 'PKEzKWv_FktMm2mGPjwd0Q',
#   'business_id': '6MpOzb5ImLdDXHsn4HwI-Q',
#   'stars': 3.6078224101479917},
#  {'user_id': 'O5wlSc2GODv_YG826f67Ug',
#   'business_id': '6MpOzb5ImLdDXHsn4HwI-Q',
#   'stars': 4.428571428571429},
#  {'user_id': 'HMhkj1hsA6MzVyzwraRzng',
#   'business_id': '6MpOzb5ImLdDXHsn4HwI-Q',
#   'stars': 4.5},
#  {'user_id': 'Crh9gnrLT1YvOM4l_VdweQ',
#   'business_id': '6MpOzb5ImLdDXHsn4HwI-Q',
#   'stars': 4.444444444444445},
#  {'user_id': '5PTZFJ0etDjWN3BvbqNDVg',
#   'business_id': '6MpOzb5ImLdDXHsn4HwI-Q',
#   'stars': 4.7924528301886795},
#  {'user_id': 'sys6XtOZVLDzwn3qistBKw',
#   'business_id': '6s7uduX1Q1KSjOKvwxYkRA',
#   'stars': 3.875},
#  {'user_id': 'dF6j86LQWN3RS0r-Oz5Q2A',
#   'business_id': '6s7uduX1Q1KSjOKvwxYkRA',
#   'stars': 3.690909090909091},
#  {'user_id': '6n5JvhRD403_-rFQob_Vyw',
#   'business_id': '6s7uduX1Q1KSjOKvwxYkRA',
#   'stars': 3.642857142857143},
#  {'user_id': 'De-dImXf-TOFWWPTUWwIvw',
#   'business_id': '6s7uduX1Q1KSjOKvwxYkRA',
#   'stars': 4.048780487804878},
#  {'user_id': '1wLCq_1Gy6ingAE4uBSV2g',
#   'business_id': '6s7uduX1Q1KSjOKvwxYkRA',
#   'stars': 4.230769230769231},
#  {'user_id': 'DJ-ZFC5RLfEO9z2H7PFffA',
#   'business_id': '6s7uduX1Q1KSjOKvwxYkRA',
#   'stars': 3.7142857142857144},
#  {'user_id': 'xL4EOIKW6ZRM06T1lMjb_w',
#   'business_id': '6s7uduX1Q1KSjOKvwxYkRA',
#   'stars': 3.6666666666666665},
#  {'user_id': 'C_CqWSkpn2aOnUXtHx0-iw',
#   'business_id': 'IPL9C2A4GfpBuLNe9k4qYQ',
#   'stars': 4.22972972972973},
#  {'user_id': '9xgTU7KxnPEwOKXkaPSY4A',
#   'business_id': 'IPL9C2A4GfpBuLNe9k4qYQ',
#   'stars': 2.967741935483871},
#  {'user_id': 'xFIJOdPk3SQWUm4wadPnUg',
#   'business_id': 'IPL9C2A4GfpBuLNe9k4qYQ',
#   'stars': 4.444444444444445},
#  {'user_id': 'Lgd6-9JZy7bSuE2RFgpyoQ',
#   'business_id': 'IPL9C2A4GfpBuLNe9k4qYQ',
#   'stars': 3.909090909090909},
#  {'user_id': '9bZRfbCsuqatVXJzbYSrzQ',
#   'business_id': 'IPL9C2A4GfpBuLNe9k4qYQ',
#   'stars': 3.942857142857143},
#  {'user_id': 'dzu58-1_m1g91ZXYOhmVXA',
#   'business_id': 'IPL9C2A4GfpBuLNe9k4qYQ',
#   'stars': 3.5384615384615383},
#  {'user_id': 'ByIMZrqficXy9bhztQbJRw',
#   'business_id': 'IPL9C2A4GfpBuLNe9k4qYQ',
#   'stars': 3.888888888888889},
#  {'user_id': 'NEN5RFpZp7DE6K1PK2KZzg',
#   'business_id': 'OBvPj3NiXxt47fjsQ0edsQ',
#   'stars': 3.9625},
#  {'user_id': '3hWJxx8-gMutgaKY2T7IKQ',
#   'business_id': 'OBvPj3NiXxt47fjsQ0edsQ',
#   'stars': 3.5267175572519083},
#  {'user_id': 'zWm22VdQMQQNZxRua5W51g',
#   'business_id': 'OBvPj3NiXxt47fjsQ0edsQ',
#   'stars': 2.6},
#  {'user_id': 'Vibnqwm5vB17oag5etg_wQ',
#   'business_id': 'c06xDgPtZDKsI-w0Z_eujg',
#   'stars': 3.3333333333333335},
#  {'user_id': 'twkMzQGzP3umqj3VjoiZKQ',
#   'business_id': 'c06xDgPtZDKsI-w0Z_eujg',
#   'stars': 3.490566037735849},
#  {'user_id': 'ACMYTmlycF2-HgSZ8lyC0A',
#   'business_id': 'nUqR8iIJt2J91bo6U5g6rQ',
#   'stars': 4.376470588235295},
#  {'user_id': 'fuMLnjEjt3_GM5rc0XJY2Q',
#   'business_id': 'nUqR8iIJt2J91bo6U5g6rQ',
#   'stars': 3.5869565217391304},
#  {'user_id': 'i9ny3oipXJMfZezK983RAw',
#   'business_id': 'p7vxpHPxOQi1Qr5cDoEpQg',
#   'stars': 3.5454545454545454},
#  {'user_id': 'xPSXDnjJ_oXoVSlkvmDItA',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 3.5285714285714285},
#  {'user_id': 'b3tK3CkLOfrWpSuvn9Yo1g',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.481481481481482},
#  {'user_id': 'cGn3B71bNKlVigJLjHVNzg',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.125},
#  {'user_id': 'yLaZk0HDmySN49H5l4niOQ',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 3.875},
#  {'user_id': 'XEH2VtVx5ZYATKEM4jZOXg',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.271028037383178},
#  {'user_id': 'zuJwiAXFGQ4_Dfozybx5kg',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 3.6774193548387095},
#  {'user_id': 'vENR70IrUsDNTDebbuxyQA',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 3.45},
#  {'user_id': '_E1i0Hzko-jE4whky_ds1A',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.473684210526316},
#  {'user_id': 'jPcrABeWgWlTPi-E0Op_aA',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 3.566666666666667},
#  {'user_id': '4j5syz3FV5yPuWRSZA_-rQ',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 3.875},
#  {'user_id': 'vUcAM6d1K3nVnLUtXQIU7A',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.428571428571429},
#  {'user_id': 'LhxC6t1GLcOxY5I7exFnFw',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 3.8333333333333335},
#  {'user_id': 'N5cTSxPNGm012ozk1xA1Xw',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.739130434782608},
#  {'user_id': 'NH778V12SNdpczpQumjySw',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.833333333333333},
#  {'user_id': 'MA3ZOeBjnVPGFx98mXooBg',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 3.6875},
#  {'user_id': '-QZUJr0kLsSc5PfiQYh_dQ',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.0},
#  {'user_id': 'xBGXJD0iFnPj_3foqa5DPA',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.153846153846154},
#  {'user_id': 'SyX94Qkpowm_9dsn1SDrCQ',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.096774193548387},
#  {'user_id': '4aRespr3mEIxRRoW9tio2A',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.083333333333333},
#  {'user_id': 'Fbb0xtV33sBhrWD2B6L3SQ',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.3076923076923075},
#  {'user_id': 'gMpRhZfnlVoVqy0o1oYazg',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 5.0},
#  {'user_id': 'C1wTIZiSON7VA_v6QOFWcQ',
#   'business_id': 'nlsibvBeSc8vfus2KuQatA',
#   'stars': 4.285714285714286},
#  {'user_id': 'Tdv7HZa4Hyjm-X0MtNmeag',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.837078651685393},
#  {'user_id': 'TnhTyk1qfJ8jL2bHpeTrhQ',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.7857142857142856},
#  {'user_id': 'IDl8QswIXwI6Fr6KW3TbRw',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.46875},
#  {'user_id': '8X1yYVqGXuhHW65oEVwBsw',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.923076923076923},
#  {'user_id': 'ZbkA2bI3HGqQmy_z-YWAmg',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.65},
#  {'user_id': 'eOIMO2wT_WbNqmavhnCRxw',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.6451612903225805},
#  {'user_id': 'yV5GOIgaB2U2ilb7kj1ybg',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.8181818181818183},
#  {'user_id': 'pOGoWnHqeV_XkW1IEH0TsQ',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.304347826086956},
#  {'user_id': 'Spgm6HFWgc4YXJlbhg11Pg',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.5517241379310347},
#  {'user_id': 'XRSdeFZosqxyykWA1Ii3HA',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.045454545454546},
#  {'user_id': 'DeVGAiOf2mHVUDfxvuhVlQ',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.2181069958847734},
#  {'user_id': 'vWP8-aQX0rYJszqkWVL7Ew',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.630901287553648},
#  {'user_id': 'F_5_UNX-wrAFCXuAkBZRDw',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.0703125},
#  {'user_id': 'aEMadd3c9ufio64ngrDu8A',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.4054054054054053},
#  {'user_id': 'BjTabf62vN0c35MsUSINJA',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.7837837837837838},
#  {'user_id': 'JEwo8vAdGFX14pcbkNDm3w',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.0},
#  {'user_id': 'HlZWeFB-VBfeY5NNcXsC6g',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.28},
#  {'user_id': 'CkqT3yGUeM_9vSbFES_O5w',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.321428571428571},
#  {'user_id': 'sW5b9NR-vV1ypVS1Gd_1TQ',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.137931034482759},
#  {'user_id': '2Z29fLaeLtGnNroTuHyJ2A',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.7241379310344827},
#  {'user_id': 'rXSTTSDOhcjLrv16kWsM2w',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.535714285714286},
#  {'user_id': 'wIHlfo_U6M9-2OTHKf_D3g',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.190476190476191},
#  {'user_id': 'Cg189N5utFD_4VxXImPZjg',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.9375},
#  {'user_id': 'kkPgJv6KBFN15caG7NYYlg',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.157894736842105},
#  {'user_id': 'TPxipHcMRZh6KcV5uUNWyA',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 5.0},
#  {'user_id': 'B2Pv4Tnekou6jsVZ_C5JxA',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.0},
#  {'user_id': '-sby2p3gq-Ou0kBv6FsoXA',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 5.0},
#  {'user_id': '8JwSmvviX2dEAgaPRZ70nQ',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 5.0},
#  {'user_id': 'iuoWUmvleAusz0_T5iHNHg',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.444444444444445},
#  {'user_id': 'g4IdAWXgwno6KsIY7adJnQ',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.555555555555555},
#  {'user_id': 'yU6NK_18CmCtHB7OetPkoQ',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.666666666666667},
#  {'user_id': '2jUb855nZej5lsm7dVYwSQ',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 3.6923076923076925},
#  {'user_id': 'G1J-MuWmwt3PMfkSga1k-A',
#   'business_id': 'rioQ_p2pILNbJ4Xp5jW6-Q',
#   'stars': 4.648648648648648},
#  {'user_id': '7fyAtRSYYqOKZPr39L2UYg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.6666666666666665},
#  {'user_id': 'SZVBKjtG-x0Rmb0TmkHCLw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.0588235294117645},
#  {'user_id': 'ZQYNombDho1PYfnEWFZevw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.58974358974359},
#  {'user_id': 'Ik8PLdmfOR7j3WaQzP1PJQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.7058823529411766},
#  {'user_id': 'LaNC8-1OyFAZZH1HU-z9BA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.4375},
#  {'user_id': 'CLTqCD90vhQBLB9zN-pmzw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.769230769230769},
#  {'user_id': 'fgkJ6KUlrmbKyLDQervxsw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.7767857142857144},
#  {'user_id': 'Vp5DzIiP_MmaMZMZVFFltA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.789473684210526},
#  {'user_id': 'QIy3iLXjBUBqRzwd2lnWGQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.5},
#  {'user_id': 'Ryxj0u0AW3mRsRypdYli2A',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.2905982905982905},
#  {'user_id': 'gZ7mbHLlQsLd6S_i5U69tQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.1},
#  {'user_id': 'LkP5uU4ncr5MgNp8ercSCA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.90625},
#  {'user_id': '-pzlhxN6-DtuvpX4blnTxw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.9},
#  {'user_id': 'kiKyT3FN1H3d3jSTU5I3zg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.875},
#  {'user_id': 'BXW9PnbO6f5KSs1M2004KA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.727272727272727},
#  {'user_id': 'c2cPbYj-9lpy-aou4OkhdA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.7777777777777777},
#  {'user_id': 'XvVkluYp5Sx3aqpo1NFM4Q',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.0},
#  {'user_id': 'RRsbPGYyKJ3zqMMkzcHZaQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.6666666666666665},
#  {'user_id': 'Te18TxvzfLomGE56N7s3Dw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.4},
#  {'user_id': 'gmM7maEZA7FrV9XbGsThrQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.96},
#  {'user_id': 'YoalcArR_6rHWlzxXhHE8A',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.2857142857142856},
#  {'user_id': '4qmjySJprpPSKDoxHLIuEQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.5833333333333335},
#  {'user_id': 'IpI4NsEHYeAPLTRLppcHNQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.25},
#  {'user_id': 'dLuNvprTH04p6ZNCyjIq9g',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.736842105263158},
#  {'user_id': 'VYOQLKuR0Ugy9lU-QiOuLw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.5223880597014925},
#  {'user_id': 'UQa9RqoJZWAawzqN-2pT2Q',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.2666666666666666},
#  {'user_id': '4IjzfbO7XKFNWWVufHNhww',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.7142857142857144},
#  {'user_id': 'lOMM7HTHhabi1qofd-w7zw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.571428571428571},
#  {'user_id': 'VD8Ox-akHloK3-QV3FxY-g',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.4705882352941178},
#  {'user_id': 'Z202VYJ8Na3c7EVbZ_gtkA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.7142857142857144},
#  {'user_id': 'O3slQM5zE77Ga6qrxfpKoQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.8},
#  {'user_id': 'epkRB3J_oBEiyiwahvdmGg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.5031055900621118},
#  {'user_id': 'IJfJlr0BIu-dH1ie__MbNg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.892857142857143},
#  {'user_id': 'ubUJYqlLxTNA7yixnO9CDQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.4444444444444446},
#  {'user_id': 'HrsOUf77EUu3aydEo_OVmw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.5},
#  {'user_id': 'B1Qi1Fr4XgrqTz_c0RIs6g',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.25},
#  {'user_id': 'zqeOwIpO1a2IUXkU8s1oyg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.6923076923076925},
#  {'user_id': 'TgCLIZJnI4k0KFgt6hGQeg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.9},
#  {'user_id': 'x9g-i1DsB-VjSDGVOdRonA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.7551020408163267},
#  {'user_id': 'CiJat5Up2jAO3B0qTbiN5Q',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.896551724137931},
#  {'user_id': 'DoRCeCcJbrsM2BiAKj3trA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.4505494505494507},
#  {'user_id': 'qOODN0RsLbNQaLPN3srixQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.162162162162162},
#  {'user_id': 'Egxm2aSl_e9PoO-I-0XaLA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.4444444444444446},
#  {'user_id': '416uX1dOkO0kj8tkCfhnCw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.4545454545454546},
#  {'user_id': 'whINg-cC-FiAv_ATDGMDTg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.435483870967742},
#  {'user_id': 'cf-J2rZQyklNDFuTEeCIMw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.5454545454545454},
#  {'user_id': '-2UOdDlzg7XLuUuyOrldhA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.8461538461538463},
#  {'user_id': 'EiwxlbR8fb68lMgEXhcWKA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.5714285714285716},
#  {'user_id': 'mX84lBw8jwS2uQqdgKu_aA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.147058823529412},
#  {'user_id': 'jsRjSlPZ67OR4YEgoucbtg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 3.933333333333333},
#  {'user_id': 'AFdDw-Hxmyzadm8yK-XCig',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.3},
#  {'user_id': 'fculb8vYYR-85rYS-d10Xg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.125},
#  {'user_id': 'DeVGAiOf2mHVUDfxvuhVlQ',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.2181069958847734},
#  {'user_id': 'Oc_xwPthjKrNoMH_5-9Few',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.181818181818182},
#  {'user_id': 'daFKDurMk_AoULJeBfCqNw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.6},
#  {'user_id': 'mlAspUSI3gS9cBaljJgObg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.285714285714286},
#  {'user_id': 'Y6XH1iNsuuGAcO5nODI6rg',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.4},
#  {'user_id': '-Ow4AaVk8Y253eTADLxIDA',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.1},
#  {'user_id': 'px8P3jO0Jgr_Amwdvo-vuw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.857142857142857},
#  {'user_id': 'RqurJWeLYgt_-fDr_g5Fxw',
#   'business_id': 'uGupeWqih0yIcCg8anM1PA',
#   'stars': 4.181818181818182},
#  {'user_id': 'zRGtyW374pq0fNGcc-yTNQ',
#   'business_id': '-Sgt6wFx05Ox-O1ZSC3LOA',
#   'stars': 3.7},
#  {'user_id': 'YVn9hcc-GB_4UWx5r2ZyiA',
#   'business_id': '-Sgt6wFx05Ox-O1ZSC3LOA',
#   'stars': 3.0},
#  {'user_id': 'dqU621Ol6vswgP5BjDPU_w',
#   'business_id': '6T39H2dGUnrM91WqvR0VcQ',
#   'stars': 4.28},
#  {'user_id': 't4iVnHPd9lDKI9MDFkS4Hg',
#   'business_id': '6T39H2dGUnrM91WqvR0VcQ',
#   'stars': 4.181818181818182},
#  {'user_id': 'SiXUv1oE6uTAbbHXOaXy4Q',
#   'business_id': '6T39H2dGUnrM91WqvR0VcQ',
#   'stars': 4.357142857142857},
#  {'user_id': 'OPJ0TW8tt5UanY2_YpCgIQ',
#   'business_id': '6T39H2dGUnrM91WqvR0VcQ',
#   'stars': 3.9448818897637796},
#  {'user_id': '9teqovwDI0r7m1M-f5eq5w',
#   'business_id': '6T39H2dGUnrM91WqvR0VcQ',
#   'stars': 4.365853658536586},
#  {'user_id': 'qp0jdiDO-czs101-gt4CvA',
#   'business_id': '6T39H2dGUnrM91WqvR0VcQ',
#   'stars': 4.4375},
#  {'user_id': 'meKdytMEnFTncIBZ_IhYvA',
#   'business_id': '6T39H2dGUnrM91WqvR0VcQ',
#   'stars': 3.5},
#  {'user_id': 'BeeOV-pyDvxP7c6ZwH7bKg',
#   'business_id': '6T39H2dGUnrM91WqvR0VcQ',
#   'stars': 4.3},
#  {'user_id': 'QkUQFXgJTiTo2bOWwzVm2A',
#   'business_id': '6T39H2dGUnrM91WqvR0VcQ',
#   'stars': 4.833333333333333},
#  {'user_id': 'lxJEVNNn6iGjjxtDE9pOaw',
#   'business_id': '6T39H2dGUnrM91WqvR0VcQ',
#   'stars': 2.9285714285714284},
#  {'user_id': 'eYW6HKDCOLAf1COkxhVG5g',
#   'business_id': '9ehTNgvu0vZgHjWkQqF6KQ',
#   'stars': 4.209302325581396},
#  {'user_id': 'vpvW58vXP9xuOsWg-OCFxg',
#   'business_id': '9ehTNgvu0vZgHjWkQqF6KQ',
#   'stars': 3.8412698412698414},
#  {'user_id': '_3_4iBgr1JBjBsdwKD2zlg',
#   'business_id': 'Delyh_0oCJJGPta5We_SlA',
#   'stars': 4.8076923076923075},
#  {'user_id': '6wB4-Qeb6lMK6799IitdLQ',
#   'business_id': 'Delyh_0oCJJGPta5We_SlA',
#   'stars': 3.6153846153846154},
#  {'user_id': 'dvqgxx4hFcfraHvhddzOXA',
#   'business_id': 'Delyh_0oCJJGPta5We_SlA',
#   'stars': 3.5},
#  {'user_id': 'sjl8z9XTo0cQGnUedkzIPQ',
#   'business_id': 'P7Dqa0IbcFgRZ1aK7CPAOw',
#   'stars': 3.8333333333333335},
#  {'user_id': 'GTCKY8Vaos3Bz8SoXyC0qQ',
#   'business_id': 'P7Dqa0IbcFgRZ1aK7CPAOw',
#   'stars': 2.5454545454545454},
#  {'user_id': 'xvtBlzl5ZPgrGiWLA97bGQ',
#   'business_id': 'XfUg7AJJliNGNFseki2y3Q',
#   'stars': 3.63265306122449},
#  {'user_id': 'Xl8DWmA8eaE7ygCGPfz8sQ',
#   'business_id': 'XfUg7AJJliNGNFseki2y3Q',
#   'stars': 3.142857142857143},
#  {'user_id': 'QRPfVvg8r7jufOe2Ha68sQ',
#   'business_id': 'XfUg7AJJliNGNFseki2y3Q',
#   'stars': 3.375},
#  {'user_id': 'P19z16iz5I9Hh4T99pY8Sg',
#   'business_id': 'XfUg7AJJliNGNFseki2y3Q',
#   'stars': 4.148648648648648},
#  {'user_id': 'ycAQG7RWywLfOhc10C4A-Q',
#   'business_id': 'XfUg7AJJliNGNFseki2y3Q',
#   'stars': 3.5555555555555554},
#  {'user_id': 'AVegkpnPVnmDOREOa37BAQ',
#   'business_id': 'XfUg7AJJliNGNFseki2y3Q',
#   'stars': 3.9},
#  {'user_id': 'ZooIUtPN1ZCmUWN1kv8xUQ',
#   'business_id': 'YR_k9zvSFn60bzjmoaMrOg',
#   'stars': 4.2105263157894735},
#  {'user_id': 'AhwUJOe4tQtzXi-nP_ma4Q',
#   'business_id': 'YR_k9zvSFn60bzjmoaMrOg',
#   'stars': 4.0},
#  {'user_id': 'hDxmUDG5PYF0a-pWP-fDOA',
#   'business_id': 'YR_k9zvSFn60bzjmoaMrOg',
#   'stars': 4.2727272727272725},
#  {'user_id': 'mQ53aut35LWpCmyQ-b5IXQ',
#   'business_id': 'aAkzcX2aPYXhY9OtBVD7-A',
#   'stars': 4.714285714285714},
#  {'user_id': 'MEBWqqaUOnxVLjvEcNZJWA',
#   'business_id': 'aAkzcX2aPYXhY9OtBVD7-A',
#   'stars': 3.2580645161290325},
#  {'user_id': 'PKEzKWv_FktMm2mGPjwd0Q',
#   'business_id': 'jfKk7kPCESFO4DsQQu5SNw',
#   'stars': 3.6078224101479917},
#  {'user_id': 'fTt_rcnc-nNpjWaDrbvEow',
#   'business_id': 'jfKk7kPCESFO4DsQQu5SNw',
#   'stars': 3.635135135135135},
#  {'user_id': 'RQlnSCjuqMnhR3Qk6j4KoA',
#   'business_id': 'jfKk7kPCESFO4DsQQu5SNw',
#   'stars': 3.6893939393939394},
#  {'user_id': 'fKPEVpkLdcLz2cIdhgOiSQ',
#   'business_id': 'ow9r_DRGqgpiNUr4SXBHrw',
#   'stars': 3.3},
#  {'user_id': 'jVV1jqwx7MTKm1nhs1gVpA',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 3.111111111111111},
#  {'user_id': 'ju3HIitwo4seyPGiZIc40w',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 3.05},
#  {'user_id': 'xFSLb_pxXta5G4oaRB1ylQ',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 4.09433962264151},
#  {'user_id': '9BuTUHt6Zlm-UCjaGD6aJQ',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 2.7473684210526317},
#  {'user_id': 'hPoyOGAnbjJ6IKbJQ1UABQ',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 4.461538461538462},
#  {'user_id': '_5eUkJQKNUc0lVAHnTp4pA',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 4.48},
#  {'user_id': 'loQ-44OXWfpGPWspl7iqVg',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 4.64},
#  {'user_id': 'OJEe-_8YdU71GkbuGt0CDg',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 4.208333333333333},
#  {'user_id': 'fw77NvoY5DNTXdpuSf862A',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 2.7},
#  {'user_id': 'v8B9xbrsahpn0_nujJRkvw',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 4.333333333333333},
#  {'user_id': '6qPMkT8kb5jGFxvDH3GaTA',
#   'business_id': '-C8S2OPEOI1fL-2Q41tWVA',
#   'stars': 4.375},
#  {'user_id': '8la7DygWKVkfpDatXztktg',
#   'business_id': 'VfYjrvBqXDttErkUi_6_7w',
#   'stars': 3.741573033707865},
#  {'user_id': 'zFL4oW2ipBFwas8754XFGQ',
#   'business_id': 'VfYjrvBqXDttErkUi_6_7w',
#   'stars': 3.35},
#  {'user_id': 'I-ccY4mtepA9oFl6n-9Q2w',
#   'business_id': 'VfYjrvBqXDttErkUi_6_7w',
#   'stars': 3.6666666666666665},
#  {'user_id': '65Bcz8_Rbbrcz_HGpq9Y-g',
#   'business_id': '_vHI2zsJp7b02MFJUWJgbw',
#   'stars': 3.1012658227848102},
#  {'user_id': 'wLc6l8v7O9hXjrDi3Q7tyw',
#   'business_id': '_vHI2zsJp7b02MFJUWJgbw',
#   'stars': 4.086956521739131},
#  {'user_id': 'mIPlHNvX9wtIjhrfiF4ggA',
#   'business_id': '_vHI2zsJp7b02MFJUWJgbw',
#   'stars': 4.0},
#  {'user_id': 'xWCDD4AVIVjDfLZp5Qc5yQ',
#   'business_id': '_vHI2zsJp7b02MFJUWJgbw',
#   'stars': 3.891891891891892},
#  {'user_id': 'qAdAdIMD0AsrmCAKd9uiEg',
#   'business_id': '_vHI2zsJp7b02MFJUWJgbw',
#   'stars': 4.3},
#  {'user_id': 'sys6XtOZVLDzwn3qistBKw',
#   'business_id': '_vHI2zsJp7b02MFJUWJgbw',
#   'stars': 3.875},
#  {'user_id': 'EoHdx-byYkY0X3low3-Rgg',
#   'business_id': 'foPp-aKIZsWcsYf5zuhcNw',
#   'stars': 3.6792452830188678},
#  {'user_id': 'IeVYKQZObeFnKTa04oB5Gg',
#   'business_id': 'foPp-aKIZsWcsYf5zuhcNw',
#   'stars': 4.535714285714286},
#  {'user_id': 'FzsAwqRGE5GvVpbJ7LfuEw',
#   'business_id': 'i1-qbDDkvf0RlmkxewkHyA',
#   'stars': 3.72},
#  {'user_id': 'GQKroeIMvVG21BJTWwKUtg',
#   'business_id': 'i1-qbDDkvf0RlmkxewkHyA',
#   'stars': 4.428571428571429},
#  {'user_id': 'wmyoMUiW6YU9Audm0lACDg',
#   'business_id': 'n3JVzP4c1xXvFPPV0Pc04g',
#   'stars': 4.543478260869565},
#  {'user_id': 'QgC_KZOR2oqGepIbkVkLjQ',
#   'business_id': 'n3JVzP4c1xXvFPPV0Pc04g',
#   'stars': 3.0},
#  {'user_id': 'QPgAgjzE_uEHBEgm4Q0WEg',
#   'business_id': 'oplMwj97GyoG3emUEej99w',
#   'stars': 4.1692307692307695},
#  {'user_id': 'FEwPxhjdVKxSPVQQAHX2gg',
#   'business_id': 'uOfXyUQLtJFUvxGjiBUPoA',
#   'stars': 3.8109756097560976},
#  {'user_id': 'vX4zE6Plk7lOlSme_U2lKw',
#   'business_id': 'uOfXyUQLtJFUvxGjiBUPoA',
#   'stars': 2.9454545454545453},
#  {'user_id': 'Vr8JAUALxs8lb6_TwuabpA',
#   'business_id': 'uOfXyUQLtJFUvxGjiBUPoA',
#   'stars': 4.483870967741935},
#  {'user_id': 'okRZtLfI7tlfGqQxUo53fg',
#   'business_id': 'uOfXyUQLtJFUvxGjiBUPoA',
#   'stars': 4.3},
#  {'user_id': 'AuIK5tF2GjO7SftHawTLKw',
#   'business_id': 'uu5AtMrz_94e8kk4Gixg9Q',
#   'stars': 3.951219512195122},
#  {'user_id': 'QiyvjCMCGhqscz26JcfEkw',
#   'business_id': 'uu5AtMrz_94e8kk4Gixg9Q',
#   'stars': 4.0},
#  {'user_id': '0FMte0z-repSVWSJ_BaQTg',
#   'business_id': 'uu5AtMrz_94e8kk4Gixg9Q',
#   'stars': 3.538152610441767},
#  {'user_id': 'lXZ7aziyUJyA6V0FlIR1Wg',
#   'business_id': 'uu5AtMrz_94e8kk4Gixg9Q',
#   'stars': 3.573529411764706},
#  {'user_id': 'Wi0VgIrbb8vqU6weyVw6tg',
#   'business_id': 'uu5AtMrz_94e8kk4Gixg9Q',
#   'stars': 4.086956521739131},
#  {'user_id': 'A0Sy2srGc-AhXEuFoErDkw',
#   'business_id': 'uu5AtMrz_94e8kk4Gixg9Q',
#   'stars': 4.173076923076923},
#  {'user_id': 'CZnuW6YeZg7ZIiTbmI58BQ',
#   'business_id': 'uu5AtMrz_94e8kk4Gixg9Q',
#   'stars': 4.597222222222222},
#  {'user_id': 'MNRlASr0Hn9f2wvtvrxsjQ',
#   'business_id': 'yhgUyctWczUN13MinNgZ3w',
#   'stars': 3.75},
#  {'user_id': 'vpvW58vXP9xuOsWg-OCFxg',
#   'business_id': 'yhgUyctWczUN13MinNgZ3w',
#   'stars': 3.8412698412698414},
#  {'user_id': 'nlFiF0gCM9Tet3D-EYrH5A',
#   'business_id': 'yhgUyctWczUN13MinNgZ3w',
#   'stars': 4.0606060606060606},
#  {'user_id': 'Pd9iyEE_8ZPTv0zHNXiwZw',
#   'business_id': 'yhgUyctWczUN13MinNgZ3w',
#   'stars': 3.8},
#  {'user_id': 'Ue_7yUlkEbX4AhnYdUfL7g',
#   'business_id': 'ANbJU2y9q5kjqHyPW_x-Ow',
#   'stars': 4.34375},
#  {'user_id': 'ymPziCT9HyrXKB6CD9lgxA',
#   'business_id': 'ANbJU2y9q5kjqHyPW_x-Ow',
#   'stars': 3.7777777777777777},
#  {'user_id': 'lLS3A-62z7oJGj1KSso53g',
#   'business_id': 'LGQaDfMM20aRXIHbwXJp8w',
#   'stars': 4.157894736842105},
#  {'user_id': 'GTyx-peqMdbVec9Ja602LQ',
#   'business_id': 'LGQaDfMM20aRXIHbwXJp8w',
#   'stars': 3.6},
#  {'user_id': 'ltUb21ZilinnvIjGbO9FAQ',
#   'business_id': 'LGQaDfMM20aRXIHbwXJp8w',
#   'stars': 3.4791666666666665},
#  {'user_id': 'CrEBVkzIQs7tS-wWfaCjNQ',
#   'business_id': 'LnEaDZms5NfvZHLnvamgyA',
#   'stars': 3.8974358974358974},
#  {'user_id': 'quDu_Z0-i9TCYvdHRnULEw',
#   'business_id': 'LnEaDZms5NfvZHLnvamgyA',
#   'stars': 3.9696969696969697},
#  {'user_id': 'j5yf-kxSwuyrcQ4sYPBT3Q',
#   'business_id': 'LnEaDZms5NfvZHLnvamgyA',
#   'stars': 3.5714285714285716},
#  {'user_id': 'HunegbY8N9jHa1_dK_pFvw',
#   'business_id': 'LnEaDZms5NfvZHLnvamgyA',
#   'stars': 4.3},
#  {'user_id': 'YJNVwDdzwjwhptzh9y2vBg',
#   'business_id': 'ObOI8Vopk60YlPA32AQDBg',
#   'stars': 3.163265306122449},
#  {'user_id': 'Y6qBDFNgdIYwabFT8Vby5w',
#   'business_id': 'ObOI8Vopk60YlPA32AQDBg',
#   'stars': 3.3333333333333335},
#  {'user_id': 'f11jaYom5iLwuVPkYBFssw',
#   'business_id': 'ObOI8Vopk60YlPA32AQDBg',
#   'stars': 5.0},
#  {'user_id': 'BLaAsCSh6WI4pSnb1N3IYw',
#   'business_id': 'ObOI8Vopk60YlPA32AQDBg',
#   'stars': 3.8275862068965516},
#  {'user_id': 'szwtYEFdA9WXoXS2g9D3Gg',
#   'business_id': 'PDr3YWRcuWCxA9XDv08owg',
#   'stars': 4.473684210526316},
#  {'user_id': 'L6-_EsiHFy3a1K2kGOdm1g',
#   'business_id': 'PDr3YWRcuWCxA9XDv08owg',
#   'stars': 3.4705882352941178},
#  {'user_id': 'S8RI5ojv8kdLzBTQ5_1i7g',
#   'business_id': 'SLk2g7Lem-szfRAV5b2hoQ',
#   'stars': 5.0},
#  {'user_id': 'sR36qNl5SSbUZH4Kn960Iw',
#   'business_id': 'SLk2g7Lem-szfRAV5b2hoQ',
#   'stars': 4.363636363636363},
#  {'user_id': 'kzcq8pE-zDHE2Y7YaKkqqQ',
#   'business_id': 'SLk2g7Lem-szfRAV5b2hoQ',
#   'stars': 4.571428571428571},
#  {'user_id': 'IPlLcdNG426qOopHH4EwkQ',
#   'business_id': 'SLk2g7Lem-szfRAV5b2hoQ',
#   'stars': 3.5283018867924527},
#  {'user_id': 'phejNXvxr8fUE1CHJS5JcA',
#   'business_id': 'SLk2g7Lem-szfRAV5b2hoQ',
#   'stars': 4.230769230769231},
#  {'user_id': 'SNRhq0GYfoTdm87sNpn_Ww',
#   'business_id': 'SLk2g7Lem-szfRAV5b2hoQ',
#   'stars': 4.428571428571429},
#  {'user_id': 'Bfe564xSYnjvpfxknA4g8A',
#   'business_id': 'SLk2g7Lem-szfRAV5b2hoQ',
#   'stars': 3.625},
#  {'user_id': 'dIHHaoF-yyIvBFEOyEQ8Pw',
#   'business_id': 'SLk2g7Lem-szfRAV5b2hoQ',
#   'stars': 4.215909090909091},
#  {'user_id': '5Bs1BZcD6_wo_sUiAGe7FA',
#   'business_id': 'bPfvv7TvMLxxA3__VomsxQ',
#   'stars': 3.764705882352941},
#  {'user_id': '9buV4R83SPaE5THyTNkubg',
#   'business_id': 'bPfvv7TvMLxxA3__VomsxQ',
#   'stars': 4.266666666666667},
#  {'user_id': '-8syaSLDbMXW2F2FApVgig',
#   'business_id': 'q1rp-QrVnr_0tqH4fl-9zA',
#   'stars': 3.64},
#  {'user_id': 'Hqk48Hqul5YTl1DG8MhTUA',
#   'business_id': 'q1rp-QrVnr_0tqH4fl-9zA',
#   'stars': 4.2},
#  {'user_id': 'KRVoWUiPgnSrnDUtC-A12g',
#   'business_id': 'q1rp-QrVnr_0tqH4fl-9zA',
#   'stars': 4.375},
#  {'user_id': 'hqpYckXlzHgath-sxp1bWw',
#   'business_id': 'q1rp-QrVnr_0tqH4fl-9zA',
#   'stars': 4.090909090909091},
#  {'user_id': 'w0rOddG--P4h7ZZrQD2IcQ',
#   'business_id': 'q1rp-QrVnr_0tqH4fl-9zA',
#   'stars': 3.5833333333333335},
#  {'user_id': 'Ck4qmuLGN2vE1rRJqU4yqw',
#   'business_id': 'q1rp-QrVnr_0tqH4fl-9zA',
#   'stars': 3.0},
#  {'user_id': 'oJbAHPe3pLhQExQOWAS0Xg',
#   'business_id': 'q1rp-QrVnr_0tqH4fl-9zA',
#   'stars': 3.7777777777777777},
#  {'user_id': '4AjocDGdZNPyhBLQpxpa_Q',
#   'business_id': 'q1rp-QrVnr_0tqH4fl-9zA',
#   'stars': 3.669811320754717},
#  {'user_id': 'Bj_MarPEKBe2xN12YimekQ',
#   'business_id': 'xPirEAysB7zTgKzCpSoqFQ',
#   'stars': 4.1466666666666665},
#  {'user_id': '9nYGi-5vHUIUbr8t6cPX2w',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8333333333333335},
#  {'user_id': 'cdCvHUFdssePxowTHIo3dQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8666666666666667},
#  {'user_id': '2Na5lgDJwN1dPyvLmKmWgg',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.5714285714285716},
#  {'user_id': 'lkE4-o-k-rJyDxxmxqiZ5g',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.0},
#  {'user_id': 'DiU4XmSLGZQ6XfTwp8SSpw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.285714285714286},
#  {'user_id': 'NGf8elOfHZ3PPmt3UZIBlw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.555555555555555},
#  {'user_id': 'WwORJZIzZG0L5zFf0D1hIA',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.727272727272727},
#  {'user_id': '3UY0P5vAPTavFNTqqE2nVw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.0},
#  {'user_id': 'Rjd9Td7yYOqu0A1e2KDAyA',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.6470588235294117},
#  {'user_id': 'nmqX1cxPOYHwql5e4U9LuA',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.225806451612903},
#  {'user_id': 'Kx4RtLVvwFuH2F4hWKB0ig',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.871794871794872},
#  {'user_id': 'zBi_JWB5uUdVuz3JLoAxGQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.515748031496063},
#  {'user_id': 'xcW5lXyjxODJQATvB8xN5A',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.4166666666666665},
#  {'user_id': '2oxqbck3MJErUffBa6JIew',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.3684210526315788},
#  {'user_id': 'T9WkOx1h6EvgFEg8kM2aMw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.1},
#  {'user_id': '8rzqG5NLuDlnqE49USzvTw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8484848484848486},
#  {'user_id': 'e8VMhCCX9fLH0a9AwWytEQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.0},
#  {'user_id': 'C9uFU8rbWvQmCtk_3GAqUg',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.5454545454545454},
#  {'user_id': 'zpwWpno3U-oZaG3AJuKqSQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.214814814814815},
#  {'user_id': 'E1KlcWb0qYwRSsR-iYzkXg',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.823529411764706},
#  {'user_id': 'ePWsbOWDTJcgIus-BFuKpg',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.7976190476190474},
#  {'user_id': 'tXqVduTJHLbrrwVEO8JX6w',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.65},
#  {'user_id': 'kZJWAY828P8QZTqVYzhTCg',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.43859649122807},
#  {'user_id': 'IprKHet03baoU8heBOYuwQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.413793103448276},
#  {'user_id': 'Z1elyh9rDtx4S22uIo75-w',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.75},
#  {'user_id': 'ldqh2aWLTW6D2RHDCj_2TA',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.72},
#  {'user_id': 'NmJdxBB81JduuoalTUjqNQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.96},
#  {'user_id': 'ou3HegPkOmcKC_Ocodr9Mg',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.6},
#  {'user_id': '5RhE6tDc2xH6ySYGiSjiGQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8095238095238093},
#  {'user_id': '3WW_w0uI8HCRRaft0Yzv2g',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.352941176470588},
#  {'user_id': 'TMr715sCsKg-22WcMnjUlQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.6666666666666665},
#  {'user_id': '19ZvQNKbKKjlmj8v8JyAjw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8},
#  {'user_id': 'k8okFWX0acPR8c4L7XM55A',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8947368421052633},
#  {'user_id': 'jUZW1alRK8QvdZ-pH1OquQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.078947368421052},
#  {'user_id': 'Tdv7HZa4Hyjm-X0MtNmeag',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.837078651685393},
#  {'user_id': 'QcckMs29Z47tuSyWDCMUlA',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.6626506024096384},
#  {'user_id': 'GmQR50bIII7gDNRYEgfXfA',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.0},
#  {'user_id': '_ir8NHMtV7KPTwmBmlkmQw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.684931506849315},
#  {'user_id': '-ne-7caCLAk2j3kD7tzBGw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.4545454545454546},
#  {'user_id': '-2UOdDlzg7XLuUuyOrldhA',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8461538461538463},
#  {'user_id': 'y4xrOPXEB75lJaLjr7Rtaw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.5689655172413794},
#  {'user_id': 'W5UE4LllnPipYa0470mIwA',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8461538461538463},
#  {'user_id': 'HZYQoZfIvyuVjKUThw-o3g',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.25},
#  {'user_id': 'UXd56jH3f76kppekXqui9g',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.176470588235294},
#  {'user_id': '0mvmUHuGQL2kRRkX14CkTw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.25},
#  {'user_id': '6mYfeB7ZxsgNq0Peyt_eFg',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.0394736842105265},
#  {'user_id': 'bYrOWxXO60ElNCrCS4xntw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.375},
#  {'user_id': 'bTLYe1FJ4LNnwJAfaOxvEQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8823529411764706},
#  {'user_id': 'eectGb7-g_Xx7ftGqxr5bg',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.133333333333334},
#  {'user_id': 'teJhmB5DsIpAuqG1wrUVDw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.0},
#  {'user_id': '_VLJPIDqRMwtuF17Dcz-EQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.428571428571429},
#  {'user_id': '6TSQGF2-pSITBb9aXVCNAA',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.043478260869565},
#  {'user_id': '1Emn0g5YmOFVNyD-h372nQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.818181818181818},
#  {'user_id': '4wMh3OTCZrzV2OcJ_ey6tQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.083333333333333},
#  {'user_id': 'l4UZV5O50VKd04y4JvI9gw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.285714285714286},
#  {'user_id': '0so6layxcCRH2pv1OJUYJA',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.125},
#  {'user_id': 'tfb1Sw_C9PH6oOhAbMarDw',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8125},
#  {'user_id': 'AQGV3k1i3lshCi0_Voiy4Q',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.916666666666667},
#  {'user_id': 'MmHCNElMsS8wgKOW5EU94g',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.321428571428571},
#  {'user_id': '6pJICQMKi7CjMIKU-y9oTQ',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.8},
#  {'user_id': 'rLfg_CmTr8YvfHClN-uJ8w',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.6666666666666665},
#  {'user_id': 'OR_rfqfqV3WQSrqu71gFyg',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 4.7},
#  {'user_id': 'ghwqimFsDVMEUOYVDTdmxg',
#   'business_id': 'RwMLuOkImBIqqYj4SSKSPg',
#   'stars': 3.4},
#  {'user_id': 'vKsoRog51j2820WF8LV9YA',
#   'business_id': '0Q8qkmzeiYCTs7taERNHMw',
#   'stars': 4.397260273972603},
#  {'user_id': 'SZhN3WGCN5OJEvuYvNuyUg',
#   'business_id': '0Q8qkmzeiYCTs7taERNHMw',
#   'stars': 4.333333333333333},
#  {'user_id': 'OIa6ptM1qUts5arovQUAFQ',
#   'business_id': '1t5hd9IXLpBOv3ICtk-bCw',
#   'stars': 3.775},
#  {'user_id': 'bMUllZks5Vo6ut6NdLRpWw',
#   'business_id': '1t5hd9IXLpBOv3ICtk-bCw',
#   'stars': 4.875},
#  {'user_id': 'SyX94Qkpowm_9dsn1SDrCQ',
#   'business_id': '1t5hd9IXLpBOv3ICtk-bCw',
#   'stars': 4.096774193548387},
#  {'user_id': 'l-MTV8EvG_s5n0GVAlCOMA',
#   'business_id': '1t5hd9IXLpBOv3ICtk-bCw',
#   'stars': 3.111111111111111},
#  {'user_id': 'nYHTs61RuM-r9kJ8rCNsUw',
#   'business_id': '1t5hd9IXLpBOv3ICtk-bCw',
#   'stars': 4.384615384615385},
#  {'user_id': '3IBIIaiOrzVP-LTOLPBqRw',
#   'business_id': 'ASdkR68GWVdt6rQsiZAN5w',
#   'stars': 4.238095238095238},
#  {'user_id': 'YD58b0ZxmB6a2pdX4yjziw',
#   'business_id': 'ASdkR68GWVdt6rQsiZAN5w',
#   'stars': 4.5},
#  {'user_id': 'CMu9FmdK8xpiawJowJuGQg',
#   'business_id': 'ASdkR68GWVdt6rQsiZAN5w',
#   'stars': 3.625},
#  {'user_id': 'vbj1Avhvoa2RVm5suizHyw',
#   'business_id': 'VHW4OkWuFyQjb0ggEUgTPg',
#   'stars': 3.6923076923076925},
#  {'user_id': 'QaTPyZYd-hTdnzxonDonBw',
#   'business_id': 'VHW4OkWuFyQjb0ggEUgTPg',
#   'stars': 3.0},
#  {'user_id': 'YmuHitzT-bWAptpd1QY0YA',
#   'business_id': 'WqjHEdAftag4ixm09POepQ',
#   'stars': 3.1176470588235294},
#  {'user_id': 'Wamin4k5s07vLbx_jq4qcQ',
#   'business_id': 'WqjHEdAftag4ixm09POepQ',
#   'stars': 2.1666666666666665},
#  {'user_id': 'j3i9cNSQ8_Rj-6OQhRCt9w',
#   'business_id': 'WqjHEdAftag4ixm09POepQ',
#   'stars': 4.214285714285714},
#  {'user_id': 'JD7L3z31GmOuVsRRPyqdFQ',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 3.5},
#  {'user_id': 'q93KSB8PtxchdgcY17bH8Q',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 4.166666666666667},
#  {'user_id': 'ALw8EN21lby0vWtfD6JfIw',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 3.5357142857142856},
#  {'user_id': 'ss_Vle2x9Tm722QtzuR92Q',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 4.0},
#  {'user_id': '51UaY_JKrEOzA1CeEbuDNg',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 3.8923076923076922},
#  {'user_id': '2JUW4ay9IEcJSxMDSm-HBQ',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 4.0},
#  {'user_id': 'E6C-y4TjrnQOuBmep2Lvig',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 3.933333333333333},
#  {'user_id': 'Ed20T0T3jkAqVBBiyXju6A',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 3.3793103448275863},
#  {'user_id': 'hHvkUOtUvg9PT70-BMakEw',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 4.222222222222222},
#  {'user_id': 'GhCpWwQYJUc6tqe99lr5_w',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 4.0},
#  {'user_id': 'pf7pB-UbvKT-AWfQcg6kBg',
#   'business_id': 'a3APDveO8DSEIp7o1f24hw',
#   'stars': 3.875},
#  {'user_id': 'Jbd1x8jj3EgOkQMZ3RImKw',
#   'business_id': 'cjLf6ijfBz1WcsI3WEr-ww',
#   'stars': 3.75},
#  {'user_id': 'IIumEd4NKdw9Iglfx6NjWA',
#   'business_id': 'cjLf6ijfBz1WcsI3WEr-ww',
#   'stars': 3.3846153846153846},
#  {'user_id': 'U-nR7ND8CDN2x8ia73CH2Q',
#   'business_id': 'v6QXg4TI84FKEkcYGTrcNw',
#   'stars': 3.606060606060606},
#  {'user_id': 'vp93T_AshEE9blhTGtJWLg',
#   'business_id': 'v6QXg4TI84FKEkcYGTrcNw',
#   'stars': 3.59375},
#  {'user_id': 'Ad-v2Z4vvuzxZxbpywIm0A',
#   'business_id': 'v6QXg4TI84FKEkcYGTrcNw',
#   'stars': 4.0523255813953485},
#  {'user_id': '-Dzue1b_x1uaa8HzkzbwAg',
#   'business_id': 'v6QXg4TI84FKEkcYGTrcNw',
#   'stars': 1.3076923076923077},
#  {'user_id': 'w9z4RxpTpGg4pOlr1h2k_A',
#   'business_id': 'v6QXg4TI84FKEkcYGTrcNw',
#   'stars': 3.2857142857142856},
#  {'user_id': 'qYR-4ljU2Qa1ibxuGYpsGQ',
#   'business_id': 'v6QXg4TI84FKEkcYGTrcNw',
#   'stars': 3.375},
#  {'user_id': 'y8sguRYgpYbkdGHJwyHYPg',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.277777777777778},
#  {'user_id': '8XKSiMpMxgdwI3qjuqmXFg',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 3.711864406779661},
#  {'user_id': 'aSAeSk2JPDvl_tk_wT01nw',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.285714285714286},
#  {'user_id': 'dnsCCmwYrONjUAivm3XR4w',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 3.65625},
#  {'user_id': 'RzjEJQrq8FCy_9nHrmMB9g',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.045454545454546},
#  {'user_id': '825Ol4rTvAZnUyFMke37jA',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 3.934065934065934},
#  {'user_id': 'XB3jLxGXzD7euz3cGKdkMw',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 3.7333333333333334},
#  {'user_id': 'bydI3xl_ZpDZRbAQMAPITQ',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 3.9420289855072466},
#  {'user_id': 'vO0C8USUDuEtFbKZYqrbZg',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.444444444444445},
#  {'user_id': 'ejPlmOEPDsl0wHTqGau6Mw',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.2},
#  {'user_id': 'olGu2s7mGuSDPKcDbJpoaQ',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 3.857142857142857},
#  {'user_id': 'YV-6sw3s29CPDilatMaT2Q',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.136363636363637},
#  {'user_id': 'j0rZxHHAp8mImZ1x7Clm5Q',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.214285714285714},
#  {'user_id': '74sdrfg2SFhH3kAslZjjrg',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.0227272727272725},
#  {'user_id': 'l-r9iHW6XGtCraTmOSCH-A',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.104166666666667},
#  {'user_id': 'bEZjkjMe1HDWjec-R5O8bw',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 3.85},
#  {'user_id': 'pZ6P_1V-bTSoYG1fg1TXzw',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 3.981707317073171},
#  {'user_id': '4wpZiDawbO6n4ZSFrRt-Rw',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.363636363636363},
#  {'user_id': 'CG7vDoa2iGGrYQonSVn4Bw',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.298701298701299},
#  {'user_id': 'vscwczKGWKlwUOVwp8V5Cg',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 4.0},
#  {'user_id': 'Ulu30-Gz32RBggy_x8b-dA',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 3.875},
#  {'user_id': '-HcirMcpUDd3GvexCOCCzg',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
#   'stars': 3.0},
#  {'user_id': 'osZIl8D537mLeCNhrkfazQ',
#   'business_id': '0EgYXYjt2XJL4hlsKnzrcw',
# ...
#   'stars': 3.677350427350427},
#  {'user_id': 'Nh75diBuPgSSBMNoT5IGDA',
#   'business_id': 'UvF68aNDfzCWQbxO6-647g',
#   'stars': 3.8214285714285716},
#  {'user_id': 'UVxY0iyPaqY7s4BSFtt-xA',
#   'business_id': 'UvF68aNDfzCWQbxO6-647g',
#   'stars': 3.3783783783783785},
#  {'user_id': 'zh7sSdnM3CefK8RBRWahZQ',
#   'business_id': 'UvF68aNDfzCWQbxO6-647g',
#   'stars': 4.128205128205129},
#  {'user_id': '0guV-tXB82pi2stV7a5g5Q',
#   'business_id': 'UvF68aNDfzCWQbxO6-647g',
#   'stars': 3.909090909090909},
#  {'user_id': 'cImvLb3Wvd5EZ8SRjKAPsw',
#   'business_id': 'UvF68aNDfzCWQbxO6-647g',
#   'stars': 3.6216216216216215},
#  {'user_id': 'mU45slngHxgFkmx40yI8gQ',
#   'business_id': 'UvF68aNDfzCWQbxO6-647g',
#   'stars': 3.8666666666666667},
#  {'user_id': '3qRovLbdNAPbrRwL4I7MNA',
#   'business_id': 'UvF68aNDfzCWQbxO6-647g',
#   'stars': 3.6666666666666665},
#  {'user_id': 'ZgzRXqtwueWeHW_-nCWeXA',
#   'business_id': 'UvF68aNDfzCWQbxO6-647g',
#   'stars': 3.7777777777777777},
#  {'user_id': '2GNEzgkAKu7T1l3hdxjovQ',
#   'business_id': 'UvF68aNDfzCWQbxO6-647g',
#   'stars': 4.0},
#  {'user_id': 'y3FcL4bLy0eLlkb0SDPnBQ',
#   'business_id': 'xDMUoSI8yb7_FZlMqQGzkA',
#   'stars': 3.8856502242152464},
#  {'user_id': 'iwQsBQDrpQirBmmCxmzLeQ',
#   'business_id': 'xDMUoSI8yb7_FZlMqQGzkA',
#   'stars': 3.4942528735632186},
#  {'user_id': 'taTV9oXIavM3U6JqcBRm9A',
#   'business_id': 'xDMUoSI8yb7_FZlMqQGzkA',
#   'stars': 4.0},
#  {'user_id': 'rdHfno4-15xCufO-KPrm2Q',
#   'business_id': 'xDMUoSI8yb7_FZlMqQGzkA',
#   'stars': 3.875},
#  {'user_id': 'E-l859cXysR01w-_LjKsNw',
#   'business_id': '1d4OiPU75_KvXkgiBD35-g',
#   'stars': 3.8181818181818183},
#  {'user_id': 'cr7gSrG2Vc4AB-HE0l3SaA',
#   'business_id': '1d4OiPU75_KvXkgiBD35-g',
#   'stars': 3.56},
#  {'user_id': '8zBbj_W2qS13c8SGNF7Tbg',
#   'business_id': 'Izj6jNylEJCvCNj3_nTNBQ',
#   'stars': 4.0},
#  {'user_id': 'eLdwfNAeDzAK1h8MrTaojQ',
#   'business_id': 'Izj6jNylEJCvCNj3_nTNBQ',
#   'stars': 3.769230769230769},
#  {'user_id': 'fCeXNWuEwWGrG7qCP_EY0Q',
#   'business_id': 'Izj6jNylEJCvCNj3_nTNBQ',
#   'stars': 3.875},
#  {'user_id': 'ZlgmfdzsNpa8zD6NmSrcVA',
#   'business_id': 'Mn6PbumS7GL2v3jPilTaeg',
#   'stars': 3.375},
#  {'user_id': '29yBaTFMSh-l6wNwy9d_mA',
#   'business_id': 'Mn6PbumS7GL2v3jPilTaeg',
#   'stars': 3.302325581395349},
#  {'user_id': 'IwycOt-Ms4tsMO30arVfyg',
#   'business_id': 'Mn6PbumS7GL2v3jPilTaeg',
#   'stars': 3.6},
#  {'user_id': 'ugWxbTOPPYLjGQswi0QR3g',
#   'business_id': 'Mn6PbumS7GL2v3jPilTaeg',
#   'stars': 3.4444444444444446},
#  {'user_id': 'UyjOsdvAPTqwUvy581k8Tw',
#   'business_id': 'Mn6PbumS7GL2v3jPilTaeg',
#   'stars': 4.0},
#  {'user_id': 'QYGpsb5b9sQx_zKFHt3l3A',
#   'business_id': 'Mn6PbumS7GL2v3jPilTaeg',
#   'stars': 5.0},
#  {'user_id': 'QJdraewm6Gh24mbHIudzHg',
#   'business_id': 'Mn6PbumS7GL2v3jPilTaeg',
#   'stars': 4.0},
#  {'user_id': 'rtIBgGmyq6nHHPaU1E7Zmg',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.6744186046511627},
#  {'user_id': 'Yr2ju67IQb1hUdCf9MEGMw',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.88},
#  {'user_id': 'RfINmpF81jUmeXkW_KmB1w',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.583333333333333},
#  {'user_id': 'fcb3NvbGr9qaPPLUlSnk6A',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.416666666666667},
#  {'user_id': 'dEp7BNFhnjaMYWcJ_KqsyQ',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.423076923076923},
#  {'user_id': 'xWCDD4AVIVjDfLZp5Qc5yQ',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.891891891891892},
#  {'user_id': 'I510KttlB4dxqER7AueQnA',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.7857142857142856},
#  {'user_id': 'klmOwvl7gJLFcyzFCPRPFg',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.125},
#  {'user_id': '3wB-JjsUjkvdNUDRnChsVg',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.3947368421052633},
#  {'user_id': 'EQqor5tO_1L8lseEhpDYPA',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.5},
#  {'user_id': '1NpE-NHj7YC_EZXEzeDYqw',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.785714285714286},
#  {'user_id': '5QHBApQWyZ2Rlp-BGzYg7A',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.333333333333333},
#  {'user_id': 'GmQR50bIII7gDNRYEgfXfA',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.0},
#  {'user_id': 'EmWRBnsaKgpJLT2xmKJgiA',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.114285714285714},
#  {'user_id': 'AQpt0Lt4SWF5kFeUbvd88A',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.9583333333333335},
#  {'user_id': '_BjA6dgKK2Jeo4_Jm8B4eg',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.066666666666667},
#  {'user_id': 'UL5K2rnSYIPD1LcqPgbmDQ',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.725806451612903},
#  {'user_id': 'i_gbQdvN135NZbSn9oMS8w',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.789473684210526},
#  {'user_id': 'c4K6T9igqe5WSe-nMP-bNw',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.0},
#  {'user_id': '6QFyYvYgN1XcVfxMMMWxGw',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.8333333333333335},
#  {'user_id': 'j8ZZTMPIY9S3S3HV9862gw',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.6666666666666665},
#  {'user_id': 'n1pp7Kqj9p9HQACdbabkFQ',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.333333333333333},
#  {'user_id': '0X6-k6zxbbV8Crq5SITIkw',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.7777777777777777},
#  {'user_id': 'Ec7k5Nxp1rohv1f1nMU_ig',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.3181818181818183},
#  {'user_id': 'DyMhw62zEnMp3-9_ModB5A',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.8333333333333335},
#  {'user_id': 'VFDCUUyDEe4EK4ySPGWRPQ',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.875},
#  {'user_id': 'e6FXiDbuPC9PQhd20h79lg',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.090909090909091},
#  {'user_id': 'voNl6rXo9c-NuYIBIj5AQg',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.791666666666667},
#  {'user_id': '94r0BrYa6pVa8RoAFMm1DQ',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 4.2},
#  {'user_id': 'l-MTV8EvG_s5n0GVAlCOMA',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.111111111111111},
#  {'user_id': 'eptndiIAdcbw5I82sOh5Dg',
#   'business_id': 'bpRo8L8dkhgbJhdIKa9mwA',
#   'stars': 3.75},
#  {'user_id': '-0HhZbPBlB1YZx3BhAfaEA',
#   'business_id': 'cGHdjkXa2n9B2apkicdCXQ',
#   'stars': 3.7611940298507465},
#  {'user_id': 'Sd357RRT7uLQ3v52aQaLqw',
#   'business_id': 'cGHdjkXa2n9B2apkicdCXQ',
#   'stars': 3.5625},
#  {'user_id': 'GMyeEaiXMLIg712fG-v5yQ',
#   'business_id': 'cGHdjkXa2n9B2apkicdCXQ',
#   'stars': 4.5777777777777775},
#  {'user_id': '_tjHgQIRF7_HPdB3GKw9Dw',
#   'business_id': 'cGHdjkXa2n9B2apkicdCXQ',
#   'stars': 4.363636363636363},
#  {'user_id': 'QsRE2JN6sF9svFNVpfqx9Q',
#   'business_id': 'cGHdjkXa2n9B2apkicdCXQ',
#   'stars': 3.7142857142857144},
#  {'user_id': 'MdFC0NEXXZyNNDNIRcmNUQ',
#   'business_id': 'cGHdjkXa2n9B2apkicdCXQ',
#   'stars': 3.3125},
#  {'user_id': 'E9IlgNIKYTcu3E3kXz3rXw',
#   'business_id': 'cGHdjkXa2n9B2apkicdCXQ',
#   'stars': 3.3333333333333335},
#  {'user_id': 'N3oNEwh0qgPqPP3Em6wJXw',
#   'business_id': 'uenrK0IMuky3ChiX2sVvXw',
#   'stars': 3.782214156079855},
#  {'user_id': '1sghNitdObSPFhxqS5Othg',
#   'business_id': 'uenrK0IMuky3ChiX2sVvXw',
#   'stars': 4.080645161290323},
#  {'user_id': 'glv6L3h2NfEk5vdaufLU0A',
#   'business_id': 'uenrK0IMuky3ChiX2sVvXw',
#   'stars': 2.8},
#  {'user_id': 'igHwNbVd_gi0bUGECwiD1g',
#   'business_id': '1S2xTqqz1l-X20lCFTs-mw',
#   'stars': 4.333333333333333},
#  {'user_id': 'uP7zEIagg-ORBkbRQADsiQ',
#   'business_id': '8CNNs7jFv0yVptAvnga4xQ',
#   'stars': 3.7857142857142856},
#  {'user_id': 'BrKoAfW32omNcaFqW9pKsA',
#   'business_id': '8CNNs7jFv0yVptAvnga4xQ',
#   'stars': 3.902439024390244},
#  {'user_id': 'dORqNO8SY-0YGwoY8Nzk4Q',
#   'business_id': '8CNNs7jFv0yVptAvnga4xQ',
#   'stars': 3.25},
#  {'user_id': 'fiGqQ7pIGKyZ9G0RqWLMpg',
#   'business_id': '9t_kFVG77fs0qUA-MsvZHg',
#   'stars': 3.9763779527559056},
#  {'user_id': 'Cfwvos6oFlDquGiI2Qy1gQ',
#   'business_id': '9t_kFVG77fs0qUA-MsvZHg',
#   'stars': 4.186440677966102},
#  {'user_id': '_jTNDvLNoUJFJrld7MYBmQ',
#   'business_id': '9t_kFVG77fs0qUA-MsvZHg',
#   'stars': 4.12280701754386},
#  {'user_id': 'x0cbvislTvwFrzbYMXM3Gw',
#   'business_id': '9t_kFVG77fs0qUA-MsvZHg',
#   'stars': 4.166666666666667},
#  {'user_id': 'e1WA0YE3JpTg2Zb_lrHKQA',
#   'business_id': '9t_kFVG77fs0qUA-MsvZHg',
#   'stars': 3.685185185185185},
#  {'user_id': 'N8JIVlrbIV2-FkTetAkbnw',
#   'business_id': 'Kr5k9eEm-2dGBGGlF2HvaQ',
#   'stars': 4.3},
#  {'user_id': 'wwKQ3KG83TB3va3rUfIbTg',
#   'business_id': 'NEZCr0zLIPNYWNF57KsJJQ',
#   'stars': 4.519230769230769},
#  {'user_id': '75GS1krojLBSmw_xMi12Bw',
#   'business_id': 'NEZCr0zLIPNYWNF57KsJJQ',
#   'stars': 3.1666666666666665},
#  {'user_id': 'Fuekh1vNrATMHlE5k2NFMg',
#   'business_id': 'NEZCr0zLIPNYWNF57KsJJQ',
#   'stars': 4.461538461538462},
#  {'user_id': 'wqcO86hX2t2X9MsDIsIwnQ',
#   'business_id': 'NEZCr0zLIPNYWNF57KsJJQ',
#   'stars': 4.147058823529412},
#  {'user_id': 'XbrgwqwKyCUAVeQMSE7Lvg',
#   'business_id': 'NEZCr0zLIPNYWNF57KsJJQ',
#   'stars': 3.875},
#  {'user_id': 'NMx2Zxf2aLukc5SoDK5ypQ',
#   'business_id': 'NEZCr0zLIPNYWNF57KsJJQ',
#   'stars': 3.7},
#  {'user_id': 'wmE7kY21MnhX2_wQdeKz7A',
#   'business_id': 'NEZCr0zLIPNYWNF57KsJJQ',
#   'stars': 4.4},
#  {'user_id': '4slxBUw4gqvUpMynoUN6dg',
#   'business_id': 'b48IZPvY6MQO8MXK3uCNCQ',
#   'stars': 3.706896551724138},
#  {'user_id': 'YnQNGG0R5_a2XdXEgEpSIA',
#   'business_id': 'bvGdqJ-SeGdIHX-HEabwlg',
#   'stars': 3.727272727272727},
#  {'user_id': 'y3FcL4bLy0eLlkb0SDPnBQ',
#   'business_id': 'bvGdqJ-SeGdIHX-HEabwlg',
#   'stars': 3.8856502242152464},
#  {'user_id': 'p8rbNHeEVEFOK7jLvcDxLA',
#   'business_id': 'bvGdqJ-SeGdIHX-HEabwlg',
#   'stars': 4.294117647058823},
#  {'user_id': '9O8uWeJ3dZ1f7jygS7i4KA',
#   'business_id': 'bvGdqJ-SeGdIHX-HEabwlg',
#   'stars': 2.6666666666666665},
#  {'user_id': '577yFF9Pj8_zKZ2rxWTa8g',
#   'business_id': 'bvGdqJ-SeGdIHX-HEabwlg',
#   'stars': 4.2727272727272725},
#  {'user_id': 'A0Z_UchZuzddAJjnay2f0g',
#   'business_id': 'bvGdqJ-SeGdIHX-HEabwlg',
#   'stars': 4.8},
#  {'user_id': 'Wk--RNQokW9Jrj2vJuWBww',
#   'business_id': 'iHWC_tHYYZVAvDqlPvAP2Q',
#   'stars': 4.010752688172043},
#  {'user_id': 'y3BRV9BnG7OZTJ7mRcMP_A',
#   'business_id': 'iHWC_tHYYZVAvDqlPvAP2Q',
#   'stars': 4.0},
#  {'user_id': '1UYNRsT2BGyLA33y-1SElw',
#   'business_id': 'iHWC_tHYYZVAvDqlPvAP2Q',
#   'stars': 1.8181818181818181},
#  {'user_id': 'URb6znpCCVzd1kZvugedwg',
#   'business_id': 'jMZxeaQTu0fY0M4iv1cVyw',
#   'stars': 4.67741935483871},
#  {'user_id': '7Oe6ikklTjVBbEFw9emLcA',
#   'business_id': 'jMZxeaQTu0fY0M4iv1cVyw',
#   'stars': 4.189910979228487},
#  {'user_id': 'O7ojb5NC5XgIPSpTb3hK7Q',
#   'business_id': 'jMZxeaQTu0fY0M4iv1cVyw',
#   'stars': 3.1818181818181817},
#  {'user_id': '4Wg50q9gMmxKiM_ezkiIXg',
#   'business_id': 'jMZxeaQTu0fY0M4iv1cVyw',
#   'stars': 2.8333333333333335},
#  {'user_id': 'FIk4lQQu1eTe2EpzQ4xhBA',
#   'business_id': 'uiR2czejQmub7x3BW5u5Sg',
#   'stars': 4.0886075949367084},
#  {'user_id': 'U2mGtvRgKTHbxalQMcWyeg',
#   'business_id': 'uiR2czejQmub7x3BW5u5Sg',
#   'stars': 4.8},
#  {'user_id': 'cdns1znzy0twbXBJAXIqYQ',
#   'business_id': 'uiR2czejQmub7x3BW5u5Sg',
#   'stars': 4.1875},
#  {'user_id': 'pOGoWnHqeV_XkW1IEH0TsQ',
#   'business_id': 'uiR2czejQmub7x3BW5u5Sg',
#   'stars': 4.304347826086956},
#  {'user_id': 'y0axDGrceM7ve0chunw2Iw',
#   'business_id': 'vfVy-2M2K5xSl0g2dpWBZA',
#   'stars': 3.6666666666666665},
#  {'user_id': 'JEdU91t2ucPw-e__2eXnfg',
#   'business_id': 'vfVy-2M2K5xSl0g2dpWBZA',
#   'stars': 2.2857142857142856},
#  {'user_id': 'FTPe7VVwGDM8j9csFhShWA',
#   'business_id': 'vfVy-2M2K5xSl0g2dpWBZA',
#   'stars': 3.9242424242424243},
#  {'user_id': 'j76GJV2iludVhVrf2eiKlg',
#   'business_id': 'vfVy-2M2K5xSl0g2dpWBZA',
#   'stars': 4.545454545454546},
#  {'user_id': 'naFKYTD45_9IgfTNUrW_fQ',
#   'business_id': 'vfVy-2M2K5xSl0g2dpWBZA',
#   'stars': 3.7333333333333334},
#  {'user_id': 'CfGtdsu0Npd1Zjx43rXIqQ',
#   'business_id': 'vfVy-2M2K5xSl0g2dpWBZA',
#   'stars': 3.5217391304347827},
#  {'user_id': 'eytpwJXgg5nWU6jrlQ6qAA',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.5871559633027523},
#  {'user_id': 'bLbSNkLggFnqwNNzzq-Ijw',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.341501976284585},
#  {'user_id': 'Gab1_sLsjJLAJojoFd-d-g',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.5697674418604652},
#  {'user_id': '31S2OLWUDVVP7FJoowTBkg',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.5945945945945947},
#  {'user_id': 'dsaj_eA71FvpUh49zzKcGA',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.1904761904761907},
#  {'user_id': 'JqP9_2Ky-X1MRro0pBPPNQ',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.6470588235294117},
#  {'user_id': 'U4INQZOPSUaj8hMjLlZ3KA',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.65625},
#  {'user_id': 'OPJ0TW8tt5UanY2_YpCgIQ',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.9448818897637796},
#  {'user_id': 'C2C0GPKvzWWnP57Os9eQ0w',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.677350427350427},
#  {'user_id': 'U15Jw2bBUiRF1DalVV-PHg',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.739130434782609},
#  {'user_id': '3nIuSCZk5f_2WWYMLN7h3w',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.962686567164179},
#  {'user_id': 'rqKCE0ASDODEd3IHlRI-OA',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.9166666666666665},
#  {'user_id': 'Qdw5mcLXN26vjRV5mwa3Mg',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 2.875},
#  {'user_id': '0tSz5Gzf1SeNOGnq6a3pEQ',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 4.0},
#  {'user_id': 'bkZm5pMRKzo7B5IHyAVAUQ',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.95},
#  {'user_id': 'BVQ1p0g1wcKT7J689ROnSw',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.642857142857143},
#  {'user_id': 'U9-W_eMpvHa6MPA-3wpFcg',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.3636363636363638},
#  {'user_id': 'ztGOFVpMu06lk1WZ6zt0VQ',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 3.909090909090909},
#  {'user_id': 'TIhBPEujTLmdZNQsBgVEVg',
#   'business_id': '7xn6RDKmCanq2C8Fn-FNgg',
#   'stars': 4.416666666666667},
#  {'user_id': 'kmE8w5Y785eZmodsx0V6Ag',
#   'business_id': 'H0xrqDnQuei14LAkjEeInA',
#   'stars': 3.810344827586207},
#  {'user_id': 'Xj0O2l0bp633ebmG468aZw',
#   'business_id': 'H0xrqDnQuei14LAkjEeInA',
#   'stars': 3.289473684210526},
#  {'user_id': 'zvoDcHLURhJpHDIItLlJxQ',
#   'business_id': 'H0xrqDnQuei14LAkjEeInA',
#   'stars': 4.196078431372549},
#  {'user_id': 'IDVX4Is4CanREchBmpFXoA',
#   'business_id': 'H0xrqDnQuei14LAkjEeInA',
#   'stars': 4.0},
#  {'user_id': 'wuT2zH7Atq-98BirpB-8Aw',
#   'business_id': 'H0xrqDnQuei14LAkjEeInA',
#   'stars': 3.5106382978723403},
#  {'user_id': 'mnoe2vwouRADn97dTDkw4A',
#   'business_id': 'H0xrqDnQuei14LAkjEeInA',
#   'stars': 3.7714285714285714},
#  {'user_id': '51Dg7npqsTegnd1ZDxVb3w',
#   'business_id': 'H0xrqDnQuei14LAkjEeInA',
#   'stars': 3.8947368421052633},
#  {'user_id': 'bWTIMv6FKnkOEfxw7yR5jw',
#   'business_id': 'IuC3576zAW63PExF5d0vhA',
#   'stars': 3.380952380952381},
#  {'user_id': '3CVT71cTx_fLbLr9JFr-Cw',
#   'business_id': 'O1nxp1sVeB_uc7Ml8n9D-Q',
#   'stars': 4.1},
#  {'user_id': 'WfePuaS_iXGNGU6bfDe3JQ',
#   'business_id': 'UJButeGhEReFgTS9VJ7TBQ',
#   'stars': 3.4545454545454546},
#  {'user_id': 'UvY0E6Wuhv_0Bita52RPOw',
#   'business_id': 'jkAr4Dnoh7fZL66DNv6jqg',
#   'stars': 3.6930693069306932},
#  {'user_id': 'NnNdqH3DaleFtQk60UT-og',
#   'business_id': 'jkAr4Dnoh7fZL66DNv6jqg',
#   'stars': 4.111111111111111},
#  {'user_id': '9x8o-z3LQ2mIk0X9sQOTZQ',
#   'business_id': 'mbZe40oM-Ha-Q_qWh49-Mg',
#   'stars': 3.923076923076923},
#  {'user_id': 'EA-UgJmd-hQ8RBn1odmDJg',
#   'business_id': 'mbZe40oM-Ha-Q_qWh49-Mg',
#   'stars': 3.061224489795918},
#  {'user_id': 'g1gazid2muNbsgDa4E1KCA',
#   'business_id': 'mbZe40oM-Ha-Q_qWh49-Mg',
#   'stars': 4.3076923076923075},
#  {'user_id': 'znpuWlUd8i3UefN4KSyXcQ',
#   'business_id': 'mbZe40oM-Ha-Q_qWh49-Mg',
#   'stars': 3.92},
#  {'user_id': 'Kp5KHBSmV-Htc9NeSjJfPA',
#   'business_id': 'vmg_VdqXVOVhUoacU2pfdw',
#   'stars': 3.575438596491228},
#  {'user_id': '9SkCxhSPFVr28xkPXFAPCA',
#   'business_id': 'vmg_VdqXVOVhUoacU2pfdw',
#   'stars': 3.8666666666666667},
#  {'user_id': 'a8gTsX6gBLgt0eG9ecu77Q',
#   'business_id': 'vmg_VdqXVOVhUoacU2pfdw',
#   'stars': 3.6666666666666665},
#  ...]

# %%
[1,2,3][:2]
# Out:
# [1, 2]

# %%
a = 0
if a:
    print(1+1)
else:
    print(2+2)
# Out:
# 4

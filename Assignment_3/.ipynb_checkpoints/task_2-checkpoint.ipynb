# %%
import findspark
findspark.init()
from pyspark import SparkContext, SparkConf

# %%
import json
import math
import itertools
import random
import sys

# %%
conf = SparkConf()
# conf.set("spark.driver.memory", "4g")
# conf.set("spark.executor.memory", "4g")
conf.setMaster('local[8]')
conf.setAppName('Assignment_2')
sc = SparkContext.getOrCreate(conf)

# %%
import re
import string
escape_chars = r'[' + string.whitespace + ']'

# %%
def create_word_count_dict(word_list):
    count_dict = {}
    for word in word_list:
        if word not in count_dict:
            count_dict[word] = 0
        count_dict[word] += 1
    return count_dict

# %%
reviews_json = sc.textFile('asnlib/publicdata/train_review.json').map(json.loads)

# %%
reviews_json.first()
# Out:
# {'review_id': 'pxOrtki0sqXps5hSyLXKpA',
#  'user_id': 'OLR4DvqFxCKLOEHqfAxpqQ',
#  'business_id': 'zK7sltLeRRioqYwgLiWUIA',
#  'stars': 5.0,
#  'text': "Second time I've been here. First time was whatever. This time it was actually good. Way better than inn n out. It's the same type of burger that's why I put it up against that. I love that you can get grilled jalapeños. Just wish they came on the burger and not on the side.",
#  'date': '2015-12-19 07:35:30'}

# %%
users_token_dict = reviews_json.map(lambda x: x.get('user_id')).distinct().sortBy(lambda x: x).zipWithIndex().collectAsMap()

# %%
business_token_dict = reviews_json.map(lambda x: x.get('business_id')).distinct().sortBy(lambda x: x).zipWithIndex().collectAsMap()

# %%
users_token_dict

# %%
stop_words = set(word.strip() for word in open("asnlib/publicdata/stopwords"))

# %%
business_reviews = reviews_json \
        .map(lambda x: (x.get('business_id'), x.get('text'))) \
        .flatMap(lambda x: [(x[0], word) for word in re.split(escape_chars, x[1])]) \
        .map(lambda x: (x[0], x[1].lower().strip(string.punctuation)))  \
        .filter(lambda x: x[1] and x[1] != '' and x[1] not in stop_words and x[1] not in string.ascii_lowercase) \
        .groupByKey().map(lambda x: (x[0], list(x[1])))

# %%
business_reviews.take(10)
# Out:
# [('bZMcorDrciRbjdjRyANcjA',
#   ['listened',
#    'reviews',
#    'place',
#    'highly',
#    'unprofessional',
#    '1st',
#    'visit',
#    'great',
#    'signed',
#    'package',
#    'needed',
#    '2',
#    'months',
#    'directed',
#    'cancel',
#    'email',
#    'corporate',
#    '30',
#    'days',
#    'advance',
#    'paid',
#    'partial',
#    'month',
#    'directed',
#    'month',
#    'would',
#    'automatically',
#    'pulled',
#    'point',
#    'sent',
#    '4',
#    'emails',
#    'response',
#    'requesting',
#    'cancel',
#    '2nd',
#    'visit',
#    'recommended',
#    'lotion',
#    '30',
#    'holiday',
#    'weekend',
#    'special',
#    'advised',
#    'due',
#    'something',
#    'could',
#    'use',
#    'lotion',
#    'today',
#    'keep',
#    'store',
#    'another',
#    '2',
#    'days',
#    'thought',
#    'weird',
#    'hey',
#    'whatever',
#    'went',
#    'also',
#    '2nd',
#    'visit',
#    '2',
#    'bulbs',
#    'bed',
#    'lastly',
#    'would',
#    'would',
#    'started',
#    'package',
#    '2',
#    'days',
#    'later',
#    'would',
#    'got',
#    'following',
#    'month',
#    '1.00',
#    'highly',
#    'disappointing',
#    '3rd',
#    'visit',
#    'come',
#    'pick',
#    'lotion',
#    'problem',
#    'however',
#    'decided',
#    'ask',
#    'full',
#    'price',
#    'lotion',
#    'was...she',
#    'provided',
#    'price',
#    'tax...which',
#    'exactly',
#    'paid',
#    'girls',
#    'behind',
#    'desk',
#    'advised',
#    'would',
#    'need',
#    'go',
#    'corporate',
#    'difference',
#    'far',
#    'company',
#    'mess',
#    'believe',
#    'provide',
#    'front',
#    'line',
#    'proper',
#    'tools',
#    'provide',
#    'good',
#    'customer',
#    'service',
#    'really',
#    'trust',
#    'company',
#    'trust',
#    'staff',
#    'adjust',
#    'price',
#    '30',
#    'trust',
#    'enter',
#    'cancelation',
#    'baffles',
#    'really',
#    'like',
#    'tanning',
#    'salon',
#    'service',
#    'great',
#    'far',
#    "i've",
#    'tanned',
#    'regularly',
#    'couple',
#    'salons',
#    'town',
#    'loved',
#    'really',
#    'looking',
#    'convenience',
#    'close',
#    'gym',
#    "i'm",
#    'back',
#    'lvac',
#    'salon',
#    'parking',
#    'lot',
#    "couldn't",
#    'convenient',
#    'salon',
#    'clean',
#    'full',
#    'new',
#    'amazing',
#    'beds',
#    'informative',
#    'sales',
#    'reps',
#    'think',
#    'biggest',
#    'desires',
#    'tanning',
#    'salon',
#    "they've",
#    'met',
#    'body',
#    'heat',
#    'body',
#    'heat',
#    'pho',
#    'sagion8',
#    'well',
#    'came',
#    'first',
#    'time',
#    'location',
#    'maria',
#    'showed',
#    'around',
#    'different',
#    'beds',
#    'work',
#    'opposed',
#    'locations',
#    'im',
#    'used',
#    'great',
#    'since',
#    "i'm",
#    'new',
#    'henderson',
#    'even',
#    'gave',
#    'directions',
#    'around',
#    'stops',
#    'mentioned',
#    'make',
#    'disappointed',
#    'customer',
#    'service',
#    'corporate',
#    'went',
#    'bought',
#    'package',
#    'maria',
#    'paid',
#    'cash',
#    'never',
#    'told',
#    'tanning',
#    'tax',
#    'top',
#    '69.88',
#    'month',
#    'ok...is',
#    'credit',
#    'card',
#    'got',
#    'charged',
#    'monthly',
#    'fee',
#    'even',
#    'though',
#    'first',
#    'month',
#    'half',
#    'paid',
#    'cash',
#    'went',
#    'ask',
#    'mari',
#    'called',
#    'corporate',
#    'spoke',
#    'tara',
#    'billing',
#    'quote',
#    'unquote',
#    'direct',
#    "maria's",
#    'mouth.....said',
#    'first',
#    'time',
#    'corporate',
#    'done',
#    'client',
#    'body',
#    'heat',
#    'shady',
#    'lot',
#    'hmmmmmmm',
#    'told',
#    'call',
#    'tara',
#    'directly',
#    'corporate',
#    'standing',
#    'maria',
#    'speaking',
#    'tara',
#    'super',
#    'rude',
#    'told',
#    'nothing',
#    'could',
#    'call',
#    'credit',
#    'card',
#    'file',
#    'dispute',
#    'reverse',
#    'charge',
#    'said',
#    'account',
#    'canceled',
#    'want',
#    'cash',
#    'back',
#    'unused',
#    'portion',
#    'told',
#    'power',
#    'hung',
#    'called',
#    'back',
#    'told',
#    'everyone',
#    'office',
#    'whole',
#    'week...ummm...talking',
#    'right',
#    'told',
#    'body',
#    'heat',
#    'tara',
#    'one',
#    'speak',
#    'call',
#    'her......she',
#    'hung',
#    'meagain',
#    'called',
#    'back',
#    'sent',
#    'voice',
#    'mail',
#    'next',
#    'hour',
#    'called',
#    'told',
#    'thank',
#    'money',
#    'getting',
#    'back',
#    'hung',
#    'lot',
#    'options',
#    'city',
#    'better',
#    'deals...better',
#    'customer',
#    'service',
#    'already',
#    'sent',
#    'email',
#    'better',
#    'business',
#    'bureau',
#    'credit',
#    'card',
#    'body',
#    'heat',
#    'owes',
#    'cash',
#    'money',
#    'right',
#    'legit',
#    'stolen',
#    'money',
#    'manager',
#    'location',
#    'agreed',
#    'right',
#    'phone',
#    'corporate',
#    'cause',
#    'lot',
#    'locations',
#    'prices',
#    'cheap',
#    'willing',
#    'work',
#    'gonna',
#    'check',
#    'palm',
#    'beach',
#    'local',
#    'places',
#    'first',
#    'want',
#    'money',
#    'back',
#    'versa',
#    'spa',
#    'spray',
#    'tan',
#    'machine',
#    'much',
#    'much',
#    'better',
#    'one',
#    'maryland',
#    'parkway',
#    'spray',
#    'leave',
#    'streaks',
#    'clear',
#    'medium',
#    'actually',
#    'medium',
#    'shade',
#    'one',
#    'maryland',
#    'pkwy',
#    'left',
#    'uneven',
#    'streaky',
#    'plus',
#    'clear',
#    'medium',
#    'turned',
#    'super',
#    'light',
#    'may',
#    'little',
#    'bit',
#    'way',
#    'much',
#    'prefer',
#    'go',
#    'location',
#    'spray',
#    'tans',
#    'good',
#    'time',
#    'depends',
#    'go',
#    'eastern',
#    'busy',
#    'certain',
#    'times',
#    'girls',
#    'night',
#    'great',
#    'actually',
#    "haven't",
#    'location',
#    'couple',
#    'months',
#    'drove',
#    'realized',
#    'never',
#    'reviewed',
#    'reason',
#    'giving',
#    '1',
#    'star',
#    '100',
#    'customer',
#    'service',
#    'warned',
#    'customer',
#    'service',
#    'location',
#    'told',
#    'ask',
#    'specific',
#    'girl',
#    'friend',
#    'good',
#    'experience',
#    'asked',
#    'particular',
#    'girl',
#    'blonde',
#    'girl',
#    'rolled',
#    'eyes',
#    'said',
#    'fine',
#    "didn't",
#    'go',
#    'find',
#    "don't",
#    'know',
#    'thought',
#    'friend',
#    'either',
#    'way',
#    'potential',
#    'customer',
#    'first',
#    'sign',
#    'unacceptable',
#    'service',
#    'girl',
#    'told',
#    'came',
#    'extremely',
#    'sweet',
#    'happy',
#    'go',
#    'different',
#    'monthly',
#    'options',
#    'also',
#    'explained',
#    'free',
#    '7',
#    'day',
#    'trial',
#    'new',
#    'tanning',
#    'perfect',
#    'blonde',
#    'girl',
#    'spoke',
#    'twice',
#    'time',
#    'asked',
#    'nice',
#    'girl',
#    'told',
#    'manager',
#    'kind',
#    'person',
#    'hired',
#    'manager',
#    'particular',
#    'manager',
#    'dealing',
#    'customers',
#    'daily',
#    'basis',
#    'completely',
#    'unacceptable',
#    'made',
#    'worse',
#    'actually',
#    'seen',
#    'girl',
#    'different',
#    'location',
#    'several',
#    'months',
#    'mocked',
#    'physically',
#    'disabled',
#    'girl',
#    'also',
#    'appeared',
#    'work',
#    "didn't",
#    'sign',
#    'first',
#    'time',
#    'took',
#    'everything',
#    'act',
#    'irrationally',
#    'say',
#    'anything',
#    'might',
#    'regret',
#    'girl',
#    'deserve',
#    'job',
#    'let',
#    'alone',
#    'one',
#    'customer',
#    'service',
#    'asked',
#    'couple',
#    'workers',
#    'name',
#    'anybody',
#    'needs',
#    'contact',
#    'feel',
#    'free',
#    'get',
#    'details',
#    'needless',
#    'say',
#    'sign',
#    'free',
#    'week',
#    'love',
#    'also',
#    'love',
#    'new',
#    'one',
#    'opened',
#    'silverado',
#    'ranch',
#    'maryland',
#    'pkwy',
#    'tanning',
#    'beds',
#    'awesome',
#    'always',
#    'go',
#    'extreme',
#    'fgt',
#    'beds',
#    'also',
#    'fantastic',
#    "haven't",
#    'better',
#    'place',
#    'better',
#    'tanning',
#    'beds',
#    'monthly',
#    'fee',
#    'bit',
#    'pricey',
#    "i've",
#    'membership',
#    'almost',
#    'two',
#    'years',
#    "it's",
#    'totally',
#    'worth',
#    'go',
#    'best',
#    'beds',
#    'one',
#    'time',
#    'drop-in',
#    'session',
#    'expensive',
#    'get',
#    'pricey',
#    'go',
#    'time',
#    'like',
#    'location',
#    'way',
#    'one',
#    'college',
#    'horizon',
#    'girls',
#    'actually',
#    'front',
#    'desk',
#    'came',
#    'left',
#    'beds',
#    'lot',
#    'better',
#    'fans',
#    'clean',
#    'wish',
#    'would',
#    'used',
#    '10',
#    'month',
#    'membership',
#    "couldn't",
#    'get',
#    'location',
#    'lol',
#    'love',
#    'body',
#    'heat',
#    'aspen',
#    'always',
#    'remembers',
#    'name',
#    'always',
#    'helpful',
#    'questions',
#    'great',
#    'place',
#    'change',
#    '1',
#    'star',
#    '3',
#    'corporate',
#    'contacted',
#    'honoring',
#    'promotion',
#    'started',
#    '2',
#    'days',
#    'signed',
#    'next',
#    'month',
#    '1',
#    'corporate',
#    'also',
#    'agreed',
#    'adjust',
#    '30',
#    'charged',
#    'advised',
#    'see',
#    'credit',
#    '10',
#    'days',
#    'seen',
#    'credit',
#    'yet',
#    'day',
#    '4',
#    'opinion',
#    'still',
#    'stands',
#    'trust',
#    'company',
#    "doesn't",
#    'provide',
#    'front',
#    'line',
#    'staff',
#    'tools',
#    'provide',
#    'level',
#    'customer',
#    'service',
#    'every',
#    'customer',
#    'deserves',
#    'plenty',
#    'tanning',
#    'salons',
#    'vegas',
#    "wouldn't",
#    'first',
#    'choose',
#    'using',
#    'upgraded',
#    'beds',
#    'take',
#    'care',
#    'upgraded',
#    'beds',
#    'clean',
#    'good',
#    'working',
#    'order',
#    'basic',
#    'package',
#    'using',
#    'level',
#    'tanning',
#    'another',
#    'establishment',
#    'las',
#    'vegas',
#    'figured',
#    "i'd",
#    'drop',
#    'free',
#    'tan',
#    'weekend',
#    'see',
#    'missed',
#    'things',
#    'bodyheat',
#    'verdict',
#    "don't",
#    'miss',
#    'three',
#    'girls',
#    'desk',
#    'even',
#    'rude',
#    'remembered',
#    'yes',
#    'realize',
#    "haven't",
#    'tanned',
#    'company',
#    'two',
#    'years',
#    'however',
#    "it's",
#    'quite',
#    'obvious',
#    'solid',
#    'base',
#    'tan',
#    "don't",
#    'need',
#    'put',
#    'bed',
#    'minimum',
#    'time',
#    'took',
#    'nearly',
#    'eight',
#    'minutes',
#    'convince',
#    "wouldn't",
#    'fry',
#    'bits',
#    'put',
#    'level',
#    '3',
#    'bed',
#    'full',
#    'time',
#    'also',
#    'tanning',
#    'education',
#    'slipped',
#    'significantly',
#    'sun',
#    'angel',
#    'high',
#    'pressure',
#    'hp',
#    'bulbs',
#    'face',
#    'high',
#    'pressure',
#    'bed',
#    'knew',
#    'argument',
#    "wasn't",
#    'even',
#    'worth',
#    'spent',
#    'time',
#    'desk',
#    'would',
#    'spending',
#    'bed',
#    '12',
#    'minutes',
#    'get',
#    'star',
#    'selection',
#    'beds',
#    '24-hour',
#    'convenience',
#    'fact',
#    'carry',
#    'favorite',
#    'lotion',
#    'line',
#    'mrinternational',
#    'lack',
#    'tanning',
#    'education',
#    'nonchalance',
#    'downright',
#    'rudeness',
#    'ensures',
#    'never',
#    'paying',
#    'customer',
#    'favorite',
#    'location',
#    'best',
#    'machines',
#    'machines',
#    'love',
#    'extreme',
#    'machine',
#    'workers',
#    'always',
#    'friendly',
#    'even',
#    'gave',
#    'card',
#    'thingy',
#    'scan',
#    'instead',
#    'making',
#    'type',
#    'name',
#    'every',
#    'time',
#    'nice',
#    'tanned',
#    'past',
#    'couple',
#    'years',
#    'month',
#    'leading',
#    'summer',
#    'always',
#    'clear',
#    'interested',
#    'membership',
#    'pay',
#    'cash',
#    'time',
#    'last',
#    'year',
#    'insisted',
#    'atm',
#    'card',
#    'record',
#    'even',
#    'though',
#    'paying',
#    'cash',
#    'assured',
#    'charges',
#    'made',
#    'account',
#    'would',
#    'call',
#    'corporate',
#    'office',
#    'sure',
#    'enough',
#    'first',
#    'next',
#    'month',
#    'charged',
#    'membership',
#    'fee',
#    'account',
#    'every',
#    'month',
#    'six',
#    'months',
#    'thereafter',
#    'charged',
#    'account',
#    'sent',
#    'emails',
#    'called',
#    'corporate',
#    'office',
#    'countless',
#    'times',
#    'time',
#    'never',
#    'response',
#    'ultimately',
#    'handle',
#    'financial',
#    'institution',
#    'block',
#    'authorized',
#    'retailer',
#    'accessing',
#    'account',
#    'year',
#    'went',
#    'pre-summer',
#    'tanning',
#    'sessions',
#    'told',
#    'owed',
#    '400',
#    'explain',
#    'never',
#    'interested',
#    'membership',
#    'never',
#    'signed',
#    'one',
#    'able',
#    'contact',
#    'corporate',
#    'office',
#    'point',
#    'time',
#    'got',
#    'matter',
#    'straightened',
#    'charges',
#    'removed',
#    'never',
#    'used',
#    'sessions',
#    'month',
#    'paid',
#    'told',
#    'girl',
#    'purchasing',
#    'first',
#    'place',
#    'went',
#    'back',
#    'salon',
#    'paid',
#    'cash',
#    'started',
#    'tanning',
#    'figuring',
#    'would',
#    'put',
#    'best',
#    'foot',
#    'forward',
#    'went',
#    'following',
#    'month',
#    'paid',
#    'cash',
#    'month',
#    'tanning',
#    'went',
#    'store',
#    'try',
#    'tan',
#    'informed',
#    'owe',
#    '200',
#    'unpaid',
#    'membership',
#    'past',
#    'two',
#    'months',
#    'explained',
#    'girl',
#    'membership',
#    'authorize',
#    ...]),
#  ('n8Zqqhff-2cxzWt_nwhU2Q',
#   ['really',
#    'enjoyed',
#    'place',
#    'happy',
#    'hour',
#    'awesome',
#    'food',
#    'delicious',
#    'unique',
#    'drinks',
#    'also',
#    'excellent',
#    'however',
#    'service',
#    'needs',
#    'help',
#    'waiter',
#    'mia',
#    'needed',
#    'cocktail',
#    'refills',
#    'several',
#    'times',
#    'wanted',
#    'dessert',
#    'never',
#    'came',
#    'back',
#    'take',
#    'order',
#    'said',
#    'okkaayy',
#    'guess',
#    "we'll",
#    'skip',
#    'tip',
#    'would',
#    'much',
#    'bigger',
#    'stayed',
#    'overall',
#    'great',
#    'place',
#    "we'll",
#    'go',
#    'back',
#    'hoping',
#    'get',
#    'better',
#    'waiter',
#    "doesn't",
#    'like',
#    'happy',
#    'hour',
#    'friday',
#    'drink',
#    'food',
#    'specials',
#    'available',
#    'food',
#    'came',
#    'delicious',
#    'promptly',
#    'clean',
#    'environment',
#    'fast',
#    'service',
#    'place',
#    'awesome',
#    'really',
#    'loved',
#    'atmosphere',
#    'fun',
#    'food',
#    'amazing',
#    'bison',
#    'burger',
#    'lamb',
#    'burger',
#    'adobo',
#    'tacos',
#    'desert',
#    'amazing',
#    'pretty',
#    'cool',
#    'spot',
#    'bit',
#    'yuppy-ish',
#    'sometimes',
#    'great',
#    'spot',
#    'first',
#    'dates',
#    "i've",
#    'taken',
#    'couple',
#    'ladies',
#    'never',
#    'bad',
#    'time',
#    'staff',
#    'friendly',
#    'younger',
#    'plenty',
#    'tattoos',
#    'piercings',
#    'go',
#    'around',
#    'food',
#    'innovative',
#    'fun',
#    'eat',
#    'beer',
#    'selection',
#    'outstanding',
#    'pub',
#    'went',
#    'dinner',
#    'saturday',
#    'evening',
#    'got',
#    'us',
#    'pretty',
#    'quick',
#    "didn't",
#    'make',
#    'reservation',
#    'understand',
#    "it's",
#    'called',
#    'public',
#    'school',
#    'tables',
#    'chairs',
#    'probably',
#    'uncomfortable',
#    'actual',
#    'public',
#    'school',
#    'fan',
#    'cold',
#    'hard',
#    'metal',
#    'chairs',
#    'really',
#    'loud',
#    'said',
#    'food',
#    'really',
#    'awesome',
#    'buffalo',
#    'cauliflower',
#    'bites',
#    'really',
#    'good',
#    'beer',
#    'selection',
#    'good',
#    "it's",
#    'pricy',
#    'ok',
#    'ambiance',
#    '9',
#    'kids',
#    'meal',
#    'steep',
#    'root',
#    'beer',
#    'wine',
#    'glass',
#    'pricy',
#    'starts',
#    '9',
#    'pinot',
#    'grigio',
#    'looks',
#    'like',
#    'lot',
#    'things',
#    'server',
#    'melissa',
#    'terrible',
#    'rude',
#    'slow',
#    'great',
#    'place',
#    'friend',
#    'walked',
#    'sat',
#    'bar',
#    'promptly',
#    'taken',
#    'care',
#    'bryan',
#    'informed',
#    'us',
#    'happy',
#    'hour',
#    'specials',
#    'made',
#    'us',
#    'delicious',
#    'cocktails',
#    'night',
#    "he's",
#    'great',
#    'mixologist',
#    'great',
#    'service',
#    'bar',
#    'next',
#    'time',
#    'try',
#    'food',
#    'outdoor',
#    'fun',
#    'food',
#    'delicious',
#    'mac',
#    'cheese',
#    'appetizer',
#    'blown',
#    'away',
#    'yummy',
#    'french',
#    'toast',
#    'day',
#    'strawberry',
#    'cream',
#    'huge',
#    'boyfriend',
#    'breakfast',
#    'burrito',
#    'finished',
#    'food',
#    'amazing',
#    'reason',
#    'rated',
#    'four',
#    'literally',
#    'forgotten',
#    'server',
#    'ordered',
#    'drink',
#    'never',
#    'came',
#    'ask',
#    'another',
#    'server',
#    'good',
#    'customer',
#    'service',
#    'makes',
#    'best',
#    'dining',
#    'experience',
#    "wasn't",
#    'happy',
#    'experience',
#    'could',
#    'actually',
#    'attention',
#    'paid',
#    'us',
#    'food',
#    'delicious',
#    'locally',
#    'sourced',
#    'beer',
#    'selection',
#    'pretty',
#    'decent',
#    'friend',
#    'diet',
#    'asked',
#    'chicken',
#    'shredded',
#    'romaine',
#    'lettuce',
#    'dressing',
#    'anything',
#    'charged',
#    '16',
#    'seemed',
#    'ridiculously',
#    'steep',
#    'pricing',
#    'appropriate',
#    'would',
#    'given',
#    'place',
#    '5',
#    'stars',
#    'super',
#    'overpriced',
#    'everything',
#    '2',
#    'little',
#    'skirt',
#    'steak',
#    'tacos',
#    '13',
#    'fries',
#    'tasteless',
#    'overpriced',
#    'beers',
#    'undereducated',
#    'staff',
#    'food',
#    'good',
#    'pretty',
#    'disappointing',
#    'cool',
#    'place',
#    'tho',
#    'lots',
#    'potential',
#    'bad',
#    "it's",
#    'crap',
#    'times',
#    'girl',
#    'friend',
#    'every',
#    'time',
#    'service',
#    'great',
#    'seat',
#    'quickly',
#    'make',
#    'sure',
#    'comfortable',
#    'pizza',
#    'alway',
#    'delicious',
#    'also',
#    'great',
#    'appetizers',
#    'wings',
#    'good',
#    'cauliflower',
#    'tots',
#    'also',
#    'yummy',
#    'check',
#    'service',
#    'good',
#    'nice',
#    'open',
#    'atmosphere',
#    'liked',
#    'tge',
#    'simplicity',
#    'menu',
#    "we're",
#    'happy',
#    'choices',
#    'lamb',
#    'burger',
#    'medium',
#    'fantastic',
#    'watermelon',
#    'heirloom',
#    'tomato',
#    'salad',
#    'fantastic',
#    'restaurant',
#    'average',
#    'decor',
#    'cool',
#    'really',
#    'take',
#    'theme',
#    'new',
#    'level',
#    'food',
#    'ok',
#    'seasoned....i',
#    'new',
#    'orleans',
#    'girl',
#    'nothing',
#    'really',
#    'exceeded',
#    'expectation',
#    'honestly',
#    'could',
#    'went',
#    'california',
#    'kitchen',
#    'excited',
#    'try',
#    'public',
#    'school',
#    '702',
#    'downtown',
#    'summerlin',
#    'restaurant',
#    'fun',
#    'charming',
#    'overall',
#    'schoolhouse',
#    'theme',
#    'staff',
#    'pretty',
#    'friendly',
#    'helpful',
#    'group',
#    'four',
#    'us',
#    'starving',
#    'decided',
#    'things',
#    'share',
#    'amongst',
#    'us',
#    'bacon',
#    'cheddar',
#    'tots',
#    'sriracha',
#    'ketchup',
#    'deep',
#    'fried',
#    'tator',
#    'tots',
#    'bacon',
#    'cheese',
#    'inside',
#    'served',
#    'sirracha',
#    'ketchup',
#    'chorizo',
#    'mac',
#    'cheese',
#    'emmental',
#    'cheddar',
#    'kale',
#    'sea',
#    'salt',
#    'vinegar',
#    'crunch',
#    'hand',
#    'tossed',
#    'pizza',
#    'house',
#    'pepperoni',
#    'mozzarella',
#    'provolone',
#    'crushed',
#    'tomatoes',
#    'jalapeños',
#    'really',
#    'enjoyed',
#    'choices',
#    'would',
#    'order',
#    'great',
#    'place',
#    'watch',
#    'games',
#    'lots',
#    'tv',
#    'plenty',
#    'room',
#    'good',
#    'brew',
#    'selection',
#    'bar',
#    'food',
#    'bad',
#    'would',
#    'given',
#    '5',
#    'star',
#    'kept',
#    'things',
#    'consistent',
#    'sometimes',
#    'fries',
#    'perfect',
#    'sometimes',
#    'soggy',
#    'switch',
#    'brew',
#    'sometimes',
#    "don't",
#    'clean',
#    'line',
#    'really',
#    'bad',
#    "don't",
#    'like',
#    'sour',
#    'big',
#    'plus',
#    'staff',
#    'service',
#    'place',
#    'fantastic',
#    'would',
#    'enjoy',
#    'hanging',
#    'bar',
#    'really',
#    'hate',
#    'find',
#    'new',
#    'restaurant',
#    'becomes',
#    'instant',
#    'favorite',
#    'go',
#    'often',
#    'one',
#    'day',
#    'corporate',
#    'decides',
#    'change',
#    'menu',
#    'take',
#    'away',
#    'top-selling',
#    'items',
#    'favorite',
#    'things',
#    'order',
#    'make',
#    'entrée',
#    'sizes',
#    'way',
#    'smaller',
#    'keep',
#    'prices',
#    'public',
#    'school',
#    '702',
#    'many',
#    'many',
#    'times',
#    "it's",
#    'always',
#    'good',
#    'last',
#    'night',
#    'menu',
#    'noticeably',
#    'smaller',
#    'missing',
#    'many',
#    'items',
#    'shrimp',
#    'grits',
#    'personal',
#    'favorite',
#    "didn't",
#    'get',
#    'order',
#    "i've",
#    'chicken',
#    'waffles',
#    'also',
#    'really',
#    'good',
#    'saw',
#    'pass',
#    'way',
#    'another',
#    'table',
#    'noticed',
#    'half',
#    'size',
#    'portion',
#    'normally',
#    'still',
#    'price',
#    'menu',
#    'husband',
#    'ordered',
#    'lamb',
#    'burger',
#    'asked',
#    'medium',
#    'rare',
#    'cooked',
#    'well',
#    'done',
#    'lamb',
#    'good',
#    'cooked',
#    'well',
#    'done',
#    'calamari',
#    'cold',
#    'sitting',
#    'window',
#    'even',
#    'though',
#    'got',
#    'shortly',
#    'ordered',
#    'thinking',
#    'maybe',
#    'order',
#    'somebody',
#    'else',
#    'girls',
#    'love',
#    'chicken',
#    'fries',
#    'normally',
#    'chicken',
#    'tenders',
#    'much',
#    'larger',
#    'portion',
#    'two',
#    'small',
#    'pieces',
#    'chicken',
#    "we're",
#    'cooked',
#    'waitress',
#    'extremely',
#    'friendly',
#    'helpful',
#    'gave',
#    'us',
#    'insight',
#    'changes',
#    'made',
#    'profusely',
#    'apologetic',
#    'lamb',
#    'burger',
#    'cooked',
#    'comped',
#    'us',
#    'burger',
#    "didn't",
#    'need',
#    'even',
#    'gave',
#    'us',
#    'free',
#    'appetizer',
#    'coupon',
#    'service',
#    'excellent',
#    'like',
#    'always',
#    "didn't",
#    'blame',
#    'anything',
#    "it's",
#    'unfortunate',
#    'corporate',
#    'decided',
#    'make',
#    'changes',
#    'good',
#    'restaurant',
#    'sure',
#    "we're",
#    'going',
#    'come',
#    'back',
#    'came',
#    'couple',
#    'days',
#    'ago',
#    'know',
#    'guys',
#    'waiting',
#    'review',
#    'place',
#    "isn't",
#    'tooo',
#    'shabby',
#    "it's",
#    'nice',
#    'hipster',
#    'type',
#    'place',
#    'food',
#    'mediocre',
#    'say',
#    'least',
#    "i'm",
#    'gonna',
#    'hop',
#    'hype',
#    'train',
#    'like',
#    'everyone',
#    'else',
#    "i'm",
#    'going',
#    'give',
#    'guys',
#    'real',
#    'review',
#    'food',
#    'ehh',
#    'know',
#    'tell',
#    'neighbors',
#    'keep',
#    "you're",
#    'like',
#    'keep',
#    "i'm",
#    'like',
#    'food',
#    'ehhhhhh',
#    'know',
#    'mean',
#    'rather',
#    'go',
#    'bjs',
#    'lazy',
#    'dog',
#    'anywhere',
#    'dts',
#    'place',
#    'gross',
#    'gross',
#    'beer',
#    'menu',
#    'changes',
#    'time',
#    'good',
#    'thing',
#    'flank',
#    'steak',
#    'mac',
#    'cheese',
#    'top',
#    'salt',
#    'vinegar',
#    'chips',
#    'salty',
#    'dead',
#    'sea',
#    'everything',
#    'pretty',
#    'gross',
#    'went',
#    'date',
#    'night',
#    'movie',
#    'wait',
#    '20mins',
#    'sat',
#    'bar',
#    'area',
#    'took',
#    'forever',
#    'get',
#    'drinks',
#    'server',
#    'friendly',
#    'order',
#    'poke',
#    'app',
#    'great',
#    'husband',
#    'ordered',
#    'steak',
#    'salad',
#    "didn't",
#    'like',
#    'dressing',
#    'order',
#    'tacos',
#    'get',
#    '2',
#    '2',
#    'meal',
#    'took',
#    'one',
#    'bite',
#    'gross',
#    'meat',
#    'rare',
#    'chewy',
#    'soft',
#    'basically',
#    'seemed',
#    'old',
#    "don't",
#    'like',
#    'sending',
#    'food',
#    'bad',
#    "i'm",
#    'giving',
#    '2',
#    'stars',
#    'thanks',
#    'staff',
#    'poke',
#    'app',
#    "won't",
#    'back',
#    'feel',
#    'like',
#    'wasted',
#    '75',
#    'meal',
#    'pretty',
#    'disappointed',
#    'cool',
#    'spot',
#    'great',
#    'dinner',
#    'late',
#    'night',
#    'drinks/snacks',
#    'got',
#    'shortly',
#    '9pm',
#    'saturday',
#    'night',
#    'busy',
#    'sat',
#    'booth',
#    'near',
#    'bar',
#    'outlets',
#    'usb',
#    'outlets',
#    'wall',
#    'every',
#    'restaurant',
#    'ordered',
#    'crispy',
#    'buffalo',
#    'cauliflower',
#    'possibly',
#    'best',
#    'vegetable',
#    "i've",
#    'ever',
#    'eaten',
#    'bacon',
#    'cheddar',
#    'tots',
#    'attempt',
#    'healthy',
#    'got',
#    'tomato',
#    'watermelon',
#    'stacked',
#    'salad',
#    'okay',
#    'hubby',
#    'got',
#    'steak',
#    'came',
#    'chorizo',
#    'mac',
#    'cheese',
#    'mac',
#    'cheese',
#    'fantastic',
#    'cheesy',
#    'greasy',
#    'still',
#    'flavorful',
#    'often',
#    'feel',
#    'like',
#    '70',
#    'year',
#    'trapped',
#    'nearly',
#    '40',
#    'year',
#    'old',
#    'body',
#    'little',
#    'noisy',
#    'taste',
#    '6:30',
#    'wednesday',
#    'night',
#    'instead',
#    "i'm",
#    'sure',
#    "would've",
#    'slightly',
#    'different',
#    'experience',
#    'overall',
#    'great',
#    'food',
#    "i'd",
#    'definitely',
#    'go',
#    'back',
#    "i'm",
#    'biggest',
#    'fan',
#    'place',
#    'esthetic',
#    'cool',
#    'going',
#    'service',
#    'substandard',
#    'food',
#    'lackluster',
#    'worst',
#    'service',
#    'ever',
#    'jessica',
#    'horrible',
#    'server',
#    'took',
#    '10',
#    'minutes',
#    'greet',
#    'us',
#    'another',
#    '5',
#    'minutes',
#    'get',
#    'us',
#    'water',
#    'write',
#    'order',
#    'fine',
#    'good',
#    'server',
#    'okay',
#    "can't",
#    'remember',
#    'order',
#    'took',
#    'another',
#    '10',
#    'minutes',
#    'actually',
#    'input',
#    'order',
#    'pos',
#    'know',
#    'since',
#    'table',
#    'next',
#    'pos',
#    'confirm',
#    'wanted',
#    'burger',
#    'entered',
#    'system',
#    'delayed',
#    'effort',
#    'resulted',
#    'forgetting',
#    'ordering',
#    'appetizer',
#    'worked',
#    'restaurant',
#    'understand',
#    'gets',
#    'busy',
#    'mistakes',
#    'happen',
#    'etc',
#    'jessica',
#    'audacity',
#    'lie',
#    'forgetting',
#    'appetizer',
#    'instead',
#    'blamed',
#    'person',
#    'ran',
#    'food',
#    'taking',
#    'app',
#    'wrong',
#    'table',
#    'later',
#    'blamed',
#    'kitchen',
#    'problem',
#    'said',
#    'kitchen',
#    'bad',
#    'day',
#    'like',
#    'bad',
#    'day',
#    'would',
#    'much',
#    'better',
#    'admit',
#    'making',
#    'mistake',
#    ...]),
#  ('1Df5WnLX3DqN6ymlhqznaQ',
#   ['hands',
#    'best',
#    'place',
#    'eaten',
#    'vegas',
#    'far',
#    'trips',
#    'time',
#    'filet',
#    'also',
#    'sampler',
#    'plate',
#    'mix',
#    'everything',
#    'sushi',
#    'good',
#    'short',
#    'ribs',
#    'potstickers',
#    'desserts',
#    'etc',
#    'everything',
#    'amazing',
#    'favor',
#    'go',
#    'start',
#    'picking',
#    'everything',
#    'menu',
#    'back',
#    'place',
#    'every',
#    'time',
#    'visit',
#    'vegas',
#    'friend',
#    'worked',
#    'hooked',
#    'us',
#    'kinds',
#    'different',
#    'food',
#    'everything',
#    'pretty',
#    'good',
#    'thing',
#    "didn't",
#    'like',
#    'schezuan',
#    'sp',
#    'ribs',
#    'believe',
#    'ick',
#    'molten',
#    'lava',
#    'chocolate',
#    'cake',
#    'orgasmic',
#    'though',
#    'wanted',
#    'dine',
#    "roy's",
#    'got',
#    'chance',
#    'tonight',
#    'attending',
#    'seminar',
#    'one',
#    'dining',
#    'rooms',
#    'restaurant',
#    'well',
#    'laid',
#    'wait',
#    'staff',
#    'exceptional',
#    'evening',
#    'menu',
#    'appetizers',
#    'asian',
#    'chilled',
#    'shrimp',
#    'spicy',
#    'lime',
#    'cocktail',
#    'sauce',
#    'thai',
#    'chicken',
#    'satay',
#    'w/bangkok',
#    'style',
#    'peanut',
#    'dipping',
#    'sauce',
#    'crispy',
#    'wagyu',
#    'beef',
#    'dumpling',
#    'w/chili',
#    'lime',
#    'soy',
#    'salad',
#    'baby',
#    'greens',
#    'salad',
#    'shaved',
#    'carrot',
#    'daikon',
#    'heirloom',
#    'tomatoes',
#    'onion',
#    'shoyu',
#    'vinaigrette',
#    'entree',
#    'selection',
#    'grilled',
#    '8',
#    'oz',
#    'filet',
#    'mignon',
#    'truffle',
#    'misoyaki',
#    'demi',
#    'glace',
#    'dessert',
#    'belgian',
#    'chocolate',
#    'torte',
#    'raspberry',
#    'sauce',
#    'seasonal',
#    'berries',
#    'vanilla',
#    'whipped',
#    'cream',
#    'delicious',
#    'favorite',
#    'crispy',
#    'wagyu',
#    'beef',
#    'dumpling',
#    'seasoned',
#    'well',
#    'flavorful',
#    'filet',
#    'mignon',
#    'cooked',
#    'perfect',
#    'medium',
#    'opportunity',
#    'comes',
#    'definitely',
#    'returning',
#    'happy',
#    'hour',
#    'bomb',
#    'miss',
#    'dani',
#    'food',
#    'hoard',
#    'one',
#    'day',
#    'came',
#    'ordered',
#    '5',
#    'items',
#    'hh',
#    'menu',
#    "i'm",
#    '2',
#    'rolls',
#    'got',
#    'deep-friend',
#    'fusion',
#    'nevertheless',
#    'tasty',
#    'ahi',
#    'dish',
#    'flavorful',
#    'made',
#    'high',
#    'quality',
#    'ingredients',
#    'fish',
#    'service',
#    'efficient',
#    'sweet',
#    'got',
#    'go',
#    'baggies',
#    'pack',
#    'leftovers',
#    'staff',
#    'graciously',
#    'packed',
#    'neat',
#    'cute',
#    'containers',
#    'even',
#    'packed',
#    'sauces',
#    'individually',
#    'sealed',
#    'sauce',
#    'containers',
#    'happily',
#    'waltzed',
#    'full',
#    'tummy',
#    'bag',
#    'full',
#    'leftovers',
#    'next',
#    'door',
#    'time',
#    'reached',
#    'car',
#    'one',
#    'servers',
#    'chased',
#    'give',
#    'sauce',
#    'containers',
#    'accidentally',
#    'left',
#    'table',
#    "wouldn't",
#    'eat',
#    'leftover',
#    'w/o',
#    'sauce',
#    'cute',
#    'great',
#    'service',
#    'love',
#    'place',
#    'well',
#    'decorated',
#    'place',
#    'lots',
#    'good',
#    'hawain',
#    'food',
#    'selections',
#    'ambiance',
#    'friendly',
#    'well',
#    "it's",
#    'las',
#    'vegas',
#    'much',
#    'comments',
#    'restaurant',
#    'except',
#    'give',
#    'try',
#    'going',
#    'vegas',
#    'price',
#    'right',
#    'portion',
#    'plate',
#    'right',
#    'crabcake',
#    'yummy',
#    'definitely',
#    'recommended',
#    "i'm",
#    'sad',
#    'give',
#    'review',
#    'truth',
#    'told',
#    'aloha',
#    'hour',
#    'sucked',
#    "roy's",
#    'declined',
#    'quality',
#    "i'm",
#    'sorry',
#    'take',
#    'pictures',
#    'thing',
#    'enjoyed',
#    'kimchi',
#    "that's",
#    'dinner',
#    'menu',
#    'service',
#    'solid',
#    '5',
#    'stars',
#    'come',
#    'food',
#    'nothing',
#    'new',
#    'ah',
#    'menu',
#    'right',
#    'happened',
#    "roy's",
#    'went',
#    'years',
#    'ago',
#    "friend's",
#    'birthday',
#    'top',
#    'notch',
#    'service',
#    'superb',
#    'put',
#    'note',
#    'every',
#    'menu',
#    'know',
#    'birthday',
#    'girl',
#    'sitting',
#    'saying',
#    'happy',
#    'birthday',
#    'name',
#    'sweet',
#    'food',
#    'delicious',
#    'nice',
#    'atmosphere',
#    'came',
#    'around',
#    'cake',
#    'scoop',
#    'ice',
#    'cream',
#    'let',
#    'us',
#    'share',
#    'chocolate',
#    'wrote',
#    'happy',
#    'birthday',
#    'name',
#    'plate',
#    'well',
#    'beautiful',
#    'presentation',
#    'definitely',
#    'go',
#    "can't",
#    'believe',
#    'forgot',
#    'review',
#    "roy's",
#    'wife',
#    'went',
#    'anniversary',
#    'dinner',
#    'last',
#    'year',
#    'anyway',
#    'food',
#    'spectacular',
#    'like',
#    'always',
#    "roy's",
#    'jalapeno',
#    'infused',
#    'margarita',
#    'awesome',
#    "i've",
#    'trying',
#    'replicate',
#    'home',
#    'far',
#    "haven't",
#    'able',
#    'make',
#    'good',
#    'table',
#    'seated',
#    'decorated',
#    'since',
#    'knew',
#    'anniversary',
#    '2',
#    'managers',
#    'came',
#    'see',
#    'must',
#    'great',
#    'experience',
#    "i'm",
#    'still',
#    'thinking',
#    'year',
#    'later',
#    'great',
#    'food',
#    'great',
#    'service',
#    "roy's",
#    'always',
#    'seems',
#    'deliver',
#    'went',
#    "wife's",
#    'birthday',
#    "roy's",
#    'waikiki',
#    'wanted',
#    'see',
#    "roy's",
#    'anything',
#    'different',
#    'ambience',
#    'quite',
#    'cozy',
#    'low',
#    'lighting',
#    'started',
#    'canoe',
#    'appetizer',
#    'two',
#    'following',
#    'thai',
#    'peanut',
#    'chicken',
#    'satay',
#    'vegetable',
#    'spring',
#    'rolls',
#    'szechuan',
#    'ribs',
#    'spicy',
#    'tuna',
#    'roll',
#    'kim',
#    'chee',
#    'lobster',
#    'potstickers',
#    'everything',
#    'delicious',
#    'come',
#    'empty',
#    'stomach',
#    'demolished',
#    'tell',
#    'like',
#    'item',
#    'came',
#    'different',
#    'sauce',
#    'get',
#    'good',
#    'variety',
#    'flavors',
#    'taste',
#    'wife',
#    'roasted',
#    'macadamia',
#    'nut',
#    'crusted',
#    'mahi',
#    'mahi',
#    'asian',
#    'fried',
#    'chicken',
#    'sweet',
#    'potato',
#    'mash',
#    'asparagus',
#    'entrees',
#    'prie',
#    'fixed',
#    'menu',
#    'also',
#    'included',
#    'tuna',
#    'sashimi',
#    'appetizer',
#    'food',
#    'great',
#    'still',
#    'lot',
#    'left',
#    'breakfast',
#    'tomorrow',
#    'molten',
#    'chocolate',
#    'cake',
#    'dessert',
#    'wife',
#    'chocoholic',
#    'loved',
#    '2',
#    'things',
#    'remember',
#    'made',
#    'experience',
#    'memorable',
#    'us',
#    '1',
#    "roy's",
#    'made',
#    'special',
#    'menu',
#    "wife's",
#    'name',
#    '2',
#    'gave',
#    'complimentary',
#    'dessert',
#    'candle',
#    'overall',
#    'night',
#    'went',
#    'great',
#    'eating',
#    "roy's",
#    'brought',
#    'back',
#    'dining',
#    'home',
#    'hawaii',
#    'saw',
#    'ad',
#    "roy's",
#    '39',
#    'prix',
#    'fixe',
#    'dinner',
#    'thought',
#    'would',
#    'give',
#    'try',
#    "roy's",
#    'orlando',
#    'hawaii',
#    'good',
#    'arrived',
#    '5:00',
#    'reservations',
#    'problem',
#    'since',
#    'restaurant',
#    'empty',
#    "roy's",
#    'seems',
#    'really',
#    'outdated',
#    'compared',
#    'locations',
#    'visited',
#    'quickly',
#    'greeted',
#    'seated',
#    'waited',
#    'table',
#    'quickly',
#    'take',
#    'drink',
#    'orders',
#    'went',
#    'recommended',
#    'signature',
#    'maitai',
#    'ready',
#    'order',
#    'returned',
#    'drinks',
#    'prix',
#    'fixe',
#    'menu',
#    'allows',
#    'choose',
#    '1',
#    '2',
#    'appetizers',
#    '1',
#    '2',
#    'entrees',
#    '1',
#    '2',
#    'desserts',
#    'went',
#    'shrimp',
#    'shumai',
#    'kona',
#    'coffee',
#    'crusted',
#    'pork',
#    'kauai',
#    'prawns',
#    'chocolate',
#    'souffle',
#    'also',
#    'started',
#    'ebi',
#    'roll',
#    'shrimp',
#    'tempura',
#    'cream',
#    'cheese',
#    'avocado',
#    'coconut',
#    'habanero',
#    'sauce',
#    'unfortunately',
#    'theme',
#    'night',
#    'nicely',
#    'presented',
#    'good',
#    'looking',
#    'food',
#    'little',
#    'flavor',
#    'descriptions',
#    'sounded',
#    'wonderful',
#    'failed',
#    'live',
#    'expectations',
#    'ebi',
#    'roll',
#    'arrived',
#    'mintutes',
#    'quite',
#    'small',
#    '6',
#    'pieces',
#    'sushi',
#    'rolls',
#    '8',
#    'ok',
#    'quite',
#    'bland',
#    'could',
#    'taste',
#    'coconut',
#    'habanero',
#    'next',
#    'shumai',
#    'served',
#    'long',
#    'white',
#    'plate',
#    'probably',
#    'least',
#    'appealing',
#    'looking',
#    'tasting',
#    'tasted',
#    'heated',
#    'freshly',
#    'made',
#    'next',
#    'main',
#    'course',
#    'really',
#    'missing',
#    'flavors',
#    'promised',
#    'description',
#    'pork',
#    'loin',
#    'kona',
#    'coffee',
#    'flavor',
#    'well',
#    'cooked',
#    'though',
#    'prawns',
#    "didn't",
#    'much',
#    'flavor',
#    'little',
#    'fishy',
#    'fresh',
#    'prawns',
#    'lastly',
#    'chocolate',
#    'souffle',
#    'souffle',
#    'cooked',
#    'perfection',
#    'served',
#    'vanilla',
#    'ice',
#    'cream',
#    'raspberry',
#    'sauce',
#    'mentioned',
#    'menu',
#    'raspberry',
#    'sauce',
#    'totally',
#    'powered',
#    'chocolate',
#    'every',
#    'time',
#    'took',
#    'bite',
#    'rich',
#    'chewy',
#    'chocolate',
#    'could',
#    'taste',
#    'tart',
#    'raspberry',
#    'shame',
#    'would',
#    '10',
#    'without',
#    'sauce',
#    'service',
#    'absolutely',
#    'fantastic',
#    '5',
#    'stars',
#    'sure',
#    'waters',
#    'never',
#    'less',
#    '3/4',
#    'full',
#    'empty',
#    'dishes',
#    'cleared',
#    'quickly',
#    'waiter',
#    'around',
#    'one',
#    'assistants',
#    'always',
#    'courses',
#    'also',
#    'timed',
#    'well',
#    'compared',
#    'two',
#    "roy's",
#    'experiences',
#    'disappointing',
#    "roy's",
#    'ohana',
#    'pretty',
#    'fancy',
#    'plating',
#    'food',
#    'light',
#    'flavorful',
#    'service',
#    'outstanding',
#    'husband',
#    'celebrating',
#    '12',
#    'year',
#    'anniversary',
#    'meeting',
#    'gave',
#    'card',
#    'table',
#    'server',
#    'todd',
#    'noticed',
#    'card',
#    'asked',
#    'celebrating',
#    'told',
#    'dessert',
#    'brings',
#    'pineapple',
#    'upside',
#    'cake',
#    'written',
#    'carmel',
#    'sauce',
#    'happy',
#    '12th',
#    'anniversary',
#    'took',
#    'picture',
#    'made',
#    'copy',
#    'put',
#    'nice',
#    'frame...now',
#    "that's",
#    'service',
#    'ohana',
#    'mahalo',
#    "roy's",
#    'todd',
#    'memorable',
#    'evening',
#    "i've",
#    'many',
#    "roy's",
#    'day',
#    'overall',
#    'restaurant',
#    'usually',
#    'gets',
#    '4-star',
#    'rating',
#    'book',
#    'location',
#    'gets',
#    '3',
#    'stars',
#    'food',
#    'good',
#    'left',
#    'feeling',
#    'unsatsified',
#    'service',
#    'also',
#    'lacking',
#    'read',
#    'waiter',
#    'attitude',
#    'positives',
#    'calamari',
#    'appetizer',
#    'yuzu',
#    'pesto',
#    'crisp',
#    'refreshing',
#    'without',
#    'rubbery',
#    'shortrib',
#    'appetizer',
#    'fall-off-the-bone',
#    'tender',
#    'seasoned',
#    'sweet',
#    'tangy',
#    'glaze',
#    'orange',
#    'ginger',
#    'creme',
#    'brulee',
#    'light',
#    'velvety',
#    'negatives',
#    'lobster',
#    'potstickers...no,no',
#    'no..soggy',
#    'oily',
#    'almost',
#    'trace',
#    'lobster',
#    'miso',
#    'butterfish',
#    'soy',
#    'glaze',
#    'overdone',
#    'masked',
#    'flavor',
#    'fish...the',
#    'cut',
#    'also',
#    'much',
#    'fattier',
#    'usual',
#    'rib',
#    'eye',
#    'unimpressive',
#    'portion',
#    'cut',
#    'less',
#    'tender',
#    'like',
#    "roy's",
#    "i'd",
#    'avoid',
#    'location',
#    'awesome',
#    'restaurant',
#    'even',
#    'created',
#    'special',
#    'happy',
#    'anniversary',
#    'flyer',
#    'custom-made',
#    'names',
#    'inserted',
#    'dinner',
#    'menu',
#    'left',
#    'removed',
#    'flyers',
#    'wrapped',
#    'us',
#    'take',
#    'home',
#    'souvenirs',
#    'nice',
#    'personal',
#    'touch',
#    'food',
#    'fantastic',
#    'course',
#    'service',
#    'good',
#    'chocolate',
#    'souffle',
#    'rich',
#    'creamy',
#    'oh',
#    'also',
#    'gave',
#    'us',
#    'complimentary',
#    'dessert',
#    'anniversary',
#    'chocolate',
#    'words',
#    'said',
#    'happy',
#    'anniversary',
#    'names',
#    'plate',
#    'dessert',
#    'beautiful',
#    'touch',
#    'love',
#    'love',
#    'loooooove',
#    'place',
#    'especially',
#    'happy',
#    'hour',
#    'well',
#    "i'm",
#    'fan',
#    'happy',
#    'hours',
#    'definitely',
#    'great',
#    'ones',
#    'hh',
#    'menu',
#    "isn't",
#    'biggest',
#    'good',
#    'eats',
#    'love',
#    'house',
#    'martini',
#    'i.e',
#    "roy's",
#    'special',
#    'perfect',
#    'end',
#    'couple',
#    'not-so-great',
#    'work',
#    'days',
#    'staff',
#    'nice',
#    'attentive',
#    'atmosphere',
#    'little',
#    'quiet',
#    'sometimes',
#    'like...i',
#    "don't",
#    'even',
#    'recall',
#    'play',
#    'music',
#    'uh',
#    'oh)...but',
#    "that's",
#    'probably',
#    'friends',
#    'probably',
#    'busy',
#    'munching',
#    'notice',
#    "i've",
#    'eaten',
#    'regular',
#    'menu',
#    'chose',
#    'steak',
#    'pretty',
#    'hard',
#    'go',
#    'wrong',
#    'shrug',
#    'get',
#    'vote',
#    'nice',
#    'pitstop',
#    'way',
#    'home',
#    ...]),
#  ('VfFHPsPtTW4Mgx0eHDyJiQ',
#   ['enjoy',
#    'durango',
#    'location',
#    '6',
#    'friends',
#    'decided',
#    'try',
#    'one',
#    "it's",
#    'bit',
#    'larger',
#    'saturday',
#    'night',
#    'quite',
#    'busy',
#    'went',
#    'patio',
#    "weren't",
#    'served',
#    'talked',
#    '30',
#    'minutes',
#    'busser',
#    'stopped',
#    'asked',
#    'helped',
#    'said',
#    'said',
#    "he'd",
#    'get',
#    'someone',
#    '10',
#    'minutes',
#    'later',
#    'nobody',
#    'showed',
#    'try',
#    'short',
#    'pour',
#    'heaven',
#    "you're",
#    'looking',
#    'super',
#    'expensive',
#    'short',
#    'pours',
#    'place',
#    'wow',
#    'martinis',
#    'half',
#    'full',
#    'shots',
#    'half',
#    'full',
#    'even',
#    'glass',
#    'changed',
#    'every',
#    'drink',
#    'smaller',
#    'smaller',
#    'ran',
#    'makers',
#    'mark',
#    'chatted',
#    'manager',
#    'brought',
#    'us',
#    'one',
#    'new',
#    'drink',
#    'waitress',
#    'walked',
#    'away',
#    'soon',
#    'mentioned',
#    'glass',
#    'change',
#    'short',
#    'pour',
#    "i'm",
#    'local',
#    'wish',
#    'loved',
#    'place',
#    'sucks',
#    "i'll",
#    'never',
#    'back',
#    'super',
#    'sucks',
#    'hoped',
#    'like',
#    "it's",
#    '3rd',
#    'time',
#    "haven't",
#    'impressed',
#    'bjs',
#    'way',
#    'better',
#    'islands',
#    'go',
#    'instead',
#    'last',
#    'couple',
#    'months',
#    'friends',
#    'became',
#    'regulars',
#    'atmosphere',
#    'enjoyable',
#    'usually',
#    'always',
#    'fun',
#    'depending',
#    'crowd',
#    'managed',
#    'way',
#    'side',
#    'first',
#    'visit',
#    'extremely',
#    'hard',
#    'get',
#    'bartenders',
#    'attention',
#    'mentioned',
#    'bar',
#    'back',
#    'rob',
#    'top',
#    'customer',
#    'service..he',
#    'got',
#    'us',
#    'drinks',
#    'convinced',
#    'us',
#    'come',
#    'back',
#    'continued',
#    'come',
#    'back',
#    'service',
#    'definitely',
#    'changed',
#    'better',
#    'must',
#    'say',
#    'still',
#    'sometimes',
#    "it's",
#    'hard',
#    'get',
#    'drink',
#    'could',
#    'easily',
#    'fixed',
#    'little',
#    'organization',
#    'behind',
#    'bar',
#    'food',
#    'absolutely',
#    'delicious',
#    "i'm",
#    'pretty',
#    'picky',
#    'person',
#    'part',
#    "i'm",
#    'definitely',
#    'trying',
#    'everything',
#    'menu',
#    'mozzarella',
#    'sticks',
#    'salads',
#    'wings',
#    'wraps',
#    'pretzel',
#    'bites',
#    'sliders',
#    "it's",
#    'delicious',
#    'phil',
#    'dan',
#    'rob',
#    'rick',
#    'pretty',
#    'awesome',
#    'bartenders',
#    'enjoy',
#    'coming',
#    "they're",
#    'working',
#    'rob',
#    'usually',
#    'top',
#    'game',
#    'always',
#    'checking',
#    'make',
#    'sure',
#    "you're",
#    'okay',
#    'need',
#    'anything',
#    "there's",
#    'two',
#    'guys',
#    'named',
#    'could',
#    'careless',
#    'due',
#    'attitude',
#    'try',
#    'stay',
#    'bar',
#    "i've",
#    'crappy',
#    'service',
#    'bars',
#    'ended',
#    'even',
#    'enjoying',
#    'drinks',
#    'least',
#    'place',
#    'know',
#    "i'm",
#    'going',
#    'great',
#    'time',
#    'anyways',
#    'great',
#    'local',
#    'hangout',
#    'pretty',
#    'chill',
#    'fun',
#    'environment',
#    'see',
#    'rick',
#    'far',
#    'favorite',
#    'bartender',
#    "i've",
#    '3',
#    'times',
#    'since',
#    'september',
#    'time',
#    'excellent',
#    'staff',
#    'extremely',
#    'friendly',
#    'helpful',
#    'food',
#    'fantastic',
#    'drinks',
#    'reasonably',
#    'priced',
#    'entrance',
#    'seems',
#    'little',
#    'intimidating',
#    'first',
#    'enter',
#    'nice',
#    'mix',
#    'restaurant/bar',
#    'seating',
#    'small',
#    'lounge',
#    'area',
#    'near',
#    'back',
#    'would',
#    'recommend',
#    'distill',
#    'great',
#    'start',
#    'beginning',
#    'night',
#    'final',
#    'stop',
#    'night',
#    "i'll",
#    'give',
#    '3.5',
#    'stars',
#    'overall',
#    "i've",
#    '3',
#    'times',
#    'around',
#    '7pm',
#    '4am',
#    '3pm',
#    'college',
#    'hoops',
#    'first',
#    'time',
#    'sat',
#    'bar',
#    'ordered',
#    'mule',
#    'drink',
#    'chicken',
#    'dinner',
#    'cute',
#    'bartender',
#    'took',
#    'order',
#    'drinks',
#    'disappeared...finally',
#    'another',
#    'one',
#    'took',
#    'meal',
#    'order',
#    'chicken',
#    'good',
#    'flavor',
#    'lots',
#    'food',
#    'plate',
#    'touch',
#    'dry',
#    'friend',
#    'tacos',
#    'enjoyed',
#    'got',
#    'full',
#    '3',
#    '2nd',
#    'time',
#    'came',
#    'bit',
#    'drunk',
#    'couple',
#    'friends',
#    'many',
#    'people',
#    'except',
#    'bar/wait',
#    'staff',
#    'work',
#    'chicken',
#    'fried',
#    'steak',
#    'breakfast',
#    'pretty',
#    'good',
#    'friends',
#    "didn't",
#    'win',
#    'money',
#    'went',
#    'home',
#    'early',
#    'unhappy',
#    '3rd',
#    'time',
#    'came',
#    'group',
#    '3',
#    'friends',
#    'cocktails',
#    'chips/salsa',
#    'watching',
#    'college',
#    'hoop',
#    'games',
#    "tv's",
#    'little',
#    'weird',
#    'sit',
#    'hightop',
#    'table',
#    'waitress',
#    'fantastic',
#    'gave',
#    'us',
#    'free',
#    'beer',
#    'mistake',
#    'free',
#    'philly',
#    'cheesesteak',
#    'sandwich',
#    'another',
#    'mistake',
#    'good',
#    'time',
#    'drink',
#    'orders',
#    'bit',
#    'slow',
#    'start',
#    'glass',
#    'water',
#    'come',
#    'someone',
#    'different',
#    'strange',
#    'place',
#    'relatively',
#    'busy',
#    "didn't",
#    'notice',
#    'smoky',
#    'guess',
#    'reason',
#    "i'm",
#    'downgrading',
#    '3.5',
#    'stars',
#    'slow',
#    'service',
#    'visit',
#    '1',
#    '3',
#    'chicken',
#    'great',
#    'guess',
#    "i'm",
#    'used',
#    'really',
#    'good',
#    'food',
#    'typical',
#    'normal',
#    'bar',
#    'food',
#    'nothing',
#    'special',
#    'okay',
#    "shouldn't",
#    'review',
#    'bar/restaurant',
#    'opening',
#    'night',
#    "i'm",
#    'one',
#    'else',
#    'doin',
#    'glitch',
#    '1',
#    'lvrj',
#    'ad',
#    'said',
#    'food',
#    'fun',
#    'prizes',
#    'first',
#    '100',
#    'people',
#    'really',
#    "didn't",
#    'think',
#    "we'd",
#    'coveted',
#    'swag',
#    'group',
#    'even',
#    'though',
#    'got',
#    '6:40',
#    'seeing',
#    'distill',
#    're-distilling',
#    'space',
#    'occupied',
#    'late',
#    'lamented',
#    'agave',
#    'restaurant',
#    'cavernous',
#    'place',
#    "didn't",
#    'expect',
#    'fighting',
#    'wall',
#    'space',
#    "how'd",
#    'happen',
#    'opened',
#    '4:30',
#    'happened',
#    'truth',
#    'advertising',
#    'buffet',
#    'station',
#    'set',
#    'pizza',
#    'round',
#    'potato',
#    'bites',
#    'beef',
#    'strips',
#    'fixings',
#    'fajitas',
#    'chicken',
#    'artichoke',
#    'dip',
#    'bruschetta',
#    'jumbo',
#    'shrimp',
#    'shrimp',
#    'cocktail',
#    'fajitas',
#    'good',
#    'potato',
#    'puffs',
#    'delicious',
#    'rest',
#    'okay',
#    'finally',
#    'snagged',
#    'booth',
#    'except',
#    'demo',
#    'girls',
#    'handing',
#    'royal',
#    'crown',
#    'jack',
#    'daniels',
#    'tennessee',
#    'honey',
#    'samples',
#    'cute',
#    't-shirts',
#    "couldn't",
#    'snag',
#    'server',
#    'even',
#    'clear',
#    'table',
#    'let',
#    'alone',
#    'slake',
#    'parched',
#    'palates',
#    'servers',
#    'also',
#    'bussers',
#    "didn't",
#    'help',
#    'speed',
#    'things',
#    'bar',
#    'backed',
#    'drink',
#    'orders',
#    'definitely',
#    'could',
#    'benefit',
#    'second',
#    'bar',
#    'manage',
#    'fill',
#    'free',
#    'offerings',
#    "i'll",
#    'reserve',
#    'food',
#    'critique',
#    'next',
#    'time',
#    'checked',
#    'menu',
#    'standard',
#    'assortment',
#    'appetizers',
#    'salads',
#    'burgers',
#    'sandwiches',
#    'prices',
#    'pretty',
#    'reasonable',
#    'happy',
#    'hour',
#    '3-6',
#    'pm',
#    '3-6',
#    'catering',
#    'early',
#    'joggers',
#    'menu',
#    'completely',
#    'unimaginative',
#    'eminently',
#    'skippable',
#    "i'll",
#    'update',
#    'review',
#    'impressions',
#    'food',
#    'excitement',
#    'dies',
#    'hopefully',
#    'noise',
#    'place',
#    'jet-takeoff',
#    'loud',
#    'initial',
#    'impressions',
#    'ho-hum',
#    'place',
#    'chill,lounge',
#    'like',
#    'saying',
#    'says',
#    'stragers',
#    'friends',
#    "haven't",
#    'met',
#    'love',
#    'string',
#    'calamari',
#    'course',
#    'moscow',
#    'mule',
#    'gotta',
#    'servers',
#    'service',
#    'awesome',
#    'first',
#    'time',
#    'came',
#    'yelp',
#    'event',
#    'purely',
#    'enjoyed',
#    'came',
#    'last',
#    'night',
#    'see',
#    "it's",
#    'like',
#    'regular',
#    'night',
#    'vibe',
#    'relaxed',
#    'bar',
#    'seemed',
#    'pretty',
#    'packed',
#    'able',
#    'sit',
#    'dining',
#    'area',
#    'someone',
#    'automatically',
#    'brings',
#    'menu',
#    'lets',
#    'us',
#    'know',
#    'server',
#    'us',
#    'erin',
#    'server',
#    'night',
#    'automatically',
#    'checked',
#    'yelp',
#    'redeemed',
#    'free',
#    'whiskey',
#    'shots',
#    'also',
#    'ordered',
#    'mad',
#    'mule',
#    '10',
#    'served',
#    'yelp',
#    'event',
#    'cinnamon',
#    'apple',
#    'sour',
#    '7',
#    'apple',
#    'sour',
#    'sour',
#    'side',
#    'extremely',
#    'strong',
#    'whiskey',
#    'shots',
#    'came',
#    'coffee',
#    'cinnamon',
#    'flavored',
#    'yuck',
#    'drinks',
#    'job',
#    'done',
#    'alright',
#    'food',
#    'shrimp',
#    'spinach',
#    'artichoke',
#    'dip',
#    '9.99',
#    'bland',
#    "didn't",
#    'enough',
#    'cheesiness',
#    'shrimp',
#    "didn't",
#    'blend',
#    'well',
#    'ingredients',
#    'lot',
#    'chips',
#    'enough',
#    'dip',
#    'street',
#    'tacos',
#    '7.99',
#    'shredded',
#    'chicken',
#    'usual',
#    'contents',
#    'comes',
#    'taco',
#    'chipotle',
#    'dressing',
#    'top',
#    'pretty',
#    'good',
#    'still',
#    'nothing',
#    'made',
#    'want',
#    'order',
#    'new',
#    'york',
#    'steak',
#    'eggs',
#    '11.99',
#    'beau',
#    'said',
#    'good',
#    'cooked',
#    'perfect',
#    'came',
#    'hash',
#    'browns',
#    'choose',
#    'english',
#    'muffin',
#    'toast',
#    'tasted',
#    'tasted',
#    'like',
#    'regular',
#    'steak',
#    '¯\\_(ツ)_/¯',
#    'french',
#    'toast',
#    '7.99',
#    'beau',
#    'also',
#    'got',
#    'french',
#    'toast',
#    'guess',
#    'hungry',
#    'excellent',
#    'probably',
#    'best',
#    'thing',
#    'ate',
#    'last',
#    'night',
#    'light',
#    'fluffy',
#    'erin',
#    'server',
#    'attentive',
#    'came',
#    'checked',
#    'us',
#    'every',
#    'often',
#    'nice',
#    'lots',
#    'personality',
#    'asked',
#    'change',
# ...
#    'time',
#    'service',
#    'really',
#    'slow',
#    'staff',
#    'seem',
#    'indifferent',
#    'way',
#    'greet',
#    'customers',
#    'know',
#    "it's",
#    'close',
#    'closing',
#    'time',
#    'least',
#    'welcome',
#    'say',
#    'hello',
#    'asking',
#    'want',
#    'last',
#    'couple',
#    'times',
#    'ordered',
#    'particular',
#    'smoothie',
#    'taste',
#    'different',
#    'smoothies',
#    'made',
#    'tropical',
#    'smoothie',
#    'stores',
#    'town',
#    "i'm",
#    'going',
#    'stop',
#    'going',
#    'location',
#    '3/19/16',
#    'came',
#    'tropical',
#    'smoothie',
#    'lunch',
#    'get',
#    'something',
#    'refreshing',
#    'drink',
#    'place',
#    'great',
#    'variety',
#    'wraps',
#    'sandwiches',
#    'fruit',
#    'course',
#    'smoothies-duh',
#    'got',
#    'avacado',
#    'smoothie',
#    'filling',
#    'enough',
#    'tasty',
#    'addicted',
#    'tropical',
#    'smoothie',
#    'really',
#    'think',
#    'putting',
#    'addictive',
#    'agent',
#    'drinks',
#    'good',
#    'give',
#    'top',
#    'marks',
#    'drinks',
#    'peanut',
#    'paradise',
#    'whey',
#    'fav',
#    'basil/lemon/mint/orange',
#    'new',
#    'killer',
#    '4',
#    'lv',
#    'locations',
#    'feel',
#    'pretty',
#    'confident',
#    'give',
#    'feedback',
#    'addition',
#    'frequent',
#    'establishments',
#    'least',
#    '2-3',
#    'times',
#    'week',
#    'said',
#    'addicted',
#    'wait',
#    'usually',
#    '5-10',
#    'minutes',
#    'longer',
#    '2',
#    'people',
#    'line',
#    'prepared',
#    'really',
#    "isn't",
#    'fast',
#    'food',
#    'establishment',
#    'quick',
#    "isn't",
#    'motto',
#    'stopped',
#    'going',
#    'location',
#    'flamingo',
#    'wait',
#    'ridiculous',
#    'time',
#    'food',
#    'ok',
#    'tried',
#    'thai',
#    'chicken',
#    'salad',
#    'chicken',
#    'wrap',
#    'chicken',
#    'salad',
#    'walnut',
#    'bread',
#    'food',
#    'fresh',
#    'expensive',
#    'amount',
#    'get',
#    'last',
#    '2',
#    'times',
#    'got',
#    'sandwiches',
#    'filling',
#    'part',
#    'sandwich',
#    'small',
#    'bread',
#    'bonus',
#    'info...they',
#    'stamp',
#    'card',
#    'infrequently',
#    'give',
#    'coupons',
#    'worth',
#    'though',
#    'penny',
#    'saved',
#    'penny',
#    'earned',
#    'sense',
#    'make',
#    "i'd",
#    'like',
#    'turkey,bacon,ranch/smoothie',
#    'combo',
#    'speaker',
#    'side',
#    'would',
#    'like',
#    "don't",
#    'like',
#    'baked',
#    'chips',
#    'banana',
#    'speaker',
#    'sure',
#    'problem',
#    'put',
#    'banana',
#    'bahama',
#    'mama',
#    'please',
#    'speaker',
#    "i'm",
#    'sure',
#    'let',
#    'ask',
#    'ok',
#    'speaker',
#    'manager',
#    'says',
#    "can't",
#    'come',
#    "doesn't",
#    'make',
#    'sense',
#    'speaker',
#    'to...(interrupted',
#    'new',
#    'voice',
#    'manager',
#    'ashley',
#    'charge',
#    '50',
#    'add',
#    'banana',
#    'smoothie',
#    'sir',
#    'already',
#    'banana',
#    'side',
#    'come',
#    "can't",
#    'get',
#    'thrown',
#    'into..(interrupted',
#    'ashley',
#    'manager',
#    'ashley',
#    "i'm",
#    'sorry',
#    'sir',
#    'pay',
#    'extra',
#    'banana',
#    "don't",
#    'need',
#    'extra',
#    'banana',
#    'want',
#    'banana',
#    'already',
#    'combo',
#    'put',
#    'smoothie',
#    'please',
#    'manager',
#    'ashley',
#    "don't",
#    'sorry',
#    'befuddled',
#    'fine',
#    'pull',
#    'around',
#    'window',
#    'pay',
#    'young',
#    'server',
#    'light',
#    'eyes',
#    'hands',
#    'change',
#    'bag',
#    'w/food',
#    'banana',
#    'napkins',
#    'shaking',
#    'head',
#    'hand',
#    'back',
#    'banana',
#    'offer',
#    '50cent',
#    'upon',
#    'receiving',
#    'smoothie',
#    'ask',
#    'managers',
#    'name',
#    'gave',
#    'inconvenience',
#    'drive',
#    'smoothies',
#    'best',
#    'even',
#    'babies',
#    'love',
#    'flatbread',
#    'sandwiches',
#    'really',
#    'good',
#    'definitely',
#    'going',
#    'back',
#    'experienced',
#    'better',
#    'ask',
#    'went',
#    'gym',
#    'got',
#    'peanut',
#    'paradise',
#    'soy',
#    'protein',
#    "can't",
#    'complain',
#    'really',
#    'good',
#    'also',
#    'ordered',
#    'chicken',
#    'caesar',
#    'wrap',
#    'okay',
#    'think',
#    'place',
#    'healthy',
#    'ummm',
#    'went',
#    'website',
#    'home',
#    'see',
#    'many',
#    'calories',
#    'wrap',
#    'protein',
#    'shake',
#    'ordered',
#    'immediately',
#    'put',
#    'wrap',
#    'refrigerator',
#    'drank',
#    'half',
#    'smoothie',
#    'however',
#    'shakes',
#    '200',
#    'calories',
#    'usually',
#    'get',
#    'good',
#    'thing',
#    'place',
#    "it's",
#    'across',
#    'street',
#    'csn',
#    'want',
#    'something',
#    'quick',
#    'go',
#    'also',
#    'kinds',
#    'different',
#    'smoothies',
#    'choose',
#    'hungry',
#    'wraps',
#    'salads',
#    'sandwiches',
#    'even',
#    'serve',
#    'breakfast',
#    'first',
#    'off-let',
#    'start',
#    'fact',
#    'love',
#    'trop',
#    'smoothie',
#    'whole',
#    'never',
#    'anything',
#    'subpar',
#    'yesterday',
#    "hadn't",
#    'chance',
#    'eat',
#    'lunch',
#    'starving',
#    '2:30',
#    'pm',
#    'closest',
#    'location',
#    'work',
#    'ordered',
#    'health',
#    'nut',
#    'smoothie',
#    'taste',
#    'delicious',
#    'started',
#    'getting',
#    'seemed',
#    'wirey',
#    'bristles',
#    'every',
#    'sip',
#    "don't",
#    'know',
#    'something',
#    'cleaned',
#    'wire',
#    'brush',
#    'foreign',
#    'material',
#    'threw',
#    '5.40',
#    'smoothie',
#    'disappointed',
#    'considered',
#    'calling',
#    'store',
#    'seems',
#    'like',
#    'bunch',
#    'college/high',
#    'school',
#    'aged',
#    'kids',
#    'running',
#    'went',
#    'definitely',
#    'need',
#    'step',
#    'game',
#    'although',
#    "it's",
#    'nothing',
#    'fancy',
#    'seems',
#    'go',
#    'place',
#    'quick',
#    'easy',
#    'meal',
#    'pick',
#    "it's",
#    'healthiest',
#    ...]),
#  ('aEGV0W2i8HRoDFsRrMz-BA',
#   ["i've",
#    'looking',
#    'authentic',
#    'food',
#    'like',
#    'months',
#    'vegas',
#    'located',
#    'inside',
#    'marketplace',
#    'place',
#    'everything',
#    'including',
#    'everyone',
#    'forgets',
#    'great',
#    'hospitality',
#    'folks',
#    'work',
#    'treat',
#    'like',
#    'family',
#    'notice',
#    "haven't",
#    'even',
#    'started',
#    'talking',
#    'food',
#    'yet',
#    'ordered',
#    'takeout',
#    'late',
#    'friday',
#    'called',
#    'first',
#    "didn't",
#    'pick',
#    'later',
#    'found',
#    'busy',
#    'owner',
#    'called',
#    'back',
#    'first',
#    'time',
#    'ever',
#    'restaurant',
#    'called',
#    'back',
#    'lol',
#    'ordered',
#    'steak',
#    'enchilada',
#    'carne',
#    'asada',
#    'fries',
#    'chicken',
#    'wings',
#    'told',
#    'exactly',
#    'expect',
#    'order',
#    'pick',
#    'called',
#    'back',
#    'update',
#    'know',
#    'crazy',
#    'right',
#    'upon',
#    'arriving',
#    'noticed',
#    'place',
#    'way',
#    'offer',
#    'see',
#    'yelp',
#    'owner',
#    'gave',
#    'samples',
#    'dishes',
#    'display',
#    'drooling',
#    'app',
#    'download',
#    'best',
#    'way',
#    'order',
#    'pics',
#    'hands',
#    'great',
#    'place',
#    'authentic',
#    'mexican',
#    'food',
#    'order',
#    'try',
#    'everything',
#    'sit',
#    'eat',
#    'place',
#    'primarily',
#    'takeout/pickup',
#    'delivery',
#    'delivery',
#    'yeah',
#    'delivery',
#    'ordered',
#    '2',
#    'items',
#    'fried',
#    'catfish',
#    'yum',
#    'family',
#    'carnitas',
#    '2lbs',
#    'sure',
#    'shredded',
#    'made',
#    'really',
#    'dry',
#    'ok',
#    'ordering',
#    'big',
#    'props',
#    'though',
#    'salsa',
#    'sides',
#    'asked',
#    'extra',
#    'crispy',
#    'fish',
#    'crispy',
#    'got',
#    'house',
#    'order',
#    'try',
#    'different',
#    'things',
#    'expected',
#    'starving',
#    'work',
#    'needed',
#    'food',
#    'visited',
#    'vending',
#    'machine',
#    'instead',
#    'chilaquiles',
#    'worst',
#    'ever',
#    'semi',
#    'hard',
#    'fried',
#    'egg',
#    'dry',
#    'tortillas',
#    'good',
#    'dish',
#    'make',
#    'fruit',
#    'bowl',
#    'include',
#    'strawberries',
#    'instead',
#    'green-rimmed',
#    'cantaloupe',
#    'tasteless',
#    'papaya',
#    'expect',
#    '5-star',
#    'cuisine',
#    'least',
#    'let',
#    'feel',
#    'like',
#    '22',
#    'spent',
#    '3',
#    'non-meat',
#    'items',
#    'worth',
#    'best',
#    'experience....the',
#    'delivery',
#    'driver',
#    'fish',
#    'taco',
#    'sorry',
#    'folks...will',
#    'repeat',
#    'customer',
#    'okay',
#    'came',
#    'use',
#    'one',
#    'multiple',
#    'yelp',
#    'offers',
#    'place',
#    'posted',
#    'namely',
#    '15',
#    'coupon',
#    'ordered',
#    'standard',
#    'lunch',
#    'plate',
#    'drink',
#    'consisted',
#    'rice',
#    'beans',
#    'mexican',
#    'style',
#    'roast',
#    'tortillas',
#    'get',
#    'cashier',
#    'show',
#    'yelp',
#    'coupon',
#    'realize',
#    "doesn't",
#    'speak',
#    'one',
#    'word',
#    'english',
#    'lol',
#    'finally',
#    'communicate',
#    'coupon',
#    'calls',
#    'someone',
#    'phone',
#    'finally',
#    'hangs',
#    'says',
#    '11',
#    'dohlars',
#    'wow',
#    '11',
#    'bucks',
#    'regular',
#    'lunch',
#    'plate',
#    'coupon',
#    'used',
#    'well',
#    'food',
#    'taste',
#    '2',
#    '10',
#    'fairly',
#    'bland',
#    'nothing',
#    'get',
#    'excited',
#    '11',
#    'bucks',
#    'gas',
#    'station',
#    'lunch',
#    'line',
#    'food',
#    'insane',
#    'skip',
#    'place',
#    'go',
#    'next',
#    'door',
#    'decent',
#    'cuisine',
#    'half',
#    'price',
#    'joint',
#    'really',
#    'good',
#    'authentic',
#    'mexican',
#    'food',
#    'pastor',
#    'carnitas',
#    'tacos',
#    'delicious',
#    'ordered',
#    'delivery',
#    'charged',
#    'fee',
#    'every',
#    'little',
#    'side',
#    'side',
#    'made',
#    'seem',
#    'pricier',
#    'places',
#    'excellent',
#    'food',
#    'would',
#    'order',
#    'also',
#    'burrito',
#    'enchilada',
#    'style',
#    'good',
#    'large',
#    'portion',
#    'pozole',
#    'soup',
#    'really',
#    'good',
#    'lots',
#    'flavor',
#    'cucumber',
#    'lime',
#    'drink',
#    'sweet',
#    'refreshing',
#    'fair',
#    'two',
#    'salsas',
#    'ordered',
#    'much',
#    'needed',
#    'also',
#    'given',
#    'ceviche',
#    'free',
#    'fresh',
#    'delicious',
#    "yes...it's",
#    'hood',
#    "that's",
#    'comparisons',
#    'end',
#    'first',
#    'thing',
#    'look',
#    'clean',
#    'establishment',
#    'place',
#    'clean',
#    'service',
#    'professional',
#    'courteous',
#    'cheeseburger',
#    'good',
#    'homemade',
#    'quality',
#    'recommend',
#    'establishment',
#    'ordered',
#    'wings',
#    'grubhub',
#    'back',
#    'called',
#    'back',
#    'telling',
#    "didn't",
#    'even',
#    'wings',
#    'stock',
#    'asked',
#    'wanted',
#    'order',
#    'something',
#    'else',
#    'said',
#    'thank',
#    'would',
#    'alright',
#    'could',
#    'cancel',
#    'order',
#    'rude',
#    'people',
#    'handle',
#    'food',
#    "life's",
#    'rough',
#    'went',
#    'order',
#    'give',
#    'another',
#    'chance',
#    'longer',
#    'grubhub',
#    'find',
#    'phone',
#    'number',
#    'ask',
#    'lady',
#    'answered',
#    'phone',
#    'said',
#    'well',
#    "can't",
#    'deliver',
#    'must',
#    'reason',
#    'whhhhhat',
#    'hung',
#    'phone',
#    "couldn't",
#    'even',
#    'fathom',
#    'kind',
#    'customer',
#    'service',
#    'get',
#    'blocked',
#    'something',
#    "wasn't",
#    'even',
#    'fault',
#    'kindly',
#    'declined',
#    'order',
#    'something',
#    'else',
#    "i'll",
#    'never',
#    'know',
#    "didn't",
#    'answer',
#    'guess',
#    'people',
#    "don't",
#    'care',
#    'service',
#    'trash',
#    'like',
#    'gross',
#    'ass',
#    'food',
#    'truck',
#    'inside',
#    'convince',
#    'store',
#    'highly',
#    'recommend',
#    'place',
#    'turned',
#    'stomach',
#    'thinking',
#    'food',
#    'poisoning',
#    'hole',
#    'hole',
#    'caused',
#    'went',
#    'customer',
#    'service',
#    'great',
#    'tacos',
#    'good',
#    'forgot',
#    'put',
#    'sauce',
#    'problem',
#    'place',
#    "it's",
#    'pretty',
#    'difficult',
#    'find',
#    "don't",
#    'mind',
#    'liquor',
#    'store',
#    'least',
#    'sort',
#    'sign',
#    'indicating',
#    'restaurant',
#    'inside',
#    'store',
#    'checked',
#    'place',
#    'waiting',
#    'food',
#    'little',
#    'hard',
#    'find',
#    "it's",
#    'inside',
#    "maria's",
#    'market',
#    'think',
#    "that's",
#    'name',
#    'got',
#    '2',
#    'orders',
#    'wings',
#    'fries',
#    'website',
#    'said',
#    'comes',
#    '12',
#    'sign',
#    'says',
#    '10',
#    'order',
#    'came',
#    '9',
#    'prices',
#    'differ',
#    'site',
#    'still',
#    'cheap',
#    'checked',
#    'using',
#    'yelp',
#    'received',
#    'discount',
#    'offer',
#    'ranch',
#    'wings',
#    'blu',
#    'cheese',
#    'wings',
#    'okay',
#    'sauce',
#    'good',
#    'smelt',
#    'different',
#    'places',
#    'came',
#    'seasoned',
#    'fries',
#    'paid',
#    '13.50',
#    'wanting',
#    'try',
#    'place',
#    'forever',
#    'decided',
#    'go',
#    'get',
#    'wings',
#    'fries',
#    'special',
#    'first',
#    'trying',
#    'get',
#    'place',
#    'almost',
#    'missed',
#    "it's",
#    'actual',
#    'fast',
#    'food',
#    'place',
#    'inside',
#    'liquor',
#    'store',
#    'left',
#    'side',
#    'get',
#    'food',
#    'side',
#    'liquor',
#    'store',
#    'perfect',
#    'idea',
#    'cause',
#    'ended',
#    'picking',
#    'bottle',
#    'wine',
#    'go',
#    'meal',
#    'place',
#    'looks',
#    'pretty',
#    'clean',
#    'although',
#    "it's",
#    'best',
#    'neighborhood',
#    'usually',
#    'kinds',
#    'place',
#    'best',
#    'food',
#    "isn't",
#    'much',
#    'seating',
#    '2',
#    '3',
#    'tables',
#    'privacy',
#    'customers',
#    'entering',
#    'liquor',
#    'store',
#    'privacy',
#    'may',
#    'eaten',
#    'food',
#    'service',
#    'ok',
#    'considering',
#    'lady',
#    'took',
#    'order',
#    "didn't",
#    'speak',
#    'much',
#    'english',
#    'enough',
#    'understand',
#    'order',
#    'lady',
#    'paid',
#    'food',
#    'really',
#    'friendly',
#    'helpful',
#    'service',
#    'alone',
#    'bring',
#    'back',
#    'business',
#    'got',
#    'fries',
#    'wait',
#    'bit',
#    'made',
#    'order',
#    "weren't",
#    'sitting',
#    'waiting',
#    'get',
#    'sauce',
#    'added',
#    "i'm",
#    'french',
#    'fry',
#    'connoisseur',
#    "weren't",
#    'good',
#    'would',
#    'like',
#    "weren't",
#    'crispy',
#    'made',
#    'fresh',
#    'boyfriend',
#    'mild',
#    'wings',
#    'got',
#    'hot',
#    'wings',
#    'wings',
#    'huge',
#    'skimpy',
#    'ones',
#    'like',
#    'wing',
#    'stop',
#    'mean',
#    'huge',
#    'meaty',
#    'since',
#    'like',
#    'spicy',
#    'food',
#    'wings',
#    "weren't",
#    'spicy',
#    'pretty',
#    'good',
#    'tried',
#    "boyfriend's",
#    'mild',
#    'wings',
#    'pretty',
#    'good',
#    'looked',
#    'mexican',
#    'food',
#    "didn't",
#    'look',
#    'great',
#    'looked',
#    'like',
#    'sitting',
#    'day',
#    'film',
#    'around',
#    'seen',
#    'pictures',
#    'food',
#    'maybe',
#    'go',
#    'another',
#    'time',
#    'try',
#    'tacos',
#    'burritos',
#    'since',
#    'mexican',
#    'food',
#    'favorite',
#    'planet',
#    'definitely',
#    'back',
#    'say',
#    'give',
#    'try',
#    'delicious',
#    'received',
#    'order',
#    'delivery',
#    'love',
#    'love',
#    'wish',
#    'found',
#    'guys',
#    'sooner',
#    'moving',
#    'hope',
#    'deliver',
#    'new',
#    'address',
#    'ordered',
#    '2',
#    'plates',
#    'tacos',
#    'rice',
#    'beans',
#    'half',
#    'roasted',
#    'chicken',
#    'combo',
#    'medium',
#    'size',
#    'order',
#    'fruit',
#    'one',
#    'taco',
#    'plate',
#    'roommate',
#    'roasted',
#    'chicken',
#    'dinner',
#    'exited',
#    'try',
#    'place',
#    'disappointed',
#    'delivery',
#    'burrito',
#    'rolled',
#    'correctly',
#    'tortilla',
#    'oily',
#    'soggy',
#    'even',
#    'considered',
#    'toasting',
#    'toaster',
#    'oven',
#    'crisp',
#    'appetizer',
#    'anymore',
#    'unfortunately',
#    "won't",
#    'ordering',
#    'time',
#    'soon',
#    'waited',
#    '4',
#    'hours',
#    'food',
#    'even',
#    'though',
#    'restraunt',
#    'said',
#    'food',
#    'left',
#    'twice',
#    'actually',
#    'cancelled',
#    'tge',
#    'order',
#    'delivery.com',
#    'minutes',
#    'later',
#    'driver',
#    'came',
#    'promised',
#    'food',
#    'fresh',
#    "wasn't",
#    'service',
#    'bad',
#    'ordered',
#    'food',
#    '6',
#    "didn't",
#    'come',
#    'till',
#    '10',
#    'night',
#    'used',
#    'using',
#    'grub',
#    'hub',
#    'amazing',
#    'food',
#    'service',
#    'delivery',
#    'order',
#    'actually',
#    'arrived',
#    '30',
#    'minutes',
#    'estimated',
#    'delivery',
#    'time',
#    'food',
#    'hot',
#    'delicious',
#    'husband',
#    'made',
#    'sure',
#    'remembered',
#    'name',
#    'order'])]

# %%
business_review_word_counts = business_reviews.groupByKey().map(lambda x: (x[0], create_word_count_dict(x[1])))

# %%
import findspark
findspark.init()
from pyspark import SparkContext, SparkConf

# %%
import json
import math
import itertools
import random
import sys

# %%
conf = SparkConf()
# conf.set("spark.driver.memory", "4g")
# conf.set("spark.executor.memory", "4g")
conf.setMaster('local[8]')
conf.setAppName('Assignment_2')
sc = SparkContext.getOrCreate(conf)

# %%
import re
import string
escape_chars = r'[' + string.whitespace + ']'

# %%
def create_word_count_dict(word_list):
    count_dict = {}
    for word in word_list:
        if word not in count_dict:
            count_dict[word] = 0
        count_dict[word] += 1
    return count_dict

# %%
def get_tf_scores(word_dict):
    max_freq = max(word_dict.values())
    tf_scores = {}
    for word in word_dict:
        tf_scores[word] = word_dict[word]/max_freq
    return tf_scores

# %%
reviews_json = sc.textFile('asnlib/publicdata/train_review.json').map(json.loads)

# %%
reviews_json.first()
# Out:
# {'review_id': 'pxOrtki0sqXps5hSyLXKpA',
#  'user_id': 'OLR4DvqFxCKLOEHqfAxpqQ',
#  'business_id': 'zK7sltLeRRioqYwgLiWUIA',
#  'stars': 5.0,
#  'text': "Second time I've been here. First time was whatever. This time it was actually good. Way better than inn n out. It's the same type of burger that's why I put it up against that. I love that you can get grilled jalapeños. Just wish they came on the burger and not on the side.",
#  'date': '2015-12-19 07:35:30'}

# %%
users_token_dict = reviews_json.map(lambda x: x.get('user_id')).distinct().sortBy(lambda x: x).zipWithIndex().collectAsMap()

# %%
business_token_dict = reviews_json.map(lambda x: x.get('business_id')).distinct().sortBy(lambda x: x).zipWithIndex().collectAsMap()

# %%
users_token_dict

# %%
stop_words = set(word.strip() for word in open("asnlib/publicdata/stopwords"))

# %%
business_reviews = reviews_json \
        .map(lambda x: (x.get('business_id'), x.get('text'))) \
        .flatMap(lambda x: [(x[0], word) for word in re.split(escape_chars, x[1])]) \
        .map(lambda x: (x[0], x[1].lower().strip(string.punctuation)))  \
        .filter(lambda x: x[1] and x[1] != '' and x[1] not in string.ascii_lowercase and x[1] not in string. and x[1] not in stop_words) \
        .groupByKey().map(lambda x: (x[0], list(x[1])))

# %%
business_reviews.take(10)
# Out:
# [('bZMcorDrciRbjdjRyANcjA',
#   ['listened',
#    'reviews',
#    'place',
#    'highly',
#    'unprofessional',
#    '1st',
#    'visit',
#    'great',
#    'signed',
#    'package',
#    'needed',
#    '2',
#    'months',
#    'directed',
#    'cancel',
#    'email',
#    'corporate',
#    '30',
#    'days',
#    'advance',
#    'paid',
#    'partial',
#    'month',
#    'directed',
#    'month',
#    'would',
#    'automatically',
#    'pulled',
#    'point',
#    'sent',
#    '4',
#    'emails',
#    'response',
#    'requesting',
#    'cancel',
#    '2nd',
#    'visit',
#    'recommended',
#    'lotion',
#    '30',
#    'holiday',
#    'weekend',
#    'special',
#    'advised',
#    'due',
#    'something',
#    'could',
#    'use',
#    'lotion',
#    'today',
#    'keep',
#    'store',
#    'another',
#    '2',
#    'days',
#    'thought',
#    'weird',
#    'hey',
#    'whatever',
#    'went',
#    'also',
#    '2nd',
#    'visit',
#    '2',
#    'bulbs',
#    'bed',
#    'lastly',
#    'would',
#    'would',
#    'started',
#    'package',
#    '2',
#    'days',
#    'later',
#    'would',
#    'got',
#    'following',
#    'month',
#    '1.00',
#    'highly',
#    'disappointing',
#    '3rd',
#    'visit',
#    'come',
#    'pick',
#    'lotion',
#    'problem',
#    'however',
#    'decided',
#    'ask',
#    'full',
#    'price',
#    'lotion',
#    'was...she',
#    'provided',
#    'price',
#    'tax...which',
#    'exactly',
#    'paid',
#    'girls',
#    'behind',
#    'desk',
#    'advised',
#    'would',
#    'need',
#    'go',
#    'corporate',
#    'difference',
#    'far',
#    'company',
#    'mess',
#    'believe',
#    'provide',
#    'front',
#    'line',
#    'proper',
#    'tools',
#    'provide',
#    'good',
#    'customer',
#    'service',
#    'really',
#    'trust',
#    'company',
#    'trust',
#    'staff',
#    'adjust',
#    'price',
#    '30',
#    'trust',
#    'enter',
#    'cancelation',
#    'baffles',
#    'really',
#    'like',
#    'tanning',
#    'salon',
#    'service',
#    'great',
#    'far',
#    "i've",
#    'tanned',
#    'regularly',
#    'couple',
#    'salons',
#    'town',
#    'loved',
#    'really',
#    'looking',
#    'convenience',
#    'close',
#    'gym',
#    "i'm",
#    'back',
#    'lvac',
#    'salon',
#    'parking',
#    'lot',
#    "couldn't",
#    'convenient',
#    'salon',
#    'clean',
#    'full',
#    'new',
#    'amazing',
#    'beds',
#    'informative',
#    'sales',
#    'reps',
#    'think',
#    'biggest',
#    'desires',
#    'tanning',
#    'salon',
#    "they've",
#    'met',
#    'body',
#    'heat',
#    'body',
#    'heat',
#    'pho',
#    'sagion8',
#    'well',
#    'came',
#    'first',
#    'time',
#    'location',
#    'maria',
#    'showed',
#    'around',
#    'different',
#    'beds',
#    'work',
#    'opposed',
#    'locations',
#    'im',
#    'used',
#    'great',
#    'since',
#    "i'm",
#    'new',
#    'henderson',
#    'even',
#    'gave',
#    'directions',
#    'around',
#    'stops',
#    'mentioned',
#    'make',
#    'disappointed',
#    'customer',
#    'service',
#    'corporate',
#    'went',
#    'bought',
#    'package',
#    'maria',
#    'paid',
#    'cash',
#    'never',
#    'told',
#    'tanning',
#    'tax',
#    'top',
#    '69.88',
#    'month',
#    'ok...is',
#    'credit',
#    'card',
#    'got',
#    'charged',
#    'monthly',
#    'fee',
#    'even',
#    'though',
#    'first',
#    'month',
#    'half',
#    'paid',
#    'cash',
#    'went',
#    'ask',
#    'mari',
#    'called',
#    'corporate',
#    'spoke',
#    'tara',
#    'billing',
#    'quote',
#    'unquote',
#    'direct',
#    "maria's",
#    'mouth.....said',
#    'first',
#    'time',
#    'corporate',
#    'done',
#    'client',
#    'body',
#    'heat',
#    'shady',
#    'lot',
#    'hmmmmmmm',
#    'told',
#    'call',
#    'tara',
#    'directly',
#    'corporate',
#    'standing',
#    'maria',
#    'speaking',
#    'tara',
#    'super',
#    'rude',
#    'told',
#    'nothing',
#    'could',
#    'call',
#    'credit',
#    'card',
#    'file',
#    'dispute',
#    'reverse',
#    'charge',
#    'said',
#    'account',
#    'canceled',
#    'want',
#    'cash',
#    'back',
#    'unused',
#    'portion',
#    'told',
#    'power',
#    'hung',
#    'called',
#    'back',
#    'told',
#    'everyone',
#    'office',
#    'whole',
#    'week...ummm...talking',
#    'right',
#    'told',
#    'body',
#    'heat',
#    'tara',
#    'one',
#    'speak',
#    'call',
#    'her......she',
#    'hung',
#    'meagain',
#    'called',
#    'back',
#    'sent',
#    'voice',
#    'mail',
#    'next',
#    'hour',
#    'called',
#    'told',
#    'thank',
#    'money',
#    'getting',
#    'back',
#    'hung',
#    'lot',
#    'options',
#    'city',
#    'better',
#    'deals...better',
#    'customer',
#    'service',
#    'already',
#    'sent',
#    'email',
#    'better',
#    'business',
#    'bureau',
#    'credit',
#    'card',
#    'body',
#    'heat',
#    'owes',
#    'cash',
#    'money',
#    'right',
#    'legit',
#    'stolen',
#    'money',
#    'manager',
#    'location',
#    'agreed',
#    'right',
#    'phone',
#    'corporate',
#    'cause',
#    'lot',
#    'locations',
#    'prices',
#    'cheap',
#    'willing',
#    'work',
#    'gonna',
#    'check',
#    'palm',
#    'beach',
#    'local',
#    'places',
#    'first',
#    'want',
#    'money',
#    'back',
#    'versa',
#    'spa',
#    'spray',
#    'tan',
#    'machine',
#    'much',
#    'much',
#    'better',
#    'one',
#    'maryland',
#    'parkway',
#    'spray',
#    'leave',
#    'streaks',
#    'clear',
#    'medium',
#    'actually',
#    'medium',
#    'shade',
#    'one',
#    'maryland',
#    'pkwy',
#    'left',
#    'uneven',
#    'streaky',
#    'plus',
#    'clear',
#    'medium',
#    'turned',
#    'super',
#    'light',
#    'may',
#    'little',
#    'bit',
#    'way',
#    'much',
#    'prefer',
#    'go',
#    'location',
#    'spray',
#    'tans',
#    'good',
#    'time',
#    'depends',
#    'go',
#    'eastern',
#    'busy',
#    'certain',
#    'times',
#    'girls',
#    'night',
#    'great',
#    'actually',
#    "haven't",
#    'location',
#    'couple',
#    'months',
#    'drove',
#    'realized',
#    'never',
#    'reviewed',
#    'reason',
#    'giving',
#    '1',
#    'star',
#    '100',
#    'customer',
#    'service',
#    'warned',
#    'customer',
#    'service',
#    'location',
#    'told',
#    'ask',
#    'specific',
#    'girl',
#    'friend',
#    'good',
#    'experience',
#    'asked',
#    'particular',
#    'girl',
#    'blonde',
#    'girl',
#    'rolled',
#    'eyes',
#    'said',
#    'fine',
#    "didn't",
#    'go',
#    'find',
#    "don't",
#    'know',
#    'thought',
#    'friend',
#    'either',
#    'way',
#    'potential',
#    'customer',
#    'first',
#    'sign',
#    'unacceptable',
#    'service',
#    'girl',
#    'told',
#    'came',
#    'extremely',
#    'sweet',
#    'happy',
#    'go',
#    'different',
#    'monthly',
#    'options',
#    'also',
#    'explained',
#    'free',
#    '7',
#    'day',
#    'trial',
#    'new',
#    'tanning',
#    'perfect',
#    'blonde',
#    'girl',
#    'spoke',
#    'twice',
#    'time',
#    'asked',
#    'nice',
#    'girl',
#    'told',
#    'manager',
#    'kind',
#    'person',
#    'hired',
#    'manager',
#    'particular',
#    'manager',
#    'dealing',
#    'customers',
#    'daily',
#    'basis',
#    'completely',
#    'unacceptable',
#    'made',
#    'worse',
#    'actually',
#    'seen',
#    'girl',
#    'different',
#    'location',
#    'several',
#    'months',
#    'mocked',
#    'physically',
#    'disabled',
#    'girl',
#    'also',
#    'appeared',
#    'work',
#    "didn't",
#    'sign',
#    'first',
#    'time',
#    'took',
#    'everything',
#    'act',
#    'irrationally',
#    'say',
#    'anything',
#    'might',
#    'regret',
#    'girl',
#    'deserve',
#    'job',
#    'let',
#    'alone',
#    'one',
#    'customer',
#    'service',
#    'asked',
#    'couple',
#    'workers',
#    'name',
#    'anybody',
#    'needs',
#    'contact',
#    'feel',
#    'free',
#    'get',
#    'details',
#    'needless',
#    'say',
#    'sign',
#    'free',
#    'week',
#    'love',
#    'also',
#    'love',
#    'new',
#    'one',
#    'opened',
#    'silverado',
#    'ranch',
#    'maryland',
#    'pkwy',
#    'tanning',
#    'beds',
#    'awesome',
#    'always',
#    'go',
#    'extreme',
#    'fgt',
#    'beds',
#    'also',
#    'fantastic',
#    "haven't",
#    'better',
#    'place',
#    'better',
#    'tanning',
#    'beds',
#    'monthly',
#    'fee',
#    'bit',
#    'pricey',
#    "i've",
#    'membership',
#    'almost',
#    'two',
#    'years',
#    "it's",
#    'totally',
#    'worth',
#    'go',
#    'best',
#    'beds',
#    'one',
#    'time',
#    'drop-in',
#    'session',
#    'expensive',
#    'get',
#    'pricey',
#    'go',
#    'time',
#    'like',
#    'location',
#    'way',
#    'one',
#    'college',
#    'horizon',
#    'girls',
#    'actually',
#    'front',
#    'desk',
#    'came',
#    'left',
#    'beds',
#    'lot',
#    'better',
#    'fans',
#    'clean',
#    'wish',
#    'would',
#    'used',
#    '10',
#    'month',
#    'membership',
#    "couldn't",
#    'get',
#    'location',
#    'lol',
#    'love',
#    'body',
#    'heat',
#    'aspen',
#    'always',
#    'remembers',
#    'name',
#    'always',
#    'helpful',
#    'questions',
#    'great',
#    'place',
#    'change',
#    '1',
#    'star',
#    '3',
#    'corporate',
#    'contacted',
#    'honoring',
#    'promotion',
#    'started',
#    '2',
#    'days',
#    'signed',
#    'next',
#    'month',
#    '1',
#    'corporate',
#    'also',
#    'agreed',
#    'adjust',
#    '30',
#    'charged',
#    'advised',
#    'see',
#    'credit',
#    '10',
#    'days',
#    'seen',
#    'credit',
#    'yet',
#    'day',
#    '4',
#    'opinion',
#    'still',
#    'stands',
#    'trust',
#    'company',
#    "doesn't",
#    'provide',
#    'front',
#    'line',
#    'staff',
#    'tools',
#    'provide',
#    'level',
#    'customer',
#    'service',
#    'every',
#    'customer',
#    'deserves',
#    'plenty',
#    'tanning',
#    'salons',
#    'vegas',
#    "wouldn't",
#    'first',
#    'choose',
#    'using',
#    'upgraded',
#    'beds',
#    'take',
#    'care',
#    'upgraded',
#    'beds',
#    'clean',
#    'good',
#    'working',
#    'order',
#    'basic',
#    'package',
#    'using',
#    'level',
#    'tanning',
#    'another',
#    'establishment',
#    'las',
#    'vegas',
#    'figured',
#    "i'd",
#    'drop',
#    'free',
#    'tan',
#    'weekend',
#    'see',
#    'missed',
#    'things',
#    'bodyheat',
#    'verdict',
#    "don't",
#    'miss',
#    'three',
#    'girls',
#    'desk',
#    'even',
#    'rude',
#    'remembered',
#    'yes',
#    'realize',
#    "haven't",
#    'tanned',
#    'company',
#    'two',
#    'years',
#    'however',
#    "it's",
#    'quite',
#    'obvious',
#    'solid',
#    'base',
#    'tan',
#    "don't",
#    'need',
#    'put',
#    'bed',
#    'minimum',
#    'time',
#    'took',
#    'nearly',
#    'eight',
#    'minutes',
#    'convince',
#    "wouldn't",
#    'fry',
#    'bits',
#    'put',
#    'level',
#    '3',
#    'bed',
#    'full',
#    'time',
#    'also',
#    'tanning',
#    'education',
#    'slipped',
#    'significantly',
#    'sun',
#    'angel',
#    'high',
#    'pressure',
#    'hp',
#    'bulbs',
#    'face',
#    'high',
#    'pressure',
#    'bed',
#    'knew',
#    'argument',
#    "wasn't",
#    'even',
#    'worth',
#    'spent',
#    'time',
#    'desk',
#    'would',
#    'spending',
#    'bed',
#    '12',
#    'minutes',
#    'get',
#    'star',
#    'selection',
#    'beds',
#    '24-hour',
#    'convenience',
#    'fact',
#    'carry',
#    'favorite',
#    'lotion',
#    'line',
#    'mrinternational',
#    'lack',
#    'tanning',
#    'education',
#    'nonchalance',
#    'downright',
#    'rudeness',
#    'ensures',
#    'never',
#    'paying',
#    'customer',
#    'favorite',
#    'location',
#    'best',
#    'machines',
#    'machines',
#    'love',
#    'extreme',
#    'machine',
#    'workers',
#    'always',
#    'friendly',
#    'even',
#    'gave',
#    'card',
#    'thingy',
#    'scan',
#    'instead',
#    'making',
#    'type',
#    'name',
#    'every',
#    'time',
#    'nice',
#    'tanned',
#    'past',
#    'couple',
#    'years',
#    'month',
#    'leading',
#    'summer',
#    'always',
#    'clear',
#    'interested',
#    'membership',
#    'pay',
#    'cash',
#    'time',
#    'last',
#    'year',
#    'insisted',
#    'atm',
#    'card',
#    'record',
#    'even',
#    'though',
#    'paying',
#    'cash',
#    'assured',
#    'charges',
#    'made',
#    'account',
#    'would',
#    'call',
#    'corporate',
#    'office',
#    'sure',
#    'enough',
#    'first',
#    'next',
#    'month',
#    'charged',
#    'membership',
#    'fee',
#    'account',
#    'every',
#    'month',
#    'six',
#    'months',
#    'thereafter',
#    'charged',
#    'account',
#    'sent',
#    'emails',
#    'called',
#    'corporate',
#    'office',
#    'countless',
#    'times',
#    'time',
#    'never',
#    'response',
#    'ultimately',
#    'handle',
#    'financial',
#    'institution',
#    'block',
#    'authorized',
#    'retailer',
#    'accessing',
#    'account',
#    'year',
#    'went',
#    'pre-summer',
#    'tanning',
#    'sessions',
#    'told',
#    'owed',
#    '400',
#    'explain',
#    'never',
#    'interested',
#    'membership',
#    'never',
#    'signed',
#    'one',
#    'able',
#    'contact',
#    'corporate',
#    'office',
#    'point',
#    'time',
#    'got',
#    'matter',
#    'straightened',
#    'charges',
#    'removed',
#    'never',
#    'used',
#    'sessions',
#    'month',
#    'paid',
#    'told',
#    'girl',
#    'purchasing',
#    'first',
#    'place',
#    'went',
#    'back',
#    'salon',
#    'paid',
#    'cash',
#    'started',
#    'tanning',
#    'figuring',
#    'would',
#    'put',
#    'best',
#    'foot',
#    'forward',
#    'went',
#    'following',
#    'month',
#    'paid',
#    'cash',
#    'month',
#    'tanning',
#    'went',
#    'store',
#    'try',
#    'tan',
#    'informed',
#    'owe',
#    '200',
#    'unpaid',
#    'membership',
#    'past',
#    'two',
#    'months',
#    'explained',
#    'girl',
#    'membership',
#    'authorize',
#    ...]),
#  ('n8Zqqhff-2cxzWt_nwhU2Q',
#   ['really',
#    'enjoyed',
#    'place',
#    'happy',
#    'hour',
#    'awesome',
#    'food',
#    'delicious',
#    'unique',
#    'drinks',
#    'also',
#    'excellent',
#    'however',
#    'service',
#    'needs',
#    'help',
#    'waiter',
#    'mia',
#    'needed',
#    'cocktail',
#    'refills',
#    'several',
#    'times',
#    'wanted',
#    'dessert',
#    'never',
#    'came',
#    'back',
#    'take',
#    'order',
#    'said',
#    'okkaayy',
#    'guess',
#    "we'll",
#    'skip',
#    'tip',
#    'would',
#    'much',
#    'bigger',
#    'stayed',
#    'overall',
#    'great',
#    'place',
#    "we'll",
#    'go',
#    'back',
#    'hoping',
#    'get',
#    'better',
#    'waiter',
#    "doesn't",
#    'like',
#    'happy',
#    'hour',
#    'friday',
#    'drink',
#    'food',
#    'specials',
#    'available',
#    'food',
#    'came',
#    'delicious',
#    'promptly',
#    'clean',
#    'environment',
#    'fast',
#    'service',
#    'place',
#    'awesome',
#    'really',
#    'loved',
#    'atmosphere',
#    'fun',
#    'food',
#    'amazing',
#    'bison',
#    'burger',
#    'lamb',
#    'burger',
#    'adobo',
#    'tacos',
#    'desert',
#    'amazing',
#    'pretty',
#    'cool',
#    'spot',
#    'bit',
#    'yuppy-ish',
#    'sometimes',
#    'great',
#    'spot',
#    'first',
#    'dates',
#    "i've",
#    'taken',
#    'couple',
#    'ladies',
#    'never',
#    'bad',
#    'time',
#    'staff',
#    'friendly',
#    'younger',
#    'plenty',
#    'tattoos',
#    'piercings',
#    'go',
#    'around',
#    'food',
#    'innovative',
#    'fun',
#    'eat',
#    'beer',
#    'selection',
#    'outstanding',
#    'pub',
#    'went',
#    'dinner',
#    'saturday',
#    'evening',
#    'got',
#    'us',
#    'pretty',
#    'quick',
#    "didn't",
#    'make',
#    'reservation',
#    'understand',
#    "it's",
#    'called',
#    'public',
#    'school',
#    'tables',
#    'chairs',
#    'probably',
#    'uncomfortable',
#    'actual',
#    'public',
#    'school',
#    'fan',
#    'cold',
#    'hard',
#    'metal',
#    'chairs',
#    'really',
#    'loud',
#    'said',
#    'food',
#    'really',
#    'awesome',
#    'buffalo',
#    'cauliflower',
#    'bites',
#    'really',
#    'good',
#    'beer',
#    'selection',
#    'good',
#    "it's",
#    'pricy',
#    'ok',
#    'ambiance',
#    '9',
#    'kids',
#    'meal',
#    'steep',
#    'root',
#    'beer',
#    'wine',
#    'glass',
#    'pricy',
#    'starts',
#    '9',
#    'pinot',
#    'grigio',
#    'looks',
#    'like',
#    'lot',
#    'things',
#    'server',
#    'melissa',
#    'terrible',
#    'rude',
#    'slow',
#    'great',
#    'place',
#    'friend',
#    'walked',
#    'sat',
#    'bar',
#    'promptly',
#    'taken',
#    'care',
#    'bryan',
#    'informed',
#    'us',
#    'happy',
#    'hour',
#    'specials',
#    'made',
#    'us',
#    'delicious',
#    'cocktails',
#    'night',
#    "he's",
#    'great',
#    'mixologist',
#    'great',
#    'service',
#    'bar',
#    'next',
#    'time',
#    'try',
#    'food',
#    'outdoor',
#    'fun',
#    'food',
#    'delicious',
#    'mac',
#    'cheese',
#    'appetizer',
#    'blown',
#    'away',
#    'yummy',
#    'french',
#    'toast',
#    'day',
#    'strawberry',
#    'cream',
#    'huge',
#    'boyfriend',
#    'breakfast',
#    'burrito',
#    'finished',
#    'food',
#    'amazing',
#    'reason',
#    'rated',
#    'four',
#    'literally',
#    'forgotten',
#    'server',
#    'ordered',
#    'drink',
#    'never',
#    'came',
#    'ask',
#    'another',
#    'server',
#    'good',
#    'customer',
#    'service',
#    'makes',
#    'best',
#    'dining',
#    'experience',
#    "wasn't",
#    'happy',
#    'experience',
#    'could',
#    'actually',
#    'attention',
#    'paid',
#    'us',
#    'food',
#    'delicious',
#    'locally',
#    'sourced',
#    'beer',
#    'selection',
#    'pretty',
#    'decent',
#    'friend',
#    'diet',
#    'asked',
#    'chicken',
#    'shredded',
#    'romaine',
#    'lettuce',
#    'dressing',
#    'anything',
#    'charged',
#    '16',
#    'seemed',
#    'ridiculously',
#    'steep',
#    'pricing',
#    'appropriate',
#    'would',
#    'given',
#    'place',
#    '5',
#    'stars',
#    'super',
#    'overpriced',
#    'everything',
#    '2',
#    'little',
#    'skirt',
#    'steak',
#    'tacos',
#    '13',
#    'fries',
#    'tasteless',
#    'overpriced',
#    'beers',
#    'undereducated',
#    'staff',
#    'food',
#    'good',
#    'pretty',
#    'disappointing',
#    'cool',
#    'place',
#    'tho',
#    'lots',
#    'potential',
#    'bad',
#    "it's",
#    'crap',
#    'times',
#    'girl',
#    'friend',
#    'every',
#    'time',
#    'service',
#    'great',
#    'seat',
#    'quickly',
#    'make',
#    'sure',
#    'comfortable',
#    'pizza',
#    'alway',
#    'delicious',
#    'also',
#    'great',
#    'appetizers',
#    'wings',
#    'good',
#    'cauliflower',
#    'tots',
#    'also',
#    'yummy',
#    'check',
#    'service',
#    'good',
#    'nice',
#    'open',
#    'atmosphere',
#    'liked',
#    'tge',
#    'simplicity',
#    'menu',
#    "we're",
#    'happy',
#    'choices',
#    'lamb',
#    'burger',
#    'medium',
#    'fantastic',
#    'watermelon',
#    'heirloom',
#    'tomato',
#    'salad',
#    'fantastic',
#    'restaurant',
#    'average',
#    'decor',
#    'cool',
#    'really',
#    'take',
#    'theme',
#    'new',
#    'level',
#    'food',
#    'ok',
#    'seasoned....i',
#    'new',
#    'orleans',
#    'girl',
#    'nothing',
#    'really',
#    'exceeded',
#    'expectation',
#    'honestly',
#    'could',
#    'went',
#    'california',
#    'kitchen',
#    'excited',
#    'try',
#    'public',
#    'school',
#    '702',
#    'downtown',
#    'summerlin',
#    'restaurant',
#    'fun',
#    'charming',
#    'overall',
#    'schoolhouse',
#    'theme',
#    'staff',
#    'pretty',
#    'friendly',
#    'helpful',
#    'group',
#    'four',
#    'us',
#    'starving',
#    'decided',
#    'things',
#    'share',
#    'amongst',
#    'us',
#    'bacon',
#    'cheddar',
#    'tots',
#    'sriracha',
#    'ketchup',
#    'deep',
#    'fried',
#    'tator',
#    'tots',
#    'bacon',
#    'cheese',
#    'inside',
#    'served',
#    'sirracha',
#    'ketchup',
#    'chorizo',
#    'mac',
#    'cheese',
#    'emmental',
#    'cheddar',
#    'kale',
#    'sea',
#    'salt',
#    'vinegar',
#    'crunch',
#    'hand',
#    'tossed',
#    'pizza',
#    'house',
#    'pepperoni',
#    'mozzarella',
#    'provolone',
#    'crushed',
#    'tomatoes',
#    'jalapeños',
#    'really',
#    'enjoyed',
#    'choices',
#    'would',
#    'order',
#    'great',
#    'place',
#    'watch',
#    'games',
#    'lots',
#    'tv',
#    'plenty',
#    'room',
#    'good',
#    'brew',
#    'selection',
#    'bar',
#    'food',
#    'bad',
#    'would',
#    'given',
#    '5',
#    'star',
#    'kept',
#    'things',
#    'consistent',
#    'sometimes',
#    'fries',
#    'perfect',
#    'sometimes',
#    'soggy',
#    'switch',
#    'brew',
#    'sometimes',
#    "don't",
#    'clean',
#    'line',
#    'really',
#    'bad',
#    "don't",
#    'like',
#    'sour',
#    'big',
#    'plus',
#    'staff',
#    'service',
#    'place',
#    'fantastic',
#    'would',
#    'enjoy',
#    'hanging',
#    'bar',
#    'really',
#    'hate',
#    'find',
#    'new',
#    'restaurant',
#    'becomes',
#    'instant',
#    'favorite',
#    'go',
#    'often',
#    'one',
#    'day',
#    'corporate',
#    'decides',
#    'change',
#    'menu',
#    'take',
#    'away',
#    'top-selling',
#    'items',
#    'favorite',
#    'things',
#    'order',
#    'make',
#    'entrée',
#    'sizes',
#    'way',
#    'smaller',
#    'keep',
#    'prices',
#    'public',
#    'school',
#    '702',
#    'many',
#    'many',
#    'times',
#    "it's",
#    'always',
#    'good',
#    'last',
#    'night',
#    'menu',
#    'noticeably',
#    'smaller',
#    'missing',
#    'many',
#    'items',
#    'shrimp',
#    'grits',
#    'personal',
#    'favorite',
#    "didn't",
#    'get',
#    'order',
#    "i've",
#    'chicken',
#    'waffles',
#    'also',
#    'really',
#    'good',
#    'saw',
#    'pass',
#    'way',
#    'another',
#    'table',
#    'noticed',
#    'half',
#    'size',
#    'portion',
#    'normally',
#    'still',
#    'price',
#    'menu',
#    'husband',
#    'ordered',
#    'lamb',
#    'burger',
#    'asked',
#    'medium',
#    'rare',
#    'cooked',
#    'well',
#    'done',
#    'lamb',
#    'good',
#    'cooked',
#    'well',
#    'done',
#    'calamari',
#    'cold',
#    'sitting',
#    'window',
#    'even',
#    'though',
#    'got',
#    'shortly',
#    'ordered',
#    'thinking',
#    'maybe',
#    'order',
#    'somebody',
#    'else',
#    'girls',
#    'love',
#    'chicken',
#    'fries',
#    'normally',
#    'chicken',
#    'tenders',
#    'much',
#    'larger',
#    'portion',
#    'two',
#    'small',
#    'pieces',
#    'chicken',
#    "we're",
#    'cooked',
#    'waitress',
#    'extremely',
#    'friendly',
#    'helpful',
#    'gave',
#    'us',
#    'insight',
#    'changes',
#    'made',
#    'profusely',
#    'apologetic',
#    'lamb',
#    'burger',
#    'cooked',
#    'comped',
#    'us',
#    'burger',
#    "didn't",
#    'need',
#    'even',
#    'gave',
#    'us',
#    'free',
#    'appetizer',
#    'coupon',
#    'service',
#    'excellent',
#    'like',
#    'always',
#    "didn't",
#    'blame',
#    'anything',
#    "it's",
#    'unfortunate',
#    'corporate',
#    'decided',
#    'make',
#    'changes',
#    'good',
#    'restaurant',
#    'sure',
#    "we're",
#    'going',
#    'come',
#    'back',
#    'came',
#    'couple',
#    'days',
#    'ago',
#    'know',
#    'guys',
#    'waiting',
#    'review',
#    'place',
#    "isn't",
#    'tooo',
#    'shabby',
#    "it's",
#    'nice',
#    'hipster',
#    'type',
#    'place',
#    'food',
#    'mediocre',
#    'say',
#    'least',
#    "i'm",
#    'gonna',
#    'hop',
#    'hype',
#    'train',
#    'like',
#    'everyone',
#    'else',
#    "i'm",
#    'going',
#    'give',
#    'guys',
#    'real',
#    'review',
#    'food',
#    'ehh',
#    'know',
#    'tell',
#    'neighbors',
#    'keep',
#    "you're",
#    'like',
#    'keep',
#    "i'm",
#    'like',
#    'food',
#    'ehhhhhh',
#    'know',
#    'mean',
#    'rather',
#    'go',
#    'bjs',
#    'lazy',
#    'dog',
#    'anywhere',
#    'dts',
#    'place',
#    'gross',
#    'gross',
#    'beer',
#    'menu',
#    'changes',
#    'time',
#    'good',
#    'thing',
#    'flank',
#    'steak',
#    'mac',
#    'cheese',
#    'top',
#    'salt',
#    'vinegar',
#    'chips',
#    'salty',
#    'dead',
#    'sea',
#    'everything',
#    'pretty',
#    'gross',
#    'went',
#    'date',
#    'night',
#    'movie',
#    'wait',
#    '20mins',
#    'sat',
#    'bar',
#    'area',
#    'took',
#    'forever',
#    'get',
#    'drinks',
#    'server',
#    'friendly',
#    'order',
#    'poke',
#    'app',
#    'great',
#    'husband',
#    'ordered',
#    'steak',
#    'salad',
#    "didn't",
#    'like',
#    'dressing',
#    'order',
#    'tacos',
#    'get',
#    '2',
#    '2',
#    'meal',
#    'took',
#    'one',
#    'bite',
#    'gross',
#    'meat',
#    'rare',
#    'chewy',
#    'soft',
#    'basically',
#    'seemed',
#    'old',
#    "don't",
#    'like',
#    'sending',
#    'food',
#    'bad',
#    "i'm",
#    'giving',
#    '2',
#    'stars',
#    'thanks',
#    'staff',
#    'poke',
#    'app',
#    "won't",
#    'back',
#    'feel',
#    'like',
#    'wasted',
#    '75',
#    'meal',
#    'pretty',
#    'disappointed',
#    'cool',
#    'spot',
#    'great',
#    'dinner',
#    'late',
#    'night',
#    'drinks/snacks',
#    'got',
#    'shortly',
#    '9pm',
#    'saturday',
#    'night',
#    'busy',
#    'sat',
#    'booth',
#    'near',
#    'bar',
#    'outlets',
#    'usb',
#    'outlets',
#    'wall',
#    'every',
#    'restaurant',
#    'ordered',
#    'crispy',
#    'buffalo',
#    'cauliflower',
#    'possibly',
#    'best',
#    'vegetable',
#    "i've",
#    'ever',
#    'eaten',
#    'bacon',
#    'cheddar',
#    'tots',
#    'attempt',
#    'healthy',
#    'got',
#    'tomato',
#    'watermelon',
#    'stacked',
#    'salad',
#    'okay',
#    'hubby',
#    'got',
#    'steak',
#    'came',
#    'chorizo',
#    'mac',
#    'cheese',
#    'mac',
#    'cheese',
#    'fantastic',
#    'cheesy',
#    'greasy',
#    'still',
#    'flavorful',
#    'often',
#    'feel',
#    'like',
#    '70',
#    'year',
#    'trapped',
#    'nearly',
#    '40',
#    'year',
#    'old',
#    'body',
#    'little',
#    'noisy',
#    'taste',
#    '6:30',
#    'wednesday',
#    'night',
#    'instead',
#    "i'm",
#    'sure',
#    "would've",
#    'slightly',
#    'different',
#    'experience',
#    'overall',
#    'great',
#    'food',
#    "i'd",
#    'definitely',
#    'go',
#    'back',
#    "i'm",
#    'biggest',
#    'fan',
#    'place',
#    'esthetic',
#    'cool',
#    'going',
#    'service',
#    'substandard',
#    'food',
#    'lackluster',
#    'worst',
#    'service',
#    'ever',
#    'jessica',
#    'horrible',
#    'server',
#    'took',
#    '10',
#    'minutes',
#    'greet',
#    'us',
#    'another',
#    '5',
#    'minutes',
#    'get',
#    'us',
#    'water',
#    'write',
#    'order',
#    'fine',
#    'good',
#    'server',
#    'okay',
#    "can't",
#    'remember',
#    'order',
#    'took',
#    'another',
#    '10',
#    'minutes',
#    'actually',
#    'input',
#    'order',
#    'pos',
#    'know',
#    'since',
#    'table',
#    'next',
#    'pos',
#    'confirm',
#    'wanted',
#    'burger',
#    'entered',
#    'system',
#    'delayed',
#    'effort',
#    'resulted',
#    'forgetting',
#    'ordering',
#    'appetizer',
#    'worked',
#    'restaurant',
#    'understand',
#    'gets',
#    'busy',
#    'mistakes',
#    'happen',
#    'etc',
#    'jessica',
#    'audacity',
#    'lie',
#    'forgetting',
#    'appetizer',
#    'instead',
#    'blamed',
#    'person',
#    'ran',
#    'food',
#    'taking',
#    'app',
#    'wrong',
#    'table',
#    'later',
#    'blamed',
#    'kitchen',
#    'problem',
#    'said',
#    'kitchen',
#    'bad',
#    'day',
#    'like',
#    'bad',
#    'day',
#    'would',
#    'much',
#    'better',
#    'admit',
#    'making',
#    'mistake',
#    ...]),
#  ('1Df5WnLX3DqN6ymlhqznaQ',
#   ['hands',
#    'best',
#    'place',
#    'eaten',
#    'vegas',
#    'far',
#    'trips',
#    'time',
#    'filet',
#    'also',
#    'sampler',
#    'plate',
#    'mix',
#    'everything',
#    'sushi',
#    'good',
#    'short',
#    'ribs',
#    'potstickers',
#    'desserts',
#    'etc',
#    'everything',
#    'amazing',
#    'favor',
#    'go',
#    'start',
#    'picking',
#    'everything',
#    'menu',
#    'back',
#    'place',
#    'every',
#    'time',
#    'visit',
#    'vegas',
#    'friend',
#    'worked',
#    'hooked',
#    'us',
#    'kinds',
#    'different',
#    'food',
#    'everything',
#    'pretty',
#    'good',
#    'thing',
#    "didn't",
#    'like',
#    'schezuan',
#    'sp',
#    'ribs',
#    'believe',
#    'ick',
#    'molten',
#    'lava',
#    'chocolate',
#    'cake',
#    'orgasmic',
#    'though',
#    'wanted',
#    'dine',
#    "roy's",
#    'got',
#    'chance',
#    'tonight',
#    'attending',
#    'seminar',
#    'one',
#    'dining',
#    'rooms',
#    'restaurant',
#    'well',
#    'laid',
#    'wait',
#    'staff',
#    'exceptional',
#    'evening',
#    'menu',
#    'appetizers',
#    'asian',
#    'chilled',
#    'shrimp',
#    'spicy',
#    'lime',
#    'cocktail',
#    'sauce',
#    'thai',
#    'chicken',
#    'satay',
#    'w/bangkok',
#    'style',
#    'peanut',
#    'dipping',
#    'sauce',
#    'crispy',
#    'wagyu',
#    'beef',
#    'dumpling',
#    'w/chili',
#    'lime',
#    'soy',
#    'salad',
#    'baby',
#    'greens',
#    'salad',
#    'shaved',
#    'carrot',
#    'daikon',
#    'heirloom',
#    'tomatoes',
#    'onion',
#    'shoyu',
#    'vinaigrette',
#    'entree',
#    'selection',
#    'grilled',
#    '8',
#    'oz',
#    'filet',
#    'mignon',
#    'truffle',
#    'misoyaki',
#    'demi',
#    'glace',
#    'dessert',
#    'belgian',
#    'chocolate',
#    'torte',
#    'raspberry',
#    'sauce',
#    'seasonal',
#    'berries',
#    'vanilla',
#    'whipped',
#    'cream',
#    'delicious',
#    'favorite',
#    'crispy',
#    'wagyu',
#    'beef',
#    'dumpling',
#    'seasoned',
#    'well',
#    'flavorful',
#    'filet',
#    'mignon',
#    'cooked',
#    'perfect',
#    'medium',
#    'opportunity',
#    'comes',
#    'definitely',
#    'returning',
#    'happy',
#    'hour',
#    'bomb',
#    'miss',
#    'dani',
#    'food',
#    'hoard',
#    'one',
#    'day',
#    'came',
#    'ordered',
#    '5',
#    'items',
#    'hh',
#    'menu',
#    "i'm",
#    '2',
#    'rolls',
#    'got',
#    'deep-friend',
#    'fusion',
#    'nevertheless',
#    'tasty',
#    'ahi',
#    'dish',
#    'flavorful',
#    'made',
#    'high',
#    'quality',
#    'ingredients',
#    'fish',
#    'service',
#    'efficient',
#    'sweet',
#    'got',
#    'go',
#    'baggies',
#    'pack',
#    'leftovers',
#    'staff',
#    'graciously',
#    'packed',
#    'neat',
#    'cute',
#    'containers',
#    'even',
#    'packed',
#    'sauces',
#    'individually',
#    'sealed',
#    'sauce',
#    'containers',
#    'happily',
#    'waltzed',
#    'full',
#    'tummy',
#    'bag',
#    'full',
#    'leftovers',
#    'next',
#    'door',
#    'time',
#    'reached',
#    'car',
#    'one',
#    'servers',
#    'chased',
#    'give',
#    'sauce',
#    'containers',
#    'accidentally',
#    'left',
#    'table',
#    "wouldn't",
#    'eat',
#    'leftover',
#    'w/o',
#    'sauce',
#    'cute',
#    'great',
#    'service',
#    'love',
#    'place',
#    'well',
#    'decorated',
#    'place',
#    'lots',
#    'good',
#    'hawain',
#    'food',
#    'selections',
#    'ambiance',
#    'friendly',
#    'well',
#    "it's",
#    'las',
#    'vegas',
#    'much',
#    'comments',
#    'restaurant',
#    'except',
#    'give',
#    'try',
#    'going',
#    'vegas',
#    'price',
#    'right',
#    'portion',
#    'plate',
#    'right',
#    'crabcake',
#    'yummy',
#    'definitely',
#    'recommended',
#    "i'm",
#    'sad',
#    'give',
#    'review',
#    'truth',
#    'told',
#    'aloha',
#    'hour',
#    'sucked',
#    "roy's",
#    'declined',
#    'quality',
#    "i'm",
#    'sorry',
#    'take',
#    'pictures',
#    'thing',
#    'enjoyed',
#    'kimchi',
#    "that's",
#    'dinner',
#    'menu',
#    'service',
#    'solid',
#    '5',
#    'stars',
#    'come',
#    'food',
#    'nothing',
#    'new',
#    'ah',
#    'menu',
#    'right',
#    'happened',
#    "roy's",
#    'went',
#    'years',
#    'ago',
#    "friend's",
#    'birthday',
#    'top',
#    'notch',
#    'service',
#    'superb',
#    'put',
#    'note',
#    'every',
#    'menu',
#    'know',
#    'birthday',
#    'girl',
#    'sitting',
#    'saying',
#    'happy',
#    'birthday',
#    'name',
#    'sweet',
#    'food',
#    'delicious',
#    'nice',
#    'atmosphere',
#    'came',
#    'around',
#    'cake',
#    'scoop',
#    'ice',
#    'cream',
#    'let',
#    'us',
#    'share',
#    'chocolate',
#    'wrote',
#    'happy',
#    'birthday',
#    'name',
#    'plate',
#    'well',
#    'beautiful',
#    'presentation',
#    'definitely',
#    'go',
#    "can't",
#    'believe',
#    'forgot',
#    'review',
#    "roy's",
#    'wife',
#    'went',
#    'anniversary',
#    'dinner',
#    'last',
#    'year',
#    'anyway',
#    'food',
#    'spectacular',
#    'like',
#    'always',
#    "roy's",
#    'jalapeno',
#    'infused',
#    'margarita',
#    'awesome',
#    "i've",
#    'trying',
#    'replicate',
#    'home',
#    'far',
#    "haven't",
#    'able',
#    'make',
#    'good',
#    'table',
#    'seated',
#    'decorated',
#    'since',
#    'knew',
#    'anniversary',
#    '2',
#    'managers',
#    'came',
#    'see',
#    'must',
#    'great',
#    'experience',
#    "i'm",
#    'still',
#    'thinking',
#    'year',
#    'later',
#    'great',
#    'food',
#    'great',
#    'service',
#    "roy's",
#    'always',
#    'seems',
#    'deliver',
#    'went',
#    "wife's",
#    'birthday',
#    "roy's",
#    'waikiki',
#    'wanted',
#    'see',
#    "roy's",
#    'anything',
#    'different',
#    'ambience',
#    'quite',
#    'cozy',
#    'low',
#    'lighting',
#    'started',
#    'canoe',
#    'appetizer',
#    'two',
#    'following',
#    'thai',
#    'peanut',
#    'chicken',
#    'satay',
#    'vegetable',
#    'spring',
#    'rolls',
#    'szechuan',
#    'ribs',
#    'spicy',
#    'tuna',
#    'roll',
#    'kim',
#    'chee',
#    'lobster',
#    'potstickers',
#    'everything',
#    'delicious',
#    'come',
#    'empty',
#    'stomach',
#    'demolished',
#    'tell',
#    'like',
#    'item',
#    'came',
#    'different',
#    'sauce',
#    'get',
#    'good',
#    'variety',
#    'flavors',
#    'taste',
#    'wife',
#    'roasted',
#    'macadamia',
#    'nut',
#    'crusted',
#    'mahi',
#    'mahi',
#    'asian',
#    'fried',
#    'chicken',
#    'sweet',
#    'potato',
#    'mash',
#    'asparagus',
#    'entrees',
#    'prie',
#    'fixed',
#    'menu',
#    'also',
#    'included',
#    'tuna',
#    'sashimi',
#    'appetizer',
#    'food',
#    'great',
#    'still',
#    'lot',
#    'left',
#    'breakfast',
#    'tomorrow',
#    'molten',
#    'chocolate',
#    'cake',
#    'dessert',
#    'wife',
#    'chocoholic',
#    'loved',
#    '2',
#    'things',
#    'remember',
#    'made',
#    'experience',
#    'memorable',
#    'us',
#    '1',
#    "roy's",
#    'made',
#    'special',
#    'menu',
#    "wife's",
#    'name',
#    '2',
#    'gave',
#    'complimentary',
#    'dessert',
#    'candle',
#    'overall',
#    'night',
#    'went',
#    'great',
#    'eating',
#    "roy's",
#    'brought',
#    'back',
#    'dining',
#    'home',
#    'hawaii',
#    'saw',
#    'ad',
#    "roy's",
#    '39',
#    'prix',
#    'fixe',
#    'dinner',
#    'thought',
#    'would',
#    'give',
#    'try',
#    "roy's",
#    'orlando',
#    'hawaii',
#    'good',
#    'arrived',
#    '5:00',
#    'reservations',
#    'problem',
#    'since',
#    'restaurant',
#    'empty',
#    "roy's",
#    'seems',
#    'really',
#    'outdated',
#    'compared',
#    'locations',
#    'visited',
#    'quickly',
#    'greeted',
#    'seated',
#    'waited',
#    'table',
#    'quickly',
#    'take',
#    'drink',
#    'orders',
#    'went',
#    'recommended',
#    'signature',
#    'maitai',
#    'ready',
#    'order',
#    'returned',
#    'drinks',
#    'prix',
#    'fixe',
#    'menu',
#    'allows',
#    'choose',
#    '1',
#    '2',
#    'appetizers',
#    '1',
#    '2',
#    'entrees',
#    '1',
#    '2',
#    'desserts',
#    'went',
#    'shrimp',
#    'shumai',
#    'kona',
#    'coffee',
#    'crusted',
#    'pork',
#    'kauai',
#    'prawns',
#    'chocolate',
#    'souffle',
#    'also',
#    'started',
#    'ebi',
#    'roll',
#    'shrimp',
#    'tempura',
#    'cream',
#    'cheese',
#    'avocado',
#    'coconut',
#    'habanero',
#    'sauce',
#    'unfortunately',
#    'theme',
#    'night',
#    'nicely',
#    'presented',
#    'good',
#    'looking',
#    'food',
#    'little',
#    'flavor',
#    'descriptions',
#    'sounded',
#    'wonderful',
#    'failed',
#    'live',
#    'expectations',
#    'ebi',
#    'roll',
#    'arrived',
#    'mintutes',
#    'quite',
#    'small',
#    '6',
#    'pieces',
#    'sushi',
#    'rolls',
#    '8',
#    'ok',
#    'quite',
#    'bland',
#    'could',
#    'taste',
#    'coconut',
#    'habanero',
#    'next',
#    'shumai',
#    'served',
#    'long',
#    'white',
#    'plate',
#    'probably',
#    'least',
#    'appealing',
#    'looking',
#    'tasting',
#    'tasted',
#    'heated',
#    'freshly',
#    'made',
#    'next',
#    'main',
#    'course',
#    'really',
#    'missing',
#    'flavors',
#    'promised',
#    'description',
#    'pork',
#    'loin',
#    'kona',
#    'coffee',
#    'flavor',
#    'well',
#    'cooked',
#    'though',
#    'prawns',
#    "didn't",
#    'much',
#    'flavor',
#    'little',
#    'fishy',
#    'fresh',
#    'prawns',
#    'lastly',
#    'chocolate',
#    'souffle',
#    'souffle',
#    'cooked',
#    'perfection',
#    'served',
#    'vanilla',
#    'ice',
#    'cream',
#    'raspberry',
#    'sauce',
#    'mentioned',
#    'menu',
#    'raspberry',
#    'sauce',
#    'totally',
#    'powered',
#    'chocolate',
#    'every',
#    'time',
#    'took',
#    'bite',
#    'rich',
#    'chewy',
#    'chocolate',
#    'could',
#    'taste',
#    'tart',
#    'raspberry',
#    'shame',
#    'would',
#    '10',
#    'without',
#    'sauce',
#    'service',
#    'absolutely',
#    'fantastic',
#    '5',
#    'stars',
#    'sure',
#    'waters',
#    'never',
#    'less',
#    '3/4',
#    'full',
#    'empty',
#    'dishes',
#    'cleared',
#    'quickly',
#    'waiter',
#    'around',
#    'one',
#    'assistants',
#    'always',
#    'courses',
#    'also',
#    'timed',
#    'well',
#    'compared',
#    'two',
#    "roy's",
#    'experiences',
#    'disappointing',
#    "roy's",
#    'ohana',
#    'pretty',
#    'fancy',
#    'plating',
#    'food',
#    'light',
#    'flavorful',
#    'service',
#    'outstanding',
#    'husband',
#    'celebrating',
#    '12',
#    'year',
#    'anniversary',
#    'meeting',
#    'gave',
#    'card',
#    'table',
#    'server',
#    'todd',
#    'noticed',
#    'card',
#    'asked',
#    'celebrating',
#    'told',
#    'dessert',
#    'brings',
#    'pineapple',
#    'upside',
#    'cake',
#    'written',
#    'carmel',
#    'sauce',
#    'happy',
#    '12th',
#    'anniversary',
#    'took',
#    'picture',
#    'made',
#    'copy',
#    'put',
#    'nice',
#    'frame...now',
#    "that's",
#    'service',
#    'ohana',
#    'mahalo',
#    "roy's",
#    'todd',
#    'memorable',
#    'evening',
#    "i've",
#    'many',
#    "roy's",
#    'day',
#    'overall',
#    'restaurant',
#    'usually',
#    'gets',
#    '4-star',
#    'rating',
#    'book',
#    'location',
#    'gets',
#    '3',
#    'stars',
#    'food',
#    'good',
#    'left',
#    'feeling',
#    'unsatsified',
#    'service',
#    'also',
#    'lacking',
#    'read',
#    'waiter',
#    'attitude',
#    'positives',
#    'calamari',
#    'appetizer',
#    'yuzu',
#    'pesto',
#    'crisp',
#    'refreshing',
#    'without',
#    'rubbery',
#    'shortrib',
#    'appetizer',
#    'fall-off-the-bone',
#    'tender',
#    'seasoned',
#    'sweet',
#    'tangy',
#    'glaze',
#    'orange',
#    'ginger',
#    'creme',
#    'brulee',
#    'light',
#    'velvety',
#    'negatives',
#    'lobster',
#    'potstickers...no,no',
#    'no..soggy',
#    'oily',
#    'almost',
#    'trace',
#    'lobster',
#    'miso',
#    'butterfish',
#    'soy',
#    'glaze',
#    'overdone',
#    'masked',
#    'flavor',
#    'fish...the',
#    'cut',
#    'also',
#    'much',
#    'fattier',
#    'usual',
#    'rib',
#    'eye',
#    'unimpressive',
#    'portion',
#    'cut',
#    'less',
#    'tender',
#    'like',
#    "roy's",
#    "i'd",
#    'avoid',
#    'location',
#    'awesome',
#    'restaurant',
#    'even',
#    'created',
#    'special',
#    'happy',
#    'anniversary',
#    'flyer',
#    'custom-made',
#    'names',
#    'inserted',
#    'dinner',
#    'menu',
#    'left',
#    'removed',
#    'flyers',
#    'wrapped',
#    'us',
#    'take',
#    'home',
#    'souvenirs',
#    'nice',
#    'personal',
#    'touch',
#    'food',
#    'fantastic',
#    'course',
#    'service',
#    'good',
#    'chocolate',
#    'souffle',
#    'rich',
#    'creamy',
#    'oh',
#    'also',
#    'gave',
#    'us',
#    'complimentary',
#    'dessert',
#    'anniversary',
#    'chocolate',
#    'words',
#    'said',
#    'happy',
#    'anniversary',
#    'names',
#    'plate',
#    'dessert',
#    'beautiful',
#    'touch',
#    'love',
#    'love',
#    'loooooove',
#    'place',
#    'especially',
#    'happy',
#    'hour',
#    'well',
#    "i'm",
#    'fan',
#    'happy',
#    'hours',
#    'definitely',
#    'great',
#    'ones',
#    'hh',
#    'menu',
#    "isn't",
#    'biggest',
#    'good',
#    'eats',
#    'love',
#    'house',
#    'martini',
#    'i.e',
#    "roy's",
#    'special',
#    'perfect',
#    'end',
#    'couple',
#    'not-so-great',
#    'work',
#    'days',
#    'staff',
#    'nice',
#    'attentive',
#    'atmosphere',
#    'little',
#    'quiet',
#    'sometimes',
#    'like...i',
#    "don't",
#    'even',
#    'recall',
#    'play',
#    'music',
#    'uh',
#    'oh)...but',
#    "that's",
#    'probably',
#    'friends',
#    'probably',
#    'busy',
#    'munching',
#    'notice',
#    "i've",
#    'eaten',
#    'regular',
#    'menu',
#    'chose',
#    'steak',
#    'pretty',
#    'hard',
#    'go',
#    'wrong',
#    'shrug',
#    'get',
#    'vote',
#    'nice',
#    'pitstop',
#    'way',
#    'home',
#    ...]),
#  ('VfFHPsPtTW4Mgx0eHDyJiQ',
#   ['enjoy',
#    'durango',
#    'location',
#    '6',
#    'friends',
#    'decided',
#    'try',
#    'one',
#    "it's",
#    'bit',
#    'larger',
#    'saturday',
#    'night',
#    'quite',
#    'busy',
#    'went',
#    'patio',
#    "weren't",
#    'served',
#    'talked',
#    '30',
#    'minutes',
#    'busser',
#    'stopped',
#    'asked',
#    'helped',
#    'said',
#    'said',
#    "he'd",
#    'get',
#    'someone',
#    '10',
#    'minutes',
#    'later',
#    'nobody',
#    'showed',
#    'try',
#    'short',
#    'pour',
#    'heaven',
#    "you're",
#    'looking',
#    'super',
#    'expensive',
#    'short',
#    'pours',
#    'place',
#    'wow',
#    'martinis',
#    'half',
#    'full',
#    'shots',
#    'half',
#    'full',
#    'even',
#    'glass',
#    'changed',
#    'every',
#    'drink',
#    'smaller',
#    'smaller',
#    'ran',
#    'makers',
#    'mark',
#    'chatted',
#    'manager',
#    'brought',
#    'us',
#    'one',
#    'new',
#    'drink',
#    'waitress',
#    'walked',
#    'away',
#    'soon',
#    'mentioned',
#    'glass',
#    'change',
#    'short',
#    'pour',
#    "i'm",
#    'local',
#    'wish',
#    'loved',
#    'place',
#    'sucks',
#    "i'll",
#    'never',
#    'back',
#    'super',
#    'sucks',
#    'hoped',
#    'like',
#    "it's",
#    '3rd',
#    'time',
#    "haven't",
#    'impressed',
#    'bjs',
#    'way',
#    'better',
#    'islands',
#    'go',
#    'instead',
#    'last',
#    'couple',
#    'months',
#    'friends',
#    'became',
#    'regulars',
#    'atmosphere',
#    'enjoyable',
#    'usually',
#    'always',
#    'fun',
#    'depending',
#    'crowd',
#    'managed',
#    'way',
#    'side',
#    'first',
#    'visit',
#    'extremely',
#    'hard',
#    'get',
#    'bartenders',
#    'attention',
#    'mentioned',
#    'bar',
#    'back',
#    'rob',
#    'top',
#    'customer',
#    'service..he',
#    'got',
#    'us',
#    'drinks',
#    'convinced',
#    'us',
#    'come',
#    'back',
#    'continued',
#    'come',
#    'back',
#    'service',
#    'definitely',
#    'changed',
#    'better',
#    'must',
#    'say',
#    'still',
#    'sometimes',
#    "it's",
#    'hard',
#    'get',
#    'drink',
#    'could',
#    'easily',
#    'fixed',
#    'little',
#    'organization',
#    'behind',
#    'bar',
#    'food',
#    'absolutely',
#    'delicious',
#    "i'm",
#    'pretty',
#    'picky',
#    'person',
#    'part',
#    "i'm",
#    'definitely',
#    'trying',
#    'everything',
#    'menu',
#    'mozzarella',
#    'sticks',
#    'salads',
#    'wings',
#    'wraps',
#    'pretzel',
#    'bites',
#    'sliders',
#    "it's",
#    'delicious',
#    'phil',
#    'dan',
#    'rob',
#    'rick',
#    'pretty',
#    'awesome',
#    'bartenders',
#    'enjoy',
#    'coming',
#    "they're",
#    'working',
#    'rob',
#    'usually',
#    'top',
#    'game',
#    'always',
#    'checking',
#    'make',
#    'sure',
#    "you're",
#    'okay',
#    'need',
#    'anything',
#    "there's",
#    'two',
#    'guys',
#    'named',
#    'could',
#    'careless',
#    'due',
#    'attitude',
#    'try',
#    'stay',
#    'bar',
#    "i've",
#    'crappy',
#    'service',
#    'bars',
#    'ended',
#    'even',
#    'enjoying',
#    'drinks',
#    'least',
#    'place',
#    'know',
#    "i'm",
#    'going',
#    'great',
#    'time',
#    'anyways',
#    'great',
#    'local',
#    'hangout',
#    'pretty',
#    'chill',
#    'fun',
#    'environment',
#    'see',
#    'rick',
#    'far',
#    'favorite',
#    'bartender',
#    "i've",
#    '3',
#    'times',
#    'since',
#    'september',
#    'time',
#    'excellent',
#    'staff',
#    'extremely',
#    'friendly',
#    'helpful',
#    'food',
#    'fantastic',
#    'drinks',
#    'reasonably',
#    'priced',
#    'entrance',
#    'seems',
#    'little',
#    'intimidating',
#    'first',
#    'enter',
#    'nice',
#    'mix',
#    'restaurant/bar',
#    'seating',
#    'small',
#    'lounge',
#    'area',
#    'near',
#    'back',
#    'would',
#    'recommend',
#    'distill',
#    'great',
#    'start',
#    'beginning',
#    'night',
#    'final',
#    'stop',
#    'night',
#    "i'll",
#    'give',
#    '3.5',
#    'stars',
#    'overall',
#    "i've",
#    '3',
#    'times',
#    'around',
#    '7pm',
#    '4am',
#    '3pm',
#    'college',
#    'hoops',
#    'first',
#    'time',
#    'sat',
#    'bar',
#    'ordered',
#    'mule',
#    'drink',
#    'chicken',
#    'dinner',
#    'cute',
#    'bartender',
#    'took',
#    'order',
#    'drinks',
#    'disappeared...finally',
#    'another',
#    'one',
#    'took',
#    'meal',
#    'order',
#    'chicken',
#    'good',
#    'flavor',
#    'lots',
#    'food',
#    'plate',
#    'touch',
#    'dry',
#    'friend',
#    'tacos',
#    'enjoyed',
#    'got',
#    'full',
#    '3',
#    '2nd',
#    'time',
#    'came',
#    'bit',
#    'drunk',
#    'couple',
#    'friends',
#    'many',
#    'people',
#    'except',
#    'bar/wait',
#    'staff',
#    'work',
#    'chicken',
#    'fried',
#    'steak',
#    'breakfast',
#    'pretty',
#    'good',
#    'friends',
#    "didn't",
#    'win',
#    'money',
#    'went',
#    'home',
#    'early',
#    'unhappy',
#    '3rd',
#    'time',
#    'came',
#    'group',
#    '3',
#    'friends',
#    'cocktails',
#    'chips/salsa',
#    'watching',
#    'college',
#    'hoop',
#    'games',
#    "tv's",
#    'little',
#    'weird',
#    'sit',
#    'hightop',
#    'table',
#    'waitress',
#    'fantastic',
#    'gave',
#    'us',
#    'free',
#    'beer',
#    'mistake',
#    'free',
#    'philly',
#    'cheesesteak',
#    'sandwich',
#    'another',
#    'mistake',
#    'good',
#    'time',
#    'drink',
#    'orders',
#    'bit',
#    'slow',
#    'start',
#    'glass',
#    'water',
#    'come',
#    'someone',
#    'different',
#    'strange',
#    'place',
#    'relatively',
#    'busy',
#    "didn't",
#    'notice',
#    'smoky',
#    'guess',
#    'reason',
#    "i'm",
#    'downgrading',
#    '3.5',
#    'stars',
#    'slow',
#    'service',
#    'visit',
#    '1',
#    '3',
#    'chicken',
#    'great',
#    'guess',
#    "i'm",
#    'used',
#    'really',
#    'good',
#    'food',
#    'typical',
#    'normal',
#    'bar',
#    'food',
#    'nothing',
#    'special',
#    'okay',
#    "shouldn't",
#    'review',
#    'bar/restaurant',
#    'opening',
#    'night',
#    "i'm",
#    'one',
#    'else',
#    'doin',
#    'glitch',
#    '1',
#    'lvrj',
#    'ad',
#    'said',
#    'food',
#    'fun',
#    'prizes',
#    'first',
#    '100',
#    'people',
#    'really',
#    "didn't",
#    'think',
#    "we'd",
#    'coveted',
#    'swag',
#    'group',
#    'even',
#    'though',
#    'got',
#    '6:40',
#    'seeing',
#    'distill',
#    're-distilling',
#    'space',
#    'occupied',
#    'late',
#    'lamented',
#    'agave',
#    'restaurant',
#    'cavernous',
#    'place',
#    "didn't",
#    'expect',
#    'fighting',
#    'wall',
#    'space',
#    "how'd",
#    'happen',
#    'opened',
#    '4:30',
#    'happened',
#    'truth',
#    'advertising',
#    'buffet',
#    'station',
#    'set',
#    'pizza',
#    'round',
#    'potato',
#    'bites',
#    'beef',
#    'strips',
#    'fixings',
#    'fajitas',
#    'chicken',
#    'artichoke',
#    'dip',
#    'bruschetta',
#    'jumbo',
#    'shrimp',
#    'shrimp',
#    'cocktail',
#    'fajitas',
#    'good',
#    'potato',
#    'puffs',
#    'delicious',
#    'rest',
#    'okay',
#    'finally',
#    'snagged',
#    'booth',
#    'except',
#    'demo',
#    'girls',
#    'handing',
#    'royal',
#    'crown',
#    'jack',
#    'daniels',
#    'tennessee',
#    'honey',
#    'samples',
#    'cute',
#    't-shirts',
#    "couldn't",
#    'snag',
#    'server',
#    'even',
#    'clear',
#    'table',
#    'let',
#    'alone',
#    'slake',
#    'parched',
#    'palates',
#    'servers',
#    'also',
#    'bussers',
#    "didn't",
#    'help',
#    'speed',
#    'things',
#    'bar',
#    'backed',
#    'drink',
#    'orders',
#    'definitely',
#    'could',
#    'benefit',
#    'second',
#    'bar',
#    'manage',
#    'fill',
#    'free',
#    'offerings',
#    "i'll",
#    'reserve',
#    'food',
#    'critique',
#    'next',
#    'time',
#    'checked',
#    'menu',
#    'standard',
#    'assortment',
#    'appetizers',
#    'salads',
#    'burgers',
#    'sandwiches',
#    'prices',
#    'pretty',
#    'reasonable',
#    'happy',
#    'hour',
#    '3-6',
#    'pm',
#    '3-6',
#    'catering',
#    'early',
#    'joggers',
#    'menu',
#    'completely',
#    'unimaginative',
#    'eminently',
#    'skippable',
#    "i'll",
#    'update',
#    'review',
#    'impressions',
#    'food',
#    'excitement',
#    'dies',
#    'hopefully',
#    'noise',
#    'place',
#    'jet-takeoff',
#    'loud',
#    'initial',
#    'impressions',
#    'ho-hum',
#    'place',
#    'chill,lounge',
#    'like',
#    'saying',
#    'says',
#    'stragers',
#    'friends',
#    "haven't",
#    'met',
#    'love',
#    'string',
#    'calamari',
#    'course',
#    'moscow',
#    'mule',
#    'gotta',
#    'servers',
#    'service',
#    'awesome',
#    'first',
#    'time',
#    'came',
#    'yelp',
#    'event',
#    'purely',
#    'enjoyed',
#    'came',
#    'last',
#    'night',
#    'see',
#    "it's",
#    'like',
#    'regular',
#    'night',
#    'vibe',
#    'relaxed',
#    'bar',
#    'seemed',
#    'pretty',
#    'packed',
#    'able',
#    'sit',
#    'dining',
#    'area',
#    'someone',
#    'automatically',
#    'brings',
#    'menu',
#    'lets',
#    'us',
#    'know',
#    'server',
#    'us',
#    'erin',
#    'server',
#    'night',
#    'automatically',
#    'checked',
#    'yelp',
#    'redeemed',
#    'free',
#    'whiskey',
#    'shots',
#    'also',
#    'ordered',
#    'mad',
#    'mule',
#    '10',
#    'served',
#    'yelp',
#    'event',
#    'cinnamon',
#    'apple',
#    'sour',
#    '7',
#    'apple',
#    'sour',
#    'sour',
#    'side',
#    'extremely',
#    'strong',
#    'whiskey',
#    'shots',
#    'came',
#    'coffee',
#    'cinnamon',
#    'flavored',
#    'yuck',
#    'drinks',
#    'job',
#    'done',
#    'alright',
#    'food',
#    'shrimp',
#    'spinach',
#    'artichoke',
#    'dip',
#    '9.99',
#    'bland',
#    "didn't",
#    'enough',
#    'cheesiness',
#    'shrimp',
#    "didn't",
#    'blend',
#    'well',
#    'ingredients',
#    'lot',
#    'chips',
#    'enough',
#    'dip',
#    'street',
#    'tacos',
#    '7.99',
#    'shredded',
#    'chicken',
#    'usual',
#    'contents',
#    'comes',
#    'taco',
#    'chipotle',
#    'dressing',
#    'top',
#    'pretty',
#    'good',
#    'still',
#    'nothing',
#    'made',
#    'want',
#    'order',
#    'new',
#    'york',
#    'steak',
#    'eggs',
#    '11.99',
#    'beau',
#    'said',
#    'good',
#    'cooked',
#    'perfect',
#    'came',
#    'hash',
#    'browns',
#    'choose',
#    'english',
#    'muffin',
#    'toast',
#    'tasted',
#    'tasted',
#    'like',
#    'regular',
#    'steak',
#    '¯\\_(ツ)_/¯',
#    'french',
#    'toast',
#    '7.99',
#    'beau',
#    'also',
#    'got',
#    'french',
#    'toast',
#    'guess',
#    'hungry',
#    'excellent',
#    'probably',
#    'best',
#    'thing',
#    'ate',
#    'last',
#    'night',
#    'light',
#    'fluffy',
#    'erin',
#    'server',
#    'attentive',
#    'came',
#    'checked',
#    'us',
#    'every',
#    'often',
#    'nice',
#    'lots',
#    'personality',
#    'asked',
#    'change',
# ...
#    'time',
#    'service',
#    'really',
#    'slow',
#    'staff',
#    'seem',
#    'indifferent',
#    'way',
#    'greet',
#    'customers',
#    'know',
#    "it's",
#    'close',
#    'closing',
#    'time',
#    'least',
#    'welcome',
#    'say',
#    'hello',
#    'asking',
#    'want',
#    'last',
#    'couple',
#    'times',
#    'ordered',
#    'particular',
#    'smoothie',
#    'taste',
#    'different',
#    'smoothies',
#    'made',
#    'tropical',
#    'smoothie',
#    'stores',
#    'town',
#    "i'm",
#    'going',
#    'stop',
#    'going',
#    'location',
#    '3/19/16',
#    'came',
#    'tropical',
#    'smoothie',
#    'lunch',
#    'get',
#    'something',
#    'refreshing',
#    'drink',
#    'place',
#    'great',
#    'variety',
#    'wraps',
#    'sandwiches',
#    'fruit',
#    'course',
#    'smoothies-duh',
#    'got',
#    'avacado',
#    'smoothie',
#    'filling',
#    'enough',
#    'tasty',
#    'addicted',
#    'tropical',
#    'smoothie',
#    'really',
#    'think',
#    'putting',
#    'addictive',
#    'agent',
#    'drinks',
#    'good',
#    'give',
#    'top',
#    'marks',
#    'drinks',
#    'peanut',
#    'paradise',
#    'whey',
#    'fav',
#    'basil/lemon/mint/orange',
#    'new',
#    'killer',
#    '4',
#    'lv',
#    'locations',
#    'feel',
#    'pretty',
#    'confident',
#    'give',
#    'feedback',
#    'addition',
#    'frequent',
#    'establishments',
#    'least',
#    '2-3',
#    'times',
#    'week',
#    'said',
#    'addicted',
#    'wait',
#    'usually',
#    '5-10',
#    'minutes',
#    'longer',
#    '2',
#    'people',
#    'line',
#    'prepared',
#    'really',
#    "isn't",
#    'fast',
#    'food',
#    'establishment',
#    'quick',
#    "isn't",
#    'motto',
#    'stopped',
#    'going',
#    'location',
#    'flamingo',
#    'wait',
#    'ridiculous',
#    'time',
#    'food',
#    'ok',
#    'tried',
#    'thai',
#    'chicken',
#    'salad',
#    'chicken',
#    'wrap',
#    'chicken',
#    'salad',
#    'walnut',
#    'bread',
#    'food',
#    'fresh',
#    'expensive',
#    'amount',
#    'get',
#    'last',
#    '2',
#    'times',
#    'got',
#    'sandwiches',
#    'filling',
#    'part',
#    'sandwich',
#    'small',
#    'bread',
#    'bonus',
#    'info...they',
#    'stamp',
#    'card',
#    'infrequently',
#    'give',
#    'coupons',
#    'worth',
#    'though',
#    'penny',
#    'saved',
#    'penny',
#    'earned',
#    'sense',
#    'make',
#    "i'd",
#    'like',
#    'turkey,bacon,ranch/smoothie',
#    'combo',
#    'speaker',
#    'side',
#    'would',
#    'like',
#    "don't",
#    'like',
#    'baked',
#    'chips',
#    'banana',
#    'speaker',
#    'sure',
#    'problem',
#    'put',
#    'banana',
#    'bahama',
#    'mama',
#    'please',
#    'speaker',
#    "i'm",
#    'sure',
#    'let',
#    'ask',
#    'ok',
#    'speaker',
#    'manager',
#    'says',
#    "can't",
#    'come',
#    "doesn't",
#    'make',
#    'sense',
#    'speaker',
#    'to...(interrupted',
#    'new',
#    'voice',
#    'manager',
#    'ashley',
#    'charge',
#    '50',
#    'add',
#    'banana',
#    'smoothie',
#    'sir',
#    'already',
#    'banana',
#    'side',
#    'come',
#    "can't",
#    'get',
#    'thrown',
#    'into..(interrupted',
#    'ashley',
#    'manager',
#    'ashley',
#    "i'm",
#    'sorry',
#    'sir',
#    'pay',
#    'extra',
#    'banana',
#    "don't",
#    'need',
#    'extra',
#    'banana',
#    'want',
#    'banana',
#    'already',
#    'combo',
#    'put',
#    'smoothie',
#    'please',
#    'manager',
#    'ashley',
#    "don't",
#    'sorry',
#    'befuddled',
#    'fine',
#    'pull',
#    'around',
#    'window',
#    'pay',
#    'young',
#    'server',
#    'light',
#    'eyes',
#    'hands',
#    'change',
#    'bag',
#    'w/food',
#    'banana',
#    'napkins',
#    'shaking',
#    'head',
#    'hand',
#    'back',
#    'banana',
#    'offer',
#    '50cent',
#    'upon',
#    'receiving',
#    'smoothie',
#    'ask',
#    'managers',
#    'name',
#    'gave',
#    'inconvenience',
#    'drive',
#    'smoothies',
#    'best',
#    'even',
#    'babies',
#    'love',
#    'flatbread',
#    'sandwiches',
#    'really',
#    'good',
#    'definitely',
#    'going',
#    'back',
#    'experienced',
#    'better',
#    'ask',
#    'went',
#    'gym',
#    'got',
#    'peanut',
#    'paradise',
#    'soy',
#    'protein',
#    "can't",
#    'complain',
#    'really',
#    'good',
#    'also',
#    'ordered',
#    'chicken',
#    'caesar',
#    'wrap',
#    'okay',
#    'think',
#    'place',
#    'healthy',
#    'ummm',
#    'went',
#    'website',
#    'home',
#    'see',
#    'many',
#    'calories',
#    'wrap',
#    'protein',
#    'shake',
#    'ordered',
#    'immediately',
#    'put',
#    'wrap',
#    'refrigerator',
#    'drank',
#    'half',
#    'smoothie',
#    'however',
#    'shakes',
#    '200',
#    'calories',
#    'usually',
#    'get',
#    'good',
#    'thing',
#    'place',
#    "it's",
#    'across',
#    'street',
#    'csn',
#    'want',
#    'something',
#    'quick',
#    'go',
#    'also',
#    'kinds',
#    'different',
#    'smoothies',
#    'choose',
#    'hungry',
#    'wraps',
#    'salads',
#    'sandwiches',
#    'even',
#    'serve',
#    'breakfast',
#    'first',
#    'off-let',
#    'start',
#    'fact',
#    'love',
#    'trop',
#    'smoothie',
#    'whole',
#    'never',
#    'anything',
#    'subpar',
#    'yesterday',
#    "hadn't",
#    'chance',
#    'eat',
#    'lunch',
#    'starving',
#    '2:30',
#    'pm',
#    'closest',
#    'location',
#    'work',
#    'ordered',
#    'health',
#    'nut',
#    'smoothie',
#    'taste',
#    'delicious',
#    'started',
#    'getting',
#    'seemed',
#    'wirey',
#    'bristles',
#    'every',
#    'sip',
#    "don't",
#    'know',
#    'something',
#    'cleaned',
#    'wire',
#    'brush',
#    'foreign',
#    'material',
#    'threw',
#    '5.40',
#    'smoothie',
#    'disappointed',
#    'considered',
#    'calling',
#    'store',
#    'seems',
#    'like',
#    'bunch',
#    'college/high',
#    'school',
#    'aged',
#    'kids',
#    'running',
#    'went',
#    'definitely',
#    'need',
#    'step',
#    'game',
#    'although',
#    "it's",
#    'nothing',
#    'fancy',
#    'seems',
#    'go',
#    'place',
#    'quick',
#    'easy',
#    'meal',
#    'pick',
#    "it's",
#    'healthiest',
#    ...]),
#  ('aEGV0W2i8HRoDFsRrMz-BA',
#   ["i've",
#    'looking',
#    'authentic',
#    'food',
#    'like',
#    'months',
#    'vegas',
#    'located',
#    'inside',
#    'marketplace',
#    'place',
#    'everything',
#    'including',
#    'everyone',
#    'forgets',
#    'great',
#    'hospitality',
#    'folks',
#    'work',
#    'treat',
#    'like',
#    'family',
#    'notice',
#    "haven't",
#    'even',
#    'started',
#    'talking',
#    'food',
#    'yet',
#    'ordered',
#    'takeout',
#    'late',
#    'friday',
#    'called',
#    'first',
#    "didn't",
#    'pick',
#    'later',
#    'found',
#    'busy',
#    'owner',
#    'called',
#    'back',
#    'first',
#    'time',
#    'ever',
#    'restaurant',
#    'called',
#    'back',
#    'lol',
#    'ordered',
#    'steak',
#    'enchilada',
#    'carne',
#    'asada',
#    'fries',
#    'chicken',
#    'wings',
#    'told',
#    'exactly',
#    'expect',
#    'order',
#    'pick',
#    'called',
#    'back',
#    'update',
#    'know',
#    'crazy',
#    'right',
#    'upon',
#    'arriving',
#    'noticed',
#    'place',
#    'way',
#    'offer',
#    'see',
#    'yelp',
#    'owner',
#    'gave',
#    'samples',
#    'dishes',
#    'display',
#    'drooling',
#    'app',
#    'download',
#    'best',
#    'way',
#    'order',
#    'pics',
#    'hands',
#    'great',
#    'place',
#    'authentic',
#    'mexican',
#    'food',
#    'order',
#    'try',
#    'everything',
#    'sit',
#    'eat',
#    'place',
#    'primarily',
#    'takeout/pickup',
#    'delivery',
#    'delivery',
#    'yeah',
#    'delivery',
#    'ordered',
#    '2',
#    'items',
#    'fried',
#    'catfish',
#    'yum',
#    'family',
#    'carnitas',
#    '2lbs',
#    'sure',
#    'shredded',
#    'made',
#    'really',
#    'dry',
#    'ok',
#    'ordering',
#    'big',
#    'props',
#    'though',
#    'salsa',
#    'sides',
#    'asked',
#    'extra',
#    'crispy',
#    'fish',
#    'crispy',
#    'got',
#    'house',
#    'order',
#    'try',
#    'different',
#    'things',
#    'expected',
#    'starving',
#    'work',
#    'needed',
#    'food',
#    'visited',
#    'vending',
#    'machine',
#    'instead',
#    'chilaquiles',
#    'worst',
#    'ever',
#    'semi',
#    'hard',
#    'fried',
#    'egg',
#    'dry',
#    'tortillas',
#    'good',
#    'dish',
#    'make',
#    'fruit',
#    'bowl',
#    'include',
#    'strawberries',
#    'instead',
#    'green-rimmed',
#    'cantaloupe',
#    'tasteless',
#    'papaya',
#    'expect',
#    '5-star',
#    'cuisine',
#    'least',
#    'let',
#    'feel',
#    'like',
#    '22',
#    'spent',
#    '3',
#    'non-meat',
#    'items',
#    'worth',
#    'best',
#    'experience....the',
#    'delivery',
#    'driver',
#    'fish',
#    'taco',
#    'sorry',
#    'folks...will',
#    'repeat',
#    'customer',
#    'okay',
#    'came',
#    'use',
#    'one',
#    'multiple',
#    'yelp',
#    'offers',
#    'place',
#    'posted',
#    'namely',
#    '15',
#    'coupon',
#    'ordered',
#    'standard',
#    'lunch',
#    'plate',
#    'drink',
#    'consisted',
#    'rice',
#    'beans',
#    'mexican',
#    'style',
#    'roast',
#    'tortillas',
#    'get',
#    'cashier',
#    'show',
#    'yelp',
#    'coupon',
#    'realize',
#    "doesn't",
#    'speak',
#    'one',
#    'word',
#    'english',
#    'lol',
#    'finally',
#    'communicate',
#    'coupon',
#    'calls',
#    'someone',
#    'phone',
#    'finally',
#    'hangs',
#    'says',
#    '11',
#    'dohlars',
#    'wow',
#    '11',
#    'bucks',
#    'regular',
#    'lunch',
#    'plate',
#    'coupon',
#    'used',
#    'well',
#    'food',
#    'taste',
#    '2',
#    '10',
#    'fairly',
#    'bland',
#    'nothing',
#    'get',
#    'excited',
#    '11',
#    'bucks',
#    'gas',
#    'station',
#    'lunch',
#    'line',
#    'food',
#    'insane',
#    'skip',
#    'place',
#    'go',
#    'next',
#    'door',
#    'decent',
#    'cuisine',
#    'half',
#    'price',
#    'joint',
#    'really',
#    'good',
#    'authentic',
#    'mexican',
#    'food',
#    'pastor',
#    'carnitas',
#    'tacos',
#    'delicious',
#    'ordered',
#    'delivery',
#    'charged',
#    'fee',
#    'every',
#    'little',
#    'side',
#    'side',
#    'made',
#    'seem',
#    'pricier',
#    'places',
#    'excellent',
#    'food',
#    'would',
#    'order',
#    'also',
#    'burrito',
#    'enchilada',
#    'style',
#    'good',
#    'large',
#    'portion',
#    'pozole',
#    'soup',
#    'really',
#    'good',
#    'lots',
#    'flavor',
#    'cucumber',
#    'lime',
#    'drink',
#    'sweet',
#    'refreshing',
#    'fair',
#    'two',
#    'salsas',
#    'ordered',
#    'much',
#    'needed',
#    'also',
#    'given',
#    'ceviche',
#    'free',
#    'fresh',
#    'delicious',
#    "yes...it's",
#    'hood',
#    "that's",
#    'comparisons',
#    'end',
#    'first',
#    'thing',
#    'look',
#    'clean',
#    'establishment',
#    'place',
#    'clean',
#    'service',
#    'professional',
#    'courteous',
#    'cheeseburger',
#    'good',
#    'homemade',
#    'quality',
#    'recommend',
#    'establishment',
#    'ordered',
#    'wings',
#    'grubhub',
#    'back',
#    'called',
#    'back',
#    'telling',
#    "didn't",
#    'even',
#    'wings',
#    'stock',
#    'asked',
#    'wanted',
#    'order',
#    'something',
#    'else',
#    'said',
#    'thank',
#    'would',
#    'alright',
#    'could',
#    'cancel',
#    'order',
#    'rude',
#    'people',
#    'handle',
#    'food',
#    "life's",
#    'rough',
#    'went',
#    'order',
#    'give',
#    'another',
#    'chance',
#    'longer',
#    'grubhub',
#    'find',
#    'phone',
#    'number',
#    'ask',
#    'lady',
#    'answered',
#    'phone',
#    'said',
#    'well',
#    "can't",
#    'deliver',
#    'must',
#    'reason',
#    'whhhhhat',
#    'hung',
#    'phone',
#    "couldn't",
#    'even',
#    'fathom',
#    'kind',
#    'customer',
#    'service',
#    'get',
#    'blocked',
#    'something',
#    "wasn't",
#    'even',
#    'fault',
#    'kindly',
#    'declined',
#    'order',
#    'something',
#    'else',
#    "i'll",
#    'never',
#    'know',
#    "didn't",
#    'answer',
#    'guess',
#    'people',
#    "don't",
#    'care',
#    'service',
#    'trash',
#    'like',
#    'gross',
#    'ass',
#    'food',
#    'truck',
#    'inside',
#    'convince',
#    'store',
#    'highly',
#    'recommend',
#    'place',
#    'turned',
#    'stomach',
#    'thinking',
#    'food',
#    'poisoning',
#    'hole',
#    'hole',
#    'caused',
#    'went',
#    'customer',
#    'service',
#    'great',
#    'tacos',
#    'good',
#    'forgot',
#    'put',
#    'sauce',
#    'problem',
#    'place',
#    "it's",
#    'pretty',
#    'difficult',
#    'find',
#    "don't",
#    'mind',
#    'liquor',
#    'store',
#    'least',
#    'sort',
#    'sign',
#    'indicating',
#    'restaurant',
#    'inside',
#    'store',
#    'checked',
#    'place',
#    'waiting',
#    'food',
#    'little',
#    'hard',
#    'find',
#    "it's",
#    'inside',
#    "maria's",
#    'market',
#    'think',
#    "that's",
#    'name',
#    'got',
#    '2',
#    'orders',
#    'wings',
#    'fries',
#    'website',
#    'said',
#    'comes',
#    '12',
#    'sign',
#    'says',
#    '10',
#    'order',
#    'came',
#    '9',
#    'prices',
#    'differ',
#    'site',
#    'still',
#    'cheap',
#    'checked',
#    'using',
#    'yelp',
#    'received',
#    'discount',
#    'offer',
#    'ranch',
#    'wings',
#    'blu',
#    'cheese',
#    'wings',
#    'okay',
#    'sauce',
#    'good',
#    'smelt',
#    'different',
#    'places',
#    'came',
#    'seasoned',
#    'fries',
#    'paid',
#    '13.50',
#    'wanting',
#    'try',
#    'place',
#    'forever',
#    'decided',
#    'go',
#    'get',
#    'wings',
#    'fries',
#    'special',
#    'first',
#    'trying',
#    'get',
#    'place',
#    'almost',
#    'missed',
#    "it's",
#    'actual',
#    'fast',
#    'food',
#    'place',
#    'inside',
#    'liquor',
#    'store',
#    'left',
#    'side',
#    'get',
#    'food',
#    'side',
#    'liquor',
#    'store',
#    'perfect',
#    'idea',
#    'cause',
#    'ended',
#    'picking',
#    'bottle',
#    'wine',
#    'go',
#    'meal',
#    'place',
#    'looks',
#    'pretty',
#    'clean',
#    'although',
#    "it's",
#    'best',
#    'neighborhood',
#    'usually',
#    'kinds',
#    'place',
#    'best',
#    'food',
#    "isn't",
#    'much',
#    'seating',
#    '2',
#    '3',
#    'tables',
#    'privacy',
#    'customers',
#    'entering',
#    'liquor',
#    'store',
#    'privacy',
#    'may',
#    'eaten',
#    'food',
#    'service',
#    'ok',
#    'considering',
#    'lady',
#    'took',
#    'order',
#    "didn't",
#    'speak',
#    'much',
#    'english',
#    'enough',
#    'understand',
#    'order',
#    'lady',
#    'paid',
#    'food',
#    'really',
#    'friendly',
#    'helpful',
#    'service',
#    'alone',
#    'bring',
#    'back',
#    'business',
#    'got',
#    'fries',
#    'wait',
#    'bit',
#    'made',
#    'order',
#    "weren't",
#    'sitting',
#    'waiting',
#    'get',
#    'sauce',
#    'added',
#    "i'm",
#    'french',
#    'fry',
#    'connoisseur',
#    "weren't",
#    'good',
#    'would',
#    'like',
#    "weren't",
#    'crispy',
#    'made',
#    'fresh',
#    'boyfriend',
#    'mild',
#    'wings',
#    'got',
#    'hot',
#    'wings',
#    'wings',
#    'huge',
#    'skimpy',
#    'ones',
#    'like',
#    'wing',
#    'stop',
#    'mean',
#    'huge',
#    'meaty',
#    'since',
#    'like',
#    'spicy',
#    'food',
#    'wings',
#    "weren't",
#    'spicy',
#    'pretty',
#    'good',
#    'tried',
#    "boyfriend's",
#    'mild',
#    'wings',
#    'pretty',
#    'good',
#    'looked',
#    'mexican',
#    'food',
#    "didn't",
#    'look',
#    'great',
#    'looked',
#    'like',
#    'sitting',
#    'day',
#    'film',
#    'around',
#    'seen',
#    'pictures',
#    'food',
#    'maybe',
#    'go',
#    'another',
#    'time',
#    'try',
#    'tacos',
#    'burritos',
#    'since',
#    'mexican',
#    'food',
#    'favorite',
#    'planet',
#    'definitely',
#    'back',
#    'say',
#    'give',
#    'try',
#    'delicious',
#    'received',
#    'order',
#    'delivery',
#    'love',
#    'love',
#    'wish',
#    'found',
#    'guys',
#    'sooner',
#    'moving',
#    'hope',
#    'deliver',
#    'new',
#    'address',
#    'ordered',
#    '2',
#    'plates',
#    'tacos',
#    'rice',
#    'beans',
#    'half',
#    'roasted',
#    'chicken',
#    'combo',
#    'medium',
#    'size',
#    'order',
#    'fruit',
#    'one',
#    'taco',
#    'plate',
#    'roommate',
#    'roasted',
#    'chicken',
#    'dinner',
#    'exited',
#    'try',
#    'place',
#    'disappointed',
#    'delivery',
#    'burrito',
#    'rolled',
#    'correctly',
#    'tortilla',
#    'oily',
#    'soggy',
#    'even',
#    'considered',
#    'toasting',
#    'toaster',
#    'oven',
#    'crisp',
#    'appetizer',
#    'anymore',
#    'unfortunately',
#    "won't",
#    'ordering',
#    'time',
#    'soon',
#    'waited',
#    '4',
#    'hours',
#    'food',
#    'even',
#    'though',
#    'restraunt',
#    'said',
#    'food',
#    'left',
#    'twice',
#    'actually',
#    'cancelled',
#    'tge',
#    'order',
#    'delivery.com',
#    'minutes',
#    'later',
#    'driver',
#    'came',
#    'promised',
#    'food',
#    'fresh',
#    "wasn't",
#    'service',
#    'bad',
#    'ordered',
#    'food',
#    '6',
#    "didn't",
#    'come',
#    'till',
#    '10',
#    'night',
#    'used',
#    'using',
#    'grub',
#    'hub',
#    'amazing',
#    'food',
#    'service',
#    'delivery',
#    'order',
#    'actually',
#    'arrived',
#    '30',
#    'minutes',
#    'estimated',
#    'delivery',
#    'time',
#    'food',
#    'hot',
#    'delicious',
#    'husband',
#    'made',
#    'sure',
#    'remembered',
#    'name',
#    'order'])]

# %%
business_review_word_counts = business_reviews.map(lambda x: (x[0], create_word_count_dict(x[1])))

# %%
business_review_word_counts.take(10)
# Out:
# [('bZMcorDrciRbjdjRyANcjA',
#   {'listened': 1,
#    'reviews': 1,
#    'place': 4,
#    'highly': 2,
#    'unprofessional': 1,
#    '1st': 1,
#    'visit': 4,
#    'great': 8,
#    'signed': 3,
#    'package': 5,
#    'needed': 1,
#    '2': 6,
#    'months': 5,
#    'directed': 2,
#    'cancel': 2,
#    'email': 2,
#    'corporate': 13,
#    '30': 4,
#    'days': 5,
#    'advance': 1,
#    'paid': 8,
#    'partial': 1,
#    'month': 14,
#    'would': 10,
#    'automatically': 1,
#    'pulled': 1,
#    'point': 2,
#    'sent': 4,
#    '4': 2,
#    'emails': 2,
#    'response': 2,
#    'requesting': 1,
#    '2nd': 2,
#    'recommended': 1,
#    'lotion': 5,
#    'holiday': 1,
#    'weekend': 2,
#    'special': 1,
#    'advised': 3,
#    'due': 1,
#    'something': 1,
#    'could': 2,
#    'use': 2,
#    'today': 1,
#    'keep': 1,
#    'store': 2,
#    'another': 2,
#    'thought': 2,
#    'weird': 1,
#    'hey': 1,
#    'whatever': 1,
#    'went': 7,
#    'also': 7,
#    'bulbs': 2,
#    'bed': 5,
#    'lastly': 1,
#    'started': 3,
#    'later': 1,
#    'got': 4,
#    'following': 2,
#    '1.00': 1,
#    'disappointing': 1,
#    '3rd': 1,
#    'come': 1,
#    'pick': 1,
#    'problem': 1,
#    'however': 2,
#    'decided': 1,
#    'ask': 3,
#    'full': 3,
#    'price': 3,
#    'was...she': 1,
#    'provided': 1,
#    'tax...which': 1,
#    'exactly': 1,
#    'girls': 4,
#    'behind': 1,
#    'desk': 5,
#    'need': 2,
#    'go': 9,
#    'difference': 1,
#    'far': 3,
#    'company': 4,
#    'mess': 1,
#    'believe': 1,
#    'provide': 4,
#    'front': 4,
#    'line': 4,
#    'proper': 1,
#    'tools': 2,
#    'good': 5,
#    'customer': 11,
#    'service': 11,
#    'really': 5,
#    'trust': 4,
#    'staff': 2,
#    'adjust': 2,
#    'enter': 1,
#    'cancelation': 1,
#    'baffles': 1,
#    'like': 2,
#    'tanning': 16,
#    'salon': 6,
#    "i've": 2,
#    'tanned': 3,
#    'regularly': 1,
#    'couple': 4,
#    'salons': 3,
#    'town': 1,
#    'loved': 1,
#    'looking': 1,
#    'convenience': 2,
#    'close': 1,
#    'gym': 1,
#    "i'm": 2,
#    'back': 9,
#    'lvac': 1,
#    'parking': 1,
#    'lot': 5,
#    "couldn't": 2,
#    'convenient': 1,
#    'clean': 3,
#    'new': 4,
#    'amazing': 1,
#    'beds': 10,
#    'informative': 1,
#    'sales': 1,
#    'reps': 1,
#    'think': 1,
#    'biggest': 1,
#    'desires': 1,
#    "they've": 1,
#    'met': 1,
#    'body': 6,
#    'heat': 6,
#    'pho': 1,
#    'sagion8': 1,
#    'well': 1,
#    'came': 3,
#    'first': 9,
#    'time': 14,
#    'location': 9,
#    'maria': 3,
#    'showed': 1,
#    'around': 2,
#    'different': 3,
#    'work': 3,
#    'opposed': 1,
#    'locations': 3,
#    'im': 1,
#    'used': 3,
#    'since': 1,
#    'henderson': 1,
#    'even': 6,
#    'gave': 2,
#    'directions': 1,
#    'stops': 1,
#    'mentioned': 1,
#    'make': 1,
#    'disappointed': 1,
#    'bought': 1,
#    'cash': 9,
#    'never': 8,
#    'told': 12,
#    'tax': 1,
#    'top': 1,
#    '69.88': 1,
#    'ok...is': 1,
#    'credit': 5,
#    'card': 5,
#    'charged': 4,
#    'monthly': 4,
#    'fee': 3,
#    'though': 2,
#    'half': 1,
#    'mari': 1,
#    'called': 7,
#    'spoke': 2,
#    'tara': 4,
#    'billing': 2,
#    'quote': 1,
#    'unquote': 1,
#    'direct': 1,
#    "maria's": 1,
#    'mouth.....said': 1,
#    'done': 1,
#    'client': 1,
#    'shady': 1,
#    'hmmmmmmm': 1,
#    'call': 5,
#    'directly': 1,
#    'standing': 1,
#    'speaking': 1,
#    'super': 2,
#    'rude': 4,
#    'nothing': 1,
#    'file': 1,
#    'dispute': 1,
#    'reverse': 1,
#    'charge': 1,
#    'said': 2,
#    'account': 6,
#    'canceled': 1,
#    'want': 2,
#    'unused': 1,
#    'portion': 1,
#    'power': 1,
#    'hung': 4,
#    'everyone': 1,
#    'office': 5,
#    'whole': 1,
#    'week...ummm...talking': 1,
#    'right': 3,
#    'one': 11,
#    'speak': 1,
#    'her......she': 1,
#    'meagain': 1,
#    'voice': 2,
#    'mail': 1,
#    'next': 3,
#    'hour': 1,
#    'thank': 1,
#    'money': 4,
#    'getting': 1,
#    'options': 3,
#    'city': 2,
#    'better': 6,
#    'deals...better': 1,
#    'already': 1,
#    'business': 1,
#    'bureau': 1,
#    'owes': 1,
#    'legit': 1,
#    'stolen': 1,
#    'manager': 4,
#    'agreed': 2,
#    'phone': 1,
#    'cause': 1,
#    'prices': 1,
#    'cheap': 1,
#    'willing': 1,
#    'gonna': 1,
#    'check': 1,
#    'palm': 1,
#    'beach': 1,
#    'local': 1,
#    'places': 2,
#    'versa': 1,
#    'spa': 1,
#    'spray': 5,
#    'tan': 7,
#    'machine': 2,
#    'much': 3,
#    'maryland': 3,
#    'parkway': 1,
#    'leave': 1,
#    'streaks': 1,
#    'clear': 3,
#    'medium': 3,
#    'actually': 4,
#    'shade': 1,
#    'pkwy': 2,
#    'left': 2,
#    'uneven': 1,
#    'streaky': 1,
#    'plus': 1,
#    'turned': 1,
#    'light': 1,
#    'may': 1,
#    'little': 1,
#    'bit': 2,
#    'way': 5,
#    'prefer': 1,
#    'tans': 2,
#    'depends': 1,
#    'eastern': 1,
#    'busy': 2,
#    'certain': 1,
#    'times': 2,
#    'night': 2,
#    "haven't": 3,
#    'drove': 1,
#    'realized': 1,
#    'reviewed': 1,
#    'reason': 1,
#    'giving': 1,
#    '1': 3,
#    'star': 3,
#    '100': 1,
#    'warned': 1,
#    'specific': 1,
#    'girl': 12,
#    'friend': 2,
#    'experience': 2,
#    'asked': 3,
#    'particular': 2,
#    'blonde': 2,
#    'rolled': 1,
#    'eyes': 1,
#    'fine': 1,
#    "didn't": 2,
#    'find': 1,
#    "don't": 5,
#    'know': 3,
#    'either': 1,
#    'potential': 1,
#    'sign': 4,
#    'unacceptable': 2,
#    'extremely': 1,
#    'sweet': 1,
#    'happy': 1,
#    'explained': 2,
#    'free': 4,
#    '7': 1,
#    'day': 2,
#    'trial': 1,
#    'perfect': 1,
#    'twice': 1,
#    'nice': 2,
#    'kind': 1,
#    'person': 2,
#    'hired': 1,
#    'dealing': 1,
#    'customers': 1,
#    'daily': 1,
#    'basis': 1,
#    'completely': 1,
#    'made': 2,
#    'worse': 1,
#    'seen': 2,
#    'several': 2,
#    'mocked': 1,
#    'physically': 1,
#    'disabled': 1,
#    'appeared': 1,
#    'took': 2,
#    'everything': 1,
#    'act': 1,
#    'irrationally': 1,
#    'say': 2,
#    'anything': 1,
#    'might': 1,
#    'regret': 1,
#    'deserve': 1,
#    'job': 1,
#    'let': 1,
#    'alone': 2,
#    'workers': 2,
#    'name': 3,
#    'anybody': 1,
#    'needs': 1,
#    'contact': 2,
#    'feel': 1,
#    'get': 4,
#    'details': 1,
#    'needless': 1,
#    'week': 1,
#    'love': 4,
#    'opened': 1,
#    'silverado': 1,
#    'ranch': 1,
#    'awesome': 1,
#    'always': 6,
#    'extreme': 2,
#    'fgt': 1,
#    'fantastic': 1,
#    'pricey': 2,
#    'membership': 9,
#    'almost': 1,
#    'two': 3,
#    'years': 3,
#    "it's": 2,
#    'totally': 1,
#    'worth': 2,
#    'best': 3,
#    'drop-in': 1,
#    'session': 1,
#    'expensive': 1,
#    'college': 1,
#    'horizon': 1,
#    'fans': 1,
#    'wish': 1,
#    '10': 2,
#    'lol': 1,
#    'aspen': 1,
#    'remembers': 1,
#    'helpful': 1,
#    'questions': 2,
#    'change': 1,
#    '3': 2,
#    'contacted': 1,
#    'honoring': 1,
#    'promotion': 1,
#    'see': 2,
#    'yet': 1,
#    'opinion': 1,
#    'still': 1,
#    'stands': 1,
#    "doesn't": 1,
#    'level': 3,
#    'every': 3,
#    'deserves': 1,
#    'plenty': 1,
#    'vegas': 2,
#    "wouldn't": 2,
#    'choose': 1,
#    'using': 2,
#    'upgraded': 2,
#    'take': 1,
#    'care': 1,
#    'working': 1,
#    'order': 1,
#    'basic': 1,
#    'establishment': 1,
#    'las': 1,
#    'figured': 1,
#    "i'd": 1,
#    'drop': 1,
#    'missed': 1,
#    'things': 1,
#    'bodyheat': 1,
#    'verdict': 1,
#    'miss': 1,
#    'three': 2,
#    'remembered': 1,
#    'yes': 1,
#    'realize': 1,
#    'quite': 1,
#    'obvious': 1,
#    'solid': 1,
#    'base': 1,
#    'put': 3,
#    'minimum': 1,
#    'nearly': 1,
#    'eight': 1,
#    'minutes': 2,
#    'convince': 1,
#    'fry': 1,
#    'bits': 1,
#    'education': 2,
#    'slipped': 1,
#    'significantly': 1,
#    'sun': 2,
#    'angel': 1,
#    'high': 2,
#    'pressure': 2,
#    'hp': 1,
#    'face': 1,
#    'knew': 1,
#    'argument': 1,
#    "wasn't": 2,
#    'spent': 1,
#    'spending': 1,
#    '12': 1,
#    'selection': 1,
#    '24-hour': 1,
#    'fact': 1,
#    'carry': 1,
#    'favorite': 3,
#    'mrinternational': 1,
#    'lack': 1,
#    'nonchalance': 1,
#    'downright': 1,
#    'rudeness': 1,
#    'ensures': 1,
#    'paying': 2,
#    'machines': 2,
#    'friendly': 1,
#    'thingy': 1,
#    'scan': 1,
#    'instead': 1,
#    'making': 1,
#    'type': 1,
#    'past': 2,
#    'leading': 1,
#    'summer': 1,
#    'interested': 3,
#    'pay': 2,
#    'last': 1,
#    'year': 2,
#    'insisted': 1,
#    'atm': 1,
#    'record': 1,
#    'assured': 1,
#    'charges': 3,
#    'sure': 1,
#    'enough': 1,
#    'six': 1,
#    'thereafter': 1,
#    'countless': 1,
#    'ultimately': 1,
#    'handle': 1,
#    'financial': 1,
#    'institution': 1,
#    'block': 1,
#    'authorized': 1,
#    'retailer': 1,
#    'accessing': 1,
#    'pre-summer': 1,
#    'sessions': 3,
#    'owed': 1,
#    '400': 1,
#    'explain': 1,
#    'able': 1,
#    'matter': 1,
#    'straightened': 1,
#    'removed': 1,
#    'purchasing': 1,
#    'figuring': 1,
#    'foot': 1,
#    'forward': 1,
#    'try': 2,
#    'informed': 1,
#    'owe': 1,
#    '200': 1,
#    'unpaid': 1,
#    'authorize': 1,
#    'access': 1,
#    'anytime': 1,
#    'says': 1,
#    'voicemail': 1,
#    'department': 1,
#    'explaining': 1,
#    'situation': 1,
#    'attempted': 1,
#    'continues': 1,
#    'ring': 1,
#    'raising': 1,
#    'disrespectful': 1,
#    'size': 1,
#    'many': 1,
#    'continue': 1,
#    'pull': 1,
#    'scam': 1,
#    'fees': 1,
#    'wanted': 1,
#    'recommend': 1,
#    'anyone': 1,
#    'else': 1,
#    'ugh': 1,
#    'beware': 1,
#    'ladies': 1,
#    'clueless': 1,
#    'especially': 1,
#    'bad': 1,
#    'scare': 1,
#    'people': 3,
#    'away': 1,
#    'hope': 1,
#    'nicer': 1,
#    'answer': 1,
#    'bang': 1,
#    'buck': 1,
#    'pays': 1,
#    'look': 1,
#    'without': 1,
#    'damaging': 1,
#    'rays': 1,
#    'deals': 1,
#    'lotions': 1,
#    'valley': 1,
#    'least': 1,
#    'staring': 1,
#    'phones': 2,
#    'welcoming': 1,
#    'leaving': 1,
#    'responded': 1,
#    'poor': 1}),
#  ('n8Zqqhff-2cxzWt_nwhU2Q',
#   {'really': 174,
#    'enjoyed': 47,
#    'place': 248,
#    'happy': 143,
#    'hour': 129,
#    'awesome': 47,
#    'food': 380,
#    'delicious': 74,
#    'unique': 25,
#    'drinks': 115,
#    'also': 125,
#    'excellent': 40,
#    'however': 30,
#    'service': 239,
#    'needs': 13,
#    'help': 14,
#    'waiter': 25,
#    'mia': 3,
#    'needed': 18,
#    'cocktail': 18,
#    'refills': 11,
#    'several': 18,
#    'times': 48,
#    'wanted': 31,
#    'dessert': 22,
#    'never': 52,
#    'came': 142,
#    'back': 189,
#    'take': 42,
#    'order': 90,
#    'said': 58,
#    'okkaayy': 1,
#    'guess': 10,
#    "we'll": 10,
#    'skip': 1,
#    'tip': 10,
#    'would': 146,
#    'much': 59,
#    'bigger': 4,
#    'stayed': 1,
#    'overall': 49,
#    'great': 260,
#    'go': 103,
#    'hoping': 5,
#    'get': 137,
#    'better': 45,
#    "doesn't": 18,
#    'like': 183,
#    'friday': 7,
#    'drink': 77,
#    'specials': 12,
#    'available': 6,
#    'promptly': 7,
#    'clean': 12,
#    'environment': 5,
#    'fast': 2,
#    'loved': 41,
#    'atmosphere': 70,
#    'fun': 48,
#    'amazing': 74,
#    'bison': 29,
#    'burger': 117,
#    'lamb': 17,
#    'adobo': 3,
#    'tacos': 45,
#    'desert': 1,
#    'pretty': 75,
#    'cool': 62,
#    'spot': 44,
#    'bit': 56,
#    'yuppy-ish': 1,
#    'sometimes': 9,
#    'first': 64,
#    'dates': 4,
#    "i've": 67,
#    'taken': 8,
#    'couple': 22,
#    'ladies': 4,
#    'bad': 48,
#    'time': 134,
#    'staff': 45,
#    'friendly': 58,
#    'younger': 1,
#    'plenty': 17,
#    'tattoos': 1,
#    'piercings': 1,
#    'around': 50,
#    'innovative': 3,
#    'eat': 52,
#    'beer': 159,
#    'selection': 67,
#    'outstanding': 6,
#    'pub': 6,
#    'went': 70,
#    'dinner': 47,
#    'saturday': 16,
#    'evening': 10,
#    'got': 92,
#    'us': 125,
#    'quick': 18,
#    "didn't": 86,
#    'make': 58,
#    'reservation': 8,
#    'understand': 8,
#    "it's": 137,
#    'called': 12,
#    'public': 90,
#    'school': 131,
#    'tables': 31,
#    'chairs': 6,
#    'probably': 28,
#    'uncomfortable': 2,
#    'actual': 4,
#    'fan': 15,
#    'cold': 20,
#    'hard': 14,
#    'metal': 4,
#    'loud': 35,
#    'buffalo': 77,
#    'cauliflower': 112,
#    'bites': 17,
#    'good': 368,
#    'pricy': 3,
#    'ok': 52,
#    'ambiance': 22,
#    '9': 9,
#    'kids': 25,
#    'meal': 48,
#    'steep': 4,
#    'root': 2,
#    'wine': 22,
#    'glass': 15,
#    'starts': 2,
#    'pinot': 2,
#    'grigio': 1,
#    'looks': 17,
#    'lot': 33,
#    'things': 33,
#    'server': 125,
#    'melissa': 1,
#    'terrible': 10,
#    'rude': 7,
#    'slow': 30,
#    'friend': 37,
#    'walked': 13,
#    'sat': 51,
#    'bar': 125,
#    'care': 14,
#    'bryan': 1,
#    'informed': 6,
#    'made': 67,
#    'cocktails': 22,
#    'night': 49,
#    "he's": 3,
#    'mixologist': 1,
#    'next': 30,
#    'try': 97,
#    'outdoor': 28,
#    'mac': 58,
#    'cheese': 110,
#    'appetizer': 42,
#    'blown': 1,
#    'away': 26,
#    'yummy': 19,
#    'french': 10,
#    'toast': 6,
#    'day': 35,
#    'strawberry': 1,
#    'cream': 23,
#    'huge': 33,
#    'boyfriend': 21,
#    'breakfast': 10,
#    'burrito': 8,
#    'finished': 7,
#    'reason': 10,
#    'rated': 1,
#    'four': 18,
#    'literally': 16,
#    'forgotten': 3,
#    'ordered': 164,
#    'ask': 31,
#    'another': 51,
#    'customer': 20,
#    'makes': 12,
#    'best': 60,
#    'dining': 30,
#    'experience': 51,
#    "wasn't": 62,
#    'could': 53,
#    'actually': 19,
#    'attention': 8,
#    'paid': 7,
#    'locally': 2,
#    'sourced': 1,
#    'decent': 33,
#    'diet': 3,
#    'asked': 52,
#    'chicken': 123,
#    'shredded': 3,
#    'romaine': 1,
#    'lettuce': 3,
#    'dressing': 15,
#    'anything': 22,
#    'charged': 6,
#    '16': 6,
#    'seemed': 24,
#    'ridiculously': 2,
#    'pricing': 5,
#    'appropriate': 3,
#    'given': 14,
#    '5': 36,
#    'stars': 46,
#    'super': 40,
#    'overpriced': 7,
#    'everything': 55,
#    '2': 47,
#    'little': 78,
#    'skirt': 4,
#    'steak': 36,
#    '13': 6,
#    'fries': 63,
#    'tasteless': 1,
#    'beers': 55,
#    'undereducated': 1,
#    'disappointing': 13,
#    'tho': 4,
#    'lots': 19,
#    'potential': 5,
#    'crap': 3,
#    'girl': 9,
#    'every': 31,
#    'seat': 9,
#    'quickly': 25,
#    'sure': 60,
#    'comfortable': 9,
#    'pizza': 88,
#    'alway': 1,
#    'appetizers': 38,
#    'wings': 23,
#    'tots': 56,
#    'check': 42,
#    'nice': 118,
#    'open': 13,
#    'liked': 32,
#    'tge': 1,
#    'simplicity': 1,
#    'menu': 186,
#    "we're": 9,
#    'choices': 27,
#    'medium': 16,
#    'fantastic': 23,
#    'watermelon': 13,
#    'heirloom': 3,
#    'tomato': 13,
#    'salad': 86,
#    'restaurant': 109,
#    'average': 13,
#    'decor': 36,
#    'theme': 45,
#    'new': 45,
#    'level': 9,
#    'seasoned....i': 1,
#    'orleans': 1,
#    'nothing': 32,
#    'exceeded': 1,
#    'expectation': 5,
#    'honestly': 12,
#    'california': 2,
#    'kitchen': 15,
#    'excited': 15,
#    '702': 41,
#    'downtown': 60,
#    'summerlin': 77,
#    'charming': 3,
#    'schoolhouse': 6,
#    'helpful': 10,
#    'group': 27,
#    'starving': 1,
#    'decided': 38,
#    'share': 15,
#    'amongst': 1,
#    'bacon': 69,
#    'cheddar': 27,
#    'sriracha': 14,
#    'ketchup': 28,
#    'deep': 7,
#    'fried': 44,
#    'tator': 4,
#    'inside': 48,
#    'served': 37,
#    'sirracha': 4,
#    'chorizo': 45,
#    'emmental': 2,
#    'kale': 20,
#    'sea': 4,
#    'salt': 14,
#    'vinegar': 6,
#    'crunch': 15,
#    'hand': 7,
#    'tossed': 3,
#    'house': 18,
#    'pepperoni': 15,
#    'mozzarella': 1,
#    'provolone': 2,
#    'crushed': 7,
#    'tomatoes': 9,
#    'jalapeños': 2,
#    'watch': 5,
#    'games': 8,
#    'tv': 3,
#    'room': 10,
#    'brew': 8,
#    'star': 16,
#    'kept': 13,
#    'consistent': 6,
#    'perfect': 27,
#    'soggy': 10,
#    'switch': 2,
#    "don't": 68,
#    'line': 7,
#    'sour': 6,
#    'big': 31,
#    'plus': 16,
#    'enjoy': 19,
#    'hanging': 7,
#    'hate': 3,
#    'find': 16,
#    'becomes': 2,
#    'instant': 1,
#    'favorite': 40,
#    'often': 6,
#    'one': 110,
#    'corporate': 3,
#    'decides': 1,
#    'change': 5,
#    'top-selling': 1,
#    'items': 26,
#    'entrée': 5,
#    'sizes': 2,
#    'way': 35,
#    'smaller': 5,
#    'keep': 15,
#    'prices': 36,
#    'many': 24,
#    'always': 49,
#    'last': 32,
#    'noticeably': 2,
#    'missing': 13,
#    'shrimp': 42,
#    'grits': 39,
#    'personal': 4,
#    'waffles': 34,
#    'saw': 13,
#    'pass': 3,
#    'table': 91,
#    'noticed': 13,
#    'half': 20,
#    'size': 19,
#    'portion': 25,
#    'normally': 2,
#    'still': 55,
#    'price': 18,
#    'husband': 33,
#    'rare': 14,
#    'cooked': 31,
#    'well': 79,
#    'done': 16,
#    'calamari': 38,
#    'sitting': 24,
#    'window': 3,
#    'even': 74,
#    'though': 40,
#    'shortly': 6,
#    'thinking': 2,
#    'maybe': 36,
#    'somebody': 1,
#    'else': 22,
#    'girls': 6,
#    'love': 72,
#    'tenders': 3,
#    'larger': 8,
#    'two': 58,
#    'small': 36,
#    'pieces': 13,
#    'waitress': 46,
#    'extremely': 17,
#    'gave': 18,
#    'insight': 1,
#    'changes': 7,
#    'profusely': 1,
#    'apologetic': 5,
#    'comped': 4,
#    'need': 21,
#    'free': 5,
#    'coupon': 1,
#    'blame': 1,
#    'unfortunate': 3,
#    'going': 41,
#    'come': 84,
#    'days': 10,
#    'ago': 7,
#    'know': 48,
#    'guys': 4,
#    'waiting': 17,
#    'review': 23,
#    "isn't": 16,
#    'tooo': 1,
#    'shabby': 3,
#    'hipster': 6,
#    'type': 10,
#    'mediocre': 12,
#    'say': 31,
#    'least': 19,
#    "i'm": 77,
#    'gonna': 3,
#    'hop': 1,
#    'hype': 2,
#    'train': 3,
#    'everyone': 20,
#    'give': 38,
#    'real': 10,
#    'ehh': 1,
#    'tell': 20,
#    'neighbors': 1,
#    "you're": 19,
#    'ehhhhhh': 1,
#    'mean': 7,
#    'rather': 15,
#    'bjs': 2,
#    'lazy': 3,
#    'dog': 4,
#    'anywhere': 4,
#    'dts': 5,
#    'gross': 6,
#    'thing': 36,
#    'flank': 1,
#    'top': 24,
#    'chips': 47,
#    'salty': 14,
#    'dead': 1,
#    'date': 11,
#    'movie': 6,
#    'wait': 47,
#    '20mins': 1,
#    'area': 66,
#    'took': 65,
#    'forever': 8,
#    'poke': 17,
#    'app': 7,
#    'bite': 11,
#    'meat': 13,
#    'chewy': 6,
#    'soft': 8,
#    'basically': 6,
#    'old': 17,
#    'sending': 2,
#    'giving': 11,
#    'thanks': 7,
#    "won't": 18,
#    'feel': 29,
#    'wasted': 1,
#    '75': 1,
#    'disappointed': 19,
#    'late': 9,
#    'drinks/snacks': 1,
#    '9pm': 3,
#    'busy': 41,
#    'booth': 10,
#    'near': 8,
#    'outlets': 5,
#    'usb': 8,
#    'wall': 4,
#    'crispy': 62,
#    'possibly': 3,
#    'vegetable': 5,
#    'ever': 26,
#    'eaten': 7,
#    'attempt': 1,
#    'healthy': 7,
#    'stacked': 1,
#    'okay': 22,
#    'hubby': 9,
#    'cheesy': 5,
#    'greasy': 13,
#    'flavorful': 14,
#    '70': 1,
#    'year': 4,
#    'trapped': 1,
#    'nearly': 7,
#    '40': 6,
#    'body': 1,
#    'noisy': 8,
#    'taste': 43,
#    '6:30': 4,
#    'wednesday': 5,
#    'instead': 14,
#    "would've": 6,
#    'slightly': 13,
#    'different': 42,
#    "i'd": 27,
#    'definitely': 80,
#    'biggest': 4,
#    'esthetic': 1,
#    'substandard': 1,
#    'lackluster': 4,
#    'worst': 8,
#    'jessica': 4,
#    'horrible': 11,
#    '10': 33,
#    'minutes': 70,
#    'greet': 9,
#    'water': 39,
#    'write': 4,
#    'fine': 16,
#    "can't": 40,
#    'remember': 10,
#    'input': 1,
#    'pos': 2,
#    'since': 41,
#    'confirm': 3,
#    'entered': 2,
#    'system': 4,
#    'delayed': 1,
#    'effort': 3,
#    'resulted': 1,
#    'forgetting': 3,
#    'ordering': 16,
#    'worked': 9,
#    'gets': 13,
#    'mistakes': 1,
#    'happen': 4,
#    'etc': 12,
#    'audacity': 1,
#    'lie': 1,
#    'blamed': 3,
#    'person': 11,
#    'ran': 2,
#    'taking': 8,
#    'wrong': 19,
#    'later': 18,
#    'problem': 5,
#    'admit': 2,
#    'making': 7,
#    'mistake': 5,
#    'apologize': 6,
#    'comp': 1,
#    'manager': 23,
#    'error': 2,
#    'genuinely': 2,
#    'kind': 34,
#    'meanwhile': 1,
#    'dropped': 3,
#    'disappeared': 5,
#    'box': 3,
#    'leftovers': 2,
#    'home': 14,
#    'flag': 2,
#    'figured': 2,
#    'getting': 23,
#    'longer': 9,
#    'mattered': 2,
#    'twice': 13,
#    'fully': 3,
#    'satisfied': 4,
#    'quality': 22,
#    'superior': 1,
#    'suggest': 7,
#    'salmon': 13,
#    'christopher': 1,
#    'attentive': 25,
#    'servers': 27,
#    'afternoon': 9,
#    "must've": 2,
#    'people': 43,
#    'finally': 32,
#    'bartenders': 10,
#    'oblivious': 1,
#    'concerned': 2,
#    'shift': 1,
#    'cleaning': 2,
#    'patrons': 2,
#    'visited': 5,
#    'ps': 10,
#    'happily': 1,
#    'lunch': 59,
#    'shared': 13,
#    'cutting': 18,
#    'board': 25,
#    'chucarterie': 1,
#    'cheeses': 6,
#    'olive': 3,
#    'oil': 7,
#    'bread': 21,
#    '4': 43,
#    'mini': 6,
#    'tuna': 25,
#    'sit': 22,
#    'outside': 66,
#    'lauren': 1,
#    'knowledgeable': 10,
#    'efficient---a': 1,
#    'sweetheart': 2,
#    'general': 5,
#    'bought': 5,
#    'guests': 5,
#    'main': 12,
#    'kudos': 2,
#    'brunch': 69,
#    'waited': 33,
#    'waters': 4,
#    'spent': 5,
#    'someone': 19,
#    'tired': 1,
#    '1': 21,
#    'saved': 1,
#    'dollar': 2,
#    'bottomless': 28,
#    'mimosas': 14,
#    "i'll": 26,
#    'weeks': 4,
#    'hopefully': 4,
#    'fab': 1,
#    'devotee': 1,
#    'want': 38,
#    'added': 9,
#    'bonus': 1,
#    'gf': 1,
#    'craft': 15,
#    'recommendation': 4,
#    'gr8': 1,
#    'sadly': 3,
#    'name': 22,
#    'raved': 5,
#    'it.o': 1,
#    'full': 22,
#    'specialty': 4,
#    'liquors': 1,
#    'blender': 1,
#    'apps': 20,
#    'consisting': 1,
#    'deviled': 13,
#    'eggs': 39,
#    'w/speck': 1,
#    'margarita': 11,
#    'simply': 2,
#    'deeelish': 2,
#    'stand': 9,
#    'cauliflower....very': 1,
#    'blue': 14,
#    'dip': 5,
#    'hot': 28,
#    'sauce': 57,
#    'kinda': 6,
#    'wing': 9,
#    'weather': 12,
#    'heater': 2,
#    'quite': 21,
#    'comfy': 1,
#    'plan': 6,
#    'conversation': 11,
#    'preferred': 3,
#    'indoors': 6,
#    'casual': 24,
#    'addition': 8,
#    'seating': 35,
#    'offer': 9,
#    'traditional': 8,
#    'ez': 1,
#    'parking': 3,
#    'appealing': 4,
#    'point': 20,
#    'see': 39,
#    'expansive': 2,
#    'found': 14,
#    'seems': 15,
#    'hang': 9,
#    'friends': 43,
#    'without': 24,
#    'club': 4,
#    'patio': 77,
#    'beautiful': 16,
#    'realize': 2,
#    "hadn't": 7,
#    'brought': 23,
#    'round': 14,
#    'save': 4,
#    'interesting': 13,
#    'spins': 1,
#    'space': 14,
#    'themed': 10,
#    'moment': 4,
#    "there's": 13,
#    'books': 3,
#    'note': 11,
#    'pads': 1,
#    'globes': 4,
#    'decorations': 5,
#    'noise': 7,
#    "wouldn't": 23,
#    'recommend': 38,
#    'coming': 27,
#    'romance': 1,
#    'liquor': 2,
#    'jungle': 4,
#    'juice': 11,
#    'mild': 2,
#    'buzz': 3,
#    'bartender': 15,
#    'kick': 12,
#    'prefer': 7,
#    'ol': 1,
#    'ones': 2,
#    'seem': 16,
#    'approach': 3,
#    'comment': 3,
#    'nicely': 8,
#    'thin': 8,
#    'crust': 8,
#    'charcuterie': 6,
#    'board...pretty': 1,
#    'damn': 5,
#    'crackers': 1,
#    'jam': 7,
#    'honey': 2,
#    'offered': 7,
#    'balance': 6,
#    'sweet': 28,
#    'savory': 7,
#    'tonight': 6,
#    'interested': 5,
#    'trying': 15,
#    'large': 34,
#    "couldn't": 22,
#    'feels': 5,
#    'hell': 3,
#    'issue': 8,
#    'bills': 1,
#    'scratch': 3,
#    'gastro': 3,
#    'store': 3,
#    'bloody': 24,
#    'mary': 18,
#    'mix': 8,
#    'easy': 5,
#    'brandy': 1,
#    'pina': 1,
#    'colada': 1,
#    'toasted': 2,
#    'almond': 1,
#    'martini': 1,
#    'carry': 1,
#    'decaf': 3,
#    'coffee': 5,
#    'stairs': 1,
#    'crave': 6,
#    'cup': 3,
#    'bring': 13,
#    "bailey's": 1,
#    'yellow': 4,
#    'thunder': 1,
#    'aside': 4,
#    'tater': 13,
#    'cookie': 17,
#    'ice': 25,
#    'sandwich': 30,
#    'nutella': 19,
#    'brittle': 3,
#    'someplace': 1,
#    'somewhere': 6,
#    'nicer': 1,
#    '8:30': 1,
#    '15': 24,
#    'parties': 6,
#    'tried': 46,
#    'appleton': 1,
#    'cider': 4,
#    'let': 22,
#    'completely': 6,
#    'ciders': 2,
#    'start': 19,
#    'entrees': 23,
#    'fish': 48,
#    'mind': 14,
#    'turkey': 2,
#    'melt': 3,
#    'either': 10,
#    'pay': 1,
#    'visits': 4,
#    'wonder': 1,
#    '5/5': 8,
#    'trendy': 5,
#    'able': 16,
#    'easily': 7,
#    'accommodate': 2,
#    '10ppl': 1,
#    'short': 22,
#    'notice': 4,
#    '4/5': 1,
#    'creamy': 7,
#    'goodness': 4,
#    'scrape': 1,
#    'bottom': 8,
#    'plate': 13,
#    'value': 3,
#    'side': 49,
#    'buttery': 2,
#    'flaky': 2,
#    'speck': 11,
#    '3/5': 2,
#    'ordinary': 2,
#    'jidori': 10,
#    'green': 10,
#    'chili': 17,
#    'cornbread': 9,
#    'perfectly': 22,
#    'seasoned': 5,
#    'juicy': 10,
#    'waffle': 13,
#    'typical': 5,
#    'texture': 8,
#    'stuffed': 5,
#    'overly': 1,
#    'perhaps': 4,
#    'bowl': 13,
#    'mush': 1,
#    'something': 30,
#    'grit': 3,
#    'cake--a': 1,
#    'almost': 31,
#    'mimosa': 11,
#    '2/5': 2,
#    'special': 20,
#    'loses': 1,
#    '10/5': 1,
#    'omg': 1,
#    'pickled': 1,
#    'garlic': 2,
#    'a...chicken': 1,
#    'joke': 1,
#    'solid': 9,
#    'spicy': 25,
#    'swear': 1,
#    "that's": 25,
#    'marys': 1,
#    'amazeballs': 1,
#    'work': 14,
#    'mid-day': 1,
#    "let's": 7,
#    'middle': 4,
#    'shopping': 13,
#    'tad': 3,
#    'pricey': 14,
#    "aren't": 6,
#    'including': 9,
#    'rock': 7,
#    'enough': 32,
#    'desired': 3,
#    'towards': 2,
#    'end': 21,
#    'dang': 1,
#    'impossible': 2,
#    'female': 2,
#    'courtney': 5,
#    'told': 29,
#    'charge': 1,
#    'bill': 18,
#    'right': 41,
#    'incorrectly': 1,
#    'higher': 2,
#    'oh': 9,
#    'changed': 6,
#    "shouldn't": 3,
#    'left': 22,
#    'anymore': 2,
#    'serve': 10,
#    'three': 16,
#    'sets': 5,
#    'orders': 14,
#    'knew': 5,
#    'long': 32,
#    'stuff': 8,
#    'together': 15,
#    'checked': 10,
#    'highly': 15,
#    'vibe': 21,
#    'pros': 4,
#    'cons': 6,
#    'tap': 8,
#    'definately': 1,
#    'atrocious': 1,
#    'think': 47,
#    'kinks': 3,
#    'concept': 13,
#    'failed': 2,
#    'delivery': 1,
#    'recess': 12,
#    'options': 29,
#    'wagyu': 1,
#    'corn': 9,
#    'dogs': 1,
#    'naked': 8,
#    'rotating': 7,
#    'seasonal': 1,
#    'handles': 1,
#    'stays': 3,
#    'michael': 1,
#    'job': 12,
#    'describing': 2,
#    'recommending': 2,
#    'based': 7,
#    'preferences': 1,
#    'eclectic': 2,
#    'happiness': 1,
#    'horribly': 2,
#    'bland': 14,
#    'blah': 2,
#    'flat': 7,
#    'iron': 7,
#    'burnt': 2,
#    'flavor': 48,
#    'happened': 3,
#    'second': 23,
#    'urgh': 1,
#    'cute': 23,
#    'broken': 2,
#    'vacay': 1,
#    'views': 4,
#    'relaxing': 4,
#    'marble': 1,
#    'tabletops': 1,
#    'bleu': 5,
#    'ranch': 7,
#    'visit': 45,
#    'reasonably': 2,
#    'priced': 9,
#    'walk': 9,
#    'shop': 1,
#    'delightful': 4,
#    'undercooked': 2,
#    'rice': 4,
#    'overcooked': 4,
#    'roasted': 9,
#    'poblano': 7,
#    'quinoa': 21,
#    'department': 2,
#    'stuffing': 1,
#    'mezze': 3,
#    'rear': 1,
#    'hummus': 24,
#    'lacking': 4,
#    'paprika': 1,
#    'standard': 6,
#    'subpar': 4,
#    'limited': 11,
#    'personally': 5,
#    'fathers': 2,
#    'beer"...so': 1,
#    'guavalajara': 2,
#    'strong': 3,
#    'guava': 3,
#    'overpowering': 4,
#    'tasted': 19,
#    'service...it': 1,
#    'slow...really': 1,
#    'necessarily': 3,
#    'talking': 9,
#    'enjoying': 5,
#    'lag': 1,
#    'weekend': 12,
#    'brunches': 1,
#    'location': 25,
#    'whole': 19,
#    'family': 16,
#    'oversized': 4,
#    'jenga': 14,
#    'connect': 5,
#    'play': 8,
#    'wanting': 4,
#    'awhile': 3,
#    'avoided': 1,
#    'due': 8,
#    'impression': 5,
#    'others': 14,
#    'hyped': 1,
#    'barely': 5,
#    'handful': 4,
#    'runner': 1,
#    'placed': 3,
#    'thought': 24,
#    "where'd": 1,
#    'rest': 7,
#    'truffle': 30,
#    'yet': 13,
#    '7': 12,
#    'brown': 12,
#    'paper': 11,
#    'bag': 9,
#    'cashier': 1,
#    'gas': 1,
#    'station': 2,
#    ...}),
#  ('1Df5WnLX3DqN6ymlhqznaQ',
#   {'hands': 1,
#    'best': 32,
#    'place': 42,
#    'eaten': 6,
#    'vegas': 23,
#    'far': 6,
#    'trips': 1,
#    'time': 43,
#    'filet': 17,
#    'also': 39,
#    'sampler': 13,
#    'plate': 20,
#    'mix': 2,
#    'everything': 36,
#    'sushi': 15,
#    'good': 92,
#    'short': 17,
#    'ribs': 22,
#    'potstickers': 22,
#    'desserts': 9,
#    'etc': 2,
#    'amazing': 25,
#    'favor': 1,
#    'go': 33,
#    'start': 6,
#    'picking': 1,
#    'menu': 65,
#    'back': 35,
#    'every': 10,
#    'visit': 12,
#    'friend': 6,
#    'worked': 3,
#    'hooked': 2,
#    'us': 55,
#    'kinds': 1,
#    'different': 12,
#    'food': 101,
#    'pretty': 18,
#    'thing': 16,
#    "didn't": 29,
#    'like': 47,
#    'schezuan': 1,
#    'sp': 1,
#    'believe': 8,
#    'ick': 1,
#    'molten': 8,
#    'lava': 6,
#    'chocolate': 51,
#    'cake': 34,
#    'orgasmic': 1,
#    'though': 13,
#    'wanted': 7,
#    'dine': 6,
#    "roy's": 114,
#    'got': 39,
#    'chance': 2,
#    'tonight': 2,
#    'attending': 1,
#    'seminar': 1,
#    'one': 51,
#    'dining': 19,
#    'rooms': 2,
#    'restaurant': 42,
#    'well': 38,
#    'laid': 1,
#    'wait': 12,
#    'staff': 28,
#    'exceptional': 7,
#    'evening': 12,
#    'appetizers': 18,
#    'asian': 9,
#    'chilled': 1,
#    'shrimp': 35,
#    'spicy': 8,
#    'lime': 6,
#    'cocktail': 2,
#    'sauce': 41,
#    'thai': 3,
#    'chicken': 8,
#    'satay': 2,
#    'w/bangkok': 1,
#    'style': 8,
#    'peanut': 2,
#    'dipping': 2,
#    'crispy': 8,
#    'wagyu': 14,
#    'beef': 19,
#    'dumpling': 2,
#    'w/chili': 1,
#    'soy': 4,
#    'salad': 12,
#    'baby': 7,
#    'greens': 7,
#    'shaved': 1,
#    'carrot': 2,
#    'daikon': 1,
#    'heirloom': 2,
#    'tomatoes': 1,
#    'onion': 3,
#    'shoyu': 1,
#    'vinaigrette': 3,
#    'entree': 18,
#    'selection': 3,
#    'grilled': 14,
#    '8': 6,
#    'oz': 1,
#    'mignon': 10,
#    'truffle': 2,
#    'misoyaki': 15,
#    'demi': 1,
#    'glace': 1,
#    'dessert': 57,
#    'belgian': 1,
#    'torte': 1,
#    'raspberry': 6,
#    'seasonal': 2,
#    'berries': 1,
#    'vanilla': 10,
#    'whipped': 1,
#    'cream': 18,
#    'delicious': 35,
#    'favorite': 28,
#    'seasoned': 5,
#    'flavorful': 7,
#    'cooked': 21,
#    'perfect': 10,
#    'medium': 4,
#    'opportunity': 3,
#    'comes': 5,
#    'definitely': 34,
#    'returning': 5,
#    'happy': 54,
#    'hour': 38,
#    'bomb': 1,
#    'miss': 2,
#    'dani': 1,
#    'hoard': 1,
#    'day': 9,
#    'came': 42,
#    'ordered': 63,
#    '5': 16,
#    'items': 7,
#    'hh': 5,
#    "i'm": 25,
#    '2': 22,
#    'rolls': 11,
#    'deep-friend': 1,
#    'fusion': 9,
#    'nevertheless': 3,
#    'tasty': 19,
#    'ahi': 16,
#    'dish': 21,
#    'made': 30,
#    'high': 6,
#    'quality': 12,
#    'ingredients': 3,
#    'fish': 45,
#    'service': 88,
#    'efficient': 1,
#    'sweet': 21,
#    'baggies': 1,
#    'pack': 1,
#    'leftovers': 2,
#    'graciously': 2,
#    'packed': 4,
#    'neat': 1,
#    'cute': 3,
#    'containers': 3,
#    'even': 25,
#    'sauces': 2,
#    'individually': 1,
#    'sealed': 1,
#    'happily': 2,
#    'waltzed': 1,
#    'full': 9,
#    'tummy': 1,
#    'bag': 1,
#    'next': 13,
#    'door': 5,
#    'reached': 1,
#    'car': 2,
#    'servers': 6,
#    'chased': 1,
#    'give': 19,
#    'accidentally': 1,
#    'left': 12,
#    'table': 18,
#    "wouldn't": 3,
#    'eat': 8,
#    'leftover': 1,
#    'w/o': 1,
#    'great': 69,
#    'love': 23,
#    'decorated': 3,
#    'lots': 3,
#    'hawain': 1,
#    'selections': 1,
#    'ambiance': 5,
#    'friendly': 13,
#    "it's": 29,
#    'las': 12,
#    'much': 28,
#    'comments': 1,
#    'except': 3,
#    'try': 22,
#    'going': 15,
#    'price': 14,
#    'right': 14,
#    'portion': 9,
#    'crabcake': 1,
#    'yummy': 6,
#    'recommended': 9,
#    'sad': 4,
#    'review': 17,
#    'truth': 2,
#    'told': 8,
#    'aloha': 9,
#    'sucked': 2,
#    'declined': 1,
#    'sorry': 3,
#    'take': 17,
#    'pictures': 3,
#    'enjoyed': 9,
#    'kimchi': 1,
#    "that's": 9,
#    'dinner': 40,
#    'solid': 2,
#    'stars': 13,
#    'come': 20,
#    'nothing': 10,
#    'new': 6,
#    'ah': 1,
#    'happened': 3,
#    'went': 31,
#    'years': 7,
#    'ago': 3,
#    "friend's": 2,
#    'birthday': 58,
#    'top': 6,
#    'notch': 2,
#    'superb': 2,
#    'put': 4,
#    'note': 3,
#    'know': 14,
#    'girl': 3,
#    'sitting': 4,
#    'saying': 2,
#    'name': 10,
#    'nice': 30,
#    'atmosphere': 10,
#    'around': 13,
#    'scoop': 1,
#    'ice': 14,
#    'let': 9,
#    'share': 3,
#    'wrote': 2,
#    'beautiful': 8,
#    'presentation': 14,
#    "can't": 16,
#    'forgot': 4,
#    'wife': 7,
#    'anniversary': 15,
#    'last': 11,
#    'year': 8,
#    'anyway': 1,
#    'spectacular': 3,
#    'always': 30,
#    'jalapeno': 2,
#    'infused': 3,
#    'margarita': 5,
#    'awesome': 15,
#    "i've": 19,
#    'trying': 2,
#    'replicate': 1,
#    'home': 15,
#    "haven't": 4,
#    'able': 5,
#    'make': 23,
#    'seated': 11,
#    'since': 14,
#    'knew': 3,
#    'managers': 3,
#    'see': 6,
#    'must': 10,
#    'experience': 30,
#    'still': 18,
#    'thinking': 2,
#    'later': 8,
#    'seems': 6,
#    'deliver': 1,
#    "wife's": 5,
#    'waikiki': 1,
#    'anything': 4,
#    'ambience': 3,
#    'quite': 12,
#    'cozy': 1,
#    'low': 2,
#    'lighting': 2,
#    'started': 12,
#    'canoe': 2,
#    'appetizer': 25,
#    'two': 17,
#    'following': 3,
#    'vegetable': 1,
#    'spring': 4,
#    'szechuan': 6,
#    'tuna': 3,
#    'roll': 22,
#    'kim': 1,
#    'chee': 1,
#    'lobster': 39,
#    'empty': 4,
#    'stomach': 1,
#    'demolished': 1,
#    'tell': 6,
#    'item': 3,
#    'get': 28,
#    'variety': 5,
#    'flavors': 4,
#    'taste': 11,
#    'roasted': 6,
#    'macadamia': 17,
#    'nut': 8,
#    'crusted': 7,
#    'mahi': 37,
#    'fried': 5,
#    'potato': 7,
#    'mash': 2,
#    'asparagus': 2,
#    'entrees': 13,
#    'prie': 1,
#    'fixed': 1,
#    'included': 6,
#    'sashimi': 1,
#    'lot': 14,
#    'breakfast': 1,
#    'tomorrow': 1,
#    'chocoholic': 1,
#    'loved': 21,
#    'things': 13,
#    'remember': 5,
#    'memorable': 8,
#    '1': 12,
#    'special': 37,
#    'gave': 13,
#    'complimentary': 10,
#    'candle': 3,
#    'overall': 15,
#    'night': 20,
#    'eating': 5,
#    'brought': 13,
#    'hawaii': 11,
#    'saw': 2,
#    'ad': 1,
#    '39': 2,
#    'prix': 15,
#    'fixe': 12,
#    'thought': 7,
#    'would': 27,
#    'orlando': 1,
#    'arrived': 13,
#    '5:00': 1,
#    'reservations': 7,
#    'problem': 6,
#    'really': 41,
#    'outdated': 1,
#    'compared': 4,
#    'locations': 6,
#    'visited': 3,
#    'quickly': 10,
#    'greeted': 7,
#    'waited': 2,
#    'drink': 12,
#    'orders': 5,
#    'signature': 5,
#    'maitai': 1,
#    'ready': 3,
#    'order': 26,
#    'returned': 1,
#    'drinks': 13,
#    'allows': 1,
#    'choose': 4,
#    'shumai': 2,
#    'kona': 2,
#    'coffee': 3,
#    'pork': 25,
#    'kauai': 1,
#    'prawns': 6,
#    'souffle': 15,
#    'ebi': 6,
#    'tempura': 6,
#    'cheese': 2,
#    'avocado': 2,
#    'coconut': 7,
#    'habanero': 2,
#    'unfortunately': 7,
#    'theme': 1,
#    'nicely': 10,
#    'presented': 5,
#    'looking': 12,
#    'little': 30,
#    'flavor': 13,
#    'descriptions': 1,
#    'sounded': 2,
#    'wonderful': 13,
#    'failed': 1,
#    'live': 2,
#    'expectations': 5,
#    'mintutes': 1,
#    'small': 13,
#    '6': 10,
#    'pieces': 4,
#    'ok': 14,
#    'bland': 6,
#    'could': 19,
#    'served': 12,
#    'long': 4,
#    'white': 5,
#    'probably': 13,
#    'least': 4,
#    'appealing': 1,
#    'tasting': 6,
#    'tasted': 10,
#    'heated': 1,
#    'freshly': 1,
#    'main': 13,
#    'course': 14,
#    'missing': 2,
#    'promised': 1,
#    'description': 2,
#    'loin': 1,
#    'fishy': 2,
#    'fresh': 11,
#    'lastly': 2,
#    'perfection': 8,
#    'mentioned': 4,
#    'totally': 2,
#    'powered': 1,
#    'took': 20,
#    'bite': 4,
#    'rich': 7,
#    'chewy': 2,
#    'tart': 8,
#    'shame': 1,
#    '10': 3,
#    'without': 9,
#    'absolutely': 10,
#    'fantastic': 7,
#    'sure': 17,
#    'waters': 1,
#    'never': 23,
#    'less': 3,
#    '3/4': 1,
#    'dishes': 17,
#    'cleared': 1,
#    'waiter': 26,
#    'assistants': 1,
#    'courses': 1,
#    'timed': 1,
#    'experiences': 3,
#    'disappointing': 3,
#    'ohana': 2,
#    'fancy': 3,
#    'plating': 1,
#    'light': 7,
#    'outstanding': 5,
#    'husband': 17,
#    'celebrating': 7,
#    '12': 2,
#    'meeting': 1,
#    'card': 9,
#    'server': 24,
#    'todd': 2,
#    'noticed': 1,
#    'asked': 13,
#    'brings': 3,
#    'pineapple': 11,
#    'upside': 8,
#    'written': 5,
#    'carmel': 1,
#    '12th': 1,
#    'picture': 11,
#    'copy': 2,
#    'frame...now': 1,
#    'mahalo': 1,
#    'many': 16,
#    'usually': 6,
#    'gets': 3,
#    '4-star': 1,
#    'rating': 5,
#    'book': 4,
#    'location': 22,
#    '3': 10,
#    'feeling': 2,
#    'unsatsified': 1,
#    'lacking': 2,
#    'read': 2,
#    'attitude': 1,
#    'positives': 1,
#    'calamari': 7,
#    'yuzu': 1,
#    'pesto': 2,
#    'crisp': 2,
#    'refreshing': 2,
#    'rubbery': 2,
#    'shortrib': 1,
#    'fall-off-the-bone': 1,
#    'tender': 9,
#    'tangy': 1,
#    'glaze': 3,
#    'orange': 2,
#    'ginger': 1,
#    'creme': 3,
#    'brulee': 2,
#    'velvety': 1,
#    'negatives': 1,
#    'potstickers...no,no': 1,
#    'no..soggy': 1,
#    'oily': 2,
#    'almost': 6,
#    'trace': 1,
#    'miso': 6,
#    'butterfish': 41,
#    'overdone': 1,
#    'masked': 1,
#    'fish...the': 1,
#    'cut': 6,
#    'fattier': 1,
#    'usual': 2,
#    'rib': 11,
#    'eye': 4,
#    'unimpressive': 1,
#    "i'd": 12,
#    'avoid': 1,
#    'created': 2,
#    'flyer': 1,
#    'custom-made': 1,
#    'names': 4,
#    'inserted': 1,
#    'removed': 2,
#    'flyers': 1,
#    'wrapped': 4,
#    'souvenirs': 1,
#    'personal': 2,
#    'touch': 9,
#    'creamy': 3,
#    'oh': 3,
#    'words': 1,
#    'said': 15,
#    'loooooove': 1,
#    'especially': 7,
#    'fan': 2,
#    'hours': 3,
#    'ones': 2,
#    "isn't": 2,
#    'biggest': 2,
#    'eats': 1,
#    'house': 3,
#    'martini': 13,
#    'i.e': 1,
#    'end': 12,
#    'couple': 4,
#    'not-so-great': 1,
#    'work': 4,
#    'days': 1,
#    'attentive': 9,
#    'quiet': 2,
#    'sometimes': 2,
#    'like...i': 1,
#    "don't": 11,
#    'recall': 1,
#    'play': 1,
#    'music': 2,
#    'uh': 1,
#    'oh)...but': 1,
#    'friends': 10,
#    'busy': 7,
#    'munching': 2,
#    'notice': 1,
#    'regular': 8,
#    'chose': 2,
#    'steak': 9,
#    'hard': 7,
#    'wrong': 10,
#    'shrug': 1,
#    'vote': 1,
#    'pitstop': 1,
#    'way': 19,
#    'ya': 3,
#    'second': 4,
#    'first': 14,
#    'l.a': 2,
#    'times': 11,
#    'treated': 5,
#    'kinda': 1,
#    'negative': 1,
#    'feedback': 1,
#    'free': 10,
#    'meal': 29,
#    'sake': 1,
#    'fellow': 1,
#    'yelpers': 1,
#    'say': 15,
#    'paying': 1,
#    'disappointed': 7,
#    'recent': 1,
#    'scallops': 21,
#    'six': 1,
#    'risotto': 5,
#    'four': 3,
#    'attention': 7,
#    'provided': 2,
#    'point': 4,
#    'satisfying': 1,
#    'mean': 3,
#    "i'll": 4,
#    'coupons': 2,
#    'messed': 4,
#    'groups': 2,
#    'gotten': 1,
#    'big': 9,
#    '34': 1,
#    '20': 6,
#    'something': 12,
#    'grow': 1,
#    'travel': 3,
#    'zoo': 1,
#    'deal': 6,
#    'actually': 5,
#    'liked': 3,
#    'better': 26,
#    'pebble': 1,
#    'beach': 1,
#    'town': 8,
#    'decor': 7,
#    'excellent': 27,
#    'care': 6,
#    'known': 7,
#    'black': 8,
#    'cod': 4,
#    'folks': 2,
#    'might': 4,
#    'heavy': 1,
#    'texture': 2,
#    'prefer': 2,
#    'flaky': 1,
#    'enjoy': 4,
#    'else': 8,
#    'halibut': 3,
#    'steelhead': 1,
#    'consistency': 1,
#    'par': 2,
#    "we've": 5,
#    'dined': 3,
#    'anaheim': 2,
#    'roys': 9,
#    'starts': 1,
#    '4:30': 1,
#    'actual': 1,
#    'opens': 1,
#    'elegant': 1,
#    'yet': 5,
#    'relaxed': 1,
#    'alot': 1,
#    'original': 3,
#    'hawaiian': 27,
#    'apps': 5,
#    'california': 5,
#    'average': 5,
#    'bit': 14,
#    'sliders': 8,
#    'fries': 5,
#    'tenderloin': 1,
#    'skewers': 3,
#    'tiny': 4,
#    'salt': 4,
#    'pepper': 1,
#    'crisped': 2,
#    'decent': 6,
#    'size': 4,
#    'companions': 1,
#    'seemed': 2,
#    'shared': 9,
#    'helped': 1,
#    'think': 16,
#    'skip': 1,
#    'worth': 11,
#    'rather': 4,
#    'unimpressed': 2,
#    'pulling': 1,
#    'parking': 9,
#    'cabs': 1,
#    'parked': 1,
#    'front': 4,
#    'advise': 1,
#    'anyone': 3,
#    'leave': 6,
#    'strip': 11,
#    'cab': 1,
#    'hit': 3,
#    'people': 14,
#    'coming': 5,
#    'side': 9,
#    'scooters': 1,
#    'kidding': 2,
#    'early': 6,
#    'reservation': 12,
#    '7:45': 1,
#    '7:00': 1,
#    'hostess': 6,
#    'informed': 1,
#    "we'd": 3,
#    'seat': 3,
#    'um': 1,
#    'dunno': 1,
#    '15-20': 1,
#    'unoccupied': 1,
#    'tables-ok': 1,
#    'bar': 16,
#    'indeed': 1,
#    'crowded': 1,
#    'enough': 7,
#    'missed': 2,
#    'mins': 3,
#    'minus2': 1,
#    'guy': 3,
#    'taking': 3,
#    'dirty': 2,
#    "wasn't": 13,
#    'minus': 2,
#    '30': 4,
#    'stand': 2,
#    'walked': 3,
#    '4': 14,
#    'steps': 1,
#    'behind': 1,
#    'mind': 4,
#    'whole': 3,
#    'freaking': 2,
#    'sat': 4,
#    'ummmmm': 1,
#    'sense': 2,
#    'bartender': 2,
#    'takes': 2,
#    'dim': 2,
#    'sum': 2,
#    'prices': 9,
#    'reasonable': 3,
#    'plus': 3,
#    'seafood': 9,
#    'combo': 2,
#    'mine': 3,
#    'reminded': 2,
#    'bisque': 4,
#    'soup': 2,
#    'pea': 1,
#    'meh': 5,
#    'undercooked': 2,
#    'opinion': 3,
#    'ate': 8,
#    'cook': 5,
#    'rare': 4,
#    'hmmmm': 1,
#    'googled': 1,
#    'heard': 1,
#    'anyhow': 1,
#    'scallop': 3,
#    'pink': 1,
#    'middle': 3,
#    'intentions': 1,
#    'wednesday': 1,
#    'pharmaceutical': 1,
#    'shown': 1,
#    'private': 6,
#    'room': 10,
#    'flat': 2,
#    'screen': 1,
#    'tv': 2,
#    'rep': 1,
#    'found': 7,
#    'set': 6,
#    'contract': 2,
#    '25': 4,
#    'help': 1,
#    'manager': 3,
#    'calm': 1,
#    'polite': 3,
#    'tried': 12,
#    'find': 8,
#    'solve': 1,
#    'supposedly': 1,
#    'fits': 1,
#    '28': 1,
#    'damn': 3,
#    'tight': 1,
#    'making': 4,
#    'arrangements': 1,
#    'square': 1,
#    'inches': 1,
#    'spare': 2,
#    'av': 1,
#    'issue': 3,
#    'forward': 6,
#    'bringing': 1,
#    'guests': 1,
#    'appeared': 3,
#    'unable': 1,
#    'comment': 1,
#    'strictly': 1,
#    'based': 3,
#    'facilities': 1,
#    'return': 6,
#    'another': 15,
#    'shot': 2,
#    'similar': 3,
#    'la': 3,
#    'maui': 2,
#    'aka': 2,
#    'spend': 1,
#    'closest': 1,
#    'visiting': 3,
#    'hotel': 1,
#    'downtown': 1,
#    'bargain': 2,
#    'currently': 1,
#    'promotion': 2,
#    'sundays': 1,
#    'mondays': 3,
#    'march': 1,
#    '36.95': 1,
#    'seeing': 2,
#    'alone': 3,
#    'act': 1,
#    'thankfully': 2,
#    'monday': 4,
#    'now-closed': 1,
#    'summerlin': 5,
#    'life--a': 1,
#    'country': 1,
#    'featured': 3,
#    'crab--so': 1,
#    'lakanilau': 4,
#    'poke': 6,
#    'bowl': 7,
#    'sea': 8,
#    'japanese': 4,
#    'cheesecake': 4,
#    'edamame': 7,
#    'midcourse': 1,
#    '127': 1,
#    'bottle': 4,
#    'wine': 7,
#    'handsome': 1,
#    'tip': 6,
#    '140': 1,
#    'standout': 1,
#    'beautifully': 1,
#    'salmon': 20,
#    'hamachi': 1,
#    'stood': 1,
#    'although': 3,
#    'guess': 2,
#    'lofty': 1,
#    'goals': 1,
#    'fine': 8,
#    'glad': 5,
#    'spent': 2,
#    'mostly': 2,
#    'flagging': 1,
#    'request': 2,
#    'span': 1,
#    'memory': 2,
#    'gnat': 1,
#    'bad': 11,
#    'tarnished': 1,
#    'somewhere': 2,
#    'rice': 13,
#    'yum': 6,
#    'roast': 1,
#    'desert': 4,
#    'quick': 3,
#    '180.00': 1,
#    'upscale': 3,
#    'restaurants': 13,
#    'correctly': 2,
#    'portions': 3,
#    'sized': 1,
#    'large': 8,
#    'party': 11,
#    'head': 2,
#    'chef': 5,
#    'walking': 2,
#    'talking': 1,
#    'feel': 11,
#    'comfortable': 3,
#    'taken': 4,
#    'ever': 13,
#    'upon': 3,
#    'driving': 1,
#    'establishment': 3,
#    'tiki': 3,
#    'flames': 1,
#    'spacing': 1,
#    'available': 2,
#    'valet': 10,
#    'gorgeous': 2,
#    'everyone': 11,
#    'busser': 1,
#    'warm': 6,
#    'inviting': 3,
#    'charming': 1,
#    'waitress': 5,
#    'honestly': 1,
#    'waitresses': 1,
#    'genuine': 2,
#    'kindly': 1,
#    'welcoming': 1,
#    'beginning': 3,
#    'flawless': 1,
#    'began': 1,
#    'already': 5,
#    'impressed': 3,
#    'listed': 2,
#    'specialities': 1,
#    'suggestions': 2,
#    'trio': 13,
#    'practically': 3,
#    'melted': 6,
#    'mouth': 14,
#    'perfected': 1,
#    'art': 1,
#    'creating': 1,
#    'guest': 1,
#    'pass': 6,
#    'framed': 6,
#    'surprise': 3,
#    'separate': 2,
#    'occasion': 4,
#    'father': 2,
#    'paralleled': 1,
#    'highly': 9,
#    'recommend': 11,
#    'soft': 7,
#    'interesting': 4,
#    'clashed': 1,
#    'pairing': 1,
#    'jumbo': 1,
#    'pawns': 1,
#    'pie': 2,
#    'sugar': 1,
#    'tooth': 1,
#    'spot': 5,
#    'cross': 1,
#    'scone': 1,
#    'want': 15,
#    '3.5': 1,
#    'scaling': 1,
#    'highest': 1,
#    '4.5': 3,
#    'yelp': 3,
#    'treat': 2,
#    'fiancee': 2,
#    'accross': 1,
#    'online': 4,
#    'host': 1,
#    'congratulate': 1,
#    'terminator': 1,
#    'wanna': 1,
#    'heck': 1,
#    'cakes': 3,
#    'tao': 1,
#    'alright': 2,
#    'meals': 3,
#    'three': 12,
#    'modern': 2,
#    'comforting': 1,
#    'spot-on': 1,
#    'done': 4,
#    'prepared': 8,
#    'precisely': 1,
#    'however': 6,
#    'safe': 1,
#    'crowd-pleasing': 1,
#    'tastes': 2,
#    'offered': 4,
#    'app': 5,
#    'aforementioned': 1,
#    'saving': 2,
#    'ballpark': 1,
#    'depending': 1,
#    'pot': 4,
#    'stickers': 2,
#    'mussels': 1,
#    'smartly': 1,
#    'creative': 2,
#    'famous': 2,
#    'butter': 10,
#    'lovely': 3,
#    'reason': 5,
#    'possibly': 2,
#    ...}),
#  ('VfFHPsPtTW4Mgx0eHDyJiQ',
#   {'enjoy': 6,
#    'durango': 1,
#    'location': 7,
#    '6': 3,
#    'friends': 24,
#    'decided': 12,
#    'try': 26,
#    'one': 34,
#    "it's": 40,
#    'bit': 14,
#    'larger': 2,
#    'saturday': 3,
#    'night': 29,
#    'quite': 8,
#    'busy': 17,
#    'went': 22,
#    'patio': 31,
#    "weren't": 1,
#    'served': 11,
#    'talked': 1,
#    '30': 1,
#    'minutes': 14,
#    'busser': 1,
#    'stopped': 3,
#    'asked': 14,
#    'helped': 1,
#    'said': 16,
#    "he'd": 1,
#    'get': 46,
#    'someone': 7,
#    '10': 7,
#    'later': 6,
#    'nobody': 1,
#    'showed': 4,
#    'short': 9,
#    'pour': 6,
#    'heaven': 1,
#    "you're": 10,
#    'looking': 10,
#    'super': 15,
#    'expensive': 1,
#    'pours': 1,
#    'place': 116,
#    'wow': 2,
#    'martinis': 1,
#    'half': 4,
#    'full': 12,
#    'shots': 6,
#    'even': 30,
#    'glass': 15,
#    'changed': 6,
#    'every': 14,
#    'drink': 28,
#    'smaller': 2,
#    'ran': 1,
#    'makers': 1,
#    'mark': 1,
#    'chatted': 1,
#    'manager': 13,
#    'brought': 4,
#    'us': 45,
#    'new': 15,
#    'waitress': 18,
#    'walked': 5,
#    'away': 12,
#    'soon': 5,
#    'mentioned': 3,
#    'change': 2,
#    "i'm": 29,
#    'local': 31,
#    'wish': 9,
#    'loved': 6,
#    'sucks': 3,
#    "i'll": 19,
#    'never': 14,
#    'back': 67,
#    'hoped': 1,
#    'like': 53,
#    '3rd': 2,
#    'time': 69,
#    "haven't": 2,
#    'impressed': 6,
#    'bjs': 3,
#    'way': 10,
#    'better': 18,
#    'islands': 1,
#    'go': 35,
#    'instead': 6,
#    'last': 15,
#    'couple': 11,
#    'months': 3,
#    'became': 1,
#    'regulars': 1,
#    'atmosphere': 24,
#    'enjoyable': 3,
#    'usually': 6,
#    'always': 18,
#    'fun': 13,
#    'depending': 1,
#    'crowd': 7,
#    'managed': 1,
#    'side': 10,
#    'first': 27,
#    'visit': 17,
#    'extremely': 6,
#    'hard': 12,
#    'bartenders': 17,
#    'attention': 7,
#    'bar': 106,
#    'rob': 4,
#    'top': 16,
#    'customer': 5,
#    'service..he': 1,
#    'got': 35,
#    'drinks': 44,
#    'convinced': 2,
#    'come': 24,
#    'continued': 3,
#    'service': 66,
#    'definitely': 16,
#    'must': 8,
#    'say': 22,
#    'still': 18,
#    'sometimes': 5,
#    'could': 28,
#    'easily': 3,
#    'fixed': 1,
#    'little': 16,
#    'organization': 1,
#    'behind': 4,
#    'food': 93,
#    'absolutely': 7,
#    'delicious': 25,
#    'pretty': 34,
#    'picky': 2,
#    'person': 6,
#    'part': 3,
#    'trying': 5,
#    'everything': 15,
#    'menu': 36,
#    'mozzarella': 2,
#    'sticks': 4,
#    'salads': 3,
#    'wings': 2,
#    'wraps': 3,
#    'pretzel': 2,
#    'bites': 11,
#    'sliders': 18,
#    'phil': 1,
#    'dan': 3,
#    'rick': 3,
#    'awesome': 13,
#    'coming': 8,
#    "they're": 1,
#    'working': 2,
#    'game': 19,
#    'checking': 5,
#    'make': 19,
#    'sure': 19,
#    'okay': 7,
#    'need': 10,
#    'anything': 4,
#    "there's": 5,
#    'two': 17,
#    'guys': 1,
#    'named': 3,
#    'careless': 1,
#    'due': 2,
#    'attitude': 4,
#    'stay': 4,
#    "i've": 19,
#    'crappy': 2,
#    'bars': 10,
#    'ended': 6,
#    'enjoying': 2,
#    'least': 7,
#    'know': 16,
#    'going': 19,
#    'great': 78,
#    'anyways': 1,
#    'hangout': 6,
#    'chill': 5,
#    'environment': 7,
#    'see': 25,
#    'far': 7,
#    'favorite': 6,
#    'bartender': 21,
#    '3': 15,
#    'times': 19,
#    'since': 16,
#    'september': 1,
#    'excellent': 6,
#    'staff': 20,
#    'friendly': 22,
#    'helpful': 1,
#    'fantastic': 9,
#    'reasonably': 4,
#    'priced': 4,
#    'entrance': 1,
#    'seems': 6,
#    'intimidating': 1,
#    'enter': 1,
#    'nice': 47,
#    'mix': 5,
#    'restaurant/bar': 1,
#    'seating': 11,
#    'small': 7,
#    'lounge': 3,
#    'area': 20,
#    'near': 3,
#    'would': 40,
#    'recommend': 6,
#    'distill': 40,
#    'start': 6,
#    'beginning': 5,
#    'final': 1,
#    'stop': 5,
#    'give': 16,
#    '3.5': 3,
#    'stars': 14,
#    'overall': 10,
#    'around': 10,
#    '7pm': 2,
#    '4am': 1,
#    '3pm': 1,
#    'college': 2,
#    'hoops': 1,
#    'sat': 16,
#    'ordered': 45,
#    'mule': 14,
#    'chicken': 34,
#    'dinner': 15,
#    'cute': 10,
#    'took': 20,
#    'order': 20,
#    'disappeared...finally': 1,
#    'another': 16,
#    'meal': 11,
#    'good': 101,
#    'flavor': 7,
#    'lots': 5,
#    'plate': 5,
#    'touch': 6,
#    'dry': 4,
#    'friend': 16,
#    'tacos': 8,
#    'enjoyed': 10,
#    '2nd': 1,
#    'came': 46,
#    'drunk': 2,
#    'many': 10,
#    'people': 17,
#    'except': 2,
#    'bar/wait': 1,
#    'work': 9,
#    'fried': 10,
#    'steak': 20,
#    'breakfast': 19,
#    "didn't": 31,
#    'win': 1,
#    'money': 3,
#    'home': 11,
#    'early': 7,
#    'unhappy': 1,
#    'group': 8,
#    'cocktails': 5,
#    'chips/salsa': 1,
#    'watching': 4,
#    'hoop': 1,
#    'games': 10,
#    "tv's": 3,
#    'weird': 2,
#    'sit': 13,
#    'hightop': 1,
#    'table': 22,
#    'gave': 8,
#    'free': 12,
#    'beer': 24,
#    'mistake': 3,
#    'philly': 3,
#    'cheesesteak': 1,
#    'sandwich': 7,
#    'orders': 4,
#    'slow': 6,
#    'water': 5,
#    'different': 10,
#    'strange': 1,
#    'relatively': 1,
#    'notice': 2,
#    'smoky': 2,
#    'guess': 9,
#    'reason': 4,
#    'downgrading': 1,
#    '1': 4,
#    'used': 3,
#    'really': 48,
#    'typical': 3,
#    'normal': 4,
#    'nothing': 14,
#    'special': 8,
#    "shouldn't": 1,
#    'review': 4,
#    'bar/restaurant': 3,
#    'opening': 2,
#    'else': 10,
#    'doin': 1,
#    'glitch': 1,
#    'lvrj': 1,
#    'ad': 1,
#    'prizes': 1,
#    '100': 4,
#    'think': 8,
#    "we'd": 2,
#    'coveted': 1,
#    'swag': 1,
#    'though': 18,
#    '6:40': 1,
#    'seeing': 2,
#    're-distilling': 1,
#    'space': 5,
#    'occupied': 1,
#    'late': 4,
#    'lamented': 1,
#    'agave': 6,
#    'restaurant': 14,
#    'cavernous': 1,
#    'expect': 5,
#    'fighting': 1,
#    'wall': 2,
#    "how'd": 1,
#    'happen': 3,
#    'opened': 2,
#    '4:30': 1,
#    'happened': 3,
#    'truth': 1,
#    'advertising': 1,
#    'buffet': 1,
#    'station': 1,
#    'set': 2,
#    'pizza': 12,
#    'round': 8,
#    'potato': 11,
#    'beef': 2,
#    'strips': 1,
#    'fixings': 2,
#    'fajitas': 2,
#    'artichoke': 6,
#    'dip': 12,
#    'bruschetta': 3,
#    'jumbo': 1,
#    'shrimp': 7,
#    'cocktail': 6,
#    'puffs': 1,
#    'rest': 2,
#    'finally': 7,
#    'snagged': 1,
#    'booth': 1,
#    'demo': 1,
#    'girls': 2,
#    'handing': 1,
#    'royal': 1,
#    'crown': 1,
#    'jack': 3,
#    'daniels': 1,
#    'tennessee': 1,
#    'honey': 1,
#    'samples': 1,
#    't-shirts': 1,
#    "couldn't": 4,
#    'snag': 1,
#    'server': 39,
# ...
#    'combo': 2,
#    'side': 2,
#    'baked': 2,
#    'chips': 2,
#    'problem': 1,
#    'bahama': 1,
#    'mama': 1,
#    'please': 2,
#    'ask': 5,
#    'manager': 6,
#    "can't": 4,
#    'to...(interrupted': 1,
#    'voice': 1,
#    'ashley': 7,
#    'charge': 1,
#    '50': 1,
#    'add': 2,
#    'sir': 2,
#    'thrown': 1,
#    'into..(interrupted': 1,
#    'sorry': 2,
#    'pay': 2,
#    'extra': 2,
#    'need': 3,
#    'befuddled': 1,
#    'fine': 3,
#    'pull': 1,
#    'around': 5,
#    'young': 1,
#    'server': 1,
#    'light': 1,
#    'eyes': 1,
#    'hands': 1,
#    'bag': 1,
#    'w/food': 1,
#    'napkins': 1,
#    'shaking': 1,
#    'head': 1,
#    'hand': 2,
#    'offer': 1,
#    '50cent': 1,
#    'upon': 2,
#    'receiving': 1,
#    'managers': 1,
#    'inconvenience': 1,
#    'babies': 1,
#    'flatbread': 2,
#    'gym': 1,
#    'soy': 1,
#    'caesar': 1,
#    'healthy': 2,
#    'ummm': 1,
#    'website': 1,
#    'home': 2,
#    'many': 2,
#    'calories': 3,
#    'immediately': 2,
#    'refrigerator': 1,
#    'half': 2,
#    'however': 2,
#    'shakes': 1,
#    '200': 1,
#    'thing': 2,
#    'go': 10,
#    'kinds': 1,
#    'choose': 1,
#    'hungry': 1,
#    'salads': 1,
#    'serve': 1,
#    'breakfast': 3,
#    'off-let': 1,
#    'start': 1,
#    'fact': 1,
#    'trop': 1,
#    'whole': 2,
#    'subpar': 1,
#    'yesterday': 1,
#    "hadn't": 2,
#    'chance': 1,
#    'eat': 2,
#    'starving': 1,
#    '2:30': 1,
#    'pm': 1,
#    'closest': 2,
#    'nut': 1,
#    'seemed': 1,
#    'wirey': 1,
#    'bristles': 1,
#    'sip': 2,
#    'cleaned': 1,
#    'wire': 1,
#    'brush': 1,
#    'foreign': 1,
#    'material': 1,
#    'threw': 1,
#    '5.40': 1,
#    'considered': 1,
#    'calling': 1,
#    'bunch': 1,
#    'college/high': 1,
#    'school': 1,
#    'aged': 1,
#    'running': 1,
#    'step': 1,
#    'game': 1,
#    'nothing': 3,
#    'fancy': 1,
#    'easy': 1,
#    'healthiest': 1,
#    'option': 1,
#    'near': 2,
#    'sweetener': 1,
#    'otherwise': 1,
#    'sweet': 1,
#    "children's": 1,
#    'regular': 3,
#    'husband': 1,
#    'lot': 3,
#    'prices': 1,
#    'reasonable': 1,
#    'eaten': 1,
#    'inside': 1,
#    'restaurant': 1,
#    'clean': 1,
#    'pleasant': 1,
#    'recommend': 3,
#    'decided': 2,
#    'today': 1,
#    "we'd": 1,
#    'wraps...boy': 1,
#    'mistake': 1,
#    'jamaican': 2,
#    'jerk': 2,
#    'min': 4,
#    'figured': 1,
#    'later': 3,
#    'still': 6,
#    "haven't": 1,
#    'noticing': 1,
#    'orders': 3,
#    'saw': 1,
#    'receipt': 1,
#    'confused': 1,
#    'look': 2,
#    'face': 2,
#    'rushed': 1,
#    'check': 2,
#    'screen': 1,
#    'appeared': 1,
#    'rushing': 1,
#    'approaches': 1,
#    'wrong': 2,
#    'acknowledged': 2,
#    'refund': 1,
#    'yet': 2,
#    'took': 1,
#    '7': 1,
#    'bucks': 1,
#    'register': 1,
#    'handed': 1,
#    'story': 1,
#    'short': 2,
#    'staying': 1,
#    'away': 1,
#    "you'll": 1,
#    'trip': 1,
#    'workers': 1,
#    'waste': 1,
#    'star': 1,
#    'beyond': 1,
#    '3': 1,
#    'bogo': 1,
#    'coupon': 1,
#    'stupid': 3,
#    'multiple': 1,
#    'items': 1,
#    'stingy': 1,
#    'omw': 1,
#    'wealth': 1,
#    'buff': 1,
#    'may': 3,
#    'friends': 2,
#    'relax': 1,
#    'class': 1,
#    'mcdonalds': 2,
#    'hang': 1,
#    'instead': 1,
#    'dandy': 1,
#    'einstein': 1,
#    'bros': 1,
#    'bagel': 1,
#    'sunny': 1,
#    'brighten': 1,
#    'gloomy': 1,
#    'weather': 1,
#    'outside': 1,
#    'sides': 1,
#    'chose': 1,
#    'sour': 1,
#    'cream': 1,
#    'onion': 1,
#    'flavored': 1,
#    'lays': 1,
#    'potato': 1,
#    'despite': 1,
#    'spiciness': 1,
#    'jjc': 1,
#    'spicy': 1,
#    'mortal': 1,
#    'enemies': 1,
#    'liked': 3,
#    'flavor': 1,
#    'anyone': 1,
#    "who's": 1,
#    'willing': 1,
#    'adventerous': 1,
#    'dish': 1,
#    'buffalo': 2,
#    'totally': 1,
#    'turkey': 1,
#    'things': 2,
#    'wished': 1,
#    'sized': 1,
#    'cups': 1,
#    'feeling': 1,
#    'finish': 1,
#    'right': 4,
#    'help': 1,
#    'devour': 1,
#    'remaining': 1,
#    'rest': 1,
#    'toodloo': 1,
#    "won't": 3,
#    'visiting': 1,
#    'awhile': 1,
#    'negative': 1,
#    'stars': 2,
#    'rainbow': 1,
#    'spring': 1,
#    'mt': 1,
#    'arrived': 1,
#    'sysco': 1,
#    'delivery': 2,
#    'driver': 1,
#    'large': 1,
#    'hour': 2,
#    'corporate': 3,
#    'repeatedly': 1,
#    'drove': 1,
#    'flippant': 1,
#    'must': 2,
#    'call': 4,
#    'emergency': 1,
#    'reluctantly': 1,
#    'joe': 1,
#    'answer': 3,
#    "ashley's": 1,
#    'attention': 1,
#    'person': 2,
#    "she'd": 1,
#    'honor': 1,
#    'offering': 1,
#    'priority': 2,
#    'refused': 1,
#    'saying': 1,
#    'franchise': 2,
#    'wow': 1,
#    '7.01': 1,
#    'clearly': 1,
#    'opportunity': 1,
#    'gain': 1,
#    'treating': 1,
#    'lost': 1,
#    'finally': 1,
#    'return': 1,
#    'phone': 1,
#    'left': 2,
#    'message': 1,
#    'refunding': 1,
#    'purchase': 1,
#    'sending': 1,
#    'vip': 1,
#    "we'll": 1,
#    'turns': 1,
#    'reappear': 1,
#    '45': 2,
#    'late': 1,
#    'origianlly': 1,
#    'err': 1,
#    'attitude': 1,
#    'handling': 1,
#    'situation': 1,
#    'recognizing': 1,
#    'larger': 1,
#    'brand': 1,
#    'despicable': 1,
#    'often': 1,
#    'area': 1,
#    'patronize': 1,
#    'conveniently': 1,
#    'located': 1,
#    "bf's": 1,
#    'price': 1,
#    'all-american': 1,
#    'quite': 1,
#    'yummy(the': 1,
#    'ones': 1,
#    'tried)...today': 1,
#    'hawaiian': 1,
#    'bbq': 1,
#    'dinner': 1,
#    'too....this': 1,
#    'gets': 1,
#    'bit': 1,
#    'noon': 1,
#    'little': 2,
#    'tastes': 1,
#    'sweet..the': 1,
#    'pasta': 1,
#    'mayo': 1,
#    'tasteless': 1,
#    'everything': 1,
#    'canned': 1,
#    'crack': 1,
#    'find': 3,
#    'fantasizing': 1,
#    'night': 1,
#    'paradise....i': 1,
#    'mother': 1,
#    'possibly': 3,
#    'dogs': 1,
#    '500': 1,
#    'cares': 1,
#    'several': 2,
#    "roberto's": 1,
#    'driven': 1,
#    'robertos': 1,
#    'life': 1,
#    'sneaking': 1,
#    'looking': 1,
#    'sadly': 1,
#    'pictures': 1,
#    'rolled': 1,
#    'tacos': 1,
#    'humor': 1,
#    'alwas': 1,
#    'consistency': 1,
#    'runny': 1,
#    'thinck': 1,
#    'rat': 2,
#    'straw': 1,
#    'freaking': 1,
#    'smells': 1,
#    'empty': 1,
#    'slammed': 1,
#    'daughter': 1,
#    'bacon': 1,
#    'ranch': 1,
#    'ever': 1,
#    'mouth': 1,
#    'blocking': 1,
#    'thought': 1,
#    'dessertish': 1,
#    'selection': 1,
#    'coffee': 1,
#    'carameley': 1,
#    'flavors': 1,
#    'splenda': 1,
#    'energy': 1,
#    'weight': 2,
#    'thank': 1,
#    'god': 1,
#    'weigh': 1,
#    'extrea': 1,
#    'lbs': 1,
#    'chubby': 1,
#    'chaser': 1,
#    'breath': 1,
#    'management.....heh': 1,
#    'decide': 1,
#    'meet': 1,
#    'death': 1,
#    'stranger': 1,
#    'met': 1,
#    'internet': 1,
#    "wouldn't": 2,
#    'hells': 1,
#    'behind': 1,
#    'moment': 1,
#    'meantime': 1,
#    '6': 1,
#    'scurrying': 1,
#    'exactly': 1,
#    'knew': 1,
#    '\xad\xad\xad\xad\xad\xad\xad\xad\xad\xad\xad\xad\xad\xad\xad\xad': 3,
#    'review™': 1,
#    'alright': 1,
#    'aaaaight': 1,
#    'lunchtime': 1,
#    'hit': 1,
#    'miss': 1,
#    'free': 1,
#    'birthday': 3,
#    'honoured': 1,
#    'check-ins': 2,
#    'yo': 2,
#    "ain't": 2,
#    'newbie': 1,
#    'honour': 3,
#    'single': 1,
#    'freebie': 1,
#    'ass': 1,
#    'foot': 1,
#    'one-star': 3,
#    'necessarily': 1,
#    'proud': 1,
#    'nearly': 1,
#    'café®': 1,
#    'exclusively': 1,
#    'well': 1,
#    'shit': 3,
#    'open': 1,
#    'besides': 1,
#    "mcdonald's®": 1,
#    'early': 2,
#    'campus': 1,
#    'proverbial': 1,
#    'beef': 1,
#    'dozens': 3,
#    'verified': 1,
#    '58': 1,
#    'received': 1,
#    'email': 3,
#    'e-club': 2,
#    'worthless': 1,
#    'sent': 2,
#    'printed': 2,
#    'lil': 1,
#    'soldier': 1,
#    'pro': 3,
#    'tip': 3,
#    'useless': 1,
#    'join': 1,
#    'print': 1,
#    'care': 1,
#    'id': 1,
#    'electronic': 1,
#    'mail': 1,
#    'trouble': 1,
#    'searching': 1,
#    'template': 1,
#    'photoshop': 2,
#    "someone's": 1,
#    'insert': 1,
#    "one's": 1,
#    'fucking': 3,
#    'mean': 1,
#    'prints': 1,
#    'sans': 1,
#    'accused': 1,
#    'photoshopping': 1,
#    "person's": 1,
#    'nameless': 1,
#    'insistent': 1,
#    'cannot': 1,
#    'fuck': 1,
#    'words': 1,
#    'sixty': 1,
#    'relative': 1,
#    'period': 1,
#    'kind': 1,
#    'dropping': 1,
#    'worst': 1,
#    'run': 1,
#    'cafe®': 1,
#    'planet': 1,
#    'earth': 1,
#    'red': 1,
#    'rock': 1,
#    'resort': 1,
#    'play': 1,
#    'games': 1,
#    'enjoy': 1,
#    'long-time': 1,
#    'patronise': 1,
#    'cheers': 1,
#    'fired': 1,
#    'rating': 1,
#    'eek': 1,
#    'methinks': 1,
#    'consider': 1,
#    'corrective': 1,
#    'mechanism': 1,
#    'together': 1,
#    'credit': 1,
#    'system': 1,
#    'crashes': 1,
#    "couldn't": 1,
#    'reset': 1,
#    'ability': 1,
#    'ts': 1,
#    'update': 1,
#    'ur': 1,
#    'systems': 1,
#    'nice': 1,
#    'plus': 1,
#    'job': 1}),
#  ('aEGV0W2i8HRoDFsRrMz-BA',
#   {"i've": 1,
#    'looking': 1,
#    'authentic': 3,
#    'food': 27,
#    'like': 8,
#    'months': 1,
#    'vegas': 1,
#    'located': 1,
#    'inside': 5,
#    'marketplace': 1,
#    'place': 16,
#    'everything': 2,
#    'including': 1,
#    'everyone': 1,
#    'forgets': 1,
#    'great': 4,
#    'hospitality': 1,
#    'folks': 1,
#    'work': 2,
#    'treat': 1,
#    'family': 2,
#    'notice': 1,
#    "haven't": 1,
#    'even': 6,
#    'started': 1,
#    'talking': 1,
#    'yet': 1,
#    'ordered': 9,
#    'takeout': 1,
#    'late': 1,
#    'friday': 1,
#    'called': 5,
#    'first': 4,
#    "didn't": 6,
#    'pick': 2,
#    'later': 2,
#    'found': 2,
#    'busy': 1,
#    'owner': 2,
#    'back': 7,
#    'time': 4,
#    'ever': 2,
#    'restaurant': 2,
#    'lol': 2,
#    'steak': 1,
#    'enchilada': 2,
#    'carne': 1,
#    'asada': 1,
#    'fries': 5,
#    'chicken': 3,
#    'wings': 12,
#    'told': 1,
#    'exactly': 1,
#    'expect': 2,
#    'order': 18,
#    'update': 1,
#    'know': 2,
#    'crazy': 1,
#    'right': 1,
#    'upon': 1,
#    'arriving': 1,
#    'noticed': 1,
#    'way': 2,
#    'offer': 2,
#    'see': 1,
#    'yelp': 4,
#    'gave': 1,
#    'samples': 1,
#    'dishes': 1,
#    'display': 1,
#    'drooling': 1,
#    'app': 1,
#    'download': 1,
#    'best': 4,
#    'pics': 1,
#    'hands': 1,
#    'mexican': 5,
#    'try': 6,
#    'sit': 1,
#    'eat': 1,
#    'primarily': 1,
#    'takeout/pickup': 1,
#    'delivery': 9,
#    'yeah': 1,
#    '2': 5,
#    'items': 2,
#    'fried': 2,
#    'catfish': 1,
#    'yum': 1,
#    'carnitas': 2,
#    '2lbs': 1,
#    'sure': 2,
#    'shredded': 1,
#    'made': 5,
#    'really': 4,
#    'dry': 2,
#    'ok': 2,
#    'ordering': 2,
#    'big': 1,
#    'props': 1,
#    'though': 2,
#    'salsa': 1,
#    'sides': 1,
#    'asked': 2,
#    'extra': 1,
#    'crispy': 3,
#    'fish': 2,
#    'got': 4,
#    'house': 1,
#    'different': 2,
#    'things': 1,
#    'expected': 1,
#    'starving': 1,
#    'needed': 2,
#    'visited': 1,
#    'vending': 1,
#    'machine': 1,
#    'instead': 2,
#    'chilaquiles': 1,
#    'worst': 1,
#    'semi': 1,
#    'hard': 2,
#    'egg': 1,
#    'tortillas': 2,
#    'good': 10,
#    'dish': 1,
#    'make': 1,
#    'fruit': 2,
#    'bowl': 1,
#    'include': 1,
#    'strawberries': 1,
#    'green-rimmed': 1,
#    'cantaloupe': 1,
#    'tasteless': 1,
#    'papaya': 1,
#    '5-star': 1,
#    'cuisine': 2,
#    'least': 2,
#    'let': 1,
#    'feel': 1,
#    '22': 1,
#    'spent': 1,
#    '3': 2,
#    'non-meat': 1,
#    'worth': 1,
#    'experience....the': 1,
#    'driver': 2,
#    'taco': 2,
#    'sorry': 1,
#    'folks...will': 1,
#    'repeat': 1,
#    'customer': 3,
#    'okay': 2,
#    'came': 4,
#    'use': 1,
#    'one': 3,
#    'multiple': 1,
#    'offers': 1,
#    'posted': 1,
#    'namely': 1,
#    '15': 1,
#    'coupon': 4,
#    'standard': 1,
#    'lunch': 3,
#    'plate': 3,
#    'drink': 2,
#    'consisted': 1,
#    'rice': 2,
#    'beans': 2,
#    'style': 2,
#    'roast': 1,
#    'get': 7,
#    'cashier': 1,
#    'show': 1,
#    'realize': 1,
#    "doesn't": 1,
#    'speak': 2,
#    'word': 1,
#    'english': 2,
#    'finally': 2,
#    'communicate': 1,
#    'calls': 1,
#    'someone': 1,
#    'phone': 4,
#    'hangs': 1,
#    'says': 2,
#    '11': 3,
#    'dohlars': 1,
#    'wow': 1,
#    'bucks': 2,
#    'regular': 1,
#    'used': 2,
#    'well': 2,
#    'taste': 1,
#    '10': 3,
#    'fairly': 1,
#    'bland': 1,
#    'nothing': 1,
#    'excited': 1,
#    'gas': 1,
#    'station': 1,
#    'line': 1,
#    'insane': 1,
#    'skip': 1,
#    'go': 4,
#    'next': 1,
#    'door': 1,
#    'decent': 1,
#    'half': 2,
#    'price': 1,
#    'joint': 1,
#    'pastor': 1,
#    'tacos': 4,
#    'delicious': 4,
#    'charged': 1,
#    'fee': 1,
#    'every': 1,
#    'little': 2,
#    'side': 4,
#    'seem': 1,
#    'pricier': 1,
#    'places': 2,
#    'excellent': 1,
#    'would': 3,
#    'also': 2,
#    'burrito': 2,
#    'large': 1,
#    'portion': 1,
#    'pozole': 1,
#    'soup': 1,
#    'lots': 1,
#    'flavor': 1,
#    'cucumber': 1,
#    'lime': 1,
#    'sweet': 1,
#    'refreshing': 1,
#    'fair': 1,
#    'two': 1,
#    'salsas': 1,
#    'much': 3,
#    'given': 1,
#    'ceviche': 1,
#    'free': 1,
#    'fresh': 3,
#    "yes...it's": 1,
#    'hood': 1,
#    "that's": 2,
#    'comparisons': 1,
#    'end': 1,
#    'thing': 1,
#    'look': 2,
#    'clean': 3,
#    'establishment': 2,
#    'service': 8,
#    'professional': 1,
#    'courteous': 1,
#    'cheeseburger': 1,
#    'homemade': 1,
#    'quality': 1,
#    'recommend': 2,
#    'grubhub': 2,
#    'telling': 1,
#    'stock': 1,
#    'wanted': 1,
#    'something': 3,
#    'else': 2,
#    'said': 4,
#    'thank': 1,
#    'alright': 1,
#    'could': 1,
#    'cancel': 1,
#    'rude': 1,
#    'people': 2,
#    'handle': 1,
#    "life's": 1,
#    'rough': 1,
#    'went': 2,
#    'give': 2,
#    'another': 2,
#    'chance': 1,
#    'longer': 1,
#    'find': 3,
#    'number': 1,
#    'ask': 1,
#    'lady': 3,
#    'answered': 1,
#    "can't": 1,
#    'deliver': 2,
#    'must': 1,
#    'reason': 1,
#    'whhhhhat': 1,
#    'hung': 1,
#    "couldn't": 1,
#    'fathom': 1,
#    'kind': 1,
#    'blocked': 1,
#    "wasn't": 2,
#    'fault': 1,
#    'kindly': 1,
#    'declined': 1,
#    "i'll": 1,
#    'never': 1,
#    'answer': 1,
#    'guess': 1,
#    "don't": 2,
#    'care': 1,
#    'trash': 1,
#    'gross': 1,
#    'ass': 1,
#    'truck': 1,
#    'convince': 1,
#    'store': 6,
#    'highly': 1,
#    'turned': 1,
#    'stomach': 1,
#    'thinking': 1,
#    'poisoning': 1,
#    'hole': 2,
#    'caused': 1,
#    'forgot': 1,
#    'put': 1,
#    'sauce': 3,
#    'problem': 1,
#    "it's": 4,
#    'pretty': 4,
#    'difficult': 1,
#    'mind': 1,
#    'liquor': 4,
#    'sort': 1,
#    'sign': 2,
#    'indicating': 1,
#    'checked': 2,
#    'waiting': 2,
#    "maria's": 1,
#    'market': 1,
#    'think': 1,
#    'name': 2,
#    'orders': 1,
#    'website': 1,
#    'comes': 1,
#    '12': 1,
#    '9': 1,
#    'prices': 1,
#    'differ': 1,
#    'site': 1,
#    'still': 1,
#    'cheap': 1,
#    'using': 2,
#    'received': 2,
#    'discount': 1,
#    'ranch': 1,
#    'blu': 1,
#    'cheese': 1,
#    'smelt': 1,
#    'seasoned': 1,
#    'paid': 2,
#    '13.50': 1,
#    'wanting': 1,
#    'forever': 1,
#    'decided': 1,
#    'special': 1,
#    'trying': 1,
#    'almost': 1,
#    'missed': 1,
#    'actual': 1,
#    'fast': 1,
#    'left': 2,
#    'perfect': 1,
#    'idea': 1,
#    'cause': 1,
#    'ended': 1,
#    'picking': 1,
#    'bottle': 1,
#    'wine': 1,
#    'meal': 1,
#    'looks': 1,
#    'although': 1,
#    'neighborhood': 1,
#    'usually': 1,
#    'kinds': 1,
#    "isn't": 1,
#    'seating': 1,
#    'tables': 1,
#    'privacy': 2,
#    'customers': 1,
#    'entering': 1,
#    'may': 1,
#    'eaten': 1,
#    'considering': 1,
#    'took': 1,
#    'enough': 1,
#    'understand': 1,
#    'friendly': 1,
#    'helpful': 1,
#    'alone': 1,
#    'bring': 1,
#    'business': 1,
#    'wait': 1,
#    'bit': 1,
#    "weren't": 4,
#    'sitting': 2,
#    'added': 1,
#    "i'm": 1,
#    'french': 1,
#    'fry': 1,
#    'connoisseur': 1,
#    'boyfriend': 1,
#    'mild': 2,
#    'hot': 2,
#    'huge': 2,
#    'skimpy': 1,
#    'ones': 1,
#    'wing': 1,
#    'stop': 1,
#    'mean': 1,
#    'meaty': 1,
#    'since': 2,
#    'spicy': 2,
#    'tried': 1,
#    "boyfriend's": 1,
#    'looked': 2,
#    'day': 1,
#    'film': 1,
#    'around': 1,
#    'seen': 1,
#    'pictures': 1,
#    'maybe': 1,
#    'burritos': 1,
#    'favorite': 1,
#    'planet': 1,
#    'definitely': 1,
#    'say': 1,
#    'love': 2,
#    'wish': 1,
#    'guys': 1,
#    'sooner': 1,
#    'moving': 1,
#    'hope': 1,
#    'new': 1,
#    'address': 1,
#    'plates': 1,
#    'roasted': 2,
#    'combo': 1,
#    'medium': 1,
#    'size': 1,
#    'roommate': 1,
#    'dinner': 1,
#    'exited': 1,
#    'disappointed': 1,
#    'rolled': 1,
#    'correctly': 1,
#    'tortilla': 1,
#    'oily': 1,
#    'soggy': 1,
#    'considered': 1,
#    'toasting': 1,
#    'toaster': 1,
#    'oven': 1,
#    'crisp': 1,
#    'appetizer': 1,
#    'anymore': 1,
#    'unfortunately': 1,
#    "won't": 1,
#    'soon': 1,
#    'waited': 1,
#    '4': 1,
#    'hours': 1,
#    'restraunt': 1,
#    'twice': 1,
#    'actually': 2,
#    'cancelled': 1,
#    'tge': 1,
#    'delivery.com': 1,
#    'minutes': 2,
#    'promised': 1,
#    'bad': 1,
#    '6': 1,
#    'come': 1,
#    'till': 1,
#    'night': 1,
#    'grub': 1,
#    'hub': 1,
#    'amazing': 1,
#    'arrived': 1,
#    '30': 1,
#    'estimated': 1,
#    'husband': 1,
#    'remembered': 1})]

# %%
business_tf_scores = business_review_word_counts.map(lambda x: (x[0], get_tf_scores(x[1])))

# %%
business_tf_scores.first()
# Out:
# ('bZMcorDrciRbjdjRyANcjA',
#  {'listened': 0.0625,
#   'reviews': 0.0625,
#   'place': 0.25,
#   'highly': 0.125,
#   'unprofessional': 0.0625,
#   '1st': 0.0625,
#   'visit': 0.25,
#   'great': 0.5,
#   'signed': 0.1875,
#   'package': 0.3125,
#   'needed': 0.0625,
#   '2': 0.375,
#   'months': 0.3125,
#   'directed': 0.125,
#   'cancel': 0.125,
#   'email': 0.125,
#   'corporate': 0.8125,
#   '30': 0.25,
#   'days': 0.3125,
#   'advance': 0.0625,
#   'paid': 0.5,
#   'partial': 0.0625,
#   'month': 0.875,
#   'would': 0.625,
#   'automatically': 0.0625,
#   'pulled': 0.0625,
#   'point': 0.125,
#   'sent': 0.25,
#   '4': 0.125,
#   'emails': 0.125,
#   'response': 0.125,
#   'requesting': 0.0625,
#   '2nd': 0.125,
#   'recommended': 0.0625,
#   'lotion': 0.3125,
#   'holiday': 0.0625,
#   'weekend': 0.125,
#   'special': 0.0625,
#   'advised': 0.1875,
#   'due': 0.0625,
#   'something': 0.0625,
#   'could': 0.125,
#   'use': 0.125,
#   'today': 0.0625,
#   'keep': 0.0625,
#   'store': 0.125,
#   'another': 0.125,
#   'thought': 0.125,
#   'weird': 0.0625,
#   'hey': 0.0625,
#   'whatever': 0.0625,
#   'went': 0.4375,
#   'also': 0.4375,
#   'bulbs': 0.125,
#   'bed': 0.3125,
#   'lastly': 0.0625,
#   'started': 0.1875,
#   'later': 0.0625,
#   'got': 0.25,
#   'following': 0.125,
#   '1.00': 0.0625,
#   'disappointing': 0.0625,
#   '3rd': 0.0625,
#   'come': 0.0625,
#   'pick': 0.0625,
#   'problem': 0.0625,
#   'however': 0.125,
#   'decided': 0.0625,
#   'ask': 0.1875,
#   'full': 0.1875,
#   'price': 0.1875,
#   'was...she': 0.0625,
#   'provided': 0.0625,
#   'tax...which': 0.0625,
#   'exactly': 0.0625,
#   'girls': 0.25,
#   'behind': 0.0625,
#   'desk': 0.3125,
#   'need': 0.125,
#   'go': 0.5625,
#   'difference': 0.0625,
#   'far': 0.1875,
#   'company': 0.25,
#   'mess': 0.0625,
#   'believe': 0.0625,
#   'provide': 0.25,
#   'front': 0.25,
#   'line': 0.25,
#   'proper': 0.0625,
#   'tools': 0.125,
#   'good': 0.3125,
#   'customer': 0.6875,
#   'service': 0.6875,
#   'really': 0.3125,
#   'trust': 0.25,
#   'staff': 0.125,
#   'adjust': 0.125,
#   'enter': 0.0625,
#   'cancelation': 0.0625,
#   'baffles': 0.0625,
#   'like': 0.125,
#   'tanning': 1.0,
#   'salon': 0.375,
#   "i've": 0.125,
#   'tanned': 0.1875,
#   'regularly': 0.0625,
#   'couple': 0.25,
#   'salons': 0.1875,
#   'town': 0.0625,
#   'loved': 0.0625,
#   'looking': 0.0625,
#   'convenience': 0.125,
#   'close': 0.0625,
#   'gym': 0.0625,
#   "i'm": 0.125,
#   'back': 0.5625,
#   'lvac': 0.0625,
#   'parking': 0.0625,
#   'lot': 0.3125,
#   "couldn't": 0.125,
#   'convenient': 0.0625,
#   'clean': 0.1875,
#   'new': 0.25,
#   'amazing': 0.0625,
#   'beds': 0.625,
#   'informative': 0.0625,
#   'sales': 0.0625,
#   'reps': 0.0625,
#   'think': 0.0625,
#   'biggest': 0.0625,
#   'desires': 0.0625,
#   "they've": 0.0625,
#   'met': 0.0625,
#   'body': 0.375,
#   'heat': 0.375,
#   'pho': 0.0625,
#   'sagion8': 0.0625,
#   'well': 0.0625,
#   'came': 0.1875,
#   'first': 0.5625,
#   'time': 0.875,
#   'location': 0.5625,
#   'maria': 0.1875,
#   'showed': 0.0625,
#   'around': 0.125,
#   'different': 0.1875,
#   'work': 0.1875,
#   'opposed': 0.0625,
#   'locations': 0.1875,
#   'im': 0.0625,
#   'used': 0.1875,
#   'since': 0.0625,
#   'henderson': 0.0625,
#   'even': 0.375,
#   'gave': 0.125,
#   'directions': 0.0625,
#   'stops': 0.0625,
#   'mentioned': 0.0625,
#   'make': 0.0625,
#   'disappointed': 0.0625,
#   'bought': 0.0625,
#   'cash': 0.5625,
#   'never': 0.5,
#   'told': 0.75,
#   'tax': 0.0625,
#   'top': 0.0625,
#   '69.88': 0.0625,
#   'ok...is': 0.0625,
#   'credit': 0.3125,
#   'card': 0.3125,
#   'charged': 0.25,
#   'monthly': 0.25,
#   'fee': 0.1875,
#   'though': 0.125,
#   'half': 0.0625,
#   'mari': 0.0625,
#   'called': 0.4375,
#   'spoke': 0.125,
#   'tara': 0.25,
#   'billing': 0.125,
#   'quote': 0.0625,
#   'unquote': 0.0625,
#   'direct': 0.0625,
#   "maria's": 0.0625,
#   'mouth.....said': 0.0625,
#   'done': 0.0625,
#   'client': 0.0625,
#   'shady': 0.0625,
#   'hmmmmmmm': 0.0625,
#   'call': 0.3125,
#   'directly': 0.0625,
#   'standing': 0.0625,
#   'speaking': 0.0625,
#   'super': 0.125,
#   'rude': 0.25,
#   'nothing': 0.0625,
#   'file': 0.0625,
#   'dispute': 0.0625,
#   'reverse': 0.0625,
#   'charge': 0.0625,
#   'said': 0.125,
#   'account': 0.375,
#   'canceled': 0.0625,
#   'want': 0.125,
#   'unused': 0.0625,
#   'portion': 0.0625,
#   'power': 0.0625,
#   'hung': 0.25,
#   'everyone': 0.0625,
#   'office': 0.3125,
#   'whole': 0.0625,
#   'week...ummm...talking': 0.0625,
#   'right': 0.1875,
#   'one': 0.6875,
#   'speak': 0.0625,
#   'her......she': 0.0625,
#   'meagain': 0.0625,
#   'voice': 0.125,
#   'mail': 0.0625,
#   'next': 0.1875,
#   'hour': 0.0625,
#   'thank': 0.0625,
#   'money': 0.25,
#   'getting': 0.0625,
#   'options': 0.1875,
#   'city': 0.125,
#   'better': 0.375,
#   'deals...better': 0.0625,
#   'already': 0.0625,
#   'business': 0.0625,
#   'bureau': 0.0625,
#   'owes': 0.0625,
#   'legit': 0.0625,
#   'stolen': 0.0625,
#   'manager': 0.25,
#   'agreed': 0.125,
#   'phone': 0.0625,
#   'cause': 0.0625,
#   'prices': 0.0625,
#   'cheap': 0.0625,
#   'willing': 0.0625,
#   'gonna': 0.0625,
#   'check': 0.0625,
#   'palm': 0.0625,
#   'beach': 0.0625,
#   'local': 0.0625,
#   'places': 0.125,
#   'versa': 0.0625,
#   'spa': 0.0625,
#   'spray': 0.3125,
#   'tan': 0.4375,
#   'machine': 0.125,
#   'much': 0.1875,
#   'maryland': 0.1875,
#   'parkway': 0.0625,
#   'leave': 0.0625,
#   'streaks': 0.0625,
#   'clear': 0.1875,
#   'medium': 0.1875,
#   'actually': 0.25,
#   'shade': 0.0625,
#   'pkwy': 0.125,
#   'left': 0.125,
#   'uneven': 0.0625,
#   'streaky': 0.0625,
#   'plus': 0.0625,
#   'turned': 0.0625,
#   'light': 0.0625,
#   'may': 0.0625,
#   'little': 0.0625,
#   'bit': 0.125,
#   'way': 0.3125,
#   'prefer': 0.0625,
#   'tans': 0.125,
#   'depends': 0.0625,
#   'eastern': 0.0625,
#   'busy': 0.125,
#   'certain': 0.0625,
#   'times': 0.125,
#   'night': 0.125,
#   "haven't": 0.1875,
#   'drove': 0.0625,
#   'realized': 0.0625,
#   'reviewed': 0.0625,
#   'reason': 0.0625,
#   'giving': 0.0625,
#   '1': 0.1875,
#   'star': 0.1875,
#   '100': 0.0625,
#   'warned': 0.0625,
#   'specific': 0.0625,
#   'girl': 0.75,
#   'friend': 0.125,
#   'experience': 0.125,
#   'asked': 0.1875,
#   'particular': 0.125,
#   'blonde': 0.125,
#   'rolled': 0.0625,
#   'eyes': 0.0625,
#   'fine': 0.0625,
#   "didn't": 0.125,
#   'find': 0.0625,
#   "don't": 0.3125,
#   'know': 0.1875,
#   'either': 0.0625,
#   'potential': 0.0625,
#   'sign': 0.25,
#   'unacceptable': 0.125,
#   'extremely': 0.0625,
#   'sweet': 0.0625,
#   'happy': 0.0625,
#   'explained': 0.125,
#   'free': 0.25,
#   '7': 0.0625,
#   'day': 0.125,
#   'trial': 0.0625,
#   'perfect': 0.0625,
#   'twice': 0.0625,
#   'nice': 0.125,
#   'kind': 0.0625,
#   'person': 0.125,
#   'hired': 0.0625,
#   'dealing': 0.0625,
#   'customers': 0.0625,
#   'daily': 0.0625,
#   'basis': 0.0625,
#   'completely': 0.0625,
#   'made': 0.125,
#   'worse': 0.0625,
#   'seen': 0.125,
#   'several': 0.125,
#   'mocked': 0.0625,
#   'physically': 0.0625,
#   'disabled': 0.0625,
#   'appeared': 0.0625,
#   'took': 0.125,
#   'everything': 0.0625,
#   'act': 0.0625,
#   'irrationally': 0.0625,
#   'say': 0.125,
#   'anything': 0.0625,
#   'might': 0.0625,
#   'regret': 0.0625,
#   'deserve': 0.0625,
#   'job': 0.0625,
#   'let': 0.0625,
#   'alone': 0.125,
#   'workers': 0.125,
#   'name': 0.1875,
#   'anybody': 0.0625,
#   'needs': 0.0625,
#   'contact': 0.125,
#   'feel': 0.0625,
#   'get': 0.25,
#   'details': 0.0625,
#   'needless': 0.0625,
#   'week': 0.0625,
#   'love': 0.25,
#   'opened': 0.0625,
#   'silverado': 0.0625,
#   'ranch': 0.0625,
#   'awesome': 0.0625,
#   'always': 0.375,
#   'extreme': 0.125,
#   'fgt': 0.0625,
#   'fantastic': 0.0625,
#   'pricey': 0.125,
#   'membership': 0.5625,
#   'almost': 0.0625,
#   'two': 0.1875,
#   'years': 0.1875,
#   "it's": 0.125,
#   'totally': 0.0625,
#   'worth': 0.125,
#   'best': 0.1875,
#   'drop-in': 0.0625,
#   'session': 0.0625,
#   'expensive': 0.0625,
#   'college': 0.0625,
#   'horizon': 0.0625,
#   'fans': 0.0625,
#   'wish': 0.0625,
#   '10': 0.125,
#   'lol': 0.0625,
#   'aspen': 0.0625,
#   'remembers': 0.0625,
#   'helpful': 0.0625,
#   'questions': 0.125,
#   'change': 0.0625,
#   '3': 0.125,
#   'contacted': 0.0625,
#   'honoring': 0.0625,
#   'promotion': 0.0625,
#   'see': 0.125,
#   'yet': 0.0625,
#   'opinion': 0.0625,
#   'still': 0.0625,
#   'stands': 0.0625,
#   "doesn't": 0.0625,
#   'level': 0.1875,
#   'every': 0.1875,
#   'deserves': 0.0625,
#   'plenty': 0.0625,
#   'vegas': 0.125,
#   "wouldn't": 0.125,
#   'choose': 0.0625,
#   'using': 0.125,
#   'upgraded': 0.125,
#   'take': 0.0625,
#   'care': 0.0625,
#   'working': 0.0625,
#   'order': 0.0625,
#   'basic': 0.0625,
#   'establishment': 0.0625,
#   'las': 0.0625,
#   'figured': 0.0625,
#   "i'd": 0.0625,
#   'drop': 0.0625,
#   'missed': 0.0625,
#   'things': 0.0625,
#   'bodyheat': 0.0625,
#   'verdict': 0.0625,
#   'miss': 0.0625,
#   'three': 0.125,
#   'remembered': 0.0625,
#   'yes': 0.0625,
#   'realize': 0.0625,
#   'quite': 0.0625,
#   'obvious': 0.0625,
#   'solid': 0.0625,
#   'base': 0.0625,
#   'put': 0.1875,
#   'minimum': 0.0625,
#   'nearly': 0.0625,
#   'eight': 0.0625,
#   'minutes': 0.125,
#   'convince': 0.0625,
#   'fry': 0.0625,
#   'bits': 0.0625,
#   'education': 0.125,
#   'slipped': 0.0625,
#   'significantly': 0.0625,
#   'sun': 0.125,
#   'angel': 0.0625,
#   'high': 0.125,
#   'pressure': 0.125,
#   'hp': 0.0625,
#   'face': 0.0625,
#   'knew': 0.0625,
#   'argument': 0.0625,
#   "wasn't": 0.125,
#   'spent': 0.0625,
#   'spending': 0.0625,
#   '12': 0.0625,
#   'selection': 0.0625,
#   '24-hour': 0.0625,
#   'fact': 0.0625,
#   'carry': 0.0625,
#   'favorite': 0.1875,
#   'mrinternational': 0.0625,
#   'lack': 0.0625,
#   'nonchalance': 0.0625,
#   'downright': 0.0625,
#   'rudeness': 0.0625,
#   'ensures': 0.0625,
#   'paying': 0.125,
#   'machines': 0.125,
#   'friendly': 0.0625,
#   'thingy': 0.0625,
#   'scan': 0.0625,
#   'instead': 0.0625,
#   'making': 0.0625,
#   'type': 0.0625,
#   'past': 0.125,
#   'leading': 0.0625,
#   'summer': 0.0625,
#   'interested': 0.1875,
#   'pay': 0.125,
#   'last': 0.0625,
#   'year': 0.125,
#   'insisted': 0.0625,
#   'atm': 0.0625,
#   'record': 0.0625,
#   'assured': 0.0625,
#   'charges': 0.1875,
#   'sure': 0.0625,
#   'enough': 0.0625,
#   'six': 0.0625,
#   'thereafter': 0.0625,
#   'countless': 0.0625,
#   'ultimately': 0.0625,
#   'handle': 0.0625,
#   'financial': 0.0625,
#   'institution': 0.0625,
#   'block': 0.0625,
#   'authorized': 0.0625,
#   'retailer': 0.0625,
#   'accessing': 0.0625,
#   'pre-summer': 0.0625,
#   'sessions': 0.1875,
#   'owed': 0.0625,
#   '400': 0.0625,
#   'explain': 0.0625,
#   'able': 0.0625,
#   'matter': 0.0625,
#   'straightened': 0.0625,
#   'removed': 0.0625,
#   'purchasing': 0.0625,
#   'figuring': 0.0625,
#   'foot': 0.0625,
#   'forward': 0.0625,
#   'try': 0.125,
#   'informed': 0.0625,
#   'owe': 0.0625,
#   '200': 0.0625,
#   'unpaid': 0.0625,
#   'authorize': 0.0625,
#   'access': 0.0625,
#   'anytime': 0.0625,
#   'says': 0.0625,
#   'voicemail': 0.0625,
#   'department': 0.0625,
#   'explaining': 0.0625,
#   'situation': 0.0625,
#   'attempted': 0.0625,
#   'continues': 0.0625,
#   'ring': 0.0625,
#   'raising': 0.0625,
#   'disrespectful': 0.0625,
#   'size': 0.0625,
#   'many': 0.0625,
#   'continue': 0.0625,
#   'pull': 0.0625,
#   'scam': 0.0625,
#   'fees': 0.0625,
#   'wanted': 0.0625,
#   'recommend': 0.0625,
#   'anyone': 0.0625,
#   'else': 0.0625,
#   'ugh': 0.0625,
#   'beware': 0.0625,
#   'ladies': 0.0625,
#   'clueless': 0.0625,
#   'especially': 0.0625,
#   'bad': 0.0625,
#   'scare': 0.0625,
#   'people': 0.1875,
#   'away': 0.0625,
#   'hope': 0.0625,
#   'nicer': 0.0625,
#   'answer': 0.0625,
#   'bang': 0.0625,
#   'buck': 0.0625,
#   'pays': 0.0625,
#   'look': 0.0625,
#   'without': 0.0625,
#   'damaging': 0.0625,
#   'rays': 0.0625,
#   'deals': 0.0625,
#   'lotions': 0.0625,
#   'valley': 0.0625,
#   'least': 0.0625,
#   'staring': 0.0625,
#   'phones': 0.125,
#   'welcoming': 0.0625,
#   'leaving': 0.0625,
#   'responded': 0.0625,
#   'poor': 0.0625})
